# %%
# !pip install soynlp

# %%
from soynlp.hangle import levenshtein
from soynlp.hangle import jamo_levenshtein
from soynlp.hangle import compose
from soynlp.hangle import decompose
from konlpy.tag import Kkma
import nltk
from nltk.tag import pos_tag
from nltk.corpus import gutenberg
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.tokenize import TweetTokenizer
from nltk.tokenize import regexp_tokenize
from nltk.help import upenn_tagset
from string import punctuation
from nltk import Text
from konlpy.corpus import kolaw, kobill
from konlpy.tag import Kkma, Mecab, Okt, Komoran, Hannanum
import pandas as pd
import numpy as np
import re
from PreProcessing.Dictionary import sd, ad, kopro

# %%
s1_t1 = '큰 삼각형에서 밑변 분의 높이는 어때요 팔분의육인데 이들이 모두 다 어때 같다는 걸 여러분들이 알 수 있단 얘기예요'
s2_t1 = '큰 삼각형 에서 및 변 불이 높이는 팔 분의 육 인데 이들이 모두 같다는 걸 여러분들이 할 수 있다는데요'

# %%
s1_t2 = '마찬가지로 하나 더 해 볼까요 작은 삼각형에서 밑변 분의 높이는 사분의삼이죠'
s2_t2 = '마찬가지로 하나 더 있을까요 작은 삼각형 에서 이 편 불이 높이는 사 분의 삼'

# %%
s1_t3 = '이렇게 한번 그려 보겠습니다 이렇게 여기에서부터 수선을 이렇게 그어 보겠습니다'
s2_t3 = '이렇게 만들어보겠습니다 이렇게 이렇게 여기서부터 수선을 이렇게 들어보겠습니다'

# %%
s1_t4 = '또 다른 직각삼각형를 빗변 위 한 점을 잡아서 이렇게 수선을 똑같이 그어 주면 바로 두 직각삼각형 에이비씨하고 에이디이는 서로 어떤 닮음에이에이닮음이 된다'
s2_t4 = '또다른 즉각 삼각형 하나를 이 편이 한 점을 잡아서 이렇게 수선을 똑같이 그럴 주면 바로 두 즉각 삼각형 에이 비 지시하고 에이티 서로 어떤 닮은 에이 담은 이 된다'

# %%
s1_t5 = '이건 우리가 중학교 이학년 때 배웠죠 그렇죠 각에이가 공통이고 그다음에 둘 다 직각을 갖고 있으니까 에이에이닮음이 될 테고'
s2_t5 = '이건 우리가 중학교 이해하는 데 배웠죠 가계가 공통 이고 그 다음에 둘 다 즉각 을 갖고 있으니까 에이에이 닮은 있을 테고'

# %%
def get_integrated(s, e):
    EBS_filenames = []
    for i in range(s, e+1):
        n = '{0:05d}'.format(i)
        EBS_fname = 'lec' + n + '_EBS_entered_test.txt'
        EBS_filenames.append(EBS_fname)
    print(EBS_filenames)
        
    STT_filenames = []
    for i in range(s, e+1):
        n = '{0:05d}'.format(i)
        STT_fname = 'lec' + n + '_STT_entered_test.txt'
        STT_filenames.append(STT_fname)
    print(STT_filenames)
    
    EBS_integrated = ''
    for _ in EBS_filenames:
        with open('data/' + _, 'r', encoding = 'utf8') as f:
            if EBS_filenames.index(_) == 0:
                EBS_integrated += f.read() 
            else:
                EBS_integrated += '\n'+f.read()
           
    STT_integrated = ''
    for _ in STT_filenames:
        with open('data/' + _, 'r', encoding = 'utf8') as f:
            if STT_filenames.index(_) == 0:
                STT_integrated += f.read() 
            else:
                STT_integrated += '\n'+f.read()
    
    return EBS_integrated, STT_integrated

# %%
EBS_entered, STT_entered = get_integrated(1, 3)
# Out:
# ['lec00001_EBS_entered_test.txt', 'lec00002_EBS_entered_test.txt', 'lec00003_EBS_entered_test.txt']
# ['lec00001_STT_entered_test.txt', 'lec00002_STT_entered_test.txt', 'lec00003_STT_entered_test.txt']

# %%
print(EBS_entered)
# Out:
# 반갑습니다, EBS 친구 여러분들. 여러분들과 함께 중학뉴런수학3(하)를 강의하게 된 손석민입니다.
# 2학년 뉴런을 통해서도 만났었는데요.
# 여러분들, 이렇게 다시 만나게 되어서 정말 반갑습니다.
# 앞으로 3(하) 과정 어떻게 진행되는지에 대해서는 여러분들께서 오리엔테이션 강의를 통해서 확인할 수 있을 거고요.
# 오리엔테이션 강의는 반드시 듣고 오셔야 여러분들이 3학년 과정이, (하) 과정이 특히 어떻게 수업되는지 확인할 수 있을 겁니다.
# 일단 3학년 과정 같은 경우에는 크게 3개의 대단원으로 이루어져 있는데요.
# 첫 번째가 삼각비라는 단원이고 두 번째가 원의 성질, 세 번째가 통계. 이렇게 이루어져 있습니다.
# 우리가 1학년(하)도 마찬가지고 2학년(하)도 그래 왔듯, ‘주로 도형에 대한 이야기가 3(하)에서 많이 다루어지는구나.’ 라는 걸 생각하면 될 테고요.
# 오늘은 그 첫 시간이니까 ‘삼각비.’ ‘삼각’ 알아요. ‘비’ 알아요.
# 근데 이제 합쳐져 있는 ‘삼각비’라는 새로운 용어가 나왔죠.
# 그럼 이 개념을 공부하기에 앞서서 당연히 삼각비의 뜻부터 시작하는 것이 첫 시간입니다.
# 오늘 그 첫 시간, 함께 시작해 보도록 할 텐데요. 중학교 3학년 수학! 손샘과 끝냅시다!
# 오늘 공부할 내용, 바로 두 가지 개념인데요. 오늘 두 가지 개념 첫 번째 제목이 굉장히 길어요.
# ‘닮은 직각삼각형에서 대응변의 길이의 비’라는 것이 있습니다.
# 그다음 두 번째 개념이 바로 뭐냐면, ‘삼각비’라는 건데 삼각비의 뜻이겠죠?
# 이 첫 번째 개념은, 앞으로 쭉 공부할 내용이 다 직각삼각형에서 주로 다루어질 텐데직각삼각형에서 갖는 기본적인 성질이 있는데 그 성질을 알고 가자는, ‘삼각비를 공부하기에 앞선 징검다리 내용이다.’ 라고 여러분들이 받아들이시면 됩니다.
# 그렇다면 ‘닮은 직각삼각형에서’라고 했으니까 닮은 직각삼각형을 그려 봐야 되겠죠?
# 닮은 직각삼각형 두 개를 편하게 그릴 수 있는 제일 좋은 방법은 뭘까 생각해 보면우리는 이렇게 그리면 될 거 같아요.
# 이렇게 한번 그려 보겠습니다, 이렇게. 여기에서부터 수선을 이렇게 그어 보겠습니다.
# 일단 바깥쪽에 직각삼각형 하나 보입니다, 그렇죠?
# 또 다른 직각삼각형를 빗변 위 한 점을 잡아서 이렇게 수선을 똑같이 그어 주면 바로 두 직각삼각형 ABC하고, ADE는 서로 어떤 닮음?AA닮음이 된다.
# 이건 우리가 중학교 2학년 때 배웠죠, 그렇죠? ∠A가 공통이고, 그다음에 둘 다 직각을 갖고 있으니까 AA닮음이 될 테고.
# 우리가 중2 때 배웠던 닮음비라는 건 뭐였냐 하면 대응하는 변의 길이의 비였어요, 그렇죠?
# 그래서 만약에 이 길이를 5라고 해 보고, 이 길이를 10이라고 해 보면.두 삼각형의 닮음비는 5:10. 1:2겠죠.
# 그렇다면 우리가 이 길이를 4라고 놔 보면, 이 길이는 얼마가 됩니까, 당연히?
# 그렇죠. 4의 두 배인 8이 돼야 돼.
# 이 길이를 거꾸로 우리가 6이라고 해 보겠습니다.
# 그럼 거꾸로 이 작은 쪽은 얼마가 될까?
# 1:2, 2:1. 얼마? 3이 돼야 된다는 걸 여러분들이 알 수 있죠.
# 그래서 우리는 닮음비라는 건 ‘작은 삼각형과 큰 삼각형의 대응하는 변의 길이의 비’이니까 5:10, 3:6, 4:8. 이것이 모두 다 1:2로 같고 그것을 닮음비라고 한다.
# 이렇게 공부를 했었는데 이것 말고도 이러한 것들도 성립할 거란 얘기예요.
# 예를 들어 작은 삼각형에서 빗변 분의 높이 얼마입니까? 5분의3이죠?
# 큰 삼각형에서 빗변 분의 높이 얼마죠? 10분의6이죠. 이 둘 어때요?
# 5분의3으로 서로 같다는 거 확인할 수 있고.
# 또 마찬가지로 작은 삼각형에서 예를 들어서 빗변 분의 밑변 해 봅시다. 5분의4죠.
#  큰 삼각형에서 빗변 분의 밑변 해 보면 얼마죠?10분의8이죠. 근데 이것도 서로 어때? 같아요.
# 마찬가지로 하나 더 해 볼까요? 작은 삼각형에서 밑변 분의 높이는 4분의3이죠.
# 큰 삼각형에서 밑변 분의 높이는 어때요? 8분의6인데, 이들이 모두 다 어때? 같다는 걸 여러분들이 알 수 있단 얘기예요.

# %%
print(STT_entered)
# Out:
# 반갑습니다. WITH 여러분들 여러분들과 함께 중학 유럽 수학 삼 하를 강행하기 된 분석입니다. 사.
# 이 학년 늘어 를 통해서도 만났는데요.
# 여러분들 이렇게 다시 만나게 되어서 정말 반갑습니다.
# 앞으로 삼 하 과정 어떻게 진행되는지 에 대해서는 여러분들께서 오리엔테이션 강의를 통해서 확인할 수 있을 거고요.
#  오리엔테이션 강의는 반드시 듣고 옷 여야 여러분들이 삼 학년 과정의 한 가정의 특히 어떻게 수업 되는지 확인할 수 있을 겁니다.
# 기자 일단 삼 학년 과정 같은 경우에는 크게 세계의 대단원의 으로 이뤄져 있는데요.
#  첫번째가 삼각 이라는 단원고 두 번째가 원에 성질, 세 번째가 통계 이렇게 이뤄져 있습니다.
# 우리가 일 학년 하도 마찬가지고 이 학년 하도 그랬듯 주로 도용에 대한 이야기가 삼 하에서 많이 다뤄지는 구나 라는 걸 생각하면 될 테고요.
#  오늘은 그 첫 시간이 이니까 삼 갑 의 삼각 알아요 이 알아요.
# 합쳐져 있는 삼각 이라는 새로운 용어가 나왔죠.
# 이 개념을 공부하게 앞서 당연히 삼각 비 듯 부터 시작하는 것이 첫 시간입니다.
# 오늘 사 시간 함께 시작해 보도록 할 텐데요. 중학교 삼, 학년 수학 선생과 끝납니다.
# 오늘 공부할 내용, 바로 두 가지 개념 인데요. 아! 오늘 두 가지 기념 첫 번째 제복이 굉장히 길어야
# 닮은 즉각 삼 각 통에서 대응 변의 길이의 이 라는 것이 있습니다.
# 그 다음 두 번째 개념이 바로 뭐냐하면 삼 갑 의 라는 건데 상납 뜻이겠죠
# 의 첫 번째 개념은 두 번째 앞으로 쭉 공부할 내용이 다 즉각 삼각형 에서 주로 다뤄질 텐데 즉각 상황 평에서 갖는 기본적인 성질이 있는데 그 성질을 알고 가자 라는 어떤 삼각 비를 공부하기 앞선 징검다리 내용이라고 여러분들이 받아들이지만 됩니다.
# 그렇다면 닮은 즉각 삼각형 해서 있으니까 닮은 즉각 삼각형을 그려 봐야겠죠.
# 닮은 즉각 삼각형 두 개를 편하게 그릴 수 있는 제일 좋은 방법은 뭘까? 생각해보면 우리는 이렇게 그리면 될 것 같아요.
# 이렇게 만들어보겠습니다 이렇게 이렇게 여기서부터 수선을 이렇게 들어보겠습니다.
#  일단 바깥쪽에 즉각 삼각형 않아 보입니다.
# 또다른 즉각 삼각형 하나를 이 편이 한 점을 잡아서 이렇게 수선을 똑같이 그럴 주면 바로 두 즉각 삼각형 A B 지시하고 AT 서로 어떤 닮은 A 담은 이 된다.
# 이건 우리가 중학교 이해하는 데 배웠죠. 가계가 공통 이고 그 다음에 둘 다 즉각 을 갖고 있으니까 AA 닮은 있을 테고,
#  우리가 중인 팀이었던 닮은 이라는 건 뭐냐면, 대응하는 변의 길이의 이었어요.
# 만약에 이 길이를 오라고 해보고 길이를 십 이라고 안 보면 두 삼각형의 닮은 비는 오 대 십일 대 있겠죠.
# 그렇다면 우리가 이 길이를 살아가다 보면 일이 얼마나 됩니까? 당연히
# 그쳐 사회 두 배인 팔 일 자
#  의 길이를 거꾸로 우리가 육 이라고 해보겠습니다.
# 그럼 거꾸로 이 작은 쪽은 얼마나 될까?
# 일 대 이, 이 대 일 얼마 삶의 돼야 한다는 걸 여러분이 할 수 있죠.
# 그래서 우리는 닮은 이라는 건 작은 상납 형과 큰 삼각형 에 대응하는 별이 길이 보니까 오 대 십, 선대 육, 사 대 팔, 이것이 모두 다 일 대 이 로 갖고 그것을 닮은 이라고 한다.
# 이렇게 공부했는데 이것 말고도 이러한 것들도 성립할 거라는
# 예를 들어 작은 삼각형 에서 이 변 분에 높이 얼마입니까? 오 분의 삼
# 큰 삼각형 에서 이 본부를 높여야 하죠. 십 분 의 유기적 이들 오 대
# 오 분의 삼 으로 서로 같다 라는 것을 알 수 있고
# 또 마찬가지로 작은 삼각형 에서 예를 들어 빚 변 분의 이 편 해봅시다. 오 분의 사적
# 큰 삼각형 에서 이 변 분에 및 편의 봄 얼마전 십 분의 팔 이적 근데 이것도 서로 때 같아요.
# 마찬가지로 하나 더 있을까요? 작은 삼각형 에서 이 편 불이 높이는 사 분의 삼
# 큰 삼각형 에서 및 변 불이 높이는 팔 분의 육 인데 이들이 모두 같다는 걸 여러분들이 할 수 있다는데요.

# %%
s = '얄댜룸닝르ㅑㅐㄴㄷ루ㅑㅐ눌댄. '
''.join(s.split())
# Out:
# '얄댜룸닝르ㅑㅐㄴㄷ루ㅑㅐ눌댄.'

# %%
# 한 문장의 모든 경우의 수 구하기
# input : sentence
# output : 모든 길이의 단어 리스트
def get_words_of_all_length(w1, s2):
    answer = []
    MIN_LEN = 1
    MAX_LEN = (len(s2) + len(w1))//2 + 1
    for l in range(MIN_LEN, MAX_LEN+1):
        for i in range(len(s2)-l+1):
            answer.append(s2[i:i+l])
    
    return answer

# %%
# levenshtein가 가장 낮은 단어 구하기
# input : (1개의 단어, 여러개 단어의 리스트)
# output : leven distance가 가장 낮은 단어 리스트(1개가 아닐수도있음)
def find_min_levdis_words(w, l):
    answer = []
#     answer2 = []
    
    prob_list = [jamo_levenshtein(w,_) for _ in l]
    MIN_PROB = min(prob_list)
    for i, _ in enumerate(prob_list):
        if _ == MIN_PROB:
            answer.append(l[i])
#             answer2.append(_)

    return answer
#     return answer, answer2

# %%
# EBS 문장들 전처리
def EBS_preprocessing(EBS_entered):
    pat_math_symbol = re.compile(r'[().,‘’?!]') #의미없는부호 정규식
    pat_number = re.compile(r'\d+') #숫자 정규식
    esl = EBS_entered.splitlines() #문장단위로 리스트
    
    esl = [s.strip() for s in [pat_math_symbol.sub('', _) for _ in esl]]# punctuation 제거, 앞뒤 공백 제거
    
    #수학기호 한국어로 변환(EBS)
    esl_math_conversion = []
    for _ in esl:
        for ms in sd.keys():
            if ms in _:
                _ = _.replace(ms, sd[ms])
        esl_math_conversion.append(_)
        
    #숫자 한국어로 변환(EBS)
    esl_number_conversion = []
    for _ in esl_math_conversion:
        fl = re.findall(r'\d+', _)
        for n in fl:
            _ = _.replace(n, kopro[int(n)])
        esl_number_conversion.append(_)
        
    #알파벳 한국어로 변환(EBS)
    esl_alphabet_conversion = []
    for _ in esl_number_conversion:
        for a in ad.keys():
            if a in _:
                _ = _.replace(a, ad[a])
        esl_alphabet_conversion.append(_)
        
    return esl_alphabet_conversion

# %%
def STT_preprocessing(STT_entered):
    pat_math_symbol = re.compile(r'[().,‘’?!]') #의미없는부호 정규식
    pat_number = re.compile(r'\d+') #숫자 정규식
    ssl = STT_entered.splitlines() #문장단위로 리스트
    
    ssl = [s.strip() for s in [pat_math_symbol.sub('', _) for _ in ssl]]# punctuation 제거, 앞뒤 공백 제거
    
    #숫자 한국어로 변환(EBS)
    ssl_number_conversion = []
    for _ in ssl:
        fl = re.findall(r'\d+', _)
        for n in fl:
            _ = _.replace(n, kopro[int(n)])
        ssl_number_conversion.append(_)
        
    #알파벳 한국어로 변환(EBS)
    ssl_alphabet_conversion = []
    for _ in ssl_number_conversion:
        for a in ad.keys():
            if a in _:
                _ = _.replace(a, ad[a])
        ssl_alphabet_conversion.append(_)
        
    return ssl_alphabet_conversion

# %%
# input : (EBS 띄어쓰기 아직 안 된 sentence, STT 띄어쓰기 아직 안 된 sentence)
# output : sentence => pd.DataFrame
def get_similar_word_table(EBS_entered, STT_entered):
    d = {}
    d['한글발음'] = []
    d['STT'] = []
    
    pre_EBS = EBS_preprocessing(EBS_entered)
    pre_STT = STT_preprocessing(STT_entered)
    
    for s1, s2 in zip(pre_EBS, pre_STT):
        print(s1)
        print(s2)
        print()
        
        #EBS 어절단위 끊은 리스트
        EBS_tokens = TweetTokenizer().tokenize(s1)
        
        #STT 문장 띄어쓰기 다 붙이기
        s2 = ''.join(s2.split())
        
        #EBS어절이 돌면서 d dictionary에 append하는곳
        for _ in EBS_tokens:
            if _ in d['한글발음']:
                i = d['한글발음'].index(_)
                found_word = ', '.join(find_min_levdis_words(_, get_words_of_all_length(_, s2)))
                d['STT'][i] += ', ' + found_word
            else:
                d['한글발음'].append(_)
                d['STT'].append(', '.join(find_min_levdis_words(_, get_words_of_all_length(_, s2))))
            print('EBS Token : ', _)
            print('STT result: ', ', '.join(find_min_levdis_words(_, get_words_of_all_length(_, s2))))
            print()
        print('-----------------------------------------------------------')    
            
    return pd.DataFrame(d)

# %%
result = get_similar_word_table(EBS_entered, STT_entered)
# Out:
# 반갑습니다 이비에스 친구 여러분들 여러분들과 함께 중학뉴런수학삼하를 강의하게 된 손석민입니다
# 반갑습니다 더블유아이티에이치 여러분들 여러분들과 함께 중학 유럽 수학 삼 하를 강행하기 된 분석입니다 사
#
# EBS Token :  반갑습니다
# STT result:  반갑습니다
#
# EBS Token :  이비에스
# STT result:  이티에이
#
# EBS Token :  친구
# STT result:  치여
#
# EBS Token :  여러분들
# STT result:  여러분들, 여러분들
#
# EBS Token :  여러분들과
# STT result:  여러분들과
#
# EBS Token :  함께
# STT result:  함께
#
# EBS Token :  중학뉴런수학삼하를
# STT result:  중학유럽수학삼하를
#
# EBS Token :  강의하게
# STT result:  강행하기
#
# EBS Token :  된
# STT result:  된
#
# EBS Token :  손석민입니다
# STT result:  분석입니다
#
# -----------------------------------------------------------
# 이학년 뉴런을 통해서도 만났었는데요
# 이 학년 늘어 를 통해서도 만났는데요
#
# EBS Token :  이학년
# STT result:  이학년
#
# EBS Token :  뉴런을
# STT result:  늘어를
#
# EBS Token :  통해서도
# STT result:  통해서도
#
# EBS Token :  만났었는데요
# STT result:  만났는데요
#
# -----------------------------------------------------------
# 여러분들 이렇게 다시 만나게 되어서 정말 반갑습니다
# 여러분들 이렇게 다시 만나게 되어서 정말 반갑습니다
#
# EBS Token :  여러분들
# STT result:  여러분들
#
# EBS Token :  이렇게
# STT result:  이렇게
#
# EBS Token :  다시
# STT result:  다시
#
# EBS Token :  만나게
# STT result:  만나게
#
# EBS Token :  되어서
# STT result:  되어서
#
# EBS Token :  정말
# STT result:  정말
#
# EBS Token :  반갑습니다
# STT result:  반갑습니다
#
# -----------------------------------------------------------
# 앞으로 삼하 과정 어떻게 진행되는지에 대해서는 여러분들께서 오리엔테이션 강의를 통해서 확인할 수 있을 거고요
# 앞으로 삼 하 과정 어떻게 진행되는지 에 대해서는 여러분들께서 오리엔테이션 강의를 통해서 확인할 수 있을 거고요
#
# EBS Token :  앞으로
# STT result:  앞으로
#
# EBS Token :  삼하
# STT result:  삼하
#
# EBS Token :  과정
# STT result:  과정
#
# EBS Token :  어떻게
# STT result:  어떻게
#
# EBS Token :  진행되는지에
# STT result:  진행되는지에
#
# EBS Token :  대해서는
# STT result:  대해서는
#
# EBS Token :  여러분들께서
# STT result:  여러분들께서
#
# EBS Token :  오리엔테이션
# STT result:  오리엔테이션
#
# EBS Token :  강의를
# STT result:  강의를
#
# EBS Token :  통해서
# STT result:  통해서
#
# EBS Token :  확인할
# STT result:  확인할
#
# EBS Token :  수
# STT result:  수
#
# EBS Token :  있을
# STT result:  있을
#
# EBS Token :  거고요
# STT result:  거고요
#
# -----------------------------------------------------------
# 오리엔테이션 강의는 반드시 듣고 오셔야 여러분들이 삼학년 과정이 하 과정이 특히 어떻게 수업되는지 확인할 수 있을 겁니다
# 오리엔테이션 강의는 반드시 듣고 옷 여야 여러분들이 삼 학년 과정의 한 가정의 특히 어떻게 수업 되는지 확인할 수 있을 겁니다
#
# EBS Token :  오리엔테이션
# STT result:  오리엔테이션
#
# EBS Token :  강의는
# STT result:  강의는
#
# EBS Token :  반드시
# STT result:  반드시
#
# EBS Token :  듣고
# STT result:  듣고
#
# EBS Token :  오셔야
# STT result:  옷여야
#
# EBS Token :  여러분들이
# STT result:  여러분들이
#
# EBS Token :  삼학년
# STT result:  삼학년
#
# EBS Token :  과정이
# STT result:  과정의
#
# EBS Token :  하
# STT result:  학, 한, 가, 히, 할, 다
#
# EBS Token :  과정이
# STT result:  과정의
#
# EBS Token :  특히
# STT result:  특히
#
# EBS Token :  어떻게
# STT result:  어떻게
#
# EBS Token :  수업되는지
# STT result:  수업되는지
#
# EBS Token :  확인할
# STT result:  확인할
#
# EBS Token :  수
# STT result:  수, 수
#
# EBS Token :  있을
# STT result:  있을
#
# EBS Token :  겁니다
# STT result:  겁니다
#
# -----------------------------------------------------------
# 일단 삼학년 과정 같은 경우에는 크게 삼개의 대단원으로 이루어져 있는데요
# 기자 일단 삼 학년 과정 같은 경우에는 크게 세계의 대단원의 으로 이뤄져 있는데요
#
# EBS Token :  일단
# STT result:  일단
#
# EBS Token :  삼학년
# STT result:  삼학년
#
# EBS Token :  과정
# STT result:  과정
#
# EBS Token :  같은
# STT result:  같은
#
# EBS Token :  경우에는
# STT result:  경우에는
#
# EBS Token :  크게
# STT result:  크게
#
# EBS Token :  삼개의
# STT result:  세계의
#
# EBS Token :  대단원으로
# STT result:  대단원의으, 대단원의으로
#
# EBS Token :  이루어져
# STT result:  이뤄져
#
# EBS Token :  있는데요
# STT result:  있는데요
#
# -----------------------------------------------------------
# 첫 번째가 삼각비라는 단원이고 두 번째가 원의 성질 세 번째가 통계 이렇게 이루어져 있습니다
# 첫번째가 삼각 이라는 단원고 두 번째가 원에 성질 세 번째가 통계 이렇게 이뤄져 있습니다
#
# EBS Token :  첫
# STT result:  첫
#
# EBS Token :  번째가
# STT result:  번째가, 번째가, 번째가
#
# EBS Token :  삼각비라는
# STT result:  삼각이라는
#
# EBS Token :  단원이고
# STT result:  단원고
#
# EBS Token :  두
# STT result:  두
#
# EBS Token :  번째가
# STT result:  번째가, 번째가, 번째가
#
# EBS Token :  원의
# STT result:  원에
#
# EBS Token :  성질
# STT result:  성질
#
# EBS Token :  세
# STT result:  세
#
# EBS Token :  번째가
# STT result:  번째가, 번째가, 번째가
#
# EBS Token :  통계
# STT result:  통계
#
# EBS Token :  이렇게
# STT result:  이렇게
#
# EBS Token :  이루어져
# STT result:  이뤄져
#
# EBS Token :  있습니다
# STT result:  있습니다
#
# -----------------------------------------------------------
# 우리가 일학년하도 마찬가지고 이학년하도 그래 왔듯 주로 도형에 대한 이야기가 삼하에서 많이 다루어지는구나 라는 걸 생각하면 될 테고요
# 우리가 일 학년 하도 마찬가지고 이 학년 하도 그랬듯 주로 도용에 대한 이야기가 삼 하에서 많이 다뤄지는 구나 라는 걸 생각하면 될 테고요
#
# EBS Token :  우리가
# STT result:  우리가
#
# EBS Token :  일학년하도
# STT result:  일학년하도
#
# EBS Token :  마찬가지고
# STT result:  마찬가지고
#
# EBS Token :  이학년하도
# STT result:  이학년하도
#
# EBS Token :  그래
# STT result:  그랬
#
# EBS Token :  왔듯
# STT result:  랬듯
#
# EBS Token :  주로
# STT result:  주로
#
# EBS Token :  도형에
# STT result:  도용에
#
# EBS Token :  대한
# STT result:  대한
#
# EBS Token :  이야기가
# STT result:  이야기가
#
# EBS Token :  삼하에서
# STT result:  삼하에서
#
# EBS Token :  많이
# STT result:  많이
#
# EBS Token :  다루어지는구나
# STT result:  다뤄지는구나
#
# EBS Token :  라는
# STT result:  라는
#
# EBS Token :  걸
# STT result:  걸
#
# EBS Token :  생각하면
# STT result:  생각하면
#
# EBS Token :  될
# STT result:  될
#
# EBS Token :  테고요
# STT result:  테고요
#
# -----------------------------------------------------------
# 오늘은 그 첫 시간이니까 삼각비 삼각 알아요 비 알아요
# 오늘은 그 첫 시간이 이니까 삼 갑 의 삼각 알아요 이 알아요
#
# EBS Token :  오늘은
# STT result:  오늘은
#
# EBS Token :  그
# STT result:  그
#
# EBS Token :  첫
# STT result:  첫
#
# EBS Token :  시간이니까
# STT result:  시간이이니, 시간이이니까
#
# EBS Token :  삼각비
# STT result:  삼각, 삼갑의, 삼각알
#
# EBS Token :  삼각
# STT result:  삼각
#
# EBS Token :  알아요
# STT result:  알아요, 알아요
#
# EBS Token :  비
# STT result:  시, 이, 이, 니, 이
#
# EBS Token :  알아요
# STT result:  알아요, 알아요
#
# -----------------------------------------------------------
# 근데 이제 합쳐져 있는 삼각비라는 새로운 용어가 나왔죠
# 합쳐져 있는 삼각 이라는 새로운 용어가 나왔죠
#
# EBS Token :  근데
# STT result:  는새
#
# EBS Token :  이제
# STT result:  이라
#
# EBS Token :  합쳐져
# STT result:  합쳐져
#
# EBS Token :  있는
# STT result:  있는
#
# EBS Token :  삼각비라는
# STT result:  삼각이라는
#
# EBS Token :  새로운
# STT result:  새로운
#
# EBS Token :  용어가
# STT result:  용어가
#
# EBS Token :  나왔죠
# STT result:  나왔죠
#
# -----------------------------------------------------------
# 그럼 이 개념을 공부하기에 앞서서 당연히 삼각비의 뜻부터 시작하는 것이 첫 시간입니다
# 이 개념을 공부하게 앞서 당연히 삼각 비 듯 부터 시작하는 것이 첫 시간입니다
#
# EBS Token :  그럼
# STT result:  개념
#
# EBS Token :  이
# STT result:  이, 이
#
# EBS Token :  개념을
# STT result:  개념을
#
# EBS Token :  공부하기에
# STT result:  공부하게앞
#
# EBS Token :  앞서서
# STT result:  앞서, 앞서당
#
# EBS Token :  당연히
# STT result:  당연히
#
# EBS Token :  삼각비의
# STT result:  삼각비, 삼각비듯
#
# EBS Token :  뜻부터
# STT result:  듯부터
#
# EBS Token :  시작하는
# STT result:  시작하는
#
# EBS Token :  것이
# STT result:  것이
#
# EBS Token :  첫
# STT result:  첫
#
# EBS Token :  시간입니다
# STT result:  시간입니다
#
# -----------------------------------------------------------
# 오늘 그 첫 시간 함께 시작해 보도록 할 텐데요 중학교 삼학년 수학 손샘과 끝냅시다
# 오늘 사 시간 함께 시작해 보도록 할 텐데요 중학교 삼 학년 수학 선생과 끝납니다
#
# EBS Token :  오늘
# STT result:  오늘
#
# EBS Token :  그
# STT result:  교, 과
#
# EBS Token :  첫
# STT result:  선
#
# EBS Token :  시간
# STT result:  시간
#
# EBS Token :  함께
# STT result:  함께
#
# EBS Token :  시작해
# STT result:  시작해
#
# EBS Token :  보도록
# STT result:  보도록
#
# EBS Token :  할
# STT result:  할
#
# EBS Token :  텐데요
# STT result:  텐데요
#
# EBS Token :  중학교
# STT result:  중학교
#
# EBS Token :  삼학년
# STT result:  삼학년
#
# EBS Token :  수학
# STT result:  수학
#
# EBS Token :  손샘과
# STT result:  선생과
#
# EBS Token :  끝냅시다
# STT result:  끝납니다
#
# -----------------------------------------------------------
# 오늘 공부할 내용 바로 두 가지 개념인데요 오늘 두 가지 개념 첫 번째 제목이 굉장히 길어요
# 오늘 공부할 내용 바로 두 가지 개념 인데요 아 오늘 두 가지 기념 첫 번째 제복이 굉장히 길어야
#
# EBS Token :  오늘
# STT result:  오늘, 오늘
#
# EBS Token :  공부할
# STT result:  공부할
#
# EBS Token :  내용
# STT result:  내용
#
# EBS Token :  바로
# STT result:  바로
#
# EBS Token :  두
# STT result:  두, 두
#
# EBS Token :  가지
# STT result:  가지, 가지
#
# EBS Token :  개념인데요
# STT result:  개념인데요
#
# EBS Token :  오늘
# STT result:  오늘, 오늘
#
# EBS Token :  두
# STT result:  두, 두
#
# EBS Token :  가지
# STT result:  가지, 가지
#
# EBS Token :  개념
# STT result:  개념
#
# EBS Token :  첫
# STT result:  첫
#
# EBS Token :  번째
# STT result:  번째
#
# EBS Token :  제목이
# STT result:  제복이
#
# EBS Token :  굉장히
# STT result:  굉장히
#
# EBS Token :  길어요
# STT result:  길어야
#
# -----------------------------------------------------------
# 닮은 직각삼각형에서 대응변의 길이의 비라는 것이 있습니다
# 닮은 즉각 삼 각 통에서 대응 변의 길이의 이 라는 것이 있습니다
#
# EBS Token :  닮은
# STT result:  닮은
#
# EBS Token :  직각삼각형에서
# STT result:  즉각삼각통에서
#
# EBS Token :  대응변의
# STT result:  대응변의
#
# EBS Token :  길이의
# STT result:  길이의
#
# EBS Token :  비라는
# STT result:  이라는
#
# EBS Token :  것이
# STT result:  것이
#
# EBS Token :  있습니다
# STT result:  있습니다
#
# -----------------------------------------------------------
# 그다음 두 번째 개념이 바로 뭐냐면 삼각비라는 건데 삼각비의 뜻이겠죠
# 그 다음 두 번째 개념이 바로 뭐냐하면 삼 갑 의 라는 건데 상납 뜻이겠죠
#
# EBS Token :  그다음
# STT result:  그다음
#
# EBS Token :  두
# STT result:  두
#
# EBS Token :  번째
# STT result:  번째
#
# EBS Token :  개념이
# STT result:  개념이
#
# EBS Token :  바로
# STT result:  바로
#
# EBS Token :  뭐냐면
# STT result:  뭐냐, 뭐냐하, 뭐냐하면
#
# EBS Token :  삼각비라는
# STT result:  삼갑의라는
#
# EBS Token :  건데
# STT result:  건데
#
# EBS Token :  삼각비의
# STT result:  삼갑의
#
# EBS Token :  뜻이겠죠
# STT result:  뜻이겠죠
#
# -----------------------------------------------------------
# 이 첫 번째 개념은 앞으로 쭉 공부할 내용이 다 직각삼각형에서 주로 다루어질 텐데직각삼각형에서 갖는 기본적인 성질이 있는데 그 성질을 알고 가자는 삼각비를 공부하기에 앞선 징검다리 내용이다 라고 여러분들이 받아들이시면 됩니다
# 의 첫 번째 개념은 두 번째 앞으로 쭉 공부할 내용이 다 즉각 삼각형 에서 주로 다뤄질 텐데 즉각 상황 평에서 갖는 기본적인 성질이 있는데 그 성질을 알고 가자 라는 어떤 삼각 비를 공부하기 앞선 징검다리 내용이라고 여러분들이 받아들이지만 됩니다
#
# EBS Token :  이
# STT result:  이, 이, 이, 이, 이
#
# EBS Token :  첫
# STT result:  첫
#
# EBS Token :  번째
# STT result:  번째, 번째
#
# EBS Token :  개념은
# STT result:  개념은
#
# EBS Token :  앞으로
# STT result:  앞으로
#
# EBS Token :  쭉
# STT result:  쭉
#
# EBS Token :  공부할
# STT result:  공부할
#
# EBS Token :  내용이
# STT result:  내용이, 내용이
#
# EBS Token :  다
# STT result:  다, 다, 다, 다
#
# EBS Token :  직각삼각형에서
# STT result:  즉각삼각형에서
#
# EBS Token :  주로
# STT result:  주로
#
# EBS Token :  다루어질
# STT result:  다뤄질
#
# EBS Token :  텐데직각삼각형에서
# STT result:  다즉각삼각형에서, 이다즉각삼각형에서
#
# EBS Token :  갖는
# STT result:  갖는
#
# EBS Token :  기본적인
# STT result:  기본적인
#
# EBS Token :  성질이
# STT result:  성질이
#
# EBS Token :  있는데
# STT result:  있는데
#
# EBS Token :  그
# STT result:  그
#
# EBS Token :  성질을
# STT result:  성질을
#
# EBS Token :  알고
# STT result:  알고
#
# EBS Token :  가자는
# STT result:  자라는
#
# EBS Token :  삼각비를
# STT result:  삼각비를
#
# EBS Token :  공부하기에
# STT result:  공부하기앞
#
# EBS Token :  앞선
# STT result:  앞선
#
# EBS Token :  징검다리
# STT result:  징검다리
#
# EBS Token :  내용이다
# STT result:  내용이다
#
# EBS Token :  라고
# STT result:  라고
#
# EBS Token :  여러분들이
# STT result:  여러분들이
#
# EBS Token :  받아들이시면
# STT result:  받아들이지만
#
# EBS Token :  됩니다
# STT result:  됩니다
#
# -----------------------------------------------------------
# 그렇다면 닮은 직각삼각형에서라고 했으니까 닮은 직각삼각형을 그려 봐야 되겠죠
# 그렇다면 닮은 즉각 삼각형 해서 있으니까 닮은 즉각 삼각형을 그려 봐야겠죠
#
# EBS Token :  그렇다면
# STT result:  그렇다면
#
# EBS Token :  닮은
# STT result:  닮은, 닮은
#
# EBS Token :  직각삼각형에서라고
# STT result:  즉각삼각형해서있으, 즉각삼각형을그려봐
#
# EBS Token :  했으니까
# STT result:  있으니까
#
# EBS Token :  닮은
# STT result:  닮은, 닮은
#
# EBS Token :  직각삼각형을
# STT result:  즉각삼각형을
#
# EBS Token :  그려
# STT result:  그려
#
# EBS Token :  봐야
# STT result:  봐야
#
# EBS Token :  되겠죠
# STT result:  야겠죠
#
# -----------------------------------------------------------
# 닮은 직각삼각형 두 개를 편하게 그릴 수 있는 제일 좋은 방법은 뭘까 생각해 보면우리는 이렇게 그리면 될 거 같아요
# 닮은 즉각 삼각형 두 개를 편하게 그릴 수 있는 제일 좋은 방법은 뭘까 생각해보면 우리는 이렇게 그리면 될 것 같아요
#
# EBS Token :  닮은
# STT result:  닮은
#
# EBS Token :  직각삼각형
# STT result:  즉각삼각형
#
# EBS Token :  두
# STT result:  두
#
# EBS Token :  개를
# STT result:  개를
#
# EBS Token :  편하게
# STT result:  편하게
#
# EBS Token :  그릴
# STT result:  그릴
#
# EBS Token :  수
# STT result:  수
#
# EBS Token :  있는
# STT result:  있는
#
# EBS Token :  제일
# STT result:  제일
#
# EBS Token :  좋은
# STT result:  좋은
#
# EBS Token :  방법은
# STT result:  방법은
#
# EBS Token :  뭘까
# STT result:  뭘까
#
# EBS Token :  생각해
# STT result:  생각해
#
# EBS Token :  보면우리는
# STT result:  보면우리는
#
# EBS Token :  이렇게
# STT result:  이렇게
#
# EBS Token :  그리면
# STT result:  그리면
#
# EBS Token :  될
# STT result:  될
#
# EBS Token :  거
# STT result:  개, 게, 그, 게, 그, 것
#
# EBS Token :  같아요
# STT result:  같아요
#
# -----------------------------------------------------------
# 이렇게 한번 그려 보겠습니다 이렇게 여기에서부터 수선을 이렇게 그어 보겠습니다
# 이렇게 만들어보겠습니다 이렇게 이렇게 여기서부터 수선을 이렇게 들어보겠습니다
#
# EBS Token :  이렇게
# STT result:  이렇게, 이렇게, 이렇게, 이렇게
#
# EBS Token :  한번
# STT result:  만, 선, 만들, 수선
#
# EBS Token :  그려
# STT result:  게여
#
# EBS Token :  보겠습니다
# STT result:  보겠습니다, 보겠습니다
#
# EBS Token :  이렇게
# STT result:  이렇게, 이렇게, 이렇게, 이렇게
#
# EBS Token :  여기에서부터
# STT result:  여기서부터
#
# EBS Token :  수선을
# STT result:  수선을
#
# EBS Token :  이렇게
# STT result:  이렇게, 이렇게, 이렇게, 이렇게
#
# EBS Token :  그어
# STT result:  들어, 게이, 게여, 기서, 들어
#
# EBS Token :  보겠습니다
# STT result:  보겠습니다, 보겠습니다
#
# -----------------------------------------------------------
# 일단 바깥쪽에 직각삼각형 하나 보입니다 그렇죠
# 일단 바깥쪽에 즉각 삼각형 않아 보입니다
#
# EBS Token :  일단
# STT result:  일단
#
# EBS Token :  바깥쪽에
# STT result:  바깥쪽에
#
# EBS Token :  직각삼각형
# STT result:  즉각삼각형
#
# EBS Token :  하나
# STT result:  단바, 바깥, 않아, 아보, 니다
#
# EBS Token :  보입니다
# STT result:  보입니다
#
# EBS Token :  그렇죠
# STT result:  에즉, 아보, 니다, 보입니
#
# -----------------------------------------------------------
# 또 다른 직각삼각형를 빗변 위 한 점을 잡아서 이렇게 수선을 똑같이 그어 주면 바로 두 직각삼각형 에이비씨하고 에이디이는 서로 어떤 닮음에이에이닮음이 된다
# 또다른 즉각 삼각형 하나를 이 편이 한 점을 잡아서 이렇게 수선을 똑같이 그럴 주면 바로 두 즉각 삼각형 에이 비 지시하고 에이티 서로 어떤 닮은 에이 담은 이 된다
#
# EBS Token :  또
# STT result:  또
#
# EBS Token :  다른
# STT result:  다른
#
# EBS Token :  직각삼각형를
# STT result:  즉각삼각형, 즉각삼각형, 즉각삼각형하, 즉각삼각형에
#
# EBS Token :  빗변
# STT result:  이편
#
# EBS Token :  위
# STT result:  이, 이, 아, 이, 이, 에, 이, 에, 이, 어, 에, 이, 이
#
# EBS Token :  한
# STT result:  한
#
# EBS Token :  점을
# STT result:  점을
#
# EBS Token :  잡아서
# STT result:  잡아서
#
# EBS Token :  이렇게
# STT result:  이렇게
#
# EBS Token :  수선을
# STT result:  수선을
#
# EBS Token :  똑같이
# STT result:  똑같이
#
# EBS Token :  그어
# STT result:  그럴, 고에, 로어
#
# EBS Token :  주면
# STT result:  주면
#
# EBS Token :  바로
# STT result:  바로
#
# EBS Token :  두
# STT result:  두
#
# EBS Token :  직각삼각형
# STT result:  즉각삼각형, 즉각삼각형
#
# EBS Token :  에이비씨하고
# STT result:  이비지시하고, 에이비지시하고
#
# EBS Token :  에이디이는
# STT result:  에이비지, 에이비지시
#
# EBS Token :  서로
# STT result:  서로
#
# EBS Token :  어떤
# STT result:  어떤
#
# EBS Token :  닮음에이에이닮음이
# STT result:  닮은에이담은이
#
# EBS Token :  된다
# STT result:  된다
#
# -----------------------------------------------------------
# 이건 우리가 중학교 이학년 때 배웠죠 그렇죠 각에이가 공통이고 그다음에 둘 다 직각을 갖고 있으니까 에이에이닮음이 될 테고
# 이건 우리가 중학교 이해하는 데 배웠죠 가계가 공통 이고 그 다음에 둘 다 즉각 을 갖고 있으니까 에이에이 닮은 있을 테고
#
# EBS Token :  이건
# STT result:  이건
#
# EBS Token :  우리가
# STT result:  우리가
#
# EBS Token :  중학교
# STT result:  중학교
#
# EBS Token :  이학년
# STT result:  해하는, 이닮은
#
# EBS Token :  때
# STT result:  해, 배
#
# EBS Token :  배웠죠
# STT result:  배웠죠
#
# EBS Token :  그렇죠
# STT result:  그다, 배웠죠
#
# EBS Token :  각에이가
# STT result:  건우리가, 까에이에
#
# EBS Token :  공통이고
# STT result:  공통이고
#
# EBS Token :  그다음에
# STT result:  그다음에
#
# EBS Token :  둘
# STT result:  둘
#
# EBS Token :  다
# STT result:  다, 다
#
# EBS Token :  직각을
# STT result:  즉각을
#
# EBS Token :  갖고
# STT result:  갖고
#
# EBS Token :  있으니까
# STT result:  있으니까
#
# EBS Token :  에이에이닮음이
# STT result:  에이에이닮은있
#
# EBS Token :  될
# STT result:  둘
#
# EBS Token :  테고
# STT result:  테고
#
# -----------------------------------------------------------
# 우리가 중이 때 배웠던 닮음비라는 건 뭐였냐 하면 대응하는 변의 길이의 비였어요 그렇죠
# 우리가 중인 팀이었던 닮은 이라는 건 뭐냐면 대응하는 변의 길이의 이었어요
#
# EBS Token :  우리가
# STT result:  우리가
#
# EBS Token :  중이
# STT result:  중인
#
# EBS Token :  때
# STT result:  대
#
# EBS Token :  배웠던
# STT result:  이었던
#
# EBS Token :  닮음비라는
# STT result:  닮은이라는
#
# EBS Token :  건
# STT result:  건
#
# EBS Token :  뭐였냐
# STT result:  뭐냐
#
# EBS Token :  하면
# STT result:  냐면, 하는
#
# EBS Token :  대응하는
# STT result:  대응하는
#
# EBS Token :  변의
# STT result:  변의
#
# EBS Token :  길이의
# STT result:  길이의
#
# EBS Token :  비였어요
# STT result:  이었어요
#
# EBS Token :  그렇죠
# STT result:  어요, 었어요
#
# -----------------------------------------------------------
# 그래서 만약에 이 길이를 오라고 해 보고 이 길이를 십이라고 해 보면두 삼각형의 닮음비는 오대십 일대이겠죠
# 만약에 이 길이를 오라고 해보고 길이를 십 이라고 안 보면 두 삼각형의 닮은 비는 오 대 십일 대 있겠죠
#
# EBS Token :  그래서
# STT result:  고해보
#
# EBS Token :  만약에
# STT result:  만약에
#
# EBS Token :  이
# STT result:  이, 이, 이, 이
#
# EBS Token :  길이를
# STT result:  길이를, 길이를
#
# EBS Token :  오라고
# STT result:  오라고
#
# EBS Token :  해
# STT result:  해
#
# EBS Token :  보고
# STT result:  보고
#
# EBS Token :  이
# STT result:  이, 이, 이, 이
#
# EBS Token :  길이를
# STT result:  길이를, 길이를
#
# EBS Token :  십이라고
# STT result:  십이라고
#
# EBS Token :  해
# STT result:  해
#
# EBS Token :  보면두
# STT result:  보면두
#
# EBS Token :  삼각형의
# STT result:  삼각형의
#
# EBS Token :  닮음비는
# STT result:  닮은비는
#
# EBS Token :  오대십
# STT result:  오대십
#
# EBS Token :  일대이겠죠
# STT result:  일대있겠죠
#
# -----------------------------------------------------------
# 그렇다면 우리가 이 길이를 사라고 놔 보면 이 길이는 얼마가 됩니까 당연히
# 그렇다면 우리가 이 길이를 살아가다 보면 일이 얼마나 됩니까 당연히
#
# EBS Token :  그렇다면
# STT result:  그렇다면
#
# EBS Token :  우리가
# STT result:  우리가
#
# EBS Token :  이
# STT result:  이, 이, 이
#
# EBS Token :  길이를
# STT result:  길이를
#
# EBS Token :  사라고
# STT result:  살아가, 가다보
#
# EBS Token :  놔
# STT result:  나, 니
#
# EBS Token :  보면
# STT result:  보면
#
# EBS Token :  이
# STT result:  이, 이, 이
#
# EBS Token :  길이는
# STT result:  길이를
#
# EBS Token :  얼마가
# STT result:  얼마나
#
# EBS Token :  됩니까
# STT result:  됩니까
#
# EBS Token :  당연히
# STT result:  당연히
#
# -----------------------------------------------------------
# 그렇죠 사의 두 배인 팔이 돼야 돼
# 그쳐 사회 두 배인 팔 일 자
#
# EBS Token :  그렇죠
# STT result:  그쳐, 그쳐사
#
# EBS Token :  사의
# STT result:  사회
#
# EBS Token :  두
# STT result:  두
#
# EBS Token :  배인
# STT result:  배인
#
# EBS Token :  팔이
# STT result:  팔일
#
# EBS Token :  돼야
# STT result:  두배
#
# EBS Token :  돼
# STT result:  두
#
# -----------------------------------------------------------
# 이 길이를 거꾸로 우리가 육이라고 해 보겠습니다
# 의 길이를 거꾸로 우리가 육 이라고 해보겠습니다
#
# EBS Token :  이
# STT result:  이, 이
# EBS Token :  길이를
# STT result:  길이를
#
# EBS Token :  거꾸로
# STT result:  거꾸로
#
# EBS Token :  우리가
# STT result:  우리가
#
# EBS Token :  육이라고
# STT result:  육이라고
#
# EBS Token :  해
# STT result:  해
#
# EBS Token :  보겠습니다
# STT result:  보겠습니다
#
# -----------------------------------------------------------
# 그럼 거꾸로 이 작은 쪽은 얼마가 될까
# 그럼 거꾸로 이 작은 쪽은 얼마나 될까
#
# EBS Token :  그럼
# STT result:  그럼
#
# EBS Token :  거꾸로
# STT result:  거꾸로
#
# EBS Token :  이
# STT result:  이
#
# EBS Token :  작은
# STT result:  작은
#
# EBS Token :  쪽은
# STT result:  쪽은
#
# EBS Token :  얼마가
# STT result:  얼마나
#
# EBS Token :  될까
# STT result:  될까
#
# -----------------------------------------------------------
# 일대이 이대일 얼마 삼이 돼야 된다는 걸 여러분들이 알 수 있죠
# 일 대 이 이 대 일 얼마 삶의 돼야 한다는 걸 여러분이 할 수 있죠
#
# EBS Token :  일대이
# STT result:  일대이
#
# EBS Token :  이대일
# STT result:  이대일
#
# EBS Token :  얼마
# STT result:  얼마
#
# EBS Token :  삼이
# STT result:  삶의
#
# EBS Token :  돼야
# STT result:  돼야
#
# EBS Token :  된다는
# STT result:  한다는
#
# EBS Token :  걸
# STT result:  걸
#
# EBS Token :  여러분들이
# STT result:  여러분이
#
# EBS Token :  알
# STT result:  일, 일, 얼, 할
#
# EBS Token :  수
# STT result:  수
#
# EBS Token :  있죠
# STT result:  있죠
#
# -----------------------------------------------------------
# 그래서 우리는 닮음비라는 건 작은 삼각형과 큰 삼각형의 대응하는 변의 길이의 비이니까 오대십 삼대육 사대팔 이것이 모두 다 일대이로 같고 그것을 닮음비라고 한다
# 그래서 우리는 닮은 이라는 건 작은 상납 형과 큰 삼각형 에 대응하는 별이 길이 보니까 오 대 십 선대 육 사 대 팔 이것이 모두 다 일 대 이 로 갖고 그것을 닮은 이라고 한다
#
# EBS Token :  그래서
# STT result:  그래서
#
# EBS Token :  우리는
# STT result:  우리는
#
# EBS Token :  닮음비라는
# STT result:  닮은이라는
#
# EBS Token :  건
# STT result:  건
#
# EBS Token :  작은
# STT result:  작은
#
# EBS Token :  삼각형과
# STT result:  삼각형에
#
# EBS Token :  큰
# STT result:  큰
#
# EBS Token :  삼각형의
# STT result:  삼각형에
#
# EBS Token :  대응하는
# STT result:  대응하는
#
# EBS Token :  변의
# STT result:  별이
#
# EBS Token :  길이의
# STT result:  길이보
#
# EBS Token :  비이니까
# STT result:  이보니까
#
# EBS Token :  오대십
# STT result:  오대십
#
# EBS Token :  삼대육
# STT result:  선대육
#
# EBS Token :  사대팔
# STT result:  사대팔
#
# EBS Token :  이것이
# STT result:  이것이
#
# EBS Token :  모두
# STT result:  모두
#
# EBS Token :  다
# STT result:  다, 다
#
# EBS Token :  일대이로
# STT result:  일대이로
#
# EBS Token :  같고
# STT result:  갖고
#
# EBS Token :  그것을
# STT result:  그것을
#
# EBS Token :  닮음비라고
# STT result:  닮은이라고
#
# EBS Token :  한다
# STT result:  한다
#
# -----------------------------------------------------------
# 이렇게 공부를 했었는데 이것 말고도 이러한 것들도 성립할 거란 얘기예요
# 이렇게 공부했는데 이것 말고도 이러한 것들도 성립할 거라는
#
# EBS Token :  이렇게
# STT result:  이렇게
#
# EBS Token :  공부를
# STT result:  공부, 공부했
#
# EBS Token :  했었는데
# STT result:  했는데
#
# EBS Token :  이것
# STT result:  이것
#
# EBS Token :  말고도
# STT result:  말고도
#
# EBS Token :  이러한
# STT result:  이러한
#
# EBS Token :  것들도
# STT result:  것들도
#
# EBS Token :  성립할
# STT result:  성립할
#
# EBS Token :  거란
# STT result:  거라
#
# EBS Token :  얘기예요
# STT result:  고도이러
#
# -----------------------------------------------------------
# 예를 들어 작은 삼각형에서 빗변 분의 높이 얼마입니까 오분의삼이죠
# 예를 들어 작은 삼각형 에서 이 변 분에 높이 얼마입니까 오 분의 삼
#
# EBS Token :  예를
# STT result:  예를
#
# EBS Token :  들어
# STT result:  들어
#
# EBS Token :  작은
# STT result:  작은
#
# EBS Token :  삼각형에서
# STT result:  삼각형에서
#
# EBS Token :  빗변
# STT result:  이변
#
# EBS Token :  분의
# STT result:  분의
#
# EBS Token :  높이
# STT result:  높이
#
# EBS Token :  얼마입니까
# STT result:  얼마입니까
#
# EBS Token :  오분의삼이죠
# STT result:  오분의삼
#
# -----------------------------------------------------------
# 큰 삼각형에서 빗변 분의 높이 얼마죠 십분의육이죠 이 둘 어때요
# 큰 삼각형 에서 이 본부를 높여야 하죠 십 분 의 유기적 이들 오 대
#
# EBS Token :  큰
# STT result:  큰
#
# EBS Token :  삼각형에서
# STT result:  삼각형에서
#
# EBS Token :  빗변
# STT result:  이본, 십분
#
# EBS Token :  분의
# STT result:  분의
#
# EBS Token :  높이
# STT result:  높여
#
# EBS Token :  얼마죠
# STT result:  야하죠
#
# EBS Token :  십분의육이죠
# STT result:  십분의유기적
#
# EBS Token :  이
# STT result:  이, 이
#
# EBS Token :  둘
# STT result:  들
#
# EBS Token :  어때요
# STT result:  에서이, 야하죠
#
# -----------------------------------------------------------
# 오분의삼으로 서로 같다는 거 확인할 수 있고
# 오 분의 삼 으로 서로 같다 라는 것을 알 수 있고
#
# EBS Token :  오분의삼으로
# STT result:  오분의삼으로
#
# EBS Token :  서로
# STT result:  서로
#
# EBS Token :  같다는
# STT result:  같다, 같다라, 다라는, 같다라는
#
# EBS Token :  거
# STT result:  서, 것, 고
#
# EBS Token :  확인할
# STT result:  을알, 것을알
#
# EBS Token :  수
# STT result:  수
#
# EBS Token :  있고
# STT result:  있고
#
# -----------------------------------------------------------
# 또 마찬가지로 작은 삼각형에서 예를 들어서 빗변 분의 밑변 해 봅시다 오분의사죠
# 또 마찬가지로 작은 삼각형 에서 예를 들어 빚 변 분의 이 편 해봅시다 오 분의 사적
#
# EBS Token :  또
# STT result:  또
#
# EBS Token :  마찬가지로
# STT result:  마찬가지로
#
# EBS Token :  작은
# STT result:  작은
#
# EBS Token :  삼각형에서
# STT result:  삼각형에서
#
# EBS Token :  예를
# STT result:  예를
#
# EBS Token :  들어서
# STT result:  들어, 들어빚
#
# EBS Token :  빗변
# STT result:  빚변
#
# EBS Token :  분의
# STT result:  분의, 분의
#
# EBS Token :  밑변
# STT result:  빚변
#
# EBS Token :  해
# STT result:  해
#
# EBS Token :  봅시다
# STT result:  봅시다
#
# EBS Token :  오분의사죠
# STT result:  오분의사적
#
# -----------------------------------------------------------
# 큰 삼각형에서 빗변 분의 밑변 해 보면 얼마죠십분의팔이죠 근데 이것도 서로 어때 같아요
# 큰 삼각형 에서 이 변 분에 및 편의 봄 얼마전 십 분의 팔 이적 근데 이것도 서로 때 같아요
#
# EBS Token :  큰
# STT result:  큰
#
# EBS Token :  삼각형에서
# STT result:  삼각형에서
#
# EBS Token :  빗변
# STT result:  이변
#
# EBS Token :  분의
# STT result:  분의
#
# EBS Token :  밑변
# STT result:  이변, 및편
#
# EBS Token :  해
# STT result:  때
#
# EBS Token :  보면
# STT result:  이변
#
# EBS Token :  얼마죠십분의팔이죠
# STT result:  얼마전십분의팔이적
#
# EBS Token :  근데
# STT result:  근데
#
# EBS Token :  이것도
# STT result:  이것도
#
# EBS Token :  서로
# STT result:  서로
#
# EBS Token :  어때
# STT result:  로때
#
# EBS Token :  같아요
# STT result:  같아요
#
# -----------------------------------------------------------
# 마찬가지로 하나 더 해 볼까요 작은 삼각형에서 밑변 분의 높이는 사분의삼이죠
# 마찬가지로 하나 더 있을까요 작은 삼각형 에서 이 편 불이 높이는 사 분의 삼
#
# EBS Token :  마찬가지로
# STT result:  마찬가지로
#
# EBS Token :  하나
# STT result:  하나
#
# EBS Token :  더
# STT result:  더
#
# EBS Token :  해
# STT result:  하
#
# EBS Token :  볼까요
# STT result:  을까요
#
# EBS Token :  작은
# STT result:  작은
#
# EBS Token :  삼각형에서
# STT result:  삼각형에서
#
# EBS Token :  밑변
# STT result:  이편
#
# EBS Token :  분의
# STT result:  분의
#
# EBS Token :  높이는
# STT result:  높이는
#
# EBS Token :  사분의삼이죠
# STT result:  사분의삼
#
# -----------------------------------------------------------
# 큰 삼각형에서 밑변 분의 높이는 어때요 팔분의육인데 이들이 모두 다 어때 같다는 걸 여러분들이 알 수 있단 얘기예요
# 큰 삼각형 에서 및 변 불이 높이는 팔 분의 육 인데 이들이 모두 같다는 걸 여러분들이 할 수 있다는데요
#
# EBS Token :  큰
# STT result:  큰
#
# EBS Token :  삼각형에서
# STT result:  삼각형에서
#
# EBS Token :  밑변
# STT result:  및변
#
# EBS Token :  분의
# STT result:  분의
#
# EBS Token :  높이는
# STT result:  높이는
#
# EBS Token :  어때요
# STT result:  데요, 이높이, 인데이, 이들이, 이모두, 는데요
#
# EBS Token :  팔분의육인데
# STT result:  팔분의육인데
#
# EBS Token :  이들이
# STT result:  이들이
#
# EBS Token :  모두
# STT result:  모두
#
# EBS Token :  다
# STT result:  다, 다
#
# EBS Token :  어때
# STT result:  에서, 이모, 여러
#
# EBS Token :  같다는
# STT result:  같다는
#
# EBS Token :  걸
# STT result:  걸
#
# EBS Token :  여러분들이
# STT result:  여러분들이
#
# EBS Token :  알
# STT result:  팔, 할
#
# EBS Token :  수
# STT result:  수
#
# EBS Token :  있단
# STT result:  있다
#
# EBS Token :  얘기예요
# STT result:  이들이모, 다는데요
#
# -----------------------------------------------------------

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
result
# Out:
#           한글발음                                                STT
# 0        반갑습니다                                       반갑습니다, 반갑습니다
# 1         이비에스                                               이티에이
# 2           친구                                                 치여
# 3         여러분들                                   여러분들, 여러분들, 여러분들
# 4        여러분들과                                              여러분들과
# 5           함께                                             함께, 함께
# 6    중학뉴런수학삼하를                                          중학유럽수학삼하를
# 7         강의하게                                               강행하기
# 8            된                                                  된
# 9       손석민입니다                                              분석입니다
# 10         이학년                                      이학년, 해하는, 이닮은
# 11         뉴런을                                                늘어를
# 12        통해서도                                               통해서도
# 13      만났었는데요                                              만났는데요
# 14         이렇게  이렇게, 이렇게, 이렇게, 이렇게, 이렇게, 이렇게, 이렇게, 이렇게, 이렇게, 이...
# 15          다시                                                 다시
# 16         만나게                                                만나게
# 17         되어서                                                되어서
# 18          정말                                                 정말
# 19         앞으로                                           앞으로, 앞으로
# 20          삼하                                                 삼하
# 21          과정                                             과정, 과정
# 22         어떻게                                           어떻게, 어떻게
# 23      진행되는지에                                             진행되는지에
# 24        대해서는                                               대해서는
# 25      여러분들께서                                             여러분들께서
# 26      오리엔테이션                                     오리엔테이션, 오리엔테이션
# 27         강의를                                                강의를
# 28         통해서                                                통해서
# 29         확인할                                  확인할, 확인할, 을알, 것을알
# 30           수                                수, 수, 수, 수, 수, 수, 수
# 31          있을                                             있을, 있을
# 32         거고요                                                거고요
# 33         강의는                                                강의는
# 34         반드시                                                반드시
# 35          듣고                                                 듣고
# 36         오셔야                                                옷여야
# 37       여러분들이                          여러분들이, 여러분들이, 여러분이, 여러분들이
# 38         삼학년                                      삼학년, 삼학년, 삼학년
# 39         과정이                                           과정의, 과정의
# 40           하                                   학, 한, 가, 히, 할, 다
# 41          특히                                                 특히
# 42       수업되는지                                              수업되는지
# 43         겁니다                                                겁니다
# 44          일단                                             일단, 일단
# 45          같은                                                 같은
# 46        경우에는                                               경우에는
# 47          크게                                                 크게
# 48         삼개의                                                세계의
# 49       대단원으로                                      대단원의으, 대단원의으로
# 50        이루어져                                           이뤄져, 이뤄져
# 51        있는데요                                               있는데요
# 52           첫                                   첫, 첫, 첫, 선, 첫, 첫
# 53         번째가        번째가, 번째가, 번째가, 번째가, 번째가, 번째가, 번째가, 번째가, 번째가
# 54       삼각비라는                                삼각이라는, 삼각이라는, 삼갑의라는
# 55        단원이고                                                단원고
# 56           두                          두, 두, 두, 두, 두, 두, 두, 두, 두
# 57          원의                                                 원에
# 58          성질                                                 성질
# 59           세                                                  세
# 60          통계                                                 통계
# 61        있습니다                                         있습니다, 있습니다
# 62         우리가                            우리가, 우리가, 우리가, 우리가, 우리가
# 63       일학년하도                                              일학년하도
# 64       마찬가지고                                              마찬가지고
# 65       이학년하도                                              이학년하도
# 66          그래                                                 그랬
# 67          왔듯                                                 랬듯
# 68          주로                                             주로, 주로
# 69         도형에                                                도용에
# 70          대한                                                 대한
# 71        이야기가                                               이야기가
# 72        삼하에서                                               삼하에서
# 73          많이                                                 많이
# 74     다루어지는구나                                             다뤄지는구나
# 75          라는                                                 라는
# 76           걸                                            걸, 걸, 걸
# 77        생각하면                                               생각하면
# 78           될                                            될, 될, 둘
# 79         테고요                                                테고요
# 80         오늘은                                                오늘은
# 81           그                                         그, 교, 과, 그
# 82       시간이니까                                      시간이이니, 시간이이니까
# 83         삼각비                                       삼각, 삼갑의, 삼각알
# 84          삼각                                                 삼각
# 85         알아요                                 알아요, 알아요, 알아요, 알아요
# 86           비                                      시, 이, 이, 니, 이
# 87          근데                                             는새, 근데
# 88          이제                                                 이라
# 89         합쳐져                                                합쳐져
# 90          있는                                             있는, 있는
# 91         새로운                                                새로운
# 92         용어가                                                용어가
# 93         나왔죠                                                나왔죠
# 94          그럼                                             개념, 그럼
# 95           이  이, 이, 이, 이, 이, 이, 이, 이, 이, 이, 이, 이, 이, 이, 이, 이...
# 96         개념을                                                개념을
# 97       공부하기에                                       공부하게앞, 공부하기앞
# 98         앞서서                                            앞서, 앞서당
# 99         당연히                                           당연히, 당연히
# 100       삼각비의                                     삼각비, 삼각비듯, 삼갑의
# 101        뜻부터                                                듯부터
# 102       시작하는                                               시작하는
# 103         것이                                             것이, 것이
# 104      시간입니다                                              시간입니다
# 105         오늘                                 오늘, 오늘, 오늘, 오늘, 오늘
# 106         시간                                                 시간
# 107        시작해                                                시작해
# 108        보도록                                                보도록
# 109          할                                                  할
# 110        텐데요                                                텐데요
# 111        중학교                                           중학교, 중학교
# 112         수학                                                 수학
# 113        손샘과                                                선생과
# 114       끝냅시다                                               끝납니다
# 115        공부할                                           공부할, 공부할
# 116         내용                                                 내용
# 117         바로                                         바로, 바로, 바로
# 118         가지                                     가지, 가지, 가지, 가지
# 119      개념인데요                                              개념인데요
# 120         개념                                                 개념
# 121         번째                                     번째, 번째, 번째, 번째
# 122        제목이                                                제복이
# 123        굉장히                                                굉장히
# 124        길어요                                                길어야
# 125         닮은                             닮은, 닮은, 닮은, 닮은, 닮은, 닮은
# 126    직각삼각형에서                                   즉각삼각통에서, 즉각삼각형에서
# 127       대응변의                                               대응변의
# 128        길이의                                      길이의, 길이의, 길이보
# 129        비라는                                                이라는
# 130        그다음                                                그다음
# 131        개념이                                                개념이
# 132        뭐냐면                                      뭐냐, 뭐냐하, 뭐냐하면
# 133         건데                                                 건데
# 134       뜻이겠죠                                               뜻이겠죠
# 135        개념은                                                개념은
# 136          쭉                                                  쭉
# 137        내용이                                           내용이, 내용이
# 138          다                       다, 다, 다, 다, 다, 다, 다, 다, 다, 다
# 139       다루어질                                                다뤄질
# 140  텐데직각삼각형에서                                다즉각삼각형에서, 이다즉각삼각형에서
# 141         갖는                                                 갖는
# 142       기본적인                                               기본적인
# 143        성질이                                                성질이
# 144        있는데                                                있는데
# 145        성질을                                                성질을
# 146         알고                                                 알고
# 147        가자는                                                자라는
# 148       삼각비를                                               삼각비를
# 149         앞선                                                 앞선
# 150       징검다리                                               징검다리
# 151       내용이다                                               내용이다
# 152         라고                                                 라고
# 153     받아들이시면                                             받아들이지만
# 154        됩니다                                                됩니다
# 155       그렇다면                                         그렇다면, 그렇다면
# 156  직각삼각형에서라고                               즉각삼각형해서있으, 즉각삼각형을그려봐
# 157       했으니까                                               있으니까
# 158     직각삼각형을                                             즉각삼각형을
# 159         그려                                             그려, 게여
# 160         봐야                                                 봐야
# 161        되겠죠                                                야겠죠
# 162      직각삼각형                         즉각삼각형, 즉각삼각형, 즉각삼각형, 즉각삼각형
# 163         개를                                                 개를
# 164        편하게                                                편하게
# 165         그릴                                                 그릴
# 166         제일                                                 제일
# 167         좋은                                                 좋은
# 168        방법은                                                방법은
# 169         뭘까                                                 뭘까
# 170        생각해                                                생각해
# 171      보면우리는                                              보면우리는
# 172        그리면                                                그리면
# 173          거                          개, 게, 그, 게, 그, 것, 서, 것, 고
# 174        같아요                                           같아요, 같아요
# 175         한번                                       만, 선, 만들, 수선
# 176      보겠습니다                  보겠습니다, 보겠습니다, 보겠습니다, 보겠습니다, 보겠습니다
# 177     여기에서부터                                              여기서부터
# 178        수선을                                           수선을, 수선을
# 179         그어                     들어, 게이, 게여, 기서, 들어, 그럴, 고에, 로어
# 180       바깥쪽에                                               바깥쪽에
# 181         하나                             단바, 바깥, 않아, 아보, 니다, 하나
# 182       보입니다                                               보입니다
# 183        그렇죠         에즉, 아보, 니다, 보입니, 그다, 배웠죠, 어요, 었어요, 그쳐, 그쳐사
# 184          또                                               또, 또
# 185         다른                                                 다른
# 186     직각삼각형를                       즉각삼각형, 즉각삼각형, 즉각삼각형하, 즉각삼각형에
# 187         빗변                             이편, 이변, 이본, 십분, 빚변, 이변
# 188          위              이, 이, 아, 이, 이, 에, 이, 에, 이, 어, 에, 이, 이
# 189          한                                                  한
# 190         점을                                                 점을
# 191        잡아서                                                잡아서
# 192        똑같이                                                똑같이
# 193         주면                                                 주면
# 194     에이비씨하고                                    이비지시하고, 에이비지시하고
# 195      에이디이는                                        에이비지, 에이비지시
# 196         서로                                         서로, 서로, 서로
# 197         어떤                                                 어떤
# 198  닮음에이에이닮음이                                            닮은에이담은이
# 199         된다                                                 된다
# 200         이건                                                 이건
# 201          때                                            해, 배, 대
# 202        배웠죠                                                배웠죠
# 203       각에이가                                         건우리가, 까에이에
# 204       공통이고                                               공통이고
# 205       그다음에                                               그다음에
# 206          둘                                               둘, 들
# 207        직각을                                                즉각을
# 208         갖고                                                 갖고
# 209       있으니까                                               있으니까
# 210    에이에이닮음이                                            에이에이닮은있
# 211         테고                                                 테고
# 212         중이                                                 중인
# 213        배웠던                                                이었던
# 214      닮음비라는                                       닮은이라는, 닮은이라는
# 215          건                                               건, 건
# 216        뭐였냐                                                 뭐냐
# 217         하면                                             냐면, 하는
# 218       대응하는                                         대응하는, 대응하는
# 219         변의                                             변의, 별이
# 220       비였어요                                               이었어요
# 221        그래서                                           고해보, 그래서
# 222        만약에                                                만약에
# 223        길이를                       길이를, 길이를, 길이를, 길이를, 길이를, 길이를
# 224        오라고                                                오라고
# 225          해                                   해, 해, 해, 해, 때, 하
# 226         보고                                                 보고
# 227       십이라고                                               십이라고
# 228        보면두                                                보면두
# 229       삼각형의                                         삼각형의, 삼각형에
# 230       닮음비는                                               닮은비는
# 231        오대십                                           오대십, 오대십
# 232      일대이겠죠                                              일대있겠죠
# 233        사라고                                           살아가, 가다보
# 234          놔                                               나, 니
# 235         보면                                             보면, 이변
# 236        길이는                                                길이를
# 237        얼마가                                           얼마나, 얼마나
# 238        됩니까                                                됩니까
# 239         사의                                                 사회
# 240         배인                                                 배인
# 241         팔이                                                 팔일
# 242         돼야                                             두배, 돼야
# 243          돼                                                  두
# 244        거꾸로                                           거꾸로, 거꾸로
# 245       육이라고                                               육이라고
# 246         작은                                 작은, 작은, 작은, 작은, 작은
# 247         쪽은                                                 쪽은
# 248         될까                                                 될까
# 249        일대이                                                일대이
# 250        이대일                                                이대일
# 251         얼마                                                 얼마
# 252         삼이                                                 삶의
# 253        된다는                                                한다는
# 254          알                                   일, 일, 얼, 할, 팔, 할
# 255         있죠                                                 있죠
# 256        우리는                                                우리는
# 257       삼각형과                                               삼각형에
# 258          큰                                         큰, 큰, 큰, 큰
# 259       비이니까                                               이보니까
# 260        삼대육                                                선대육
# 261        사대팔                                                사대팔
# 262        이것이                                                이것이
# 263         모두                                             모두, 모두
# 264       일대이로                                               일대이로
# 265         같고                                                 갖고
# 266        그것을                                                그것을
# 267      닮음비라고                                              닮은이라고
# 268         한다                                                 한다
# 269        공부를                                            공부, 공부했
# 270       했었는데                                                했는데
# 271         이것                                                 이것
# 272        말고도                                                말고도
# 273        이러한                                                이러한
# 274        것들도                                                것들도
# 275        성립할                                                성립할
# 276         거란                                                 거라
# 277       얘기예요                                   고도이러, 이들이모, 다는데요
# 278         예를                                             예를, 예를
# 279         들어                                                 들어
# 280      삼각형에서           삼각형에서, 삼각형에서, 삼각형에서, 삼각형에서, 삼각형에서, 삼각형에서
# 281         분의                         분의, 분의, 분의, 분의, 분의, 분의, 분의
# 282         높이                                             높이, 높여
# 283      얼마입니까                                              얼마입니까
# 284     오분의삼이죠                                               오분의삼
# 285        얼마죠                                                야하죠
# 286     십분의육이죠                                             십분의유기적
# 287        어때요              에서이, 야하죠, 데요, 이높이, 인데이, 이들이, 이모두, 는데요
# 288     오분의삼으로                                             오분의삼으로
# 289        같다는                            같다, 같다라, 다라는, 같다라는, 같다는
# 290         있고                                                 있고
# 291      마찬가지로                                       마찬가지로, 마찬가지로
# 292        들어서                                            들어, 들어빚
# 293         밑변                                 빚변, 이변, 및편, 이편, 및변
# 294        봅시다                                                봅시다
# 295      오분의사죠                                              오분의사적
# 296  얼마죠십분의팔이죠                                          얼마전십분의팔이적
# 297        이것도                                                이것도
# 298         어때                                     로때, 에서, 이모, 여러
# 299          더                                                  더
# 300        볼까요                                                을까요
# 301        높이는                                           높이는, 높이는
# 302     사분의삼이죠                                               사분의삼
# 303     팔분의육인데                                             팔분의육인데
# 304        이들이                                                이들이
# 305         있단                                                 있다

# %%
3 -> 삼, 세(개)

# %%
삼각비의 -> 삼갑의 안찾고 다른것찾음

# %%
s_1 = '이건 우리가 중학교 이학년 때 배웠죠 그렇죠 각에이가 공통이고 그다음에 둘 다 직각을 갖고 있으니까 에이에이닮음이 될 테고'
s_2 = '이건 우리가 중학교 이해하는 데 배웠죠 가계가 공통 이고 그 다음에 둘 다 즉각 을 갖고 있으니까 에이에이 닮은 있을 테고'

# %%
수학기호여부이면 데이터프레임에 표시해둘것
