# %%
# !pip install soynlp

# %%
from soynlp.hangle import levenshtein
from soynlp.hangle import jamo_levenshtein
from soynlp.hangle import compose
from soynlp.hangle import decompose
from konlpy.tag import Kkma
import nltk
from nltk.tag import pos_tag
from nltk.corpus import gutenberg
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.tokenize import TweetTokenizer
from nltk.tokenize import regexp_tokenize
from nltk.help import upenn_tagset
from string import punctuation
from nltk import Text
from konlpy.corpus import kolaw, kobill
from konlpy.tag import Kkma, Mecab, Okt, Komoran, Hannanum
import pandas as pd
import numpy as np
import re
from PreProcessing.Dictionary import sd, ad, kopro
from PreProcessing.Opentext import get_EBS
from PreProcessing.Opentext import get_EBS_entered
from PreProcessing.Opentext import get_STT1_Google_entered
from PreProcessing.Opentext import get_STT1_Transcribe_entered
from collections import defaultdict
pd.set_option("display.max_rows", None, "display.max_columns", None)
# Out:
# 0
# 0
# 0
# 1
# 2
# 5
# 4
# 8

# %%
from PreProcessing.find_common_part import find_common_part

# %%
EBS_entered = get_EBS_entered(2,2)
STT_entered = get_STT1_Google_entered(2,2)
STT2_entered  = get_STT1_Transcribe_entered(2,2)
# Out:
# ['lec00002_EBS_entered.txt']
# ['lec00002_STT1_Google_entered.txt']
# ['lec00002_STT1_Transcribe_entered.txt']

# %%
print(EBS_entered)
# Out:
# 반갑습니다, EBS 친구 여러분들. 중학뉴런수학 3학년(하)의 손석민입니다.
# 여러분, 지난 시간에 우리가 삼각비의 뜻에 관련된 공부를 했습니다.
# sin, cos, tan 값이 각각 무엇을 의미하는지.
# 즉 (빗변)분의(높이), (빗변)분의(밑변), 그다음 (밑변)분의(높이)가 각각 sin, cos, tan 기준각이라는 걸 이야기했는데요.
# 오늘 공부할 주제는 딱 한 가지입니다. 바로 30˚, 45˚, 60˚. 우리는 이 각들을 특수한 각이라고 이름 지었어요.
# 이 각에서의 삼각비의 값을 알아볼 거고.선생님이 원래는 외우는 수학을 여러분들께 별로, 그런 강의를 안 하려고 하는 편인데.
# 이 값들은 여러분들이 암기하셔야 해서 암기하기 쉬운 방법까지 선생님이 제시해 드릴 테니까오늘 수업이 끝날 때쯤에는 여러분들께서 sin, cos, tan, 30˚, 45˚, 60˚의 값이 암기되어 있으면 되겠습니다.
# 같이 함께 수업 시작해 보도록 하겠습니다. 중3 수학 끝내 봅시다.
# 오늘 함께 공부할 내용은 한 가지예요. 크기가 30˚, 45˚, 60˚인 각의 삼각비의 값. 이렇게 돼 있죠?
# 이 내용을 공부하기에 앞서서 선생님하고 한 가지 이야기해 볼게요.
# 지난 시간에 막 sin, cos, tan 기준각이 어떻고 빗변이 뭐고 막 이런 얘기 했잖아.
# 그렇죠? 근데 아마 배우면서 그랬겠죠.‘선생님, 근데 그거 왜 배워요?’ 내지는 여러분들 이 생각할 수 있을 거예요.
# ‘선생님, 왜 변의 길이의 비인데 그걸 각으로 표현해요? sin A, sin B, sin C. 왜 사인 뒤에 각이 붙나요?’이런 질문을 여러분들이 할 수 있을 거 같아요.
# ‘약속이야.’라고 하고 그냥 넘어가긴 합니다만 조금 더 살짝 깊이 있게 우리가 살펴볼게요.
# 우리는 삼각형이 어떤 도형이 갖는 성질이긴 한데 기본적으로 하나, 이 정도 느낌만 보겠습니다.
# 여기에서 이 각을 A라고 해볼게요. 지금 기준각 이런 걸 얘기하고자 하는 게 아니에요.
# 기본적으로 어떤 도형이 갖는 성질이에요.
# 직각삼각형. 만약에 이 어떤 각 A가, 기준각이 커진다는 건 무엇을 의미하냐는 거야.
# ‘왜 각하고 변의 길이의 비가 연결돼 있지?’라는 느낌을 여러분들이 가져야 돼요.
#  우리가 여기 있는 주황색 삼각형을 보면, 하얀색 삼각형과 밑변은 변함이 없죠.
# 근데 기준각이 변한다는 건 어떤 것들이 변하나 살펴봤더니, 각만 변하는 게 아니라 각을 변화시키면 높이도 하얀색보다 주황색이, 변해요.
# 길어지죠? 빗변의 길이도 어떻게 되죠? 길어집니다.결국 변의 길이는 각의 크기에 영향을 받아, 안 받아? 받아요. 이해됐죠?
# 그래서 우리는 삼각비 sin, cos, tan 뒤에 각을 넣는 거예요. 근데 이렇게 변함에 따라서.
# 뭐 더 작은 것도 있겠죠, 물론.이렇게도 있을 거예요. 그렇죠?
# 이렇게도 있을 텐데. 그러면 이 각의 변화에 따라서, (밑변)분의(높이)라든가 (빗변)분의(높이)라든가 (빗변)분의(밑변)의 길이의 비들이 마구 변화가 생기겠죠.
# 맞죠?여러분들이 한번 이렇게 왔다 갔다 하면서 머릿속에서 막 그려 보세요.
# 사이사이에 있는 걸 막 그려 보면 길이의 비들이 계속 변하고 있어요.
# 근데 이 중에 몇 개의 각들이 의미 있는 숫자를 갖는다는 거야, 비가.
# 예를 들어서 ‘이거 분의 이거 했더니 0.3678이야.’ 뭐 이런 거 말고요. 좀 더 의미 있는 거.
# 주로 무리수를 이용해서 표현되는데. 그 의미 있는 값을 갖도록 하는 각이 바로 30˚, 45˚, 60˚일 때라는 이야기예요.
# 그래서 우리는 이걸 특수한 각이라고 이야기를 합니다.
# 특수한 각이라는 게 되게 특수한 이상한 게 아니라, 우리에게 의미 있는 길이의 비를 제시해 주는 게 바로 특수한 각이고 우리는 그 의미 있는 비를 외워야 되는 겁니다.
# 그러면 우리가 개념을 한번 보도록 하겠습니다.
# 그래서 삼각비라는 게 변의 길이의 비인데 왜 각하고 연결돼 있나.
# 각이 변하면 기준각이 변함에 따라서 변의 길이의 비가 변하니까.
# 그런데 그중에 의미 있는 각이, 각이 의미 있는 게 아니라 변의 길이의 비를 의미 있게 하는 각이 30˚, 45˚, 60˚라는 이야기예요.
# 아셨죠?그럼 우리는 기준각이 30˚일 때의 세 변의 길이의 비를 먼저 살펴보겠습니다. 기준각이 30˚. 우리 이렇게 한번 그림을 놔 볼게요.
# 처음엔 이렇게 여러분들이 이제 그려 보겠죠.여기에서 이 각을 30˚라고 놔 보겠습니다.
# 그럼 이 각은 자연스럽게 60˚겠죠.
#  ‘선생님, 여기에서 기준각을 30˚라고 놨을 때, 저는 sin 30˚를 구하고 싶어요.’라고 생각해 본다면.결국 (빗변)분의(높이)죠.
# 기준각에서 마주 보는 게 높이니까 근데 ‘선생님. 이 길이하고 이 길이의 비를 어떻게 알죠? 아무 정보가 없는데?’
# 근데 우리는 그 정보를 만들어 낼 수가 있습니다.어떻게 만들어 낼지 한번 잘 보시기 바랍니다. 우리가 이 변을 a라고 잡아 볼게요.
# 그럼 이 변은 뭐가 될까. 아직은 모르죠. 그런데 뒤집어서 하나를 더 붙여 보는 겁니다. 이렇게. 됐나요?이게 일직선이 되도록.
# 그러면 ‘선생님, 이걸 뒤집어서 붙였기 때문에 이 길이가 a면 이 길이도 a예요.
# 근데 이 각이 60˚이니까 뒤집혀서 이 각이 60˚가 되거든요.’그러면 60˚, 60˚이면 이것도 60˚잖아요.
# 무슨 삼각형이에요? 정삼각형이 됩니다. 그러기 때문에 이 길이가 2a면 이 길이도 2a가 됩니다.
# 이것까지 여러분들이 생각할 수 있으면 되는 거예요.그렇다면 이제 그림을 다시 잘라서 이렇게 보겠습니다.
# 그러면 우리는 피타고라스의 정리에 의해서 이 길이를 구할 수 있을 테고.
# √(2a)²-a². 계산해 보면 √(2a)²=√4a²이죠? -a²이죠? √3a²이구나. 그러니까 a는 루트 밖으로 나가서 √3a구나.
# 이렇게 여러분들이 이 길이를 표현할 수 있다는 얘기죠.결국, 잘 들어 보세요.
# 한 내각이 30˚, 60˚, 90˚이면 제일 짧은 변, 두 번째로 긴 변, 빗변의 길이의 비는 a대√3a대2a가 항상 성립하는 거야.
# 30˚로 시작하는 이 각에 대해서는 어떤 삼각형이든, 중요한 게 어떤 직각삼각형이든이겠죠, 당연히. 그렇죠?
#  빗변과 높이의 비가 2a대a. 즉 2대1, 2대1, 2대1이 다 된다는 겁니다.
# 그렇다면 우리는 그것을 정리해서 뭐라고 이야기할 거냐.
# 기준각을 30˚로 봤을 때, sin 30˚는 결국 (빗변)분의(높이)이니까 2a분의a, ½이 된다는 이야기예요.
# 오늘 특수한 각이라는 건 의미가 처음에 뭐라 그랬어?
# 그냥 각 자체가 특수한 게 아니라 변의 길이의 비가 의미 있는 숫자로 나오는 게 특수각이라고 했어요.
# 30˚ 같은 경우에는 sin 30˚가 뭐가 돼? ½. 0.5로 이렇게 깔끔한 수가 나온다는 이야기야. 됐나요?
# 즉, (빗변)분의(높이)가 ½. 1대2, 2대1. 의미 있는 숫자가 나온다는 얘기입니다.
# 그렇다면 우리는 여기서 cos 30˚도 생각할 수 있겠죠. cos 30˚는 뭐가 돼? (빗변)분의(밑변)이겠죠?
# 기준각에서 마주 보는 게 높이였어요.
# 지난 시간 거.(빗변)분의(밑변)은 2a분의√3a이니까 약분해 보면 a, a 약분돼서 2분의√3. 이것이 바로 cos 30˚의 값이 됩니다.
# 마지막으로 tan 30˚의 값은 그럼 뭐가 되나 살펴보면 tan 30˚는 (밑변)분의(높이)잖아요.
# 그렇죠? √3a분의a이니까 a를 약분하고 나면 √3분의1. 또는 유리화해서 3분의√3이 된다는 거.
# 그럼 오늘의 결론은 뭐냐. 여러분들이 ‘sin 30˚ 얼마니?’ 그러면 ½ 나와야 된다는 얘기예요.
# cos 30˚ 얼마예요? 2분의√3 나와야 되는 거예요.tan 30˚ 얼마? 3분의√3.
# 이렇게 바로바로 나올 수 있게끔 암기되어 있는 게 오늘의 결론, 마지막 해야 할 일입니다.
# 그렇다면 이제는 이 그림에서 기준각을 60˚로 바꿔 보겠습니다. 그 얘기는 뭘 구하겠다는 얘기야?
#  sin 60˚, cos 60˚, tan 60˚의 값을 알아보자는 이야기겠죠.잘 보세요.
# 기준각이 이쪽으로 바뀌면 마주 보는 변이 뭐가 돼? 높이가 되고. 이 변은 밑변. 이 변이 빗변. 지난 시간 내용이에요. 그렇죠?
# 그렇다면 sin 60˚라는 건 (빗변)분의(높이)죠. (빗변)분의(높이)가 뭐야?
# 2a분의√3a. 이렇게 되겠죠? 2a분의√3a이니까 a 약분하면 2분의√3이 바로 sin 60˚의 값입니다.
# 암기하셔야 돼요.cos 60˚는 그럼 뭐가 될까? (빗변)분의(밑변)이니까 2a분의a이죠? 결국 뭐가 돼?
# ½. tan 60˚는 (밑변)분의(높이)이니까 a분의√3a. 이렇게 되겠죠.
# a분의√3a는 결국 a, a 약분하면 √3이구나.
# tan 60˚. 기준각 60˚에 대해서 (밑변)분의(높이)네? √3이구나.
#  1대√3. 됐죠? 이렇게 여러분들께서 1대√3 하고 암기해 주셔야 된다는 얘기예요.
# 그렇다면 45˚ 아직 빠졌잖아요. 그렇죠?그럼 45˚에 대해서 한번 알아볼게요.
# 여러분들 좀 있다 이 표 다시 한번 보여 드릴 거니까 지금은 지우셔도 상관없어요.
# 30˚, 60˚, 90˚일 때 세 변의 길이의 비는 구하는 게 뒤집어서 붙이고 좀 복잡했다면, 45˚는 조금 쉽습니다.
# 직각삼각형인데 한 내각이 45˚라는 말은 여기에서 세 변 사이의 길이의 비를 우리가 공부하겠다는 거예요.
# 근데 이 각이 45˚이면 이 각이 자연스럽게 몇 도 나와? 45˚ 나오잖아요. 그렇죠?그러면 결국 뭘 의미해? 이등변삼각형이에요.
# 두 내각이 같으니까. 그럼 우리가 이 길이를 1이라고 놓으면, 또는 a라고 놓으면 이 길이도 뭐가 돼, 당연히? a가 되겠죠?
# 그럼 이 길이는 피타고라스의 정리에 의해서 뭐가 되냐 하면 √a²+a²입니다.
# 결국 루트 몇 a²? 2a²이니까 a가 빠져 나와서 √2a가 된다는 얘기야.
# 결국 우리는 여기에서 직각이등변삼각형은 길이의 비가 a대a대√2a. 즉 1대1대√2이고.
# 그로 인해서 우리는 삼각비 3개, sin 45˚와 cos 45˚와 tan 45˚의 값을 생각해 보면그러면 45˚에 대해서 sin 값은 결국 뭐가 되냐.
# (빗변)분의(높이)죠? 마주 보는 게 높이니까. 결국 √2a분의a입니다.
# 그래서 약분해 보면 √2분의1이니까 유리화해서 2분의√2까지 갈 수 있고.cos 45˚는 (빗변)분의(밑변)이겠죠.
# 기준각에서 마주 보는 게 높이이면 이게 밑변이니까.
# 근데 뭐야? 똑같이 √2a분의a네.
# 그러니까 a, a 약분하면 √2분의1.
# 그래서 2분의√2가 똑같이 나와요.tan 45˚는 뭐죠? (밑변)분의(높이)였죠? 즉, a분의a이니까 뭐가 돼? 1. 이렇게 나온다는 이야기야.
# 그래서 여러분들께서 이걸 가지고 이제 우리가 나중 되면 결론은 뭐 하겠다는 이야기냐 하면,이런 거 하겠다는 얘기예요.
# 너무 어렵지 않으니까 보세요. 45˚ 직각삼각형인데 이 길이가 3일 때, 이 길이 구해 보라는 거야.
# 그럼 우리는 한마디로 이게 빗변이고 이게 기준각에 대해서 밑변이잖아.
# 그럼 cos 45˚이겠죠? cos 45˚라는 게 뭐 분의 뭐야?x라고 놔 보면 x분의3일 거 아냐.
# 맞죠? 근데 우리는 이 x분의3의 값을 알고 있다고. cos 45˚의 값을 알고 있다고.
# 됐나요?이렇게 해서 여기서 x를 구하는 걸 공부하는 게 최종 목적이에요.
# 근데 이렇게 되어 있고 cos 45˚의 값이 2분의√2임을 모르면 x의 값을 구할 수 없겠죠.
# 그러니까 여기 있는 9개 숫자를 암기하셔야 되는데. 선생님 중학교 때 정말 암기하는 거 못하고 싫어했어요.
# 그래서 그나마 수학이 좋았었어. 왜?
# 암기를 덜 해도 된다고 생각했는데, 결국 우리가 주요 공식이나 유도 과정들 공부하고 나면 언젠간 암기를 할 시간이 오겠죠.
# 지금 sin, cos, tan, 30˚, 45˚, 60˚의 값이 왜 각각 ½, 2분의√2, 2분의√3 해서 쭉 나오는지 설명을 드렸는데 이유를 알았다면 암기하셔야 됩니다.
# 암기하는 방법은 어떻게 되냐면, 다음 시간에 0˚, 90˚도 하고 나면 여러분에게 좀 더 다시 한번 설명 드릴 텐데.
# 분모는 다 2예요, 분모는 다 2. sin 같은 경우에. 그다음 분자는 √1, √2, √3. 됐나요? 어렵지 않죠?
# 근데 √1은 1이니까 그냥 우리가 ½로 쓰는 거예요.2분의√1, √2, √3. 그럼 외울 수 있나요, 30˚, 45˚, 60˚?
# 그렇다면 cos 같은 경우는 어떻게 될 거냐. 거꾸로 오면 됩니다.
# 1, 2, 3 갔으니까 3, 2, 1.즉, 2분의√3, 2분의√2, 2분의√1. 근데 √1은 1이죠?
# 이렇게 써 주면 돼요. 결국 sin을 써 줄 수 있다면 cos은 이렇게 엇갈려서 대각선으로 내려오는구나.
#  여러분들이 생각할 수 있으면 되겠죠.
# tan 같은 경우에는 tan 45˚의 값일 때 1이고, 이걸 기준으로 해서 √3으로 나누고, √3으로 곱해 주면 돼요.
# 결국 1을 √3으로 나눈다는 게 뭐야? √3분의1이겠죠.1÷√3. 그렇죠?
# 이걸 보통 유리화해서 3분의√3으로 많이 되어 있는데, 선생님은 이걸 쓰는 경우가 조금 더 많아요.
# 계산하다 보면 이게 더 편할 때가 많아요.
# 그래서 일반적으로 우리가 수를 쓸 때에는 분모를 유리화해서 쓰기 때문에 이렇게 되어 있지만, √3분의1로 기억해 주시면 더 편하죠.
# 왜? 1÷√3이라는 게 이거보다는 이게 좀 더 와 닿으니까.
# 그렇죠? 이쪽으로 √3 곱하면 얼마야? 1×√3=√3이겠죠. 그래서 여러분들께서 오늘 끝날 때 이 표를 그려 놓을 수 있으면 돼요.
# 선생님 중3 때는 이게 잘 안 외워지는 친구들 있잖아요. 그러면 어떻게 했냐면, OMR카드 있잖아요?
# 학교에서 시험 보기 전에 막 달달달 최대한 외워.
# 그러다 OMR카드를 받자마자 수험번호를 쓰고 뭐 그런 게 아니라,
# 선생님 때는 OMR카드 뒤가 주관식 답란이었는데 거기에다가 이 표를 일단 외운 걸 막 써요.
# 그러고 나서 이제 마음 편안하게 1번 문제부터 풀어 나갑니다.
# 그만큼 여러분들께서 이 특수각에서의 삼각비의 값은 반드시 암기되어 있어야 돼요.
# 외우는 방법 설명 드렸으니까 2분의√1, √2, √3.
# 2분의√3, √2, √1. 1을 기준으로 √3 나눈다, √3 곱한다. 됐나요?
# 여기까지 여러분들께서 정리할 수 있으면 됩니다.
# 이게 그럼 도대체 문제는 어떻게 나오느냐. 너희가 왜 외워야 되는지, 여러분들이. 이렇게 나오기 때문에 외워야 돼요.
# 이걸 ‘왜 이런 문제를 내요?’라고 하면 선생님이 할 말이 없죠.나와 있는데 어떡해.
#  sin 30˚의 값을 뭐 유도 하나요? 아니에요.
# 그냥 외워서 푸는 거야. sin 30˚ 얼마? 2분의 얼마? 30˚, 45˚, 60˚. ½, 2, 3. 그렇죠.
# cos 45˚ 얼마? 2분의√2. 45˚가 가운데이니까 1, 2, 3에서 2이겠네.
# 그래서 2분의1+√2. 됐나요? tan 45˚ 얼마였지? 제일 마지막 줄에? 가운데? 1.그걸 기준으로 √3 나누고 √3 곱했잖아.
# 그렇죠? 더하기. cos 60˚. 60˚ 제일 이쪽에 있네. √3, √2, √1이었어, cos은. sin이 1, 2, 3. cos은 3, 2, 1.
# 그래서 여러분들께서 이렇게 외워져서 나와야 되는 거예요. 알겠나요? 개념 확인 1번 문제였습니다.
# 이건 됐죠. 그렇죠?이제 여기까지 해서 간단하게 오늘 배웠던 내용에 대해서 이런 문제를 우리가 다루는구나.
# 근데 이것만 있지는 않겠죠.외워 가지고 이것만 풀진 않을 거예요.
# 다양한 문제들을 살펴봐야 되는데 이제 예제 문제 한번 시작해 보도록 하겠습니다.
# ‘선생님, 이런 문제 안 나온다면서요.’ 그냥 외워서 쓰는 거죠.
# 근데 한 번쯤은 여러분들께서 외웠는지 다시 한번 확인하는 그런 문제입니다.
# 가끔 이런 문제가 시험에 출제되기도 합니다. 근데 여러분들이 잘 틀리진 않아요, 성실히 외웠다면.
# 같이 함께 예제 1번을 가볍게 풀어 볼 텐데.tan 45˚ 얼마였어요? 표를 머릿속에 그려 봐.
# 여러분들이 연상해서 외울 때, tan 마지막 줄이었지. 45˚는 가운데였지. 그럼 뭐가 떠올라야 돼?1 떠올라야 돼.
# √3 나누고 √3 곱했던 거 기억해야죠.
# 이런 식으로 여러분들이 표의 9개의 숫자를 다 쓸 수 있지만, 머릿속에 이미지를 그려 놓는 연습도 중요합니다.
# 그다음 sin 60˚. sin 첫 줄이 뭐였더라? 2분의였고.
# √1, √2, √3인데 60˚가 제일 끝이었으니까 2분의√3이겠구나. 이런 식으로.
# 머릿속에 뭔가 생각을 정리하라는 얘기예요.두 번째, tan 30˚?
#  마지막 줄에서 30˚ 뭐였더라? 가운데가 1이었고 √3으로 뭐 했었어? 나눴었어.
# √3분의1이었구나. 이렇게. 됐나요?곱하기. cos 60˚. cos 중에, 둘째 줄에서 제일 큰 거.
# 근데 cos은 √3, √2, √1 거꾸로 갔으니까 ½이겠구나.
# 이렇게 가는 거죠.그래서 여러분들께서 계산해 보면 2분의√3 더하기.
# 여기는 우리가 유리화해 볼까? √3분의√3 살짝 곱해 볼게요.
# 3분의√3이죠.3분의√3×½이니까 6분의√3이 돼서 결국 6으로 통분해 보면,
# 6분의3√3+6분의√3이니까 6분의 몇 √3?4√3이고 약분해서 3분의2√3까지 여러분들이 답을 써 주면 되니까 정답은 ③번이다.
# 이렇게 예제 1번을 구하면 됩니다.
# 사실 여기 뭔가 복잡하게 쓰여 있지만 실제로 하는 건 뭐야?
#  45˚, 60˚, 30˚, 60˚에 대한 sin, cos, tan 값을 외워서 써 준 다음에 계산한 것. 이게 끝입니다.
# 근데 이런 문제가 나올 수 있다는 얘기예요. 왜? 안 외우니까, 여러분들께서. 외워야 돼요. 아셨죠?
# 가능하면 선생님이 안 외우는 수학을 지향하지만 좀 암기할 부분이 있습니다, 이런 거.
# 다음으로 예제 2번 문제 한번 들어가 보겠습니다. 그래요. 이거 하고 싶어요. 오늘 외운 게 이거 하려는 거야.
# 예제 2번 가 볼게요.그림과 같은 직각삼각형 ABC에서 지금 빗변의 길이가 6이고 AC의 길이가 3이래요.
#  ‘∠B의 크기를 구하세요.’ 했습니다. 이렇게 한번 놔 볼까요?∠B를 기준각으로 보면 지금 빗변의 길이가 주어져 있는 거예요.
# 추론하는 거야. 우리 추리하는 거야. B를 구하라.
# 이거 어떻게 하라는 얘기지, 문제에서?이건 뭐죠? 기준각 기준으로 봤을 때?
# 마주 보는, 높이. 이 문제가 그림이 우리에게 알려 주는 건 빗변과 높이를 알려 주고 있는 거네?
# 기준각에 대해서.빗변과 높이가 뭐였더라? sin이었어. (빗변)분의(높이)가 sin이었어. 맞아, 맞아.
# sin B가 뭐 분의 뭐라고? (빗변)분의(높이)였어.6분의3이야. 6분의3은 뭐지? ½ 딱 써 놓고 보는 거죠.
# 하는 순간 번쩍하고 스쳐 지나가야 돼. 뭐가? ‘어? sin 뭐가 ½이었지?’ 했을 때 딱 떠올라야죠.뭡니까?
# sin은 ½, 2분의√2, 2분의√3. sin 몇 도가? 30˚가 ½이죠.
#  여기에서 우리는 B의 값이 얼마라는 걸 알 수 있어?
#  30˚라는 걸 알 수 있다. 정답은 ③번.이렇게 하고 싶은 거예요. 그걸 외워서 무슨 얘기인지 알겠죠?
#  예제 3번으로 한번 들어가 볼 텐데요. 예제 3번 문제는 조금씩 조금씩 이제 다른 유형들이 나오고 있죠.
# 삼각비를 이용하여 변의 길이를 구할 거예요. 각이 주어져 있잖아.
# 조금 전 문제는 두 변이 주어져 있고 각 구하라는 거였죠?
# 이 문제는 변의 길이 하나, 각 하나가 주어져 있고 다른 변의 길이를 구하라는 유형이에요.
# 이거 어차피 삼각비를 이용할 거야.왜? 삼각비는 두 변 사이의 길이의 비율을 우리에게 알려 주고 있는 거니까. 그렇죠?
# 그러면 ∠C=30˚이고 AC=6√2일 때, 뭘 구하라 그랬어?‘AB의 길이를 구하래요.’ 하고서 쳐다볼까요?
# 지금 30˚를 알려 주고 있네. 이게 기준각이라고 바라보면, 우린 알아. 마주 보는 게 뭐였더라?
#  지난 시간에. 기준각에서 마주 보는 게 높이였어요. 맞죠?직각에서 마주 보는 게 빗변이니까 자동으로 이건 뭐가 돼?
# 밑변이야. 그러면 이 문제는 이런 얘기네? AB를 구하란 얘기는 높이를 구하란 얘기고. 주어져 있는 건 밑변이네?
# 그럼 우리는 추론하는 거죠. 생각하는 거야. 밑변하고 높이가 뭐였지? tan. 맞아. 기준각이 30˚잖아.
# 그렇죠? tan 30˚가 (밑변)분의(높이)였어. 6√2분의AB였어. 이 얘기예요.뭐야, AB 구하라고 했네? 이거 구하고 싶은 거예요?
# 그럼 이거 숫자네? 이것만 숫자이면 되는 거잖아. 그렇죠?
#  근데 tan 30˚가 뭐야? √3분의1 또는 3분의√3 대입하시면 됩니다.
# 그럼 우리는 이 등식에서 양변에 6√2를 곱해 주면 AB를 구할 수 있을 거고.
# 결국 √3분의1×6√2니까 이건 계산이죠, 이제.√3분의√3 곱해서 유리화까지 해 줄 거고. 보세요.
# 3분의6이니까 약분해서 뭐가 돼? 3분의6은 2 남으니까 2√6.이렇게 여러분들께서 AB의 길이를 구한다는 이야기예요.
# 할 수 있겠죠? 그러니까 우리가 sin, cos, tan, 30˚, 45˚, 60˚의 값을 알고 있다면.
# 근데 그것의 의미는 sin 30˚에 대해서 빗변과 높이의 비, 빗변과 밑변의 비, 밑변과 높이의 비.
# sin, cos, tan 30˚의 값을 안다는 얘기가 바로 그것을 의미하니까삼각비가 주어져 있거나 또는 삼각비가 꼭 아니더라도
#  sin, cos, tan의 값이 아니더라도 어떤 특수한 각이 주어지면우리는
# 그걸 통해서 밑변과 높이, 밑변과 빗변, 빗변과 높이 사이의 길이의 비들을 알 수 있단 얘기예요.
# sin, cos, tan의 값을. 정확히 얘기하면. 그렇죠?그래서 문제에서 구하라고 하는 길이를 구해낼 수 있다는 거.
# 그게 바로 오늘 공부할 핵심이겠죠. 그러니까 이런 복잡한 문제를 풀기 위해서 가장 먼저 할 일이 뭐라고요?
# sin, cos, tan, 30˚, 45˚, 60˚ 암기되어 있어야 돼요. 이제 유제 한번 시작해 보겠습니다.첫 번째 유제 보겠습니다.
# 첫 번째 유제, 여러분들, 이건 그냥 대입하면 돼. 그렇죠? 그러니까 우리가 이런 문제는 가볍게 풀고 가 보도록 하겠습니다.
# 근데 단지 분수로 돼 있어서 조금 번거롭죠? 이럴 때는 그냥 분모 따로, 분자 따로 이렇게 생각해 보는 건데.
#  우리 분모를 생각해 볼게요, 분모.분모는 √3 곱하기. tan 30˚ 얼마입니까? 외우셨죠? √3분의1이에요.
# 그럼 약분해서 그대로 분모가 1. 이거 너무 좋다. 분모가 1이면 뭐가 가능해?
# 생략이 가능하니까 그냥 분자 보면 되는 거예요.그냥 바로 갑시다.
# 분자. 2 곱하기. sin 45˚, 2분의√2. 더하기. cos 45˚, 2분의√2.
# 이거 이제 선생님이 가운데에 있는 거 이거 안 할 거예요.
# 여러분들 암기돼 있어야 돼요.마이너스. tan 60˚? √3이었죠.
# 이걸 계산해 보면, 결국 2분의2√2 또는 이거 이렇게 분배법칙 써 주면 √2+√2이니까 2√2이죠.
# 그리고 그 뒤에 -√3. 이게 그대로 답인 유형이에요.
# 이건 그냥 우리가 머릿속에 외워져 있기만 하면, 뭔가를 이해하고 논리적으로 생각하고 이럴 필요 없이 그냥 계산해 주면 되는 형태입니다.
#  첫 번째 문제는 이렇게 마무리가 되고요.다음 유제 2번으로 들어가 보겠습니다.
# 유제 2번, 여러분들, ㈎, ㈏, ㈐ 알맞은 값. ‘이거 외웠니?’라고 대놓고 묻는 문제이죠?
# 어떻게 됩니까?sin, cos, tan. 30˚, 45˚, 60˚. 2분의 √1, √2, √3. 2분의 √3, √2, √1. 2분의√2. 됐죠?
# √3 나눴고, √3 곱했고. 됐나요?이거 뭐 따로 설명할 게 없죠. 여러분들이 암기하셨다면 바로 해결이 가능합니다.
# 이제 조금씩 중요한 문제가 나오겠죠. 유제 3번으로 들어가 볼 텐데요.
# 오른쪽 그림과 같은 직각삼각형 ABC에서 AB의 길이가 3√6이고, BC의 길이가 3√2야.
# 그럼 여러분들 뭐 구하고 싶죠, 지금 막?이거 구하고 싶죠. 왜?
#  우리는 직각삼각형에서 피타고라스의 정리가 너무나 익숙하기 때문에.
# 그런데 ∠A의 크기를 구하라고 했는데, 그럼 우리는 지금 그걸 구할 필요가 없는 거예요, AC를.
# 왜냐하면 AC를 구하라는 말도 없어요. 두 변만 나와 있으면 이 두 변의 길이의 비를 구할 수 있고.
# 그게 ∠A의 입장에서 보면 높이가 나와 있는 거죠? 밑변이 주어져 있는 거죠?
# 그럼 머릿속에 뭐가 스쳐 지나가야 돼? ‘밑변과 높이? (밑변)분의(높이)는 tan였지.
#  A가 몇 도인지는 모르겠지만 tan A는 (밑변)분의(높이)를 의미했어.
# 밑변이 3√6이고 높이가 3√2야.’‘일단 좀 간단하게 모양을 만들어 볼까?
#  이게 √3분의1이라는 얘기네? 나 이거 외웠는데.’ 이렇게 나와야 되는 거예요.tan 몇 도가 √3분의1이야?
# 그렇죠, 30˚가. A가 30˚이구나. 이걸 구하란 이야기예요.
# 결국 우리는 마지막에 이게 외워져 있어야 문제를 해결할 수 있는 것이긴 하지만결국 tan A라는 게 주어지면,
# 기준각이 주어졌는데 지금 나와 있는 게 이 두 변이야.
# 이제 우리는 이 두 변이라는 말을 ‘밑변과 높이가 주어져 있어.’로 바꾸는 작업을 할 수 있어야 되는 거예요.왜?
# 기준각에서의 대변이 높이이니까. 이게 빗변은 아닐 테니까 당연히 밑변이겠죠.
# 이렇게 얘하고 얘가 주어져 있다는 말을, 뭐가 밑변이고 뭐가 높이인지.
# 그럼 밑변과 높이가 의미하는 게 그들의 비가 sin, cos, tan 중에 tan로 연결되는 이런 작업들.
# 그다음에 암기되어 있으면 끝나는 겁니다. 아셨죠?이제 유제 4번 문제로 들어가야 되겠죠?
#  유제 4번 문제 들어가 보겠습니다.어려워 보이죠? 굉장히 간단해요.
# 우리는 단순화시켜서 sin 몇 도가 2분의√3인지만 암기되어 있으면 해결할 수 있어요.
# sin은 순서대로 2분의√1, √2, √3이었어. 2분의√3은 그러면 결국 sin 60˚의 값이 2분의√3이었지.
# 이것만 외워져 있다면.똑같고. sin, sin 똑같으니까 3∠x+15˚=60˚이구나.
# 이것만 알면 끝나겠죠. 여기서 x 구하란 얘기잖아.
# 그렇죠?결국 3∠x가 15˚ 이항해서 45˚이니까 양변 3으로 나누면 ∠x의 크기는 몇 도가 된다? 15˚가 된다.
# 사이에 있는지 여러분들께서 확인까지 해 주시면 끝나는 겁니다.
# 됐죠?똑같이 외우는 거지만 유제 3번과 4번 중에서 선생님은 유제 3번이 조금 더,
# 그래도 조금 더 생각할 거리가 있고 좀 좋은 문제예요.
# 여러분들이 복습하시더라도 조금 더 신경 써서 유제 3번 봐 주셨으면 좋겠습니다.
# 이제 마지막 유형에 대해서 2개의 유제가 남아 있는데이 2개의 유제는 오늘 선생님이 강조하고자 하는 모든 내용,
#  그러니까 오늘의 어떤 핵심. 이것만 알면 끝나.
# 이렇게 여러분들이 생각하시면 돼요.유제 5번부터 한번 풀이를 들어가 보도록 하겠습니다.
# 오늘 배웠던 모든 내용이 이 유제 5번에 들어가 있다. 바로 볼게요.
# 오른쪽 그림과 같은 직각삼각형 ABC에서 ∠B=60˚, BC=5, AB를 구하래. 그냥 BC, AB 이렇게 생각하는 게 아니에요.
# 이해되셨나요?삼각비를 구하라고 했잖아. 기준각이 60˚가 하나 주어져 있는 거예요.
# 그러면 마주 보는 게 높이잖아요. 이게 밑변이죠. 이건 뭐야? 빗변이죠.
# 그럼 우리는 뭘 생각하란 얘기야?AB를 구하란 얘기는 빗변을 구하라는 얘기고.
# 주어져 있는 건 기준각에 대해서 밑변이 주어져 있어.
# 그럼 내 머릿속에선 밑변과 빗변 사이의 관계가 뭐였는지를 떠올려야 되는 거야.뭐죠?
# 빗변과 밑변. cos. cos이 몇 도, 특히? 여기 기준각. cos 60˚가 뭐 분의 뭐예요?
# (빗변)분의(밑변)이었어. AB분의BC. 5예요. 그러면 이거 어떻게 해야 되지?뭘 걱정해. 걱정할 필요 없지.
# 이거 구하는 거야, 일단. 그렇죠? 이게 문자예요? 숫자잖아. cos 60˚ 뭐였더라? 이거 외워져 있어야 돼요. ½입니다.
# 그러면 끝나죠.왜? 여기에서 AB 구하면 돼.
# 이렇게 곱해 보면 AB가 결국 뭐라는 얘기예요? 5×2이니까 10입니다. 단위가 있죠? 10㎝.
# 이렇게 여러분들이 구하면 끝나는 겁니다. 됐나요?
# 이 문제, 지금까지 공부한 것 중에서 꼭 한 문제를 출제해야 된다고 하면 유제 5번 나올 수 있겠죠.
#  유제 6번. 여기서 난이도를 조금 더 올려 보도록 하겠습니다.먼저 그림이 좀 복잡해요.
# 그렇죠? 함께 보도록 할게요. 그림의 △ABC에서 AH하고 BC가 서로 수직이래요.
# AH하고 BC가 서로 수직.여기가 90˚인 건 몰라요. 여러분들, 지난 시간에 배웠던 직각삼각형에서의 닮음 아니에요.
# 90˚라는 말 없습니다. 60˚, 45˚이면 당연히 이거 90˚ 아닌 것도 여러분들은 알 수 있죠.
# 이 그림을 여러분들이 바라볼 때 어떻게 바라봐야 되냐 하면 ‘△ABC가 보입니다.’라고 하면 안 되는 거예요.
# 이 도형 문제를 잘 푼다는 얘기는 ‘이 그림은 △ABH하고 △AHC가 AH를 공통으로 해서 붙어 있는 겁니다.’라고 해석해야 돼요. 됐나요?
# 그러면 문제에서 구하고자 하는 게 지금 CH예요. 그럼 우리는 생각해 보는 거지.
# ‘내가 어디까지 가야지 이 CH를 구할 수 있지?’CH를 구하고 싶다는 거, 이거 오늘 숙제입니다, 여러분들. 잘 보세요.
# CH를 구하고 싶다는 건 그럼 이 길이를 잠깐 x라고 놔 볼게요. 이걸 구하려면 뭘 알아야 되지?
# 일단 이쪽에 있는 삼각형에서 이 변이든 이 변이든 알면 돼요. 맞죠? 그래야 뭐 cos 45˚를 쓰든 할 거거든요.
#  근데 이 변보다는 누가 먼저 구해져? 이 변이 구해지죠.왜 이 변이 구해지죠? 이쪽 삼각형을 이용해야 되니까.
# 맞죠? 이쪽에서 올 거니까. 이게 공통이잖아아요, AH가.
# 그렇죠?그러니까 AH를 통해서 CH를 구할 건데 이 문제는 그래도 좀 쉬운 게, 여기 45˚이고 여기 90˚면 여기도 몇 도? 45˚.
# 무슨 삼각형? AHC는 이등변삼각형. AH도 따라서 뭐가 돼? x가 돼. 됐네.그럼 난 저 x를 구할 거야.
# 어떻게? 이제 왼쪽으로 넘어와서 보는 겁니다. 왼쪽에 있는 △ABH에서 보니까 지금 이 각 60˚ 나와 있네.
# 마주 보는 게 뭐야? 높이인데 높이를 구하고자 하는 거네. 그렇죠? 그리고 밑변이 주어져 있는 거야.
# 밑변하고 높이야. tan네요.어떻게 생각하면 돼?
# tan 60˚가 (밑변)분의(높이)인데 그게 4분의x라는 이야기이죠.
# 그렇죠? 그럼 여기서 우리는 x를 구할 수 있고.
# tan 60˚가 √3이니까 이렇게 써 주면 4배 해서 x의 값은 4√3.
# 그게 지금 AH인데 HC하고 길이가 같겠죠?
# 이등변삼각형이었습니다. CH의 길이는 따라서 4√3㎝.이렇게 여러분들께서 답을 구해 주시면 됩니다.
# 이렇게 해서 오늘 교재에 있는 전체의 문제는 마무리가 되었습니다.
# 여러분들 혹시 2학년 때 선생님의 뉴런 들은 친구들은 선생님 수강 후기에서 제일 많이 여러분들이 좋아했던 게, 신기해요.
#  보통은 수업 짧고 막 이런 거 좋아하는데 우리 제자들 너무 훌륭해요.
# 선생님의 추천 문제, 최애 문제 이런 거. 어려운 문제.
# 굉장히 여러분들이 수강 후기에 좋은 글 많이 써 주셔서 3학년 뉴런에서도 선생님이 준비했습니다.
# 궁금하시죠? 함께 오늘의 문제 시작해 보겠습니다.손샘의 최애 문제, 첫 번째 문제 함께 보도록 하겠는데요.
#  이 첫 번째 문제는 조금 전에 풀었던 유제 마지막 문제하고 유사한 형태의 문제입니다.
# 함께 문제 해결해 보도록 하겠습니다.근데 그림을 딱 보면 전혀 느낌이 다르죠?
# 그림만 조금 바뀌면 우리는 다른 문제라고 생각하기 쉬워요. 그런데 문제의 흐름이 같아요.
# 한번 느껴 봅시다.AB의 길이가 6이고, 지금 이 그림을 보고 여러분들이 캐치해야 되는 거.
# 이거 90˚, 90˚, 45˚ 알겠어. 중요한 게 뭐죠?
# 이 그림은 여기 있는 △ABC하고 또 하나의 △DCB가 누구를? BC를 공통으로 해서 있는 거예요.
# 그러니 이 두 삼각형을 연결하는 매개체는 누구야? BC가 포인트인 거야.이걸 여러분들이 생각해야 돼요.
# 그러니까 나는 이쪽에서 이리로 넘어가려면, 다리를 건널 때 BC를 구해 놔야지 넘어갈 수 있다.
# 이걸 생각하면서 문제를 읽어 볼게요.BD의 길이 구하라고 했잖아요.
# 그렇죠. 주황색, 오른쪽에 있는 이 삼각형에서 이 빗변을 구하라는 이야기예요.
#  그러면 일단 이 삼각형에서 어느 변이든, 이거든 이거든 하나를 알아야 된다는 얘기죠.그래야 빗변을 구하겠죠.
# 그럼 당연히 이걸 구하나? 아니죠. BC를 구하겠죠. 왜? 하얀색에서 넘어와야 되니까.그러면 보는 거야.
# 기준각 60˚잖아요. 그럼 지금 마주 보는 게 높이죠, 하얀색에서는. 그렇죠? 이건 뭐죠? 밑변이죠.
# (밑변)분의(높이)는 뭐였죠? tan입니다.그럼 tan 60˚가 뭐 분의 뭐입니까? 6분의BC이다.
# 여기에서 우리는 BC를 구할 거고. tan 60˚는 √3이니까 6배 해 주면 BC는 결국 뭐가 돼?
#  6√3이 될 거야.이렇게 BC를 구하는 단계가 들어가야죠? 그러면 이제 그다음 오른쪽으로 넘어올 수 있겠네.
# 다리 건너 봅시다.BD의 길이 구하라고 했습니다. 그러면 기준각 45에서, 주황색만 보세요. 빗변을 구하래.
# 기준각에서 마주 보는 뭐가 주어져 있어? 높이가 주어져 있는 거야. 됐나요?그러면 빗변과 높이는 뭐였더라?
# (빗변)분의(높이). sin이었구나. sin 45˚가 뭐 분의 뭐예요? 빗변 BD분의, 높이가 누구예요, 지금? 6√3이잖아. 그렇죠?
#  여기서 BD를 구하면 되는 거야.그러면 sin 45˚가 2분의√2이죠? 이거 외워져 있어야죠, 오늘 결론.
# 이렇게 곱해 보면 √2BD는 이렇게 곱하면 12√3이죠.
# 여기에서 양변 √2로 나누고 여기에서부턴 계산이니까 여러분들이 쭉쭉 해 나갈 수 있으면 됩니다.
# 그렇죠?그래서 BD는 결국 뭐가 될 거냐 하면, 2분의12 약분되면 6 남으니까 6√6. 이렇게 답을 구하시면 끝나는 거예요.
# 이건 할 수 있겠죠?이제 선생님이 한 문제, 여러분들과 좀 더 할 텐데. 오늘 이 문제 이해하잖아요?
# 그러면 학교 시험 끝난 거예요, 일단.학교 시험에서 나올 수 있는 삼각비 이 파트에 대한 문제는 이 문제 하나로 딱 끝납니다.
#  가 보겠습니다.△ABC에서 AB=6이고 AC=9입니다. ∠BAH=30˚일 때, tan x의 값.
# 결론이 나와 있어. tan x를 구하래. 그럼 우리는 당연히 직각삼각형 여기에서 tan x를 구할 거고.
# 뭘 구하란 얘기야? 결론 써 보자. tan x. 기준각이 이거야. 마주 보는 게 높이.
# 이게 밑변. tan x는 (밑변)분의(높이). AH분의, 뭘 구하라는 얘기야? CH. 이걸 구하라는 거라고 결론을 정해 놓고.
# 그럼 AH는 어떻게 구해? ‘AH는 어렵지 않네요, 선생님. 이 삼각형에서 오면 될 거 같아요.’ 맞아요.
# 그렇죠? CH. 이게 좀 관건이에요. 그래서 이 문제가 좀 어렵습니다.그러면 우리는 AH는 어떻게 구하면 되냐.
# 기준각 30˚에 대해서 빗변을 알고 있고 밑변을 구하고자 하는 거죠?
# 마주 보는 게 높이니까.결국 6분의AH가 뭐예요? cos 30˚입니다.
# 그러니까 양변에 6배 해 주면 AH=6×cos 30˚가 돼서 결국 뭐가 돼? 3√3. 여기까지 올 수 있어요.
# AH가 3√3.나는 분모는 해결했어. 이제 분자 CH를 구하는 게 목적이야.
#  근데 우리는 CH를 어떻게 구할 수 있느냐, CH를.‘선생님, 여기서 피타고라스의 정리 쓰면 되나요?’예, 피타고라스의 정리 써도 돼요.
# 구해 볼까요? 이 길이는 어떻게 구할 수 있어? 루트, 빗변의 제곱 빼기 다른 변의 제곱.9×9=81. 빼기.
#  (3√3)²=27이니까 √54가 돼서. 54는 9×6=54이니까 3√6까지 여러분들이 갈 수 있는 거죠.
# CH 끝났네. CH 뭐라고요? 3√6. 결과는 √2.이렇게 여러분들께서 답을 구하는 겁니다.
# 오늘 여러분들하고 공부했었던 내용 중에 핵심은 당연히 sin, cos, tan 30˚, 45˚, 60˚의 값을 외우는 거였고.
# 마지막 유형 있죠? 그리고 오늘 최애 문제까지 선생님이 여기까지 여러분들이 할 수 있다면 여러분들께서 학교 시험에 대해서는 일단 오늘 확실하게 끝냈다고 자신 있게 말씀드립니다.
# 공식 외울 내용 함께 정리하고 마무리합니다.
# 오늘! 끝내는 수학. 함께 정리할게요. sin 30˚, 45˚, 60˚ 값. 각각 ½, √2, √3. 분자가 올라간다고 했죠?
# cos은 거꾸로 내려왔죠? 2분의√3, √2, √1이었습니다.tan는, 그렇죠. √3분의1.
#  또는 유리화해서 3분의√3해서 √3씩 곱해 나간다. 반드시 암기 부탁드릴게요.
# 선생님이 아까 숙제로 여러분들께 내 드린다고 말씀드렸던 문제 기억하시나요? 마지막 유제 문제.
# 여러분들, 반드시 CH의 길이를 구하는 순서까지 한번, 어떻게 풀어 나가는지.답이 아니고요.
# 흐름을 여러분들께서 수강 후기에 남겨 주시면 여러분들과 선생님의 소통의 공간이 되겠네요.
# 오늘 수고 많이 하셨고요. 다음 시간에 또 열심히 준비해 오도록 하겠습니다. 다음 시간에 뵐게요.

# %%
print(STT_entered)
# Out:
# 반갑습니다 이비스톰 여러분들 중학 뉴런 수학 3학년 사회 손성민입니다
# 지난 시간에 우리가 삼각비의 뜻에 관련돼서 공부했습니다
#  코사인 탄젠트 값이 각각 무엇을 의미하는지
# 즉 빗변분의 높이 빗변분의 밑변 그냥 빗변분의 높이가 갈까 사인 코사인 탄젠트 기준과 기다란 건 알겠는데요
# 오늘 공부할 주제를 딱 한 가지입니다 바로 30도 45도 60도 우리는이 값들을 특수한 강의 잘하고 있어요
# 이 가게에서의 삼각비의 값을 알아 볼 거고 어 선생님 원래는 외우는 수학을 여러분들께 별로 이렇게 그런 강의를 안 하려고 하는 편인데
# 이감 여러분들이 암기를 하셔야 돼서 암기하기 쉬운 방법까지 선생님 이제 드릴테니까 오늘 수업이 끝날 때 쯤에는 여러분들께서 사인 코사인 탄젠트 34보도 60도의 값이 암기의 있으면 되겠습니다
# 같이 함께 우리 수업 시작해 보도록 하겠습니다 중 3 수학 끝내 봅시다
#  오늘 함께 공부할 내용은 1시 까지요 크기가 30도 45도 60도인 가게 삼각비 얘가 이렇게 돼 있죠
# 어이 내용을 공부하기 앞서서 한 가지 이야기를
#  지난 시간에 막 사인 코사인 탄젠트 기준 가기 어떻고 빗변이 뭐고 이런 얘기 했잖아요
# 근데 아마 배우면서 그렇겠죠 근데 왜 배워요 여름 더위 생각할 수 있을 거예요
#  선생님 왜 변의 길이의 빈데 그걸 갖다가 그로 편해요 싸인 싸인 싸인 싸인 가게 있나요 이런 질문을 여러분들이 할 수 있을 거 같아요
# 약속이야라고 하고 그냥 넘어가게 합니다만 조금 더 살짝 깊이있게 우리가 살펴볼게요
# 우리는 삼각형이 어떤 성질의 기산데 기본적으로 하나 정도 느낌만 보겠습니다
# 여기에서 여기에서 차이가 그래이라고 해 볼게요 뭐 이런 걸 얘기하고 사는게 아니에요
#  짝 기본적으로 어떤 도영이 갖는 성질이야
# 삼각형 직각 삼각형 만약에이 어떤 가기에이가 기존 가기 퍼진다라는 건 무엇을 위한 하라는 거야
#  왜 각하고 변의 길이가 연결돼 있지라는 느낌을 여러분들이 가져야 돼요
#  야 우리가 여기 있는 주황색 삼각형을 보면 하얀색 삼각형가네 뼈는 변함이 없어
#  근데 가기 기준 가기 변환 다른 건 어떤 것들이 변하나 살펴봤더니 강남 변하는게 아니라가 변화시키면 루피도 하얀색 보다 주황색이 변해요
# 빗변의길이 너 어떻게 되죠 길어집니다 결국 변의 길이는 가게 크게 영향을 받아 안 받아 받아요 됐죠
#  그래도 우리는 삼각비 싸인 코사인 탄젠트 뒤에 다들 넣는 거예요 근데 이렇게 변함에 따라서
# 모터 작은 것도 있고 이렇게 돼 이렇게 돼 있을 거야 그죠
#  응 이렇게 해도 있을 텐데 그러면이 가게 변화에 따라서 밑변 불에 높이 라던가 빗변분의 높이 라든가 빗변분의 밑변의 기계 비 드림아 구별하다 생기겠죠 맞죠
# 이런 사람을 이렇게 왔다 갔다 하면서 머릿속에서 그려보세요 그려보세요
# 사이사이에 있는 걸 막 그려 보면 길이 계속 잘하고 있어요
# 근데이 중에 몇 개 이것들이 의미있는 숫자를 갖는 달라는 거야 비가
#  내려서 이거 볼래 이거 했더니 0.3 6782 야 이런 거 말고요 의미 있는 거
#  주로 무리수를 이용해서 표현이 되는데 그 의미 있는 가글 값을 갖도록 하는 가기 바로 30 40 50 60 배달하는 이야기에요
# 그래서 우리는 이걸 갖다가 수완 가기 잘하고 이야기랍니다
#  아 일하는게 되게 특산 이상한게 아니라 아 의미 있는 길을 우리에게 교재비를 제시해 주는게 바로 특수한 가지고 우리는 그 의미에 비를 외워야 되는 겁니다
# 그러면 우리가 개념을 한번 보도록 하겠습니다
# 아 그래서 삼각비란님께 변의 길이 빈대 왜 각하고 연결되어 있나 가게에 변하면
#  생각이 전압에 따라서 변의 길이가 달라니까
#  근데 그 중에 의미있는 가기 의미 있는 가게 믿는게 아니라 변의 길이의 비를 의미 있게 하는 가기 30 45도 60도 달하는 이야기 해요
#  아셨죠 그럼 우리는 기준 가기 30도 일대의 세 변의 길이의 피를 먼저 살펴 보겠습니다 야 기준가게 30도 우리 이렇게 하면 그림을 나올게요
# 처음에 이렇게 여러분들이 이제 어 그래 보겠죠 여기서 이걸 30초 다 이렇게 나오겠습니다
# 그럼 자연스럽게 60조
#  선생님 여기에서 기준가게 30대라고 났을 때 저는 싸인 30도를 구하고 싶어요라고 생각해 본다면 결국 빗변분의 높이 저
# 중간에서 마주보이는 괴롭히니까 없음이라고이기의 해피를 어떻게 알죠 아무 정보가 없는데
#  근데 우리는 그 정보를 만들어 낼 수가 있습니다 어떻게 만들어 낼 때 한번 잘 보시기 바랍니다 우리가 유변 l.a. 다라고 잡아 볼게요
# 그럼 이거는 뭐가 될까 아직은 모르죠 그런데 뒤집어서 날 더 붙여 보는 겁니다 이렇게 되나요 이게 일직선이 되도록
#  그러면 선생님 이걸 뒤집어서 저 때문에 2기가에 인연이기를 도에이 어
# 근데이 가게 60도니까 뒤집어져서 60도 가지고 오세요 그러면 60도 60점은 이것도 60도 잖아요
# 무슨 삼각형 해요 정삼각형이 됩니다 아 그러게 때문에 여기가 이게 이해가 됩니다
# 까지 여러분들이 생각할 수 있음 되는 거야 아 그렇다면 이제 그림을 다시 잘라서 이렇게 해 보겠습니다
# 자 그러면은 피타고라스 정리 해서이 길을 구할 수 있을 테고
#  루트 2의 제곱 - a 제곱 계산해 보면 루트 2의 제곱은 사회 의미죠 - 루트 3의 제곱 이구나 그러니까 애인은 노트 밖으로 나가서 루트 3 에이구 나
#  이렇게 여러분들이 이기들 표현할 수 있다 결국 잘 들어 보세요
#  한 내각의 30 60 90이면 제일 짧은 변 두 번째로 김변 빗변의길이 에버랜드 8에 루트 4 메이데이가 항상 성립하는가
# 30도로 시작하는이 가게 대해서는 어떤 삼각형인 어떤 중요한게 직각삼각형이 드리겠다 당연히
# 빗변과 높이 애비가 e88 2대 1 2대 1 다 된다는 겁니다
# 그렇다면 우리는 그것을 정리해서 뭐라고 이야기 할 거냐
# 기준값을 30도로 왔을 때 사인 30도는 아 결국 빗변분의 높이니까 이에 2분의 Ain't 2분의 1이 된다 나는 이야기에요
# 오늘 일하는 걸 의미가 처음에 뭐라 그랬어
# 그냥 각자 자체가 특수한게 아니라 변의 길이의 비가 의미있는 숫자로 나오는게 특수 하기라고 했어요
#  30도 같은 경우에는 싸인 30도가 뭐가 돼 일 영점으로 이렇게 깔끔한 수가 나온다라는 이야기야 끝나요
# 빗변분의 높이가 2분의 1대 2 2대 1 의미 있는 숫자가 나온다라는 얘깁니다
# 그렇다면 우리는 여기서 코사인 30도 생각할 수 있겠죠 코사인 30도 뭐가 돼 빗변분의 밑변 이겠죠
# 기준가게 도와주고 있는데 높였어요
# 지난 시간을 빗변분의 2편은 이에 2분의 루트 a니까 약분 해 보면 AA 약국에서 2분의 루트 3 이것이 바로 코사인 30도에 같습니다
#  마지막으로 탄젠트 30도의 값은 그럼 뭐가 되냐고 살펴보면 탄젠트 30도는 및 피자나 해보죠
# 루트 3 A 군의 내리니까 8분 하고 나면 루트 3 / 또는 유료에서 3분의 2 3일 된다는 거야
#  오늘 결론은 뭐냐 여러분들이 싸인 30도 얼마 그러면 2분에 나와야 된다는 얘기야
#  코사인 30도 얼마예요 2분의 루트 3 나와야 되는 거예요 탄젠트 30도 얼마 3분의 2 루트 3
#  이렇게 바로 바로 나올 수 있게끔 암기가 되어 있는게 오늘의 결론 마지막 회 자
#  그렇다면 이제는이 그림에서 기준가를 60도로 바꿔보겠습니다 그 얘기는 몰고 하겠단 얘기야
#  싸인 60도 코사인 60도 탄젠트 60 값을 우리는 알아보자 나는 이야기 해 보세요
# 여기 이쪽으로 막히면 마주보이는 별이 뭐가 돼 높이가 되고 이변은 밑변 이변이 빗변 지난 시간 되면 그냥
# 그렇다면 하이닉스도라는 건 빗변분의 높이 빗변분의 높이가 뭐야
# 이렇게 되겠죠 ec3a니까 a 약분하면 2분의 루트 3의 바로 싸인 60도에습니다
#  암기하세요 코사인 60도는 그럼 뭐가 될까 빗변분의네 편이니까 이에 2분의 메이저 결국 뭐가 돼
#  2분의 1 탄젠트 60도는 높인 에이브넷 오투상회 이렇게 되겠죠
#  a4 두 사람의이는 결국 AA 아프려면 루트 3 이구나
#  탄젠트 60도가 기준가격 식초에 대해서 밑변 불에 높이를 로또
# 1대 루트 3 이렇게 해서 1대루트 3하고 암기를 해주셔야 된다니까
# 그렇다면 45도 아주 빠졌잖아 그저 그럼 45도에 대해서 한번 알아볼게요
#  좀 있다 다시 한번 보여 드릴 거니까 지금은 지우셔도 상관없어요
# 30도 60도 90대 세 변의 길이의 비는 조금 구하는게 뒤집어서 붙이고 좀 복잡해 따면 45도는 조금 춥습니다
# 자 직각 삼각형인데 한내 가기 45 도달하는 말해 여기에서 세 변의 길이를 우리가 공부하겠다는 거예요
# 근데이 길이가 다시 보는 1박 자연스럽게 몇 도나 45도 나오잖아요 그러면 결국 머리 위에 이등변삼각형이
# 돈의 같으니까 그럼 우리가이 길을 일이라고는 또는이기도 모가지 당연히 회의가 되겠어
#  그럼 여기는 피타고라스 정리 해서 뭐가 되냐면 루트 a 제곱 + a 제곱입니다
# 결국 루트 a 제곱 y 제곱 이니까 내가 빠져 나와서 루트 2에 2가 된단 얘기야
# 아 결국 우리는 여기에서 직각이등변삼각형 오는 길에 bada0228 일대일 대로 트이고
# 그로 인해서 우리는 삼각비 세 개 싸인 45 도와 코사인 45도 와 탄젠트 45도의 값을 생각해보면 그러면 45도에 대해서 싸인 값이 결국 뭐가 되냐
#  빗변분의 높이죠 마주보이는 괴롭히니까 걸그룹 애입니다 루트 2의
# 그래서 약분 해 보면 루트 2의 일이니까 유리해서까지 갈 수 있고 코사인 45도는 빗변분의 밑변 이겠죠
# 기준 가게에서 마주 보이는게 높이면 요게 편이니까
# 근데 뭐야 루트 2에 2분의 똑같이 애인의
# 그러니까 aaa 라면 루트 2분의 1
# 그래서 2분의 루트 2가 똑같이나요 높이 높이 즉 에이븐의 뭐가대 1 이렇게 남자라는 이야기야
# 이걸 가지고 이제 우리가 나중되면 결론은 못 하겠다 얘기냐면 이런 거 하겠단 얘기야
#  너무 어렵지 않으니까 보세요 45도 직각삼각형인데 이게 네가 3일때 29회 말하는 거야
# 그럼 우리는 한 마디로 이게 빗변이 보이게 기준 가기로 해서 및 편이잖아
#  그럼 코사인 45도 겠죠 코사인 45도라는게 뭔데 뭐야 나 보면 X 분의 3일 거 아니야
#  맞죠 근데 우리는 ex300 값을 알고 있다고 코사인 45도의 값을 알고 있다고
# 되나요 이렇게 해서 여기서 엑스를 구하는 걸 공부하는게 최종 목적이요
# 근데 이렇게 되어 있고 코사인 45도 7시 2분의 루트 이름을 모르면 x의 값을 구할 수 없겠죠
# 그러니까 여기는 아홉 개 숫자를 암기 하셔야 되는데 선생님이 중학교 때가 정말 안개 하는 거 정말 못 하고 싫어했어요
# 그래서 그나마 수학이 좋았었어 왜
#  안 계시더라도 된다 근데 얼굴이 가지고 검색이나 유도과정을 공부하고 나면 언젠가 남기를 할 시간이 오겠죠
# 지금 사인 코사인 탄젠트 35도 60도에 값이 왜 각각 베이블레이드 어떻게 나오는지 설명을 드렸는데 이유를 알았다면 암기를 하셔야 됩니다
# 암기 하는 방법은 어떻게 되냐면 다음 시간에 수영도 하고 라면 이름 되게 좀 더 다시 한 번 설명 드릴 텐데
# 부모는 다 이해해요 부모는 다 싸인 같은 경우에 그 다음 분자는 루트 123 됐나요 루트 123 어렵지 않지
#  루트 1은 일이니까 그냥 우리가 2분의 1로 쓰는 거예요 아 2분의 루트 123 30 40 50 60
# 그렇다면 코사인 같은 경우는 어떻게 된 거냐 거꾸로 하면 됩니다
# 123 갔으니까 3일 2분의 루트 3 2분의 1 루트 1은 1위죠
#  이렇게 써 주면 돼 결국 사인을 써 줄 수 있다면 콜사인은 요렇게 엇갈려서 대각선으로 내려놓으라라는 걸
# 여러분이 생각하지 근데 있잖아
# 탄젠트 같은 경우 이래 탄젠트 45도에 갔을때 일이고 이걸 기준으로 해서 루트 3으로 나누고 루트 3으로 곱해주면 돼요
#  결국 일을 노트 3으로 나눈다는게 뭐야 루트 3분의 일이겠죠
# 이걸 보통 유리의 3분의 2 3으로 많이 되어 있는데 선생님 욕을 쓰는 경우가 조금 더 많아요
#  배달하다 보면 이게 편할 때가 많아요
# 그래서 일반적으로 우리가 술을 쓸 때는 무료해서 쓰기 때문에 이렇게 되어 있지만 루트 3분의 1로 기억해 주시면 더 편하지
#  왜 루트 3 일하는게 이게 좀 더 하다 보니까
# 그저 이쪽으로 루트 3은 얼마 1 * 3은 루트 3 이겠죠 그대 여러분들께서 오늘 끝날 때이 표를 끓여 놓을 수 있으면 돼요
#  어 선생님 중 3때는 이사 안 헤어지면 친구들 있잖아요 그러면 어떻게 되냐면 OMR 카드 있잖아요
#  학교에서 시험 보기 전에 막 최대로 위험한
# 카드를 받자마자 수험번호를 쓰고 뭐 그런게 아니라
#  그 뒤에 주관식 담당자 선택된 막혀서 뒤에 가지고 가실 때 안 다녔는데 거기다가 이토를 갔다 이따 봐 매운 걸 써요
# 그리고서 이제 마음 편안하게 1번문제 속도 풀어나갑니다
# 아 그만큼 여러분들께서이 삼각비 특수 방에서의 삼각비의 값은 반드시 암기가 되어 있어야 돼요
# 배우는 방법 설명 드렸으니까 2분의 루트 123
# 2분의 루트 3 1일을 기준으로 삼는다 루트 3
# 여기까지 여러분들께서 정리할 수 있으면 됩니다
# 이게 그럼 도대체 문제가 어떻게 나온 야 너 이거 왜 왜 해야 되는지 여러분들이 이렇게 나오기 때문에 왜
# 이걸 왜 이런 문제를 해결하고 한번 할 말이 없죠 나와 있는데 어떡해
#  유도 하나요 아니 여기
#  외워서 푸는 거야 싸인 30도 얼마 2분의 얼마 30 40 60 2분의 1 2 3 그쳐
#  코사인 45도 얼마 2분의 루트 45 더 가까운데 인삼에서 이겼네
# 그래서 2분의 1 플러스 되나요 탄젠트 45도 얼마인지 제일 마지막 줄에 가운데 그걸 그대로 루트 3
#  + 코사인 60도 60도 제일 이쪽에 있네 아 루트 3 일이었어 콜사인은 싸인 a1331
#  그래서 여러분들께서 이렇게 외져서 나와야 되는 거야 알겠나요 자 개념확인 1번 문제 없습니다
#  여기까지 해서 간단하게 오늘 배웠던 내용에 대해서 이런 문제를 우리가 다른 거야
# 근데 이것만 잊지 않겠죠 왜 가지고 이것만 풀지 않을 거야
#  다양한 문제들을 살펴봐야 되는데 이제 예제문제 한번 시작해 보도록 하겠습니다
#  어 선생님 이런 문제 안 나온다 어 그냥 외워서 쓰는 거
# 근데 한 번쯤은 여러분들을 여러분들께서 왜 왔는지 다시 한번 확인하는 그럼 문제입니다
#  그래 가끔 이런 문제점을 출제되기도 합니다 여러분의 잘 틀리지 않아요 성실히 왜 없다면
# 같이 함께 3일권을 볼텐데 탄젠트 45도 얼마 했어요 표를 머릿속에 그려 봐
# 여러분들의 연상을 해서 배울게 아편전쟁 마지막 드렸지 45도는 가운데 어찌 그럼 뭐가 떠올라 가야 돼 가야 돼
# 루트 3 나누기 했던 걸 기억해 야죠
# 이런 소리 런드리 표를 9 케이스 닫았을 수도 있지만 머리속에 이미지를 그려놓는 연습도 중요합니다
# 그다음 싸인 60도 셔틀이 뭐더라 2분의 없고
#  루트 1 2 3인데 60도가 제일 끝이 없으니까 2분의 1 2 3 이게 떠 이런 식으로
# 머릿속에 뭔가 생각을 정리한 아니에요 두 번째 탄젠트 30도
#  마지막 줄에서 30도 뭐였더라 가운데가 일이 없고 루트 3은 뭐 했었어 나눴어
# 루트 3분의 1이 없구나 이렇게 늦나요 곱하기 코사인 60도 코사인 중에 제일 큰 거
# 근데 프사에 있는 노트 3 2 1 거꾸로 갔으니까 와 2분의 이게
# 이렇게 가는 거죠 계산해 보면 2분의 루트 3 +
# 4 6 2 우리가 유리 해볼까 루트 3의 루트 3 4 작곡 해 볼게요
# 3 9 4 루트 3 이적 3분의 2 루트 3 곱하기 2분의 일이니까 6분의 높은 사람이 돼서 결국 유튜브로 통보해 보면
# 6분의 1 2 3 + 6 9 4 루트 3이니까 6분의 1 2 3 4 루트 3의 약불에서 3분의 2 1부터 30까지 여러분들이 답을 써 주면 되니까 3번이다
# 이렇게 이제 1번을 하면 됩니다
# 사실 여기 뭔가 복잡한 일이 있어서 있지만 실제로 하는 건 뭐야
# 45도 60도 30배 60배 대한 사인 코사인 탄젠트 값을 넣어서 써 준 다음에 이게 끝입니다
# 이런 문제가 나올 수 있단 얘기야 왜 안 해 그러니까 여러분들께서 외워야 돼요 아셨죠
# 가능하면 미안해요는 싹을 지향하지만 좀 암기할 부분이 있습니다 이런 건
#  다음으로 2번 문제 한번 들어가 보겠습니다 그래요 이거 하고 싶어요 오늘 배운게 이거 하려는 거야
#  그림과 같은 직각삼각형의 MBC에서 지금 빗변의길이 교육이고 길이가 3일이야
# 각의 크기를 구하세요 있습니다 자 요렇게 하면 나올 거야 지금 빗변의길이 갖추어져 있는 거야
#  우리 둘이 하는 거야 비를 봐라
# 이거 어떻게 하란 얘기지 문제에서 이건 뭐죠 기준과 기준으로 봤을 때
#  마주보이는 높이 2분 데가 그림이 우리 애기 알려 주는 건 빗변과 높이를 알려 주고 있는 거네
#  기준가게 대해서 빗변과 높이가 뭐였더라 아 싸인 이었어 빗변분의 높이가 싸인
# 싸인 비가 뭐 보내 보라고 북변 무네노 피었어 6분의 3이야 6분에서 하면 뭐지 2분의 1 딱 써 놓고 보는 거죠
# 하는 순간 척하고 지나가야 돼 꼭 싸인 뭐가 이쁘냐 이제 딱 떠 올려야죠 뭡니까
# 쌓이는 2분의 루트 2분의 루트 3 4일 몇 도가 30도가 2분의 1이 줘
#  아 여기서 우리는 뒤에 값이 얼마나 많은 걸 할 수 있어
#  30도라는 걸 알 수 있다 정답은 3번 이렇게 하고 싶은 거예요 외로워서 무슨 약이죠
# 3번으로 한번 들어가 볼 텐데요 애들 한번 문제를 조금씩 조금씩 이제 다른 유형들이 나오겠죠
# 삼각비를 이용하여 변의 길이 할 거야 가기 지워져 있잖아
#  조금 전 문제는 두변이 좋아지고 갖고 가라는 거였죠
# 이 문제를 별 하나 있고 다른 변의 길이를 구하라는 이용해요
# 생각비디오 갈 거야 왜 상각비는 주변 사이에 길이비율 우리에게 알려 주는 거니까 그죠
#  그러면 각시가 30분이고 시간 있을 때 뭘 바라겠어 하래요 찾아볼 거야
# 지금 30돌 알려 주고 있네 이게 기준 가기라고 바라보면 우리나라 마주 보이는게 뭐였더라
# 지난 시간에 중간에서 마주 보이는게 높였어요 맞죠 집 가게에서 마시고 있는게 뒤 편이니까 자동으로 이거 뭐가 돼네
# 편이야 그러면이 문제는 이런 얘기네 얘기를 높이를 구하라 내리고 추워져요 밑변이네
# 그럼 우리는 출근하는 거야 3가 가는 거야 아 뭐라고 높이가 버렸지 밑간하고 높이 탄젠트 아 맞아 탄젠트가 탄젠트 기준가게
# 탄젠트 30도가 밑변 무네노 피었어 6노트 2분의 1이 없어이 얘기야 뭐야 이거 뭐야
# 그럼 이거 숫자네 이것만 숫자 하면 되는 거잖아 그죠
#  근데 탄젠트 30도가 뭐야 루트 3분의 1 또는 산불에 부산대입학 오시면 됩니다
# 그럼 우리는요 등식에서 양변에 주변에 이비인후과 할 수 있을 거고
# 결국 루트 3분의 1 * 6 루트 이니까 이런 계산이 저 이제 서유리야까지 해 줄 거고 보세요
# 3분의 유빈이가 약불에서 뭐가 돼 3분의 2 6 이 남으니까 2 2 2 2 3은 6 이렇게 여러분들께서 apa 길이를 구 한다라는 이야기야
#  할 수 있겠죠 아 그러니까 우리가 사인 코사인 탄젠트 35도 60도에 값을 알고 있다
# 그래서 그것에 의해 싸인 30도에 대해서 비평과 높이의 빗변과 밑변에 비밀 높이에 b
# 42 코사인 탄젠트 30도이 값을 안 달리기가 바로 그것은 의미하니까 삼각비가 줘 될 거라 또는 삼각비가 꼭 아니더라도
#  사인 코사인 탄젠트 값이 아니더라도 어떤 특정한 처지면 우리는
#  그걸 통해서 밑변과 높이 밑변과 빗변 빗변과 높이 4m의 비디오를 알 수 있단 얘기야
# 사인 코사인 탄젠트 것을 정확히 얘기하면 그죠 그래서 문제에서 구하라고 하는지를 구해 낼 수 있다라는 거
#  그게 바로 오늘 공부할 확실하겠죠 그러니까 이런 복잡한 문제를 풀기 가장 먼저 할게 뭐라고요
# 사인 코사인 탄젠트 35도 60도 암기 되어 있어야 돼요 이제 유지 한번 시작해 보겠습니다 나 첫 번째 보겠습니다
# 첫 번째 여러분들 이건 그냥 대입하면 되겠죠 배가 우리가 이런 분들 가볍게 풀고서 가도록 하겠습니다
# 그런데 단지 분수로 돼 있어서 조금 번거롭지 이럴 때는 그냥 부모 따로 한번 문자 따로 이렇게 생각해 보는 건데
# 저리 분모를 생각해 볼게요 등록 14분 모레 루트 3 * 탄젠트 30도 얼마입니까 그러셨죠 루트 3 부 자로
# 약불에서 그대로 부모가 아이고 너무 좋다 부모가 1위는 뭐가 가능해
# 생략이 가능합니까 그냥 문자 보면 되는 거야 그래서 그냥 바로 합시다
# 작품이다 사인 45도 2분의 루트 2 더하기 코사인 45도 2분의 루트
# 이거 이제 선생님이 뭐 가운데 있는 거 이거 안 할 거예요
# 그러면 안 돼 있어야 돼요 - 탄젠트 60도가 루트 3 였죠
# 아 이걸 계산해 보면 결국 2분의 루트 또는 이거 이렇게 붐볐다 주면 루트 2 더하기 루트 이니까 2루트 잊어
# 그리고 그 뒤에 - 2 3 그대로 다빈이
#  이건 그냥 우리가 머릿속에 외워져 있기만 하면 뭔가를 이해하고 논리적으로 생각하고 1월 필요 없이 그냥 계산해 주면 되는 형태입니다
# 첫 번째로 이렇게 문자를 이렇게 마무리가 되고요 다음 이번 들어가 보겠습니다
# 자유재 이번 여러분들 가나다에 알맞은 이거 왜 언니라고 대놓고 못 문제죠
# 어떻게 됩니까 사인 코사인 탄젠트 45도 60도 2분의 1 2 3 2분의 루트 3 1 3 루트 2
# 루트 3 루트 3 됐나요 이거 뭐 따로 설명할 수 없지 뭐 이런 부담 계셨다면 바로 해결이 가능합니다
#  이제 조금씩 중요한 문제가 나오겠죠 삼번으로 들어가 볼 텐데요
# 오른쪽 그림과 같은 직각삼각형 ABC에서 길이가 3루트 17일 3가 상두트
# 여러분들 모두 하고 싶다 지금 막 이거 구하고 싶다 왜
# 우리는 직각삼각형에서 피타고라스 정리가 너무나 익숙하게
# 그런데 가게에 크기를 바라는데 그럼 우리는 지금 그거 구할 필요가 없는 거야 에이스를
# 왜냐하면 A6 거라는 말도 없어요 두 번만 나와 있으면이 두 변의 길이의 비를 씻고
#  그게 가게 입장에서 보면 높이가 나와 있는 거죠 밑변이 주어져 있는 거죠
# 그럼 머리 속에 누가 스쳐 지나가는 빗변과 높이 밑변 분의 높이는 탄젠트 였지
# 애기가 몇 도인지 모르겠지만 탄젠트 애인은 우편물에 높이를 의미에서
# 밑변이 3 루트 625 높이가 3루트 2 아 일단 이거 좀 간단하게 모양을 만들어 볼까
#  이게 루트 3분의 1 1 1 이래 이거 왜 없는데 이렇게 나와야 되는 거야 탄젠트 몇 도가도 비상도
#  글자 30도가 아 얘가 30도구나 이걸 9월 한 이야기가
# 결국은 우리는 마지막에 이게 외워져 있어야 문제를 해결할 수 있는 거긴 하지만 결국 탄젠트 A라는게 꺼지면
#  아기 종각 잊어버렸는데 지금 나와 있는게이 두변이 야
#  이제 우리는이 두변이라는 말을 밑변과 높이가 주어져 있어로 바꾸는 작업을 할 수 있어야 되는 거야 왜
#  기준가게 대변이 높이니까 이별 아닐테니까 당연히 몇편 이게
# 이렇게 얘하고 얘 가지고도 있어라는 말을 뭐가 밑변이 뭐가 노페인 지
# 금 밑변과 높이가 의미하는게 그들의 비가 코사인 탄젠트 중에 탄젠트로 연결되는 이런 작업들
# 그다음에 암기 되어 있으면 끝나는 겁니다 아셨죠 3번 문제 3번 4번 문제로 들어 가야 되겠죠
# 자유의사 번 들어가 보겠습니다 어려워 보이죠 굉장히 간다네요
# 우리는 단순화시켜서 싸인 몇 도가 2분의 루트 3인지 만한게 되어있어 해결할 수 있어
# 쌓이는 순서대로 2분의 루트 123 이었어 2분의 루트 3은 그러면 결국 까인 60도에 값이 2분의 루트 3 이어질
#  아는 것만 여러분들이 외워져 있다면 똑같고 싸인 싸인 똑같으니까 아 익스플러스 25도가 60도구나
#  이것만 알면 끝나겠죠 여기서 x
#  3 x가 15도 이상에서 45 도니까 양변 삼으로 나누면 엑셀 크기는 몇 도가 된다 25도가 된다
#  사이인지 여러분들께서 확인까지 끝나는 겁니다
# 똑같이 외우는 거 들면 안 유재 3번과 4번 중에서 선생님은 유재 3번이 조금 더
#  그래도 조금 더 생각할거리가 있고 좋은 문제여
#  이런일이 복습 하시더라도 신경 써서 이제 3번 봐 주셨으면 좋겠습니다
# 이제 마지막 내용에 대해서 두 개 유지가 남아 있는데이 두 개 유제는 오늘 선생님이 강조하고자는 모든 내용
#  오늘의 어떤 핵심 이것만 하면 끝나
#  이렇게 생각하시면 돼요 5번 서부터 한번 소리를 들어가 보도록 하겠습니다
# 오늘의 어떤 모든 내용이 이제 요번에 들어가 있다 바라보고
# 오른쪽 그림과 같은 직각삼각형 ABC에서 각 B가 60도 B 씨가 5일을 구하라 그냥 b c a b 이렇게 생각하는게 아니에요
# 이게 되잖아요 삼각비를 그랬잖아 기준가게 60도가 낮춰도 있는 거예요
# 그러면 마주 보이는게 높이 잖아요 이게 몇 번이죠 이건 뭐야 빗변 잊어
# 그럼 우리는 뭘 생각하는 얘기야 아에이 비를 구하라는 그래 변을 구하는 얘기고
#  주어져 있는 건 기준가게 대해서 밑변이 적어져 있어
# 그럼 내 머릿속에선 민병갑 빗변 사이의 관계가 뭐였지를 떠올리게 되는 거야
# 김병각 있던 코사인 코사인 2코사인 몇 호 특히 여기 중간에 60도가 코사인 60도 감원에 뭐예요
#  노래 밑변 이었어 빗변분의 및 편이었어 8분의 모여 BC 그러면 이거 어떻게 되지
# 이거 하는 거야 일단 그저 이게 문자요 숫자 자나 코사인 60도 뭐였더라
# 코사인 60도 이거 왜 그랬어요 2분의 일입니다 그러면 끝나자 왜 아 여기에서 이거 하면 돼
# 이렇게 보면 애비가 결국 뭘 한 얘기에요 12입니다 다니고 있죠 10cm
#  이렇게 여러분들이 구하면 끝남
# 이 문제 오늘까지 지금까지 공부한 거 중에서 꼭 한 문제 숙제 해야 된다 그러면 이제 5번 나올 수 있겠죠
# 자유재 6번 여기서 조금 더 올려 보도록 하겠습니다 먼저 그림이 좀 복잡해
#  여기서 잘게 보도록 할게요 제가 그림의 삼각형 abc에서 h 하고 비치가 서로 3
# ah 하고 bc857 여기가 90도인 거 몰라요 지난 시간에 배웠던 직각삼각형에서의 닮은 아니에요
# 90도 란 말 없습니다 60도 45분이면 그리고 당연히 이거 90도 아닌 것처럼 줄 알 수 있죠
# 이 그림을 여러분들이 바라볼 때 어떻게 바라봐야 되냐면 삼각형 abc가 보입니다 나가면 안 되는 거야
# 이도영 문제 잘 푸는 그래 아이 그림은 삼각형 abh 하고 AHC가 A7 공통으로 해서 붙어 있는 겁니다 해석해야 돼 되나요
#  그러면 문제 수고하고 자는게 지금 cha 우리는 생각해 보는 거지
#  내가 어디까지 가야지 27일 구할 수 있지 시리즈를 구하고 싶다 난 거 이거 오늘 잘 보세
# 위치를 구하고 싶다라는 건 일을 잠깐 하고 나올게요 이걸 관련 뭐라 해야 되지
# 일단이 쪽에 있는 삼각형에서 이번일은 이번일은 알면 돼 맞죠 그래야 뭐 코사인 45도를 쓰던 할 거거든
#  근데 입원보다는 누가 먼저 구해 줘 이변이 구했죠 왜이러니 구했죠 이쪽 삼각형을 이용해야 되니까
#  맞죠 이쪽에서 올 거니까 요게 공통 이잖아요 지금 h
#  h를 통해서 c719 할 건데이 문재인 그래도 좀 쉬운게 여기 45
#  드리고 여기 90도 맨 여기도 몇도 45도 무슨 삼각형 AHC는 이등변 삼각형 에이스도 따라서 뭐가 돼 엑스가 돼 아하 되네 그럼 남자 엑스로 갈 거야
#  어떻게 이제 왼쪽으로 넘어서 보는 겁니다 아 이쪽에 있는 위치에서 보니까 지금 요가 60도 나와있네
# 마주 보이는게 뭐야 높이 높이 가져와서 있는 거래 높일 구하고자하는 거네 그죠 그 밑변이 주변에 있는 거야
# 아 밑변 하고 높이 아 그래 아 어떻게 생각하면 돼
# 탄젠트 60도가 밑변 불에 높이는데 그게 사브레의 싸라는 이야기죠
# 그냥 여기서 우리는 엑셀 구할 수 있고
# 탄젠트 60도가 루트 3이니까 이렇게 써 주면 내 배에서 x의 값은 하루 2 3
# 그게 지금 Ah인데 HC 하고 캐리가 갔겠죠
# 이등변삼각형이 없습니다 따라서 4루트 3cm 이렇게 여러분들께서 답을 구해 주시면 됩니다
# 이렇게 오늘 교재 있는 전체 문제는 마무리가 되었습니다
# 영숙씨 2학년 때 선생님이 그런 친구들을 선생님 수고 한국에서 제일 많이 여러분들이 좋아했던게 중계역
# 보통은 수업 자꾸만 이런 거 좋아하는데 우리 제자들 훌륭한
# 선생님이 막 그 있죠 선택 천문대 체험 이제 막 이런 거 어려운 문제
# 굉장히 여러분들이 습관 위에 좋은 글 많이 써 주셔서 3학년들이 의사 선생님이 준비를 했습니다
# 궁금하시죠 함께 오늘의 문제 시작해 보겠습니다 자손이 때문에 쉬면 돼 첫 번째 문제 함께 보도록 하겠는데요
# 이첩 번째 문제는 조금 전에 풀었던 이제 마지막 문제 하고 유사한 형태입니다
# 함께 문제 해결 해 보도록 하겠습니다 그림을 딱 그 느낌이 전혀 다르지
# 그림만 조금 바꾸면 우리는 다른 문제라고 생각하기 쉬어요 그런데 문제 흐름이 같아요
#  느껴봅시다 6이고 지금이 그림을 보고 여러분들 해야 되는 거야
# 이거 90도 90도 45도 알겠어 중요한게 뭐죠
# 이 그림을 여기 있는 삼각형 abc 하고 또 하나의 삼각형 여기는 DC 비가 누구를 B 씨를 공통으로 해서 있는 거야
# 그러니 2 2 삼각형을 연결하는 누구야 B 씨가 포인트야 이걸 여러분들이 생각해야 돼
#  그니까 나는 이쪽에서 이렇게 넘어가려면 다리를 건널 때 B 씨를 구해 봐야지 넘어갈 수 있다
# 이걸 생각하면서 문제를 읽어 볼게요 비밀이 뭐야 되잖아요
# 그쵸 2함대 오른쪽에 있는 이상 가평에서 빗변을 구하는 얘기야
# 그러면 일단이 삼각형에서 어느 별 일은 이거든 이거거든 하나 알아야 된다 그래야 빗변을 구하겠어
# 그럼 당연히 이걸 구하라 아니죠 B 씨를 왜 하얀색 써 넘어가야 되니까 그러면 보는 거야
# 아 기준각 60도 잖아요 그럼 지금 마주 보이는게 높이죠 하얀색 이상 그죠 이거 밑에 편의점
# 아 그럼 이별의 높이는 모였어 탄젠트니다 아 그럼 탄젠트 60도가 5분의 뭡니까 6분의 비씨 다
#  여기서 우리 좀비 씨를 구할 거고 루트 3이니까 6대 주면 B 씨는 결국 뭐가 돼
# 노트 3의 될 거야 이렇게 B 씨를 구하는 단계가 들어가야죠 그러면 이제 그 다음 오른쪽으로 넘어올 수 있겠네
# 다리 건너 목사 비리 바라겠습니다 어 그러면 기준각 45 돼서 이제 그만 보세요 빗변을 구하라
# 기준각에서 마주보이는 뭐가 젖어있어 높이가 있는 거야 됐나요 아 그러면 빗변과 높이는 뭐였더라
#  빗변과 높이 높이 아싸인 이었구나 싸인 45도가 오븐에 보여 백변 BDP 높이가 누구예요 지금 노트 3 있잖아 그래서
#  거기서 비닐을 가면 되는 거야 아 그러면 싸인 45 2가 2분의 루트 이적 요거 왜 또 오늘 별로
#  이렇게 해보면 투입 위치는 이렇게 곱하면 3 이적
# 여기서 양변 루트 2로 나누고 연습 쌍계사 아니니까 여러분들이 쭉쭉 해 나갈 수 있으면 됩니다
# 그래서 대답이이는 결국 뭐가 될 거냐면 2분 의약품 되면은 2 3일은 이렇게 답을 구하시면 끝나는 거예요
# 이건 할 수 있겠죠네 오늘이 문제 2 하잖아요
#  그러면 학교 시험 끝난 거예요 일단 학교에서 나올 수 있는 일이 삼각비 아파트에 대한 문제는이 문제 하나로 다 끝난다
# 가보겠습니다 삼각형 abc에서 A B가 6이고 구미 다 bh가 30도 1대 탄젠트 엑셀 값
#  결론이 나와 있어 탄젠트 엑스를 우리는 당연히 직각삼각형 여기에서 탐정 팩스를 구할 거고
#  몰고 하란 얘기야 별로 써보자 탄젠트 x 기준 가기 거야 마주 보이는게 높이
# 이게 밑변 인덱스는 노래 소피 Ah 분에 뭘 바라냐 ch19 하라는 거야라고 결론을 정해 놓고
# 그럼 어떻게 구해 어렵지 않네요 선생님이 삼각형에서 오면 돼 맞아요
# 그럼 이게 중요한 거 아니에요 계세요 제가 좀 어렵습니다 그러면 우리는 h는 어떻게 하면 되냐
# 기준각 30도에 대해서 빗변을 알고 있고 밑변을 구하고 자는 거 좀
# 가지고 있는 괴롭히니까 결국 6분의 Ah가 뭐예요 코사인 30도입니다
#  그러니까 아 양변에 여섯대 주면 a h는 6 코사인 30도 가야 돼서 결국 뭐가 돼 3 루트 3 시까지 올 수 있어요
#  아 Ah가 나는 분모는 해결했어 이제 분자 c79 하는게 목적이 야
# 근데 우리는 스위치를 어떻게 구할 수 있느냐 스위치를 선생님 여기서 피타고라스적 있으면 되나요 예 피타고라스 정리 써도 돼요
#  구해볼까요 어 어떻게 구할 수 있어 루트 제곱 - 다른 변의 제곱 981 -
# 3 루트 3의 제곱은 27 이니까 루트 54가 돼서 54는 954 살루트 6가지 갈 수 있는 거잖아
# 스위치 끝났네 CH 뭐라고요 3 루트 6 결과를 루트 2 이렇게 여러분들께서 답을 구하는 겁니다
# 저는 없더라고 공부했던 내용 중에 핵심은 당연히 사인 코사인 탄젠트 35도 60도에 값을 메우는 거였고
# 마지막 유형 있죠 그리고 오늘 최 문제까지 선생님이 여기까지 어떻게 할 수 있다면 여러분께서 학교시험에 대해서는 일단 오늘 확실하게 끝냈다라고 자신있게 말씀드립니다
# 공소외 1 내용 함께 정리하고 마무리 합니다
# 오늘 함께 정리할게요 싸인 30 40 50 60 각각 2분의 루트 13 올라갔으면 됐어
#  코사인 거꾸로 내려왔죠 2분의 1로 이겼습니다 자판 제임스는 3분의 2는
#  위례에서 3분의 부산에서 루트 3 10회 나간다 반드시 부탁드릴게요
#  자스민 조금 아까 숙제로 여러분들께 내 드린다라고 말씀드렸던 문제 기억하시나요 이따 마지막 유세 문제
# 여러분들 반드시 체기를 구하는 순서까지 한번 어떻게 풀어 나 답이 아니고요
#  흐름을 남겨주시면 여름휴가 선생님이 소풍에 굉장히 되겠네요
# 오늘 수고 많이 하셨고요 다음 시간에 또 열심히 준비하도록 하겠습니다 다음 주에 뵐게요

# %%
print(STT2_entered)
# Out:
# 방법 순간에 BEST 여러분들 중학교 일 연속 삼 학년 하에 선석 명입니다.
# 자연스 지난 시간에 우리가 삼각 비리에 뜻에 관련해서 공부했습니다.
#  쌓인 COULD SIGN THAN 센트 값이 각각 무엇을 의미하는지.
# 즉 빚 변, 불에 높이 빛 해변 불에 및 변 변 불이 높이가 각각 사인 고 쌓인 탄생 을 기준 각이다 라는 걸 이야기 있는데요.
# 기자 오늘 공부할 주제는 딱 한 가지입니다. 바로 삼십 도 사십오 도 육십 도 우리는 이 각 들을 특수한 각이다 라고 이름 지었어요.
#  이 가게에서 의 삼각 비리에 값을 알아볼 거고, 선생이 원래는 외우는 수확을 여러분께 별로 이렇게 그런 강의를 안 하려고 하는 편인데
# 이감 들은 여러분들이 암기를 하셔야 해서 암이 하기 쉬운 방법까지 선생님 제시해 드릴 테니까 오늘 수업이 끝날 때쯤에는 여러분들께서 쌓인 고 사인 텐센트 삼십 사십오 도 육십 도의 값이 암이 비어 있으면 되겠습니다.
# 같이 함께 시작해 보도록 하겠습니다. 중 삼 수학 끝내 봅니다.
# 오늘 함께 공부할 내용은 한 가지요 크기가 삼십 도 사십오 도 육십 도입 가게 삼각 피해가 비록 있죠.
# 이 내용을 공부하게 앞서 선생님과 한 가지 이야기
# 지난 시간에 박사인 국산 텐센트 기준 가기 어떻게 이 편이 모으고 밀어내기 있잖아요.
# 근데 아마 배우면서 그렇겠죠. 그런데 SQ 내지는 여러분이 생각할 수 있을 거예요.
# 선생님, 왜 변의 길이가 인데 그걸 각으로 표현을 해요. 쌓인 A SIGN UP 사이 이십 위에 쌓인 뒤 가기 됐나요? 이런 질문을 여러분이 할 수 있을 것 같아요.
# 약속이 하라고 하고 그냥 넘어가기 합니다만, 조금 더 살짝 깊이 있게 우리가 살펴봅니다.
# 기자 우리는 삼각형의 어떤 도용해 갖는 성질이 있는데 기본적으로 하나 정도 느낌 만 보겠습니다.
# 여기에서 여기에서 기각을 내리라고 해 봅니다. 기준과 이름을 이야기하고자 하는 게 아니에요.
# 기본적으로 어떤 도용해 갖는 성질이 삼각형 즉각 생각해요.
#  만약 이 어떤 가기 A 가 기준 가기 커진다는 것은 무엇을 의미하는가 라는
# 왜 각하고 변해 길이 비가 연결돼 있지? 라는 느낌을 여러분들이 가져야 돼요.
# 우리가 여기 있는 주황색 삼각형을 보면 하얀색 삼각형 과 이 뼈는 변함이 없죠.
# 근데 가기 기준, 가기 변한다는 것, 어떤 것들이 변화나 살펴봤더니 강남 변하는 게 아니라 각을 변화 시키면 높이 도 하얀색 보다 주황색 이 변해야
# 길어지자 빚 변의 길이가 어떻게 되죠? 치러집니다. 결국 변의 길이는 가계 크기의 역량을 받아 안 받아 받아요. 됐죠?
# 그래서 우리는 삼각 비 쌓인 고 사인 TONS 특위에 각을 없는 거예요. 그런데 이렇게 변함에 따라서
# 모터 작은 것도 있겠죠. 물론 이렇게 돼 이렇게도 있을 거예요.
# 이렇게도 있을 텐데. 이 가게 변화에 따라 및 변 불이 높이 라든가 빈병 분에 높이 라든가 빈병 분에 및 변의 길이의 이 들이 마구 변화가 생기게 했죠.
# 맞춰 여러분 이렇게 왔다 갔다 하면서 머릿속에서 그려 보세요.
# 만일 그려보는 사이사이에 있는 걸 막으려 보면 길이 이 들이 계속 변하고 있어요.
# 이중에 몇 개의 각 들이 의미 있는 숫자를 갖는다. 란과 비가
# 예를 들어서 이거 그레이가 했더니 영접 삼십육 칠 팔 일 말고요. 좀 더 의미 있는 것
# 주로 무리수를 이용해서 표현이 되는데 그 의미 있는 각을 값을 갖도록 하는 가기 바로 삼십 사십오 도 육십 도 일 때다 라는 이야기가
# 그래서 우리는 이걸 갖다가 특수한 각이다 라고 이야기합니다.
# 특사가 이라는 게 못하게 특수한 이상한 게 아니라 의미 있는 길이를 우리에게 기대에 비를 제시해주는 게 바로 특수한 각 이고, 우리는 그 의미는 비를 외워야 되는 겁니다.
# 그러면 우리가 개념을 한번 보도록 하겠습니다.
# 그래서 삼각 이라는 게 변해 길이 인데, 왜 각하고 연결돼 있나?
# 가기 변하면 기준 가계 변함에 따라 변의 길이의 비가 편하니까.
# 그중에 의미있는 가기 의미 있는 가계의 의미 있는 게 아니라 변의 길이의 비를 의미 있게 하는 가기 삼십 사십오 도 육십 도달하는 이야기다
# 하셨죠. 우리는 기준 가기 삼십 도일 때의 세 변의 길이의 피를 먼저 살펴보겠습니다. 기준 가계 삼십 도를 이렇게 하면 그림을 나부끼고
# 처음엔 이렇게 여러분들이 그려 보겠죠. 여기서 이 같은 삼십 도가 이렇게 가보겠습니다.
# 시각은 자연스럽게 육십 있죠.
# 선생님, 여기서 기준 갑을 삼십 도 라고 났을 때 저는 쌓인 삼십 도를 구하고 싶어요 라고 생각해본다면 결국 이 변 분에 높이 적
# 기준과 에서 마주 보이는 높이 니까. 근데 이기려고 일일이 비를 어떻게 할지 아무 정보가 없는데.
# 그런데 우리는 그 정보를 만들어낼 수 있습니다. 어떻게 만들어낼지 잘 보시기 바랍니다. 우리가 주변을 A 다 라고 잡았고,
# 금 이변은 뭐가 될까? 아직은 모르죠. 그런데 뒤집어서 하나 더 붙여 보는 겁니다. 이렇게 이렇게 됐네요. 이게 일 직선이 되도록
#  그러면 선생님, 이걸 뒤집어서 붙잡기 때문에 이 기기가 해임 연 이 길이도 에 이어
# 근데 이 가게 육십 도니까 뒤집어서 일각의 육십 도가 되거든요. 그러면 육십 육십 도면 이것도 육십 되잖아요.
# 무슨 삼각형의 정상 가평의 됩니다. 그러기 때문에 욕이 리가 이해하면 이십이 도 이해가 됩니다.
# 까지 여러분들이 생각할 수 있으면 되는 거예요. 그렇다면 이제 그림을 다시 달라서 이렇게 보겠습니다.
# 우리는 피타고라스의 정리 에서 이 길이를 구할 수 있을 테고,
# 루트 EA 의 재고 배기 A 제고, 계산해보면 루트 EA 의 제보는 사회의 제곱 배기 A 제곱 루트 사회의 제거 기구나 그러니까 A 는 노트 밖으로 나가서 노트 삼 의 있구나.
# 이렇게 여러분들이 이 길이를 표현할 수 있다는 얘기죠. 결국 아, 잘 들어보세요.
# 한 내각이 삼십 육십 구십 돈이면 제일 잘 분변. 두 번째로 긴 변 빚 변의 길이의 비는 A 대 무 투사 의 이 대 이 회의가 항상 성립하는.
# 삼십 도로 시작하는 이 가계에 대해서는 어떤 삼각형, 있은 어떤 중요한 게 직각 삼각형의 들이 당연하죠.
# 아, 빚 변 과 높이의 비가 EA A 즉 이 대 일, 이 대 일, 이 대 일 의 다 된다는 겁니다.
# 그렇다면 우리는 그것을 정리해서 뭐라고 이야기할 거냐?
# 기준 각을 삼십 도로 봤을 때 쌓인 삼십 돈은 결국 빚 변 분에 높이 니까 EA 분에 애인 이 분의 일 이 된다 라는 이야기가
#  오늘 특수한 각 이라는 건 의미가 처음에 뭐라고
# 각 자체가 특수한 게 아니라 변의 길이의 비가 의미있는 숫자로 나오는 게 특수가 이라고 했어요.
# 삼십 도 같은 경우에는 쌓인 삼십 도가 뭐가 돼 이 분의 일 영접 으로 이렇게 깔끔한 수가 나온다는 이야기다.
#  즉 빚 변 불이 높이가 이 분의 일, 일 대 이, 이 대 일 의미 있는 숫자가 나온다는 얘깁니다.
# 그렇다면 우리를 여기서 고 쌓인 삼십 도로 생각할 수 있겠죠. 고 쌓인 삼십 도 모가 돼 빚 변 분에 및 변 되겠죠.
# 기준가 에서 마주 보이는 게 높이 왔어요.
#  지난 시간 빚 변 분의 이 편을 이 A 분에 노트 삼 의 이니까 약 분해 보면 AA 에서 이 분의 노트 삼 이것이 바로 것 쌓인 삼십 도에 값이 됩니다.
#  마지막으로 단 젠트 삼십 도에 값은 그런 뭐가 되라고 살펴보면 탄생 을 삼십 또는 및 변 불에 높이지 않아요.
# 두산 A 분에 A 니까 A 약품 하고 나면 루트 삼 분의 일 또는 유리하 에서 삼 분의 이 두 삶의 된다라는
# 그 오늘 결론은 분야 여러분이 쌓인 삼십 도 얼마나 그러면 이번에 나와야 한다는
#  고 쌓인 삼십 도 얼마나 이번에도 듯한 나와야 하는 거예요. TONS 삼십 도 얼마 삼 분의 이 삼
# 이렇게 바로바로 나올 수 있게끔 감기가 되어 있는 게 오늘의 결론 마지막 해야 할 일입니다.
# 잡혀 타면 이제는 이 그림에서 기준 각을 육십 도로 바꿔보겠습니다. 그에게는 몰고 하겠다는
#  쌓인 육십 도 COULD SIGN 육십 도 CONSENT 육십 도의 값을 우리는 알아보자 라는 이야기 있죠. 잘못으로
#  기준 가계 이쪽으로 바뀌면 마주 보이는 별이 모가 돼 높이가 되고 이변은 및 변 이변이 불편. 지난 시간 내용이
#  그렇다면 사인 육십 도라는 건 빚 변 불에 높이 빛 변 불이 높이가 보여야
#  EA 분에 루트 삼 이렇게 됐겠죠 이 AV 노트 삼 의 이니까 A 약 끝나면 이 분의 노트 삼 의 바로 쌓인 육십 가깝습니다
# 암이 하셨어요 고 쌓인 육십 또는 그런 뭐가 될까 빚 변 분의 이 편이니까 이 A 분에 레이저 결국 부과될
# 이 분의 일 탄중 투 육십 또는 및 변 불에 높이 니까 A 분에 노트 삼 이렇게 됐겠죠
#  에이브 내일부터 삼 A 는 결국 AA 약품 라면 두 사람이구나
# 단 젠트 육십 도 기준과 육십 도의 대해서 및 변 불이 높이를 노트 삼 가
# 일대에 부터 삼 대첩 이렇게 여러분들께서 일대에 부담하고 암기를 해주셔야 된다니까.
#  그렇다면 사십오 도 아직 빠져 잖아요. 사십오 도의 대해 한번 알아볼까요?
# 여러분은 좀 더 입혀 다시 한번 보여드릴 거니까 지금은 지우 하셔도 상관없어요.
#  기자 삼십 도 육십 도 구십 도 일대 새벽에 길이의 비는 조금 구하는 게 뒤집어서 붙이고 좀 복잡했다. 몇 사십오 돈은 조금 쉽습니다.
#  차 즉각 삼각형 인데 한 내각이 사십오 도다 라는 말은 여기서 새벽 사이에 길이 비를 우리가 공부 하겠다는 거예요.
# 그런데 이 길이 이 각이 사십오 도민이 각 자연스럽게 받거나 사십오 도 나오잖아요. 그러면 결국 모르니 이등병 삼각형의
#  두 내각이 같으니까 우리가 이 길이를 일이라고는 또는 A 라고 노면 이기도 먹었을 당연히 얘기가 되겠죠.
# 금요 기리는 피타고라스의 정리해서 뭐가 되냐 하면, 루트 A 지급도 A 직업입니다.
#  결국 루트 모델이 되고 이에 제곱 이니까 A 가 빠져 나와서 루트 A 가 된다니까
# 결국 우리는 여기에서 즉각 이등병 사각형 은 길이 비가 AD. AD FTA 즉 일 대 일 대 루트 이고
#  그로 인해 우리는 삼각 비 세계 사인 사십오 도와 고 쌓인 사십오 도와 톈진 을 사십오 도의 값을 생각해보면 그러면 사십오 도의 대해 쌓인 값은 결국 뭐가 되냐?
# 빚 변 불에 높이 저 마주 보이는 게 높으니까 결국 루트 AA 분에 열립니다. 루트 이 A 분에 셰이
# 크에서 약 군의 보면 루트 이 분의 일이니까 유리하 에서 이 분의 노트 어디까지 갈 수 있고, 고 쌓인 사십오 돈은 이 편 불에 및 변이
# 기준가 에서 마주 보이는 게 높이면 육십이 편이니까.
# 그게 뭐야? 루트 A 분에 똑같이 애인의
# 그러니까 AA 앞으로 루트 이 분의 일
# 에서 이 분의 부채가 똑같이 단 젠트 사십오 돈은 모두 민변 불에 높였다. 이 편 분에 높이, 즉 A 분에 A 니까 모가 돼 이렇게 나온다는 이야기다.
# 여러분께서 이걸 가지고 이제 우리가 나중 되면 결론은 못하겠다는 이라면 이런 거 하겠다는 게
# 너무 어렵지 않으니까 보세요. 사십오 도 즉각 삼각형 인데, 이 길이가 삼 일 대 일 의 구해 바라는 것은
#  우리는 한마디로 이게 이 편이고 이게 기준 가게 돼서 및 별 이자나
#  고 쌓인 사십오 되겠죠. 쌓인 사십오 도 라는 게 모범을 보여야 X 라고 나 보면 X 분의 삼 일간
#  맞죠? 그런데 우리는 이 X 분의 삼 값을 알고 있다고 고 쌓인 사십오 도의 값을 알고 있다고
#  됐나요? 이렇게 해서 여기서 X 를 구하는 건 공부하는 게 최종 목적이고.
# 그런데 이렇게 되어 있고 고 쌓인 사십오 도의 값이 이번에도 팀을 모르면 약세가 을 구할 수 없겠죠.
# 그러니까 여기 있는 아홉 개 숫자를 암이 하셔야 되는데 선생님 중학교 때가 선임 적극 정말 안개 하는 것 정말 못하고 실어 있어요.
#  그래서 그나마 수확이 좋았어요.
# 암이 덜 해도 된다고 생각했는데 결국 주요 공식 이나 유도 과정을 공방을 하면 언젠가 남기를 한 시간이 오겠죠.
# 지금 사인 고 쌓인 단 젠트 삼십 사십오 도 육십 도의 값이 왜 각각 이 분의 일, 일본의 볼트 EV 흡수하면서 중 나오는지 설명을 드렸는데 이유를 알았다면 암기를 하셔야 합니다.
# 자, 암기하는 방법은 어떻게 되려면 다음 시간에 영도 구십, 도로 하고 라며 여러분에게 좀 더 다시 한번 설명 드릴 텐데
# 부모는 다 이에요. 부모는 다 이 사일런트 명의 그다음 분자는 루프 일 이 삼 일 이 삼 어렵지 않죠.
# 부트 잃은 일이니까 그냥 우리가 이 분의 일 로 쓰는 거예요. 이 분의 루트 인 이상 메울 수 있는 삼십, 사십, 육십 도
# 그렇다면 COULD SIGN 같은 경우는 어떻게 된 거냐 거꾸로 보면 됩니다.
# 일 이, 삼 갔으니까 삼 일, 즉 이 분의 두 사람 이 분의 붙은 이 분의 일 로 치른 일이죠.
# 이렇게 썼는데요. 결국 사인을 써줄 수 있다면 고 쌓이는 이렇게 엇갈려 대각선으로 내려오는 문화라는 걸
#  여러분들이 생각할 수 있습니다.
#  있죠. 단 젠트 같은 경우는 단 젠트 사십오 도의 값을 때 일이고 이걸 기준으로 해서 루트 삼 으로 나누고 루트 삶으로 곱해 주는데요.
# 결국 이를 노트 삼 으로 나눈다는 게 뭐야? 부터 삼 분의 일이겠죠 일 나누기 거죠.
# 이걸 보통 유리할 에서 삼 분의 이 삼 으로 많이 되어 있는데 선생님은 욕을 쓰는 경우가 조금 더 많아요.
# 계산 하다보면 편할 때가 많아요.
# 그래서 일반적으로 우리가 수를 쓸 때는 분모를 줄여 에서 쓰기 때문에 이렇게 돼 있지만 노트 삼 분의 일 로 기억해 두시면 더 편하죠.
# 일 난 우리 루트 삶이라는 게 이것보다 좀 더 와 다르니까
# 이쪽으로 루 두산 법학 얼마 일곱 하게 부터 삼은 노트 삼 되겠죠. 여러분들께서 오늘 끝날 때 이 표를 그려 놓을 수 있었는데요,
# 선생님 주 상대하는 알려주는 친구도 있잖아요. 그러면 어떻게 했냐면? OMR 카드 있잖아요?
# 학교에서 오 회말 보기 전에 맏아들 최대한
# OMR 카드를 받자마자 수원 번호를 쓰고 그런 게 아니라
# 급히 주관식 남남 기회가 주간 식당도 아니었는데 거기다가 의표를 갔다 있다며 배운 것을 막상
# 그리고 마음 편안하게 일본 문제에서부터 풀어 나갑니다.
# 그만큼 여러분들께서 이 삼각 비 특수강 에서의 삼각 비 의 값은 반드시 감기가 되어 있어요.
# 배우는 방법 설명 됐으니까 이 문예 루트 일 이 삼
# 분의 이 삼 일 이를 기준으로 십삼 나눈다 고 판다. 됐나요?
#  여기까지 여러분들께서 정리할 수 있으면 됩니다.
#  점 이게 그럼 도대체 문제 어떻게 나오느냐에? 너희가 왜 배워야 하는지 여러분들이 이렇게 나오기 때문에
# 이걸 왜 이런 문제를 해요? 라고 하면 사람이 할 말이 없죠. 나와 있는데 어떻게
# 쌓인 삼십 도에 값을 유도하는 아닌
# 외워서 푸는 쌓인 삼십 도 얼마 이 분의 얼마 삼십 사십오 육십이 분의 일 이상 그쳐
#  고 쌓인 사십오 도 얼마 이번에 루트 사십오 도가 가운데 우리가 일, 이, 삼 에서 있겠네요.
#  그래서 이 분의 일 플러스 TONS AND 사십오 도 얼마인지 제일 마지막 줄에 가운데 일 그걸 이 루 두산 나눔으로 꼽혔다
#  나죠. 더하기 포 쌓인 육십 도 육십 도 제일 위쪽에 있는 하르트. 삼 일이어서 고 쌓이는 사인이 일, 이, 삼, 그 사이는 삼 일
#  그래서 여러분들께서 이렇게 <unk> 세워져 나와야 하는 거예요. 하잖아요. 도박인 일본 문제였습니다.
#  여기까지 와서 간단하게 오늘 배웠던 내용에 대해서 이런 문제를 우리가 다루는 것
# 같은데 이것만 있지는 않겠죠. 이것만 풀린 않았고요.
# 다양한 문제들을 살펴봐야 하는데 이제 예전 문제 한번 시작해 보도록 하겠습니다.
# 또 선생님 이런 문제 안 나오는 거예요. 외워서 쓰는 거죠.
#  그런데 한 번쯤은 여러분들을 여러분들께서 배웠는지 다시 한번 확인하는 그런 문제입니다.
# 가끔 이런 문제가 시험의 출제 되기도 합니다. 여러분들이 잘 틀리지 않아요. 성실히 외웠다.
#  몇 가지 않게 이제 일본은 가볍게 풀어 볼 텐데 단 텐트 사십오 도 얼마 있어요? 표를 머릿속에 그려볼
#  여러분들이 현상을 해서 어려울 때 톈진 은 마지막 줄이 얻지 사십오 도는 가운데 어찌 그런 뭐가 떠올라서 더 올라야
#  두산 나누고 꼽혔던 걸 기억해야 하죠.
# 이런 식으로 여러분들이 표를 아홉 개의 수사에 다 쓸 수도 있지만 머릿속에 이미지를 그려 넣는 연습도 중요합니다.
# 그다음 쌓인 육십 도 쌓인 첫 줄이 묻더라. 이분의 였고,
# 루트 일, 이, 삼, 육십 도가 제일 끝이 없으니까 이분의 부터 삼 되겠구나. 이런 식으로
# 머릿속에 뭔가 생각을 정리할 하는데요. 두 번째 탄생 삼십 도
#  마지막 줄에서 삼십 도 모였다. 나 가운데가 이백구 루트 삼은 보여줘서 나눠서
# 하르트. 삼분의 일이 없구나 이렇게 됐나요? 곱하기 고 쌓인 육십 도 없고, 쌓인 중에 둘째 주 내서 제일 큰 것
#  금액 고, 사인은 모두 삼 일 거꾸로 갔으니까 이 분의 일 되겠구나,
# 이렇게 가는 거죠. 여러분께서 계산해보면 이 블랙리스트 삼 더하기
# 여기는 우리가 유례 해볼까? 루트 산불에 살짝 꼽혀 볼게요.
# 삼 분의 이 삼 삼 분의 루트 삼 곱하기 이 분의 일이니까 육 분의 노트 삼 일에서 결국 육 으로 통보해 보면
#  육 분의 삼 두 삼 더하기 육군의 노트 삼 이니까 육 분에 몇 노트 삼 사 루트 삶이고 약 일 에서 삼 분의 일 삼 까지 여러분들이 답을 써주면 되니까. 정답은 삼 번이다
#  이렇게 일본을 구하면 됩니다.
# 사실 여부가 복잡하게 있어도 있지만 실제로 한번 모야
# 사십오 도 육십 도 삼십 도 육십 대에 대한 사이코 사인 CONTACT 갑을 모여서 써준 다음에 계산한 것 이게 것입니다.
#  이런 문제가 나올 수 있다는 왜 한 해 오니까 여러분들께서 외워야 하셨죠?
#  가능하면 손님이 아내는 수학을 지향하지만 안개 할 부분이 있습니다. 이런 건
#  다음으로 예정 이번 문제의 들어가고 있습니다. 그려 이거 하고 싶어요. 오늘 외우기 이 관련은
# 이번 가봅니다. 그림과 같은 즉각 삼각형 ABC 에서 지금 이 편의 길이가 육 이고 A 씨의 길이가 삼 일에
# 각별히 크기를 구할 수 있습니다. 자유로 간 벚나무가 각 비를 기준 가구로 보면 지금 이 병원에 길이가 주어져 있는 거예요.
# 출연하는 거울이 추리 안과 비를 관할
# 이 어떻게 알았는지 문제에서 이건 못 기준과 기준으로 봤을 때
#  마주 보이는 높이 이 문제가 그림이 우리에게 알려주는 것. 이 편과 높이를 알려주고 있는 건데
# 기준 가계 대해서 이 병과 높이가 보였다. 나 아 사이여서 빚 변 불이 높이가 사인 이어서 마저
#  쌓인 비가 몸을 해보라고 빈 병 불에 높이고 있어 육 분의 삼 일에야 육군 제 삼 후보지 이번에 딱 써놓고 보는 거죠.
# 하는 순간 뭐가 번쩍 하고 스쳐 지나갈 뭐가 꼭 쌓인 뭐가 이번 일을 했을 때 딱 떠올라요. 뭡니까
#  사인은 이번에 이번에 부터 이분을 부터 쌓인 몇 도가 삼십 도가 이분의 일이죠.
#  다. 여기서 우리는 비해 값이 얼마 라는 걸 알 수 있어
# 삼십 도 라는 걸 알 수 있다. 정답은 삼 번 이렇게 하고 싶은 거예요. 글 외워서 무슨 해야겠죠?
# 아, 예. 제 삼 번으로 한번 들어가 본 텐데요. 기자 예를 삼 번 문제는 조금씩 조금씩 다른 의혹들이 나오고 있죠.
#  삼각 비를 이용할 변해 길이를 구 했고요. 가기 주어져 있잖아.
#  종전 문제는 두 변이 줘도 있고 각 구하라는 거였죠.
# 이 문제는 변에 길이 하나 각 하다가 저도 있고 다른 변해 길이를 구하라는 이용
# 이 어차피 생각 빌 이용할 왜 삼 박 씨는 주변 사이에 길이 비율을 우리에게 알려주고 있는 거니까요.
# 그러면 각 씨가 삼십 도 이고 A 씨가 육 일 대 물가를 해서 ABL 길이를 부활해 이후 하고도 찾아 볼까?
#  지금 삼십 도로 알려주고 있는 이게 기준가 이라고 바라보면 우리나라 마주 보이는 게 묻더라.
#  지난 시간에 기준과 에서 마주 보이는 게 높이 했어요. 맞죠? 즉각 에서 마주 보이는 게 이 편이니까. 자동으로 이건 무가 돼
#  및 변이. 그러면 이 문제는 이런 얘기를 A. B 를 구 월 한 얘기는 부피를 부활한 얘기고 주어져 있는 건 및 연인의
#  우리는 출연하는 거죠. 생각합니다. 빚 변하고 높이가 보였지. 매끈하고 높이 단 젠트 라 맞아 단 젠트 가 단 젠트 기준 가계 삼십 도전하게
#  단 젠트 삼십 도가 및 변 불에 높이고 있어 육로 투입은 ABS 이유입니다. 무역 기관 어린이 이거 구하고 싶은 거예요.
# 그 미국 숫자는 이것만 숫자는 되는 거잖아요. 그저
# 텐센트 삼십 도가 모여 루트 삼 분의 일 또는 삼 분의 이 이상 대입 하시면 됩니다.
#  우리는 요오드 음식에서 양면의 육류 특위를 곱해 주면 A B 를 구할 수 있을 것이고,
# 결국 노트 삼 분의 일 곱하기 육 루트 이니까 이런 계산이 루트 산불 십삼 곳에서 유리한 까지 해줄 것이고 보세요
#  삼 분의 육 이니까 약 삼 분의 일 이나 보니까 이 두 이 삼은 이렇게 여러분들께서 A B 의 길이를 구한다 라는 이야기
# 할 수 있겠죠. 그러니까 우리가 쌓인 COULD SIGN 탄 듯 삼십 사십오 도 육십 도의 값을 알고 있다면
#  그것은 의미는 쌓인 삼십 도에 대해 이 필요한 과 높이의 이 이 병과 및 연회비 이 병과 높이의 이
# 사익 우사인 퍼센트 삼십 도에 값을 한다는 얘기가 바로 그것을 의미하는 가. 삼각 비가 젖어 있거나 또는 상납 비가 꼭 아니더라도
#  사인 코사 INTERNET 값이 아니더라도 어떤 닭이 특사가 이 주어지면 우리는
# 그걸 통해서 및 병과 높이 및 편과 빚 변 모 이 병과 높이 사이에 길이 이 들을 할 수 있다는 게
# 쌓인 콜센터 Z 값을 정확하게 하는 거죠. 그래서 문제에서 구하라는 계기를 구해낼 수 있다는 것,
# 그게 바로 오늘 공부할 핵심 있죠. 그러니까 이런 복잡한 문제를 불기소 가장 먼저 알리고 라고요.
# 사인 코사 INTERNET 삼십 사십 육십 도 암이 되어있어요. 이제 유지 한번 시작해 보겠습니다. 첫 번째 기대해보겠습니다
#  첫번째 어제 여러분들 이건 그냥 대입하면 얘기죠. 우리가 이런 분들 가볍게 풀고 가도록 하겠습니다.
# 그런데 단지 분수를 돼 있어서 좀 번거롭게 이럴 때는 그냥 부모 따라 분자 따로 이렇게 생각해 보는데
#  우리 분모를 생각해봅니다. 품목 자 부모를 루트 삼 곱하기 TONS AND 삼십 도 얼마입니까? <unk> 하셨죠. 노트 삼 분의 일 이다.
#  바로 야권에서 그대로 부모가 이라고 너무 좋다. 부모가 이르면 뭐가 가능해
# 생략이 가능합니까? 그냥 분자 보면 되는 것 같아서 그냥 바로 갑시다.
# 작품 아 이 곱하기 쌓인 사십오 도 이 분의 루트 더하기 고 쌓인 사십오 도 이 분의 NOT.
#  선생님 가운데 있는 거 이거 안 할 거예요?
#  됐어요. 마이너스 탄자니아 육십 도 노트 삼 이었죠.
# 이걸 계산해보면 결국 이 분의 일 또는 이렇게 분배 없어지면 루트 이 더하기 루트 이니까 이 루트,
# 그리고 그 뒤 마이너스 두 삼 이게 그대로 답이 이용해야 합니다.
#  우리가 머릿속에 헤어져 있기만 하면 뭔가 알고 이해하고 논리적으로 생각하고 이를 필요 없이 그냥 계산해 주면 되는 형태입니다.
# 서퍼들의 이렇게 문제를 이렇게 마무리되고 다음 주제 이번으로 들어가 보겠습니다.
#  자 이제 이번 여러분들 캐나다의 알맞은 값 회원이 라고 대놓고 묻는 문제죠.
# 어떻게 됩니까? 사이코 사인 CONTENT. 삼십 사십오 도 육십 도 이 분의 루트 일 이 삼 이 분의 루트 삼 일 이번에
#  붙은 삼 나눴고 루트 삼 곱해 했고 이거 못 따로 설명할 게 없죠. 사람들이 안개 하였다면 바로 해결이 가능합니다.
#  이제 조금씩 중요한 문제가 나오겠죠. 휴대 삼 번으로 들어가 볼 텐데요.
# 오른쪽 크림과 같은 즉각 삼각형 ABC 에서 ABL. 계기가 삼 부투어 이고 이 씨의 길이가 삼 부투어
#  여름을 보고하고 싶어지는 이곳 구하고 십점이.
#  우리는 즉각 삼각형 에서 피타고라스의 정리가 너무나 익숙하기 때문에
#  그런데 가계의 크기를 바라는데 우리는 지금 그것 구할 필요가 없는 거예요. A 씨를
#  왜냐하면 AC 구하라는 말도 없어요. 두 병만 나와 있으면 두 변의 길이의 이 를 구할 수 있고,
#  그게 각 A 의 입장에서 보면 높이가 나와 있는 거죠. 및 변이 주어져 있는 거죠.
# 머릿속에 모 갖춰져야 이 병과 도피 및 변 분에 높이는 단 SENT.
# A 가 몇 개인지 모르겠지만 단 젠트 A 는 및 변 불이 높이를 의미 있어
#  및 변이 사무 투유 이고 높이가 삼 루 투 이야 일단 간단하게 모양을 만들어 볼까
#  일 일부터 삼 분의 일 이라는 일에 더 했는데 이렇게 나와야 하는 거예요. 텐센트 몇 도가 부터 산물이자
#  삼십 도가 AI 가 삼십 도구나 이걸 구한 이야기에
#  결국 우리는 마지막에 이게 헤어져 있어야 문제를 해결할 수 있는 것이긴 하지만 결국 TONS A 라는 게 주어지면
#  기준 가기 줬는데, 지금 나와 있는 게 이 두 편의
# 이제 우리는 이 두 변 이라는 말을 및 편과 높이가 주어져 있어 로 바꾸는 작업을 할 수 있어야 하는 거예요. 왜
# 기준 각 에서의 대변이 높이 니까 이 이 편 아닐 테니까 당연히 및 편익 했죠.
#  이렇게 예약하고 예가 저도 있어 라는 말을 뭐가 및 편이고 이 규모가 높이 인지
# 및 병과 높이가 의미하는 게 그들의 비가 사이코 사인 탄 듯 중에 단 센트로 연결되는 이런 작업들이
# 그다음에 암이 되어 있으면 끝나는 것은 하셨죠. 이제 유죄 삼 번 문제 남아 사법 문제로 들어가야 되겠죠.
# 규제 사법 문제 들어가 보겠습니다. 어려워 보이죠. 굉장히 한 다네요.
#  우리는 단순화 시켜서 쌓인 몇 도가 이분의 노트 삼 인 지만 안게 되어 있으면 해결할 수 있어요.
# 싸이는 순서대로 이분의 부트 일, 이, 삼, 가 이 분의 부터 삼은 그러면 결국 쌓인 육십 도의 값이 이 분의 부터 삼 이라는
#  것만 여러분들이 세워져 있다면 똑같고 사인 사인 똑 같으니까. 하 삼 X 플러스 십오 도가 육십 도구나
# 이것만 알면 끝나고 했죠. 여기서 액수가 얘기잖아요
# 결국 삼 X 가 십오 도 이하에서 사십오 도니까 양면 삼 으로 나누면 X 의 크기는 백 도가 된다. 십오 도가 된다
#  사이에 인지 여러분들께서 확인까지 해주시면 끝나는 겁니다.
#  되죠. 똑같이 외우는 거지만 유죄 삼 번과 사 번 중에서 선생은 유죄 삼 번의 조금 더
# 그래도 조금 더 생각할 거리가 있고 좋은 문제에요.
# 사람들이 복습 하더라도 좀 더 신경 써서 유지에 삼 번 봐주셨으면 좋겠습니다.
# 이제 마지막 유형에 대해 두 개의 유죄가 남아 있는데 이 두 개 의제는 오늘 선생님이 강조하고자 하는 모든 내용이
# 오늘의 어떤 핵심 이것만 하면 끝나
#  이렇게 여러분이 생각하시는 유죄 오 번부터 한번 뿌리를 들어가 보도록 하겠습니다.
# 오늘 모든 내용이 유죄 법원에 들어가 있다 바라봅니다.
# 기자 오른쪽 그림과 같은 즉각 삼각형 ABC 에서 각 비리가 육십 도 이 씨가 오후 AV 를 구하려 그냥 BCA. 이 이렇게 생각하는 게 아니에요.
#  되잖아요. 삼각 비를 부활할 했잖아. 기준 가기 육십 도가 주어져 있는 거예요.
# 그러면 마주 보이는 게 높이지 않아요. 이게 및 편이죠. 이건 뭐야? 이 편이죠?
# 우리는 뭘 생각하느냐. 아! AV 를 구하라는 주변을 구하라는 이기고
#  주어져 있는 건 기준 가계 대해 및 변이 주어져 있어
#  금 내 머릿속에 선 늪 변경 빚 변 사이의 관계가 모여 있지를 떠올랐는데요. 무조건
#  김병화 뒤편 고 쌓인 고 사인이 구 살 몇 특히 여기 기준과 육십 도가 COULD SIGN 육십 도가 모 분에 모여
#  빚 변 분에 늪 연이어서 빚 변 불이 및 편이어서 ABB 분에 모여 BC 오히려 그러면 어떻게 될지 물 걱정이 걱정할 필요가
#  이거 구하는 거야 했던 거죠. 이게 물자의 숫자나 COULD SIGN 모습도 보였다. 코사 일도 아니고요. 됐어요 되어 이 분의 일입니다.
#  그러면 끝나자 왜 여기에서 이기고 하는데
# 이렇게 곱해 보면 A B 가 결국 몰아내기 보급하기 이니까 승리입니다 단위가 있죠. 십 센티미터
# 이렇게 여러분들이 구하면 끝나는 것 됐네요.
#  이 문제 오늘까지 지금까지 공부하고 중에서 꼭 한 문제를 출제해 된다면 유죄 오 번 나올 수 있겠죠.
#  자 유죄 육 번 여기서 난이도를 조금 더 올려 보도록 하겠습니다. 먼저 그림이 좀 복잡해요.
# 함께 보도록 그림의 삼각형 ABC 에서 AA 이 하고 이 씨가 서로 수칙이 되어
#  AHA 하고 이 씨가 서로 수직 여기가 구십 도 인근 몰라요. 이름도 지난 시간에 배웠던 직각 삼각형의 닮은 아니에요
#  구십 도 란 말이 없습니다. 육십 도 사십오 도 이 명 그리고 당연히 구십 도 아닌 것도 여러분을 할 수 있죠.
# 기자 이 그림을 여러분들이 바라볼 때 어떻게 바라봐야 하냐면, 삼각형 ABC 가 보입니다 라고 하면 안 되는 거예요.
#  조현문 전 달 은 달리기를 한 이 그림은 삼각형 A BH H 씨가 H 를 공통으로 붙어있는 겁니다 라고 해석해야 됐나요?
# 그러면 문제에서 구하고자 하는 게 지금 CH 요. 우리는 생각해보는 것이
# 내가 어디까지 가야지 이 CH 를 구할 수 있지 CH 를 구하고 싶다 는 오늘 여러분들이 잘 보세요.
# CH 를 구하고 싶다는 것 의 길이를 잠깐 액수라고. 나 볼게요. 이걸 관련 몰랐어요.
#  일단 쪽에 있는 삼각형 에서 이변이 듯 이변이 등 알면 돼 맞죠? 그래야 모로코 쌓인 사십오 도를 수사할 것 같
# 은데 입영 보다는 누가 먼저 보이죠? 이변이 구했으며 왜 이변이 보이죠? 이쪽 삼각형을 이용해야 하니까
#  맞춰 이쪽에서 온 거니까 여기에 공통 있잖아요.
# H 를 통해 CH 를 구할 건데, 이 문제는 그래도 좀 쉬운 게 여기 사십오 도 있고 여기 구십 도면 여기도 또 사십오 도
#  무슨 삼각형 H 씨는 이 등 몇 삼각형 AHP 따라서 부과돼 X 같은 하하 때문에 난자 X 를 구할 것
#  어떻게 이제 왼쪽으로 넘어서 보는 겁니다. 아, 왼쪽에 있는 ABM 위치에서 보니까 지금 유가가 육십 도 나와 있는
#  마주 보이는 게 뭐야? 높이는데 높이가 주어져 있는 거래 높일 구하고자 하는 것, 그리고 및 변이 주어져 있는가?
#  및 변하고 높이와 TONS AND 어떻게 생각하는데
#  단 젠트 육십 도가 및 변 불이 높은데 그게 사 분의 역사라는 이야기죠.
# 여기서 우리는 X 구할 수 있고
#  탄생 육십 도가 루트 삼 이니까 이렇게 써주면 내부에서 X. 의 값은 하루 두 삼
#  그게 지금 AHA HCI 길이가 않았겠죠.
# 이등병 편이었습니다. CH 에 이르는 따라서 사 루트 삼 센티미터 이렇게 여러분들께서 답을 구해 주시면 됩니다.
# 이렇게 해서 오늘 교재에 있는 전체의 문제는 마무리가 되었습니다.
# 혹시 이 학년 때 선생님의 늘어난 들은 친구들은 선생 수감 위에서 제일 많이 여러분이 좋아했던 게 신기해요.
#  보통은 수업 짧고 우리 제자를 너무 훌륭해
# 선생님의 마크 있죠. 사십이 추천 문제에 최대 문제만 이런 거 어려운 문제
#  굉장히 여러분들이 수가 목이 좋은 걸 많이 써주셔서. 삼 학년 우려하면서도 선생님이 준비를 했습니다.
# 궁금해서 함께 오늘의 문제 시작해 보겠습니다. 차 손, 새 매체에 문제 첫번째 문제와 함께 보도록 하겠는데요.
# 의 첫 번째 문제는 조금 전에 풀었던 유죄 마지막 문제하고 유사한 형태의 문제입니다.
# 함께 문제를 해결해 보도록 하겠습니다. 그림을 딱 붙는 느낌이 전혀 다른
# 그림만 조금 바꾸면 우리는 다른 문제라고 생각하기 쉬워요. 그런데 문제의 흐름이 같아요.
# 느껴봅니다 타이베이 길이가 육 이고 지금 이 그림을 보고 여러분을 개최해야 하는 거예요.
# 구십 도 구십 도 사십오 도 알겠어요. 중요한 게 보죠.
# 이 그림은 여기 있는 삼각형 ABC 하고 또 하나의 삼각형 여기는 DC. 비가 누구를 이 씨를 공통으로 해서 있는 거예요.
# 그러니 이 두 삼각형을 연결하는 매개체로 누구야? 이 씨가 포인트와, 이걸 여러분이 생각해야 하니까.
#  나는 이쪽에서 일로 넘어 가려면 다리를 건널 때 이 씨를 구해 나가야지 넘어갈 수 있다.
# 이걸 생각하면서 문제를 읽어보고 BDA 기리고 아니잖아요.
# 그쳐 주황색 오른쪽에 있는 이 삼각형 에서 이 편을 구하라.
# 그러면 일단 이 삼각형 에서 어느 변인은 이것은 이것은 하나의 알아야 한다는 거죠. 그래야 이 편을 구 하겠죠.
#  당연히 이걸 아니죠. 이 씨를 구하겠다, 왜? 하얀색 사 넘어야 하니까 그러면 보는가?
# 기준과 육십 도 잖아요. 끔찍한 마주 보이는 게 높이지 하얀색 에선 거죠. 이건 모조 및 편이죠.
#  아들은 민변 불에 높이는 보였죠. 탄생 틉니다 CONSENT 육십 도가 모 분에 뭡니까? 육 분의 일 이다
# 여기에서 우리는 이 씨를 구할 거고 단 젠트 육십 MINUTE 삼 이니까 여섯 배 주면 이 씨는 결국 무가 돼.
# 루트 삶이 될 거야. 이렇게 이 씨를 구하는 단계가 들어가야. 저, 그러면 이제 그다음 오른쪽으로 넘어올 수 있겠네요.
# 다리 건너 없어. 비리에 길이 말했습니다. 그러면 기준 각 사십오 도에 주황색 만 보세요. 이 편을 구하려
# 기준 각에서 마주 보이는 뭐가 주어져 있어? 높이가 주어져 있는 거예요. 그러면 이 병과 높이는 모였다가
#  빈 병과 높이 빛 변 불이 높이가 사인이 없구나 쌓인 사십오 도가 부분에 모여 이 변 빛이 분에 높이가 누구의 지금 육 노트 삼
#  여기서 비리를 구하면 된다 그러면 쌓인 사십오 도가 이분의 부트 AESA 요구 질세라 돈을 변론
#  이렇게 곱해 보면 루트의 BH 는 이렇게 곱하면 십이 루트 삼
#  여기서 약 별로 추위로 나누고 연속성 계산이 니까 여러분들이 쭉쭉 해나갈 수 있으면 됩니다.
# 비리는 결국 뭐가 될 거냐 하면 다 이 분의 십이 약품 내면의 영남 우니까 육로 투 삼 위는 육 이렇게 답을 구 하시면 끝나는 거예요.
# 이건 할 수 있겠죠. 한 문제 여러분들과 할 텐데 오늘 이 문제에 의해 하잖아요.
# 그러면 학교 속 끝난 것이 일단 학교에 속에서 나올 수 있는 이 삼 가 이 아파트에 대한 문제는 이 문제 하나로 다 끝납니다.
#  가보겠습니다. 삼각형 ABC 에서 A 비가 육 이고 A 씨가 꿉니다 BH 가 삼십 도 일대 단 젠트 X 의 갑
# 자 결론이 나와 있어 단 젠트 X 를 관해 우리는 당연히 즉각 삼각 총 여기에서 단 등 TAX 를 구할 거고
# 몰고 알아내기 별로 써 보자. 단 젠트 X 기증 가기가 마주 보이는 게 높이
#  이게 및 변 TONS 인덱스는 이 병 분에 높이 A H 분에 몰고와 라니냐 CH 이걸 구할 하는 거야 라고 결론을 정해놓고
#  H 는 어떻게 H 어렵지 않느냐? 이 삼각형 에서 보면 될 것 같아요. 맞아요.
# 그럼 CH I 관건이다. 그래서 이 문제가 좀 어렵습니다. 그러면 우리는 H 어떻게 되냐?
#  비중 각 삼십 도에 대해서 빚 변 을 알고 있고, 및 변을 구하고자 하는 거죠.
#  마주 보이는 게 높으니까. 결국 육 분에 H 가 모여 고 쌓인 삼십 도 입니다.
# 그러니까 다 양면의 여섯 배 주면 AA. 이 는 육 코스 쌓인 삼십 도가 돼서 결국 모가 돼? 삼 무 두 삼. 여기까지 올 수 있어요.
# H 가 삼 부두 삼 라는 부모는 해결해서 이제 분자 CH 를 구하는 게 목적이다.
#  그런데 우리는 CH 를 어떻게 구할 수 있느냐? 스위치를 선생님 여기서 피타고라스의 있으면 되나요? 네. 피타고라스의 정리 써도 돼요?
# 해볼까요? 육. 일이 어떻게 구할 수 있어? 루트 이 편의 제고 배기 다른 편의 제공 부부 팔십일 배기
# 사무 두 사람의 직업은 이십칠 이니까 루트 오십사 오십삼 년 구십육 의 오십사 하니까 삼 루 투 육 가지 여러분들이 갈 수 있는 거죠.
#  수해 측근 안내 PH 뭐라고요? 삼 두 결과는 노트 이렇게 여러분들께서 답을 구하는 겁니다.
#  문을 열었다고 공부했던 내용 중에 핵심은 당연히 사이코 쌓인 텐센트 삼십 사십오 도 육십 도의 값을 외우는 걸렸고
#  마지막 유형 있죠. 그리고 오늘 최 문제까지 선생님이 묘기까지 여러분이 할 수 있다면 여러분께서 학교 시험에 대해서는 일단 오늘 확실하게 끝냈다고 자신있게 말씀드립니다.
# 공식 배울 내용 함께 정리하고 마무리합니다
# 수사 오늘 끊으면서 함께 정략 해요. 쌓인 삼십 사십오 도 육십 대가 각각 이 분의 일 위 두산 분자가 올라갔습니다.
#  고 사인은 거꾸로 내려 왔죠. 이번에 비슷한 루트 ROUTE 일이었습니다. 단 제닝스는 수산물에 입
# 구는 유리하 에서 삼 월부터 삶에서 루트 삼십 곱해 나간다. 반드시 암이 부탁드립니다.
# 아, 선생님 조금 학과 숙제로 여러분께 내 드린다 라고 말씀하셨던 문제 기억하시나요? 마지막 휴대 문제의
#  여러분을 반드시 시의 채 길이를 구하는 순서 까지 한번 어떻게 풀어나가는 답이 아니고요.
# 흐름을 여름 등에서 수가 무기의 남겨 주시면 여러분과 상태 에 소통의 공간이 되겠네요.
# 오늘 수고 많이 하셨고요. 다음 시간에 또 열심히 준비하도록 하겠습니다.

# %%
# 한 문장의 모든 경우의 수 구하기
# input : sentence
# output : 모든 길이의 단어 리스트
def get_words_of_all_length(w1, s2):
    answer = []
    MIN_LEN = 1
    MAX_LEN = (len(s2) + len(w1))//2 + 1
    for l in range(MIN_LEN, MAX_LEN+1):
        for i in range(len(s2)-l+1):
            answer.append(s2[i:i+l])
    
    return answer

# %%
EBS w1 = 길이

STT = 모든 기리의 다너 리스트
[모, 든, 기, 리, ..., 모든, 든기, 기리, 리의, ... 모든길, 든길이, .,...]

# %%
jamo_levenshtein('단어', '달엌')
# Out:
# 0.6666666666666666

# %%
levenshtein('단어', '달어')
# Out:
# 1

# %%
문맥상 나와야하는 단어(NN) + 단어 거리로 나와야하는 단어

# %%
# levenshtein가 가장 낮은 단어 구하기
# input : (1개의 단어, 여러개 단어의 리스트)
# output : leven distance가 가장 낮은 단어 리스트(1개가 아닐수도있음)
def find_min_levdis_words(w, l):
    answer = []
#     answer2 = []
    
    prob_list = [jamo_levenshtein(w,_) for _ in l]
    MIN_PROB = min(prob_list)
    for i, _ in enumerate(prob_list):
        if _ == MIN_PROB:
            answer.append(l[i] + str(_))
#             answer2.append(_)

    return answer
#     return answer, answer2

# %%
EBS_pre = ''

# %%
dbdict = defaultdict()
dbdict['수학기호'] = []
dbdict['한글발음'] = []
dbdict['STT'] = []

# %%
all_dbdict = defaultdict()
all_dbdict['EBS_Token'] = []
all_dbdict['한글발음'] = []
all_dbdict['STT'] = []

# %%
s = '그러면내각의합180도가되기위해서는결국이각비라는건삼각형의내각의합180도에서나머지둘의합을빼주면되죠90마이너스엑스하고90의합을빼주는거니까90더하기90는180빼서없어지고마이너스마이너스엑스니까엑스가돼서이각이엑스가돼그러면결국이각이엑스일때이각이엑스라는것까지알수있죠왜이걸구할거냐결론부터본다면탄젠트엑스를구하는게문제예요근데'

fl = re.findall(r'\d+', s)
fl
# for n in fl:
#     _ = _.replace(n, kopro[int(n)])
# esl_number_conversion.append(_)
# Out:
# ['180', '180', '90', '90', '90', '90', '180']

# %%
for n in fl:
    s = s.replace(n, kopro[int(n)])

# %%
s
# Out:
# '그러면내각의합백팔십도가되기위해서는결국이각비라는건삼각형의내각의합백팔십도에서나머지둘의합을빼주면되죠구십마이너스엑스하고구십의합을빼주는거니까구십더하기구십는백팔십빼서없어지고마이너스마이너스엑스니까엑스가돼서이각이엑스가돼그러면결국이각이엑스일때이각이엑스라는것까지알수있죠왜이걸구할거냐결론부터본다면탄젠트엑스를구하는게문제예요근데'

# %%
# EBS 문장들 전처리
def EBS_preprocessing(EBS_entered):
    pat_math_symbol = re.compile(r'[().,‘’?!]') #의미없는부호 정규식
    pat_number = re.compile(r'\d+') #숫자 정규식
    esl = EBS_entered.splitlines() #문장단위로 리스트
    
    esl = [s.strip() for s in [pat_math_symbol.sub('', _) for _ in esl]]# punctuation 제거, 앞뒤 공백 제거
    
#     for _ in esl:
#         for i in esl.split():
#             all_dbdict.dbdict = defaultdict()
    
    #수학기호 한국어로 변환(EBS)
    esl_math_conversion = []
    for _ in esl:
        for ms in sd.keys():
            if ms in _:
                _ = _.replace(ms, sd[ms])
                if ms in dbdict['수학기호']:
                    continue
                else:
                    dbdict['수학기호'].append(ms)
                    dbdict['한글발음'].append(sd[ms])
                    dbdict['STT'].append('')
        esl_math_conversion.append(_)
        
    #숫자 한국어로 변환(EBS)
    esl_number_conversion = []
    for _ in esl_math_conversion:
        fl = re.findall(r'\d+', _)
        for n in fl:
            _ = _.replace(n, kopro[int(n)])
        esl_number_conversion.append(_)
        
    #알파벳 한국어로 변환(EBS)
    esl_alphabet_conversion = []
    for _ in esl_number_conversion:
        for a in ad.keys():
            if a in _:
                _ = _.replace(a, ad[a])
        esl_alphabet_conversion.append(_)
    EBS_pre = esl_alphabet_conversion
    return esl_alphabet_conversion

# %%
def STT_preprocessing(STT_entered):
    pat_math_symbol = re.compile(r'[().,‘’?!]') #의미없는부호 정규식
    pat_number = re.compile(r'\d+') #숫자 정규식
    ssl = STT_entered.splitlines() #문장단위로 리스트
    
    ssl = [s.strip() for s in [pat_math_symbol.sub('', _) for _ in ssl]]# punctuation 제거, 앞뒤 공백 제거
    
    #숫자 한국어로 변환(EBS)
    ssl_number_conversion = []
    for _ in ssl:
        fl = re.findall(r'\d+', _)
        for n in fl:
            _ = _.replace(n, kopro[int(n)])
        ssl_number_conversion.append(_)
        
    #알파벳 한국어로 변환(EBS)
    ssl_alphabet_conversion = []
    for _ in ssl_number_conversion:
        for a in ad.keys():
            if a in _:
                _ = _.replace(a, ad[a])
        ssl_alphabet_conversion.append(_)
        
    return ssl_alphabet_conversion

# %%
# input : (EBS 띄어쓰기 아직 안 된 sentence, STT 띄어쓰기 아직 안 된 sentence)
# output : sentence => pd.DataFrame
def get_similar_word_table(EBS_entered, STT_entered):
    
    pre_EBS = EBS_preprocessing(EBS_entered)
    pre_STT = STT_preprocessing(STT_entered)
#     pre_STT = STT_preprocessing(STT2_entered)
    
    for s1, s2 in zip(pre_EBS, pre_STT):
        print(s1)
        print(s2)
        print()
        
        #EBS 어절단위 끊은 리스트
        EBS_tokens = TweetTokenizer().tokenize(s1)
        
        #STT 문장 띄어쓰기 다 붙이기
        s2 = ''.join(s2.split())
        
        #EBS어절이 돌면서 d dictionary에 append하는곳
        for _ in EBS_tokens:
            if _ in dbdict['한글발음']:
                i = dbdict['한글발음'].index(_)
                found_words = ', '.join(find_min_levdis_words(_, get_words_of_all_length(_, s2)))
                dbdict['STT'][i] += ', ' + found_words
                
            else:
                dbdict['한글발음'].append(_)
                dbdict['STT'].append(', '.join(find_min_levdis_words(_, get_words_of_all_length(_, s2))))
            print('EBS Token : ', _)
            print('STT result: ', found_words)
            print()
        print('-----------------------------------------------------------')    
            
    return pd.DataFrame(d)

# %%
result = get_similar_word_table(EBS_entered, STT_entered)
# Out:
# 반갑습니다 이비에스 친구 여러분들 중학뉴런수학 삼학년하의 손석민입니다
# 반갑습니다 이비스톰 여러분들 중학 뉴런 수학 삼학년 사회 손성민입니다
#
# EBS Token :  반갑습니다
# STT result:  반갑습니다0
#
# EBS Token :  이비에스
# STT result:  이비스1
#
# EBS Token :  친구
# STT result:  런수1.0
#
# EBS Token :  여러분들
# STT result:  여러분들0
#
# EBS Token :  중학뉴런수학
# STT result:  중학뉴런수학0
#
# EBS Token :  삼학년하의
# STT result:  삼학년사회1.0
#
# EBS Token :  손석민입니다
# STT result:  손성민입니다0.3333333333333333
#
# -----------------------------------------------------------
# 여러분 지난 시간에 우리가 삼각비의 뜻에 관련된 공부를 했습니다
# 지난 시간에 우리가 삼각비의 뜻에 관련돼서 공부했습니다
#
# EBS Token :  여러분
# STT result:  우리1.6666666666666665, 우리가1.6666666666666665
#
# EBS Token :  지난
# STT result:  지난0
#
# EBS Token :  시간에
# STT result:  시간에0
#
# EBS Token :  우리가
# STT result:  우리가0
#
# EBS Token :  삼각비의
# STT result:  삼각비의0
#
# EBS Token :  뜻에
# STT result:  뜻에0
#
# EBS Token :  관련된
# STT result:  관련돼0.6666666666666666
#
# EBS Token :  공부를
# STT result:  공부1, 공부했1.0
#
# EBS Token :  했습니다
# STT result:  했습니다0
#
# -----------------------------------------------------------
# 사인 코사인 탄젠트 값이 각각 무엇을 의미하는지
# 코사인 탄젠트 값이 각각 무엇을 의미하는지
#
# EBS Token :  사인
# STT result:  사인0
#
# EBS Token :  코사인
# STT result:  코사인0
#
# EBS Token :  탄젠트
# STT result:  탄젠트0
#
# EBS Token :  값이
# STT result:  값이0
#
# EBS Token :  각각
# STT result:  각각0
#
# EBS Token :  무엇을
# STT result:  무엇을0
#
# EBS Token :  의미하는지
# STT result:  의미하는지0
#
# -----------------------------------------------------------
# 즉 빗변분의높이 빗변분의밑변 그다음 밑변분의높이가 각각 사인 코사인 탄젠트 기준각이라는 걸 이야기했는데요
# 즉 빗변분의 높이 빗변분의 밑변 그냥 빗변분의 높이가 갈까 사인 코사인 탄젠트 기준과 기다란 건 알겠는데요
#
# EBS Token :  즉
# STT result:  즉0
#
# EBS Token :  빗변분의높이
# STT result:  빗변분의높이0, 빗변분의높이0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-06b186806e5e> in <module>
# ----> 1 result = get_similar_word_table(EBS_entered, STT_entered)
#
# <ipython-input-42-98af86808107> in get_similar_word_table(EBS_entered, STT_entered)
#      23                 i = dbdict['한글발음'].index(_)
#      24                 found_words = ', '.join(find_min_levdis_words(_, get_words_of_all_length(_, s2)))
# ---> 25                 dbdict['STT'][i] += ', ' + found_words
#      26
#      27             else:
#
# IndexError: list index out of range

# %%
dbdict
# Out:
# defaultdict(None,
#             {'수학기호': ['cos',
#               'sin',
#               'tan',
#               '˚',
#               '-',
#               '=',
#               '²',
#               '√',
#               '½',
#               '+',
#               '÷',
#               '×',
#               '③',
#               '∠',
#               '㈏',
#               '㈎',
#               '㈐',
#               '㎝',
#               '△'],
#              '한글발음': ['코사인',
#               '사인',
#               '탄젠트',
#               '도',
#               '빼기',
#               '는',
#               '의제곱',
#               '루트',
#               '이분의일',
#               '더하기',
#               '나누기',
#               '곱하기',
#               '삼번',
#               '각',
#               '나',
#               '가',
#               '다',
#               '센치미터',
#               '삼각형'],
#              'STT': [', 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0',
#               ', 사인0, 사인0, 사인0, 사인0, 사인0, 사인0, 사인0, 인1, 인1, 인1, 인1, 싸인1, 싸인1, 싸인1, 싸인1, 인1, 인1, 인1, 인1, 싸인1, 싸인1, 싸인1, 싸인1, 인1, 인1, 인1, 인1, 싸인1, 싸인1, 싸인1, 싸인1, 인1, 인1, 인1, 인1, 싸인1, 싸인1, 싸인1, 싸인1, 사인0, 인1, 싸인1, 사인0, 인1, 싸인1, 인1, 싸인1, 사인0, 그2, 렇2, 다2, 면2, 하2, 이2, 닉2, 스2, 도2, 라2, 는2, 건2, 빗2, 변2, 분2, 의2, 높2, 이2, 빗2, 변2, 분2, 의2, 높2, 이2, 가2, 뭐2, 야2, 그렇2, 렇다2, 다면2, 면하2, 하이2, 이닉2, 닉스2, 스도2, 도라2, 라는2, 는건2, 건빗2, 빗변2, 변분2, 분의2, 의높2, 높이2, 이빗2, 빗변2, 변분2, 분의2, 의높2, 높이2, 이가2, 가뭐2, 뭐야2, 인1, 싸인1, 사인0, 사인0, 사인0, 사인0, 인1, 싸인1, 유2, 도2, 하2, 나2, 요2, 아2, 니2, 여2, 기2, 유도2, 도하2, 하나2, 나요2, 요아2, 아니2, 니여2, 여기2, 인1, 사1, 싸인1, 사십1, 인1, 싸인1, 인1, 싸인1, 사인0, 사인0, 인1, 싸인1, 인1, 싸인1, 사1, 사일1, 사인0, 사인0, 인1, 싸인1, 사인0, 사인0, 사인0, 사인0, 사인0, 사인0, 사인0, 사인0, 사인0, 사인0, 인1, 인1, 싸인1, 삼인1, 인1, 까인1, 인1, 인1, 싸인1, 싸인1, 인1, 인1, 싸인1, 싸인1, 인1, 인1, 사1, 싸인1, 싸인1, 사십1, 인1, 사1, 싸인1, 사십1, 사인0, 사인0, 인1, 사1, 싸인1, 사십1',
#               ', 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 여3, 러3, 분3, 들3, 의3, 연3, 상3, 을3, 해3, 서3, 배3, 울3, 게3, 아3, 편3, 전3, 쟁3, 마3, 지3, 막3, 드3, 렸3, 지3, 사3, 십3, 오3, 도3, 는3, 가3, 운3, 데3, 어3, 찌3, 그3, 럼3, 뭐3, 가3, 떠3, 올3, 라3, 가3, 야3, 돼3, 가3, 야3, 돼3, 여러3, 러분3, 분들3, 들의3, 의연3, 연상3, 상을3, 을해3, 해서3, 서배3, 배울3, 울게3, 게아3, 아편3, 편전3, 전쟁3, 쟁마3, 마지3, 지막3, 막드3, 드렸3, 렸지3, 지사3, 사십3, 십오3, 오도3, 도는3, 는가3, 가운3, 운데3, 데어3, 어찌3, 찌그3, 그럼3, 럼뭐3, 뭐가3, 가떠3, 떠올3, 올라3, 라가3, 가야3, 야돼3, 돼가3, 가야3, 야돼3, 여러분3, 러분들3, 분들의3, 들의연3, 의연상3, 연상을3, 상을해3, 을해서3, 해서배3, 서배울3, 배울게3, 울게아3, 게아편3, 아편전3, 편전쟁3, 전쟁마3, 쟁마지3, 마지막3, 지막드3, 막드렸3, 드렸지3, 렸지사3, 지사십3, 사십오3, 십오도3, 오도는3, 도는가3, 는가운3, 가운데3, 운데어3, 데어찌3, 어찌그3, 찌그럼3, 그럼뭐3, 럼뭐가3, 뭐가떠3, 가떠올3, 떠올라3, 올라가3, 라가야3, 가야돼3, 야돼가3, 돼가야3, 가야돼3, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 트2, 루트2, 고루트2, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 이3, 게3, 밑3, 변3, 인3, 덱3, 스3, 는3, 노3, 래3, 소3, 피3, 에3, 이3, 에3, 이3, 치3, 분3, 에3, 뭘3, 바3, 라3, 냐3, 씨3, 에3, 이3, 치3, 십3, 구3, 하3, 라3, 는3, 거3, 야3, 라3, 고3, 결3, 론3, 을3, 정3, 해3, 놓3, 고3, 이게3, 게밑3, 밑변3, 변인3, 인덱3, 덱스3, 스는3, 는노3, 노래3, 래소3, 소피3, 피에3, 에이3, 이에3, 에이3, 이치3, 치분3, 분에3, 에뭘3, 뭘바3, 바라3, 라냐3, 냐씨3, 씨에3, 에이3, 이치3, 치십3, 십구3, 구하3, 하라3, 라는3, 는거3, 거야3, 야라3, 라고3, 고결3, 결론3, 론을3, 을정3, 정해3, 해놓3, 놓고3, 이게밑3, 게밑변3, 밑변인3, 변인덱3, 인덱스3, 덱스는3, 스는노3, 는노래3, 노래소3, 래소피3, 소피에3, 피에이3, 에이에3, 이에이3, 에이치3, 이치분3, 치분에3, 분에뭘3, 에뭘바3, 뭘바라3, 바라냐3, 라냐씨3, 냐씨에3, 씨에이3, 에이치3, 이치십3, 치십구3, 십구하3, 구하라3, 하라는3, 라는거3, 는거야3, 거야라3, 야라고3, 라고결3, 고결론3, 결론을3, 론을정3, 을정해3, 정해놓3, 해놓고3, 탄젠트0',
#               ', 도0, 도0, 도0, 도0, 도0',
#               ', 구2, 해2, 볼2, 까2, 요2, 어2, 어2, 떻2, 게2, 구2, 할2, 수2, 있2, 어2, 루2, 트2, 제2, 곱2, -2, 다2, 른2, 변2, 의2, 제2, 곱2, 구2, 백2, 팔2, 십2, 일2, -2, 구해2, 해볼2, 볼까2, 까요2, 요어2, 어어2, 어떻2, 떻게2, 게구2, 구할2, 할수2, 수있2, 있어2, 어루2, 루트2, 트제2, 제곱2, 곱-2, -다2, 다른2, 른변2, 변의2, 의제2, 제곱2, 곱구2, 구백2, 백팔2, 팔십2, 십일2, 일-2, 구2, 해2, 볼2, 까2, 요2, 어2, 어2, 떻2, 게2, 구2, 할2, 수2, 있2, 어2, 루2, 트2, 제2, 곱2, -2, 다2, 른2, 변2, 의2, 제2, 곱2, 구2, 백2, 팔2, 십2, 일2, -2, 구해2, 해볼2, 볼까2, 까요2, 요어2, 어어2, 어떻2, 떻게2, 게구2, 구할2, 할수2, 수있2, 있어2, 어루2, 루트2, 트제2, 제곱2, 곱-2, -다2, 다른2, 른변2, 변의2, 의제2, 제곱2, 곱구2, 구백2, 백팔2, 팔십2, 십일2, 일-2',
#               '',
#               '',
#               ', 루트0, 루트0, 루트0, 루트0, 루트0, 루트0, 루트0',
#               ', 일3, 이3, 이3, 돼일3, 이렇3, 이야3, 가돼일3, 이렇게3, 이야기3, 뭐가돼일3, 이렇게깔3, 이야기야3, 이분의일0, 이분2, 이분에2, 이분에나2, 이분의일0, 이3, 이3, 이3, 이3, 이왜3, 이블3, 이드3, 이유3, 이왜각3, 이블레3, 이드어3, 이유를3, 이왜각각3, 이블레이3, 이드어떻3, 이유를알3, 이분의일0, 이분의일0, 이분의일0, 이분의1, 이분의루1',
#               ', +3, 코3, 사3, 인3, 육3, 십3, 도3, 육3, 십3, 도3, 제3, 일3, 이3, 쪽3, 에3, 있3, 네3, 아3, 루3, 트3, 삼3, 일3, 이3, 었3, 어3, 콜3, 사3, 인3, 은3, 싸3, 인3, 에3, 이3, 13, 삼3, 삼3, 13, +코3, 코사3, 사인3, 인육3, 육십3, 십도3, 도육3, 육십3, 십도3, 도제3, 제일3, 일이3, 이쪽3, 쪽에3, 에있3, 있네3, 네아3, 아루3, 루트3, 트삼3, 삼일3, 일이3, 이었3, 었어3, 어콜3, 콜사3, 사인3, 인은3, 은싸3, 싸인3, 인에3, 에이3, 이13, 1삼3, 삼삼3, 삼13, +코사3, 코사인3, 사인육3, 인육십3, 육십도3, 십도육3, 도육십3, 육십도3, 십도제3, 도제일3, 제일이3, 일이쪽3, 이쪽에3, 쪽에있3, 에있네3, 있네아3, 네아루3, 아루트3, 루트삼3, 트삼일3, 삼일이3, 일이었3, 이었어3, 었어콜3, 어콜사3, 콜사인3, 사인은3, 인은싸3, 은싸인3, 싸인에3, 인에이3, 에이13, 이1삼3, 1삼삼3, 삼삼13, 이3, 렇3, 게3, 가3, 는3, 거3, 죠3, 계3, 산3, 해3, 보3, 면3, 이3, 분3, 의3, 루3, 트3, 삼3, +3, 이렇3, 렇게3, 게가3, 가는3, 는거3, 거죠3, 죠계3, 계산3, 산해3, 해보3, 보면3, 면이3, 이분3, 분의3, 의루3, 루트3, 트삼3, 삼+3, 이렇게3, 렇게가3, 게가는3, 가는거3, 는거죠3, 거죠계3, 죠계산3, 계산해3, 산해보3, 해보면3, 보면이3, 면이분3, 이분의3, 분의루3, 의루트3, 루트삼3, 트삼+3, 더하기0',
#               '',
#               ', 저3, 리3, 분3, 모3, 를3, 생3, 각3, 해3, 볼3, 게3, 요3, 등3, 록3, 십3, 사3, 분3, 모3, 레3, 루3, 트3, 삼3, *3, 탄3, 젠3, 트3, 삼3, 03, 도3, 얼3, 마3, 입3, 니3, 까3, 그3, 러3, 셨3, 죠3, 루3, 트3, 삼3, 부3, 자3, 로3, 저리3, 리분3, 분모3, 모를3, 를생3, 생각3, 각해3, 해볼3, 볼게3, 게요3, 요등3, 등록3, 록십3, 십사3, 사분3, 분모3, 모레3, 레루3, 루트3, 트삼3, 삼*3, *탄3, 탄젠3, 젠트3, 트삼3, 삼03, 0도3, 도얼3, 얼마3, 마입3, 입니3, 니까3, 까그3, 그러3, 러셨3, 셨죠3, 죠루3, 루트3, 트삼3, 삼부3, 부자3, 자로3, 저리분3, 리분모3, 분모를3, 모를생3, 를생각3, 생각해3, 각해볼3, 해볼게3, 볼게요3, 게요등3, 요등록3, 등록십3, 록십사3, 십사분3, 사분모3, 분모레3, 모레루3, 레루트3, 루트삼3, 트삼*3, 삼*탄3, *탄젠3, 탄젠트3, 젠트삼3, 트삼03, 삼0도3, 0도얼3, 도얼마3, 얼마입3, 마입니3, 입니까3, 니까그3, 까그러3, 그러셨3, 러셨죠3, 셨죠루3, 죠루트3, 루트삼3, 트삼부3, 삼부자3, 부자로3, 하기1, 더하기1',
#               ', 삼번0, 삼번0',
#               ', 각0, 각0, 각0, 각0, 조1, 금1, 전1, 문1, 제1, 는1, 두1, 변1, 이1, 좋1, 아1, 지1, 고1, 갖1, 고1, 가1, 라1, 는1, 거1, 였1, 죠1, 이1, 문1, 제1, 를1, 별1, 하1, 나1, 있1, 고1, 다1, 른1, 변1, 의1, 길1, 이1, 를1, 구1, 하1, 라1, 는1, 이1, 용1, 해1, 요1, 어1, 떻1, 게1, 이1, 제1, 왼1, 쪽1, 으1, 로1, 넘1, 어1, 서1, 보1, 는1, 겁1, 니1, 다1, 아1, 이1, 쪽1, 에1, 있1, 는1, 위1, 치1, 에1, 서1, 보1, 니1, 까1, 지1, 금1, 요1, 가1, 육1, 십1, 도1, 나1, 와1, 있1, 네1',
#               ', 나0, 나0',
#               ', 가0, 가0, 가0, 가0, 가0, 가0, 가0, 가0, 가0',
#               ', 다0, 다0, 다0, 다0, 다0, 다0, 다0, 다0, 다0, 다0, 다0',
#               '',
#               ', 삼각형0, 삼각형0']})

# %%
pd.DataFrame(dbdict)
# Out:
#    수학기호  한글발음                                                STT
# 0   cos   코사인  , 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사인0, 코사...
# 1   sin    사인  , 사인0, 사인0, 사인0, 사인0, 사인0, 사인0, 사인0, 인1, 인1, 인...
# 2   tan   탄젠트  , 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠트0, 탄젠...
# 3     ˚     도                               , 도0, 도0, 도0, 도0, 도0
# 4     -    빼기  , 구2, 해2, 볼2, 까2, 요2, 어2, 어2, 떻2, 게2, 구2, 할2, ...
# 5     =     는
# 6     ²   의제곱
# 7     √    루트                , 루트0, 루트0, 루트0, 루트0, 루트0, 루트0, 루트0
# 8     ½  이분의일  , 일3, 이3, 이3, 돼일3, 이렇3, 이야3, 가돼일3, 이렇게3, 이야기3,...
# 9     +   더하기  , +3, 코3, 사3, 인3, 육3, 십3, 도3, 육3, 십3, 도3, 제3, ...
# 10    ÷   나누기
# 11    ×   곱하기  , 저3, 리3, 분3, 모3, 를3, 생3, 각3, 해3, 볼3, 게3, 요3, ...
# 12    ③    삼번                                         , 삼번0, 삼번0
# 13    ∠     각  , 각0, 각0, 각0, 각0, 조1, 금1, 전1, 문1, 제1, 는1, 두1, ...
# 14    ㈏     나                                           , 나0, 나0
# 15    ㈎     가               , 가0, 가0, 가0, 가0, 가0, 가0, 가0, 가0, 가0
# 16    ㈐     다       , 다0, 다0, 다0, 다0, 다0, 다0, 다0, 다0, 다0, 다0, 다0
# 17    ㎝  센치미터
# 18    △   삼각형                                       , 삼각형0, 삼각형0

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
result
# Out:
#                           한글발음  \
# 0                        반갑습니다
# 1                         이비에스
# 2                           친구
# 3                         여러분들
# 4                       중학뉴런수학
# 5                        삼학년하의
# 6                       손석민입니다
# 7                          여러분
# 8                           지난
# 9                          시간에
# 10                         우리가
# 11                        삼각비의
# 12                          뜻에
# 13                         관련된
# 14                         공부를
# 15                        했습니다
# 16                          사인
# 17                         코사인
# 18                         탄젠트
# 19                          값이
# 20                          각각
# 21                         무엇을
# 22                       의미하는지
# 23                           즉
# 24                      빗변분의높이
# 25                      빗변분의밑변
# 26                         그다음
# 27                     밑변분의높이가
# 28                      기준각이라는
# 29                           걸
# 30                     이야기했는데요
# 31                          오늘
# 32                         공부할
# 33                         주제는
# 34                           딱
# 35                           한
# 36                       가지입니다
# 37                          바로
# 38                         삼십도
# 39                        사십오도
# 40                         육십도
# 41                         우리는
# 42                           이
# 43                         각들을
# 44                         특수한
# 45                        각이라고
# 46                          이름
# 47                        지었어요
# 48                        각에서의
# 49                          값을
# 50                         알아볼
# 51                      거고선생님이
# 52                         원래는
# 53                         외우는
# 54                         수학을
# 55                       여러분들께
# 56                          별로
# 57                          그런
# 58                         강의를
# 59                           안
# 60                         하려고
# 61                          하는
# 62                         편인데
# 63                         값들은
# 64                       여러분들이
# 65                       암기하셔야
# 66                          해서
# 67                        암기하기
# 68                          쉬운
# 69                        방법까지
# 70                        선생님이
# 71                         제시해
# 72                          드릴
# 73                       테니까오늘
# 74                         수업이
# 75                          끝날
# 76                        때쯤에는
# 77                      여러분들께서
# 78                        육십도의
# 79                        암기되어
# 80                         있으면
# 81                       되겠습니다
# 82                          같이
# 83                          함께
# 84                          수업
# 85                         시작해
# 86                         보도록
# 87                       하겠습니다
# 88                          중삼
# 89                          수학
# 90                          끝내
# 91                         봅시다
# 92                         내용은
# 93                        가지예요
# 94                         크기가
# 95                        육십도인
# 96                          각의
# 97                           값
# 98                         이렇게
# 99                           돼
# 100                         있죠
# 101                        내용을
# 102                      공부하기에
# 103                        앞서서
# 104                      선생님하고
# 105                         가지
# 106                       이야기해
# 107                        볼게요
# 108                          막
# 109                       기준각이
# 110                        어떻고
# 111                        빗변이
# 112                         뭐고
# 113                         이런
# 114                         얘기
# 115                        했잖아
# 116                        그렇죠
# 117                         근데
# 118                         아마
# 119                       배우면서
# 120                    그랬겠죠선생님
# 121                         그거
# 122                          왜
# 123                        배워요
# 124                        내지는
# 125                        생각할
# 126                          수
# 127                         있을
# 128                        거예요
# 129                        선생님
# 130                         변의
# 131                        길이의
# 132                        비인데
# 133                         그걸
# 134                        각으로
# 135                       표현해요
# 136                         에이
# 137                          비
# 138                          씨
# 139                         뒤에
# 140                         각이
# 141                      붙나요이런
# 142                        질문을
# 143                          할
# 144                          거
# 145                        같아요
# 146                     약속이야라고
# 147                         하고
# 148                         그냥
# 149                       넘어가긴
# 150                       합니다만
# 151                         조금
# 152                          더
# 153                         살짝
# 154                         깊이
# 155                         있게
# 156                      살펴볼게요
# 157                       삼각형이
# 158                         어떤
# 159                        도형이
# 160                         갖는
# 161                       성질이긴
# 162                         한데
# 163                      기본적으로
# 164                         하나
# 165                         정도
# 166                        느낌만
# 167                      보겠습니다
# 168                       여기에서
# 169                         각을
# 170                       에이라고
# 171                       해볼게요
# 172                         지금
# 173                        기준각
# 174                      얘기하고자
# 175                          게
# 176                       아니에요
# 177                      성질이에요
# 178                      직각삼각형
# 179                        만약에
# 180                          각
# 181                        에이가
# 182                       커진다는
# 183                          건
# 184                      의미하냐는
# 185                         거야
# 186                        각하고
# 187                         비가
# 188                        연결돼
# 189                       있지라는
# 190                        느낌을
# 191                        가져야
# 192                         돼요
# 193                         여기
# 194                         있는
# 195                        주황색
# 196                       삼각형을
# 197                         보면
# 198                        하얀색
# 199                       삼각형과
# 200                        밑변은
# 201                        변함이
# 202                         없죠
# 203                       변한다는
# 204                        것들이
# 205                        변하나
# 206                      살펴봤더니
# 207                         각만
# 208                        변하는
# 209                        아니라
# 210                      변화시키면
# 211                        높이도
# 212                      하얀색보다
# 213                       주황색이
# 214                        변해요
# 215                       길어지죠
# 216                        빗변의
# 217                        길이도
# 218                        어떻게
# 219                         되죠
# 220                    길어집니다결국
# 221                        길이는
# 222                        크기에
# 223                        영향을
# 224                         받아
# 225                        받아요
# 226                       이해됐죠
# 227                        그래서
# 228                        삼각비
# 229                         넣는
# 230                        변함에
# 231                        따라서
# 232                          뭐
# 233                         작은
# 234                         것도
# 235                        있겠죠
# 236                     물론이렇게도
# 237                       이렇게도
# 238                         텐데
# 239                        그러면
# 240                        변화에
# 241                  밑변분의높이라든가
# 242                  빗변분의높이라든가
# 243                    빗변분의밑변의
# 244                        비들이
# 245                         마구
# 246                        변화가
# 247                       생기겠죠
# 248                    맞죠여러분들이
# 249                         한번
# 250                         왔다
# 251                         갔다
# 252                        하면서
# 253                      머릿속에서
# 254                         그려
# 255                        보세요
# 256                      사이사이에
# 257                         계속
# 258                        변하고
# 259                        있어요
# 260                         중에
# 261                          몇
# 262                         개의
# 263                        각들이
# 264                         의미
# 265                        숫자를
# 266                       갖는다는
# 267                         예를
# 268                        들어서
# 269                         이거
# 270                         분의
# 271                        했더니
# 272                  삼천육백칠십팔이야
# 273                        말고요
# 274                          좀
# 275                         주로
# 276                       무리수를
# 277                       이용해서
# 278                      표현되는데
# 279                          그
# 280                        갖도록
# 281                       육십도일
# 282                        때라는
# 283                      이야기예요
# 284                         이걸
# 285                       이야기를
# 286                        합니다
# 287                       각이라는
# 288                         되게
# 289                        이상한
# 290                       우리에게
# 291                         비를
# 292                         주는
# 293                        각이고
# 294                        외워야
# 295                         되는
# 296                        겁니다
# 297                        개념을
# 298                      삼각비라는
# 299                         있나
# 300                        변하면
# 301                       변하니까
# 302                        그런데
# 303                        그중에
# 304                      육십도라는
# 305                      아셨죠그럼
# 306                       삼십도일
# 307                         때의
# 308                          세
# 309                         먼저
# 310                    살펴보겠습니다
# 311                         우리
# 312                        그림을
# 313                          놔
# 314                        처음엔
# 315                         이제
# 316                    보겠죠여기에서
# 317                      삼십도라고
# 318                         그럼
# 319                         각은
# 320                      자연스럽게
# 321                      육십도겠죠
# 322                       기준각을
# 323                         놨을
# 324                          때
# 325                         저는
# 326                       삼십도를
# 327                        구하고
# 328                      싶어요라고
# 329                        생각해
# 330                      본다면결국
# 331                    빗변분의높이죠
# 332                      기준각에서
# 333                         마주
# 334                         보는
# 335                       높이니까
# 336                       길이하고
# 337                         알죠
# 338                         아무
# 339                        정보가
# 340                        없는데
# 341                        정보를
# 342                        만들어
# 343                          낼
# 344                         수가
# 345                    있습니다어떻게
# 346                         낼지
# 347                          잘
# 348                        보시기
# 349                       바랍니다
# 350                         변을
# 351                         잡아
# 352                         변은
# 353                         뭐가
# 354                         될까
# 355                        아직은
# 356                        모르죠
# 357                       뒤집어서
# 358                        하나를
# 359                         붙여
# 360                      됐나요이게
# 361                       일직선이
# 362                        되도록
# 363                        붙였기
# 364                        때문에
# 365                        길이가
# 366                        에이면
# 367                       에이예요
# 368                     육십도이니까
# 369                       뒤집혀서
# 370                       육십도가
# 371                    되거든요그러면
# 372                      육십도이면
# 373                        이것도
# 374                     육십도잖아요
# 375                         무슨
# 376                     삼각형이에요
# 377                      정삼각형이
# 378                        됩니다
# 379                        그러기
# 380                       이에이면
# 381                       이에이가
# 382                       이것까지
# 383                    거예요그렇다면
# 384                         다시
# 385                        잘라서
# 386                     피타고라스의
# 387                        정리에
# 388                        의해서
# 389                        길이를
# 390                         구할
# 391                         테고
# 392            루트이에이의제곱빼기에이의제곱
# 393                        계산해
# 394        루트이에이의제곱는루트사에이의제곱이죠
# 395                  빼기에이의제곱이죠
# 396                루트삼에이의제곱이구나
# 397                       그러니까
# 398                        에이는
# 399                         루트
# 400                        밖으로
# 401                        나가서
# 402                    루트삼에이구나
# 403                        표현할
# 404                        있다는
# 405                      얘기죠결국
# 406                         들어
# 407                        내각이
# 408                      구십도이면
# 409                         제일
# 410                         짧은
# 411                          변
# 412                          두
# 413                        번째로
# 414                          긴
# 415                         비는
# 416              에이대루트삼에이대이에이가
# 417                         항상
# 418                       성립하는
# 419                       삼십도로
# 420                       시작하는
# 421                         각에
# 422                       대해서는
# 423                      삼각형이든
# 424                        중요한
# 425                 직각삼각형이든이겠죠
# 426                        당연히
# 427                        빗변과
# 428                        높이의
# 429                     이에이대에이
# 430                        이대일
# 431                       이대일이
# 432                          다
# 433                        된다는
# 434                       그렇다면
# 435                        그것을
# 436                       정리해서
# 437                        뭐라고
# 438                       이야기할
# 439                         거냐
# 440                         봤을
# 441                       삼십도는
# 442                         결국
# 443                  빗변분의높이이니까
# 444                    이에이분의에이
# 445                      이분의일이
# 446                        의미가
# 447                        처음에
# 448                         뭐라
# 449                        그랬어
# 450                        자체가
# 451                        숫자로
# 452                        나오는
# 453                     특수각이라고
# 454                        했어요
# 455                         같은
# 456                       경우에는
# 457                       삼십도가
# 458                       이분의일
# 459                         오로
# 460                        깔끔한
# 461                       나온다는
# 462                       이야기야
# 463                        됐나요
# 464                    빗변분의높이가
# 465                        일대이
# 466                        숫자가
# 467                      얘기입니다
# 468                        여기서
# 469                       삼십도도
# 470                  빗변분의밑변이겠죠
# 471                      높이였어요
# 472                         시간
# 473                   거빗변분의밑변은
# 474              이에이분의루트삼에이이니까
# 475                        약분해
# 476                       약분돼서
# 477                     이분의루트삼
# 478                        이것이
# 479                       삼0도의
# 480                      마지막으로
# 481                       삼십도의
# 482                         값은
# 483                         되나
# 484                       살펴보면
# 485                  밑변분의높이잖아요
# 486               루트삼에이분의에이이니까
# 487                        에이를
# 488                       약분하고
# 489                         나면
# 490                     루트삼분의일
# 491                         또는
# 492                      유리화해서
# 493                    삼분의루트삼이
# 494                        오늘의
# 495                        결론은
# 496                         뭐냐
# 497                        얼마니
# 498                        나와야
# 499                       얘기예요
# 500                       얼마예요
# 501                     거예요탄젠트
# 502                         얼마
# 503                     삼분의루트삼
# 504                       바로바로
# 505                         나올
# 506                        있게끔
# 507                         결론
# 508                        마지막
# 509                         해야
# 510                       일입니다
# 511                        이제는
# 512                       그림에서
# 513                       육십도로
# 514                         바꿔
# 515                        얘기는
# 516                          뭘
# 517                      구하겠다는
# 518                        얘기야
# 519                      알아보자는
# 520                     이야기겠죠잘
# 521                       이쪽으로
# 522                        바뀌면
# 523                         변이
# 524                        높이가
# 525                         되고
# 526                         밑변
# 527                         빗변
# 528                      내용이에요
# 529                         뭐야
# 530                 이에이분의루트삼에이
# 531                        되겠죠
# 532                       약분하면
# 533                    이분의루트삼이
# 534                       값입니다
# 535                      돼요코사인
# 536                       육십도는
# 537                  빗변분의밑변이니까
# 538                  이에이분의에이이죠
# 539                  밑변분의높이이니까
# 540                  에이분의루트삼에이
# 541                 에이분의루트삼에이는
# 542                     루트삼이구나
# 543                       육십도에
# 544                        대해서
# 545                    밑변분의높이네
# 546                      일대루트삼
# 547                         됐죠
# 548                        암기해
# 549                        주셔야
# 550                         아직
# 551                      빠졌잖아요
# 552                      그렇죠그럼
# 553                      사십오도에
# 554                      알아볼게요
# 555                         있다
# 556                          표
# 557                         보여
# 558                        거니까
# 559                        지금은
# 560                       지우셔도
# 561                      상관없어요
# 562                       구십도일
# 563                        구하는
# 564                        붙이고
# 565                      복잡했다면
# 566                      사십오도는
# 567                       쉽습니다
# 568                    직각삼각형인데
# 569                     사십오도라는
# 570                         말은
# 571                        사이의
# 572                     공부하겠다는
# 573                     사십오도이면
# 574                          도
# 575                         나와
# 576                      나오잖아요
# 577                     그렇죠그러면
# 578                        의미해
# 579                  이등변삼각형이에요
# 580                       같으니까
# 581                       일이라고
# 582                        놓으면
# 583                         되냐
# 584                         하면
# 585         루트에이의제곱더하기에이의제곱입니다
# 586                      에이의제곱
# 587                  이에이의제곱이니까
# 588                         빠져
# 589                        나와서
# 590                     루트이에이가
# 591                  직각이등변삼각형은
# 592                에이대에이대루트이에이
# 593                  일대일대루트이이고
# 594                         그로
# 595                        인해서
# 596                         삼개
# 597                      사십오도와
# 598                      사십오도의
# 599                      보면그러면
# 600               루트이에이분의에이입니다
# 601                  루트이분의일이니까
# 602                   이분의루트이까지
# 603                          갈
# 604                      있고코사인
# 605                       높이이면
# 606                         이게
# 607                      밑변이니까
# 608                        똑같이
# 609                 루트이에이분의에이네
# 610                     루트이분의일
# 611                    이분의루트이가
# 612                     나와요탄젠트
# 613                         뭐죠
# 614                   밑변분의높이였죠
# 615                  에이분의에이이니까
# 616                          일
# 617                        가지고
# 618                         나중
# 619                         되면
# 620                       하겠다는
# 621                       이야기냐
# 622                       하면이런
# 623                         너무
# 624                        어렵지
# 625                       않으니까
# 626                         삼일
# 627                         길이
# 628                         구해
# 629                        보라는
# 630                       한마디로
# 631                       빗변이고
# 632                       기준각에
# 633                      밑변이잖아
# 634                    사십오도이겠죠
# 635                     뭐야엑스라고
# 636                     엑스분의삼일
# 637                         아냐
# 638                         맞죠
# 639                     엑스분의삼의
# 640                         알고
# 641                        있다고
# 642                     됐나요이렇게
# 643                        엑스를
# 644                       공부하는
# 645                         최종
# 646                      목적이에요
# 647                         되어
# 648                         있고
# 649                   이분의루트이임을
# 650                        모르면
# 651                        엑스의
# 652                        없겠죠
# 653                         구개
# 654                        되는데
# 655                        중학교
# 656                         정말
# 657                       암기하는
# 658                        못하고
# 659                      싫어했어요
# 660                        그나마
# 661                        수학이
# 662                       좋았었어
# 663                        암기를
# 664                          덜
# 665                         해도
# 666                        된다고
# 667                      생각했는데
# 668                         주요
# 669                       공식이나
# 670                         유도
# 671                        과정들
# 672                       공부하고
# 673                        언젠간
# 674                        시간이
# 675                        오겠죠
# 676                     이분의루트이
# 677                          쭉
# 678                       나오는지
# 679                        설명을
# 680                       드렸는데
# 681                        이유를
# 682                       알았다면
# 683                        방법은
# 684                        되냐면
# 685                         다음
# 686                         영도
# 687                       9영도도
# 688                      여러분에게
# 689                         설명
# 690                        분모는
# 691                        이예요
# 692                        경우에
# 693                        분자는
# 694                        루트일
# 695                        루트이
# 696                        루트삼
# 697                         않죠
# 698                       루트일은
# 699                       일이니까
# 700                      이분의일로
# 701                         쓰는
# 702                  거예요이분의루트일
# 703                         외울
# 704                        있나요
# 705                        삼0도
# 706                        경우는
# 707                          될
# 708                        거꾸로
# 709                         오면
# 710                          삼
# 711                       갔으니까
# 712                         일즉
# 713                     이분의루트일
# 714                        일이죠
# 715                          써
# 716                         주면
# 717                        사인을
# 718                          줄
# 719                        있다면
# 720                       코사인은
# 721                       엇갈려서
# 722                      대각선으로
# 723                     내려오는구나
# 724                         값일
# 725                        일이고
# 726                       기준으로
# 727                      루트삼으로
# 728                        나누고
# 729                         곱해
# 730                         일을
# 731                       나눈다는
# 732           루트삼분의일이겠죠일나누기루트삼
# 733                         보통
# 734                   삼분의루트삼으로
# 735                         많이
# 736                        있는데
# 737                       선생님은
# 738                        경우가
# 739                        많아요
# 740                       계산하다
# 741                         편할
# 742                         때가
# 743                      일반적으로
# 744                         수를
# 745                          쓸
# 746                        때에는
# 747                        분모를
# 748                         쓰기
# 749                        있지만
# 750                    루트삼분의일로
# 751                        기억해
# 752                        주시면
# 753                        편하죠
# 754                 일나누기루트삼이라는
# 755                      이거보다는
# 756                          와
# 757                       닿으니까
# 758                        곱하면
# 759                        얼마야
# 760             일곱하기루트삼는루트삼이겠죠
# 761                         표를
# 762                         놓을
# 763                         때는
# 764                       외워지는
# 765                        친구들
# 766                       있잖아요
# 767                        했냐면
# 768                      오엠알카드
# 769                       학교에서
# 770                         시험
# 771                         보기
# 772                         전에
# 773                        달달달
# 774                        최대한
# 775                         외워
# 776                        그러다
# 777                     오엠알카드를
# 778                       받자마자
# 779                      수험번호를
# 780                         쓰고
# 781                         뒤가
# 782                        주관식
# 783                     답란이었는데
# 784                      거기에다가
# 785                         일단
# 786                         외운
# 787                         써요
# 788                        그러고
# 789                         나서
# 790                         마음
# 791                       편안하게
# 792                         일번
# 793                       문제부터
# 794                         풀어
# 795                       나갑니다
# 796                        그만큼
# 797                     특수각에서의
# 798                        반드시
# 799                        있어야
# 800                         방법
# 801                      드렸으니까
# 802                        나눈다
# 803                        곱한다
# 804                       여기까지
# 805                        정리할
# 806                        도대체
# 807                        문제는
# 808                       나오느냐
# 809                        너희가
# 810                        되는지
# 811                        나오기
# 812                        문제를
# 813                       내요라고
# 814                         말이
# 815                       없죠나와
# 816                        어떡해
# 817                        하나요
# 818                        외워서
# 819                         푸는
# 820                        이분의
# 821                      사십오도가
# 822                     가운데이니까
# 823                        삼에서
# 824                       이이겠네
# 825                 이분의일더하기루트이
# 826                       얼마였지
# 827                         줄에
# 828                        가운데
# 829                        일그걸
# 830                       곱했잖아
# 831                        더하기
# 832                        이쪽에
# 833                         있네
# 834                     루트일이었어
# 835                        사인이
# 836                       외워져서
# 837                       알겠나요
# 838                         개념
# 839                         확인
# 840                     문제였습니다
# 841                         이건
# 842                      그렇죠이제
# 843                       간단하게
# 844                        배웠던
# 845                        내용에
# 846                      다루는구나
# 847                        이것만
# 848                        있지는
# 849                      않겠죠외워
# 850                         풀진
# 851                         않을
# 852                        다양한
# 853                       문제들을
# 854                       살펴봐야
# 855                         예제
# 856                         문제
# 857                     나온다면서요
# 858                         거죠
# 859                        번쯤은
# 860                       외웠는지
# 861                       확인하는
# 862                      문제입니다
# 863                         가끔
# 864                        문제가
# 865                        시험에
# 866                      출제되기도
# 867                        틀리진
# 868                        않아요
# 869                        성실히
# 870                       외웠다면
# 871                        일번을
# 872                        가볍게
# 873                          볼
# 874                      텐데탄젠트
# 875                      얼마였어요
# 876                       머릿속에
# 877                          봐
# 878                       연상해서
# 879                       줄이었지
# 880                      가운데였지
# 881                       떠올라야
# 882                         돼일
# 883                        곱했던
# 884                      기억해야죠
# 885                        식으로
# 886                         표의
# 887                        구개의
# 888                       이미지를
# 889                         놓는
# 890                        연습도
# 891                      중요합니다
# 892                          첫
# 893                         줄이
# 894                       뭐였더라
# 895                      이분의였고
# 896                      루트삼인데
# 897                     끝이었으니까
# 898                 이분의루트삼이겠구나
# 899                         뭔가
# 900                        생각을
# 901                      정리하라는
# 902                      얘기예요두
# 903                         번째
# 904                        줄에서
# 905                       가운데가
# 906                       일이었고
# 907                        했었어
# 908                       나눴었어
# 909                 루트삼분의일이었구나
# 910                     됐나요곱하기
# 911                         둘째
# 912                          큰
# 913                   이분의일이겠구나
# 914                         가는
# 915                      거죠그래서
# 916                        여기는
# 917                       유리화해
# 918                         볼까
# 919                   루트삼분의루트삼
# 920   삼분의루트삼이죠삼분의루트삼곱하기이분의일이니까
# 921                    육분의루트삼이
# 922                         돼서
# 923                        육으로
# 924                        통분해
# 925        육분의삼루트삼더하기육분의루트삼이니까
# 926                        육분의
# 927                     4루트삼이고
# 928                       약분해서
# 929                  삼분의이루트삼까지
# 930                         답을
# 931                        되니까
# 932                        정답은
# 933                      삼번번이다
# 934                        구하면
# 935                         사실
# 936                       복잡하게
# 937                         쓰여
# 938                        실제로
# 939                         대한
# 940                          준
# 941                        다음에
# 942                        계산한
# 943                          것
# 944                       끝입니다
# 945                       외우니까
# 946                        아셨죠
# 947                       가능하면
# 948                      지향하지만
# 949                        암기할
# 950                        부분이
# 951                       있습니다
# 952                       다음으로
# 953                         이번
# 954                        들어가
# 955                        그래요
# 956                        싶어요
# 957                        하려는
# 958                          가
# 959                     볼게요그림과
# 960                     에이비씨에서
# 961                        육이고
# 962                       에이씨의
# 963                       삼이래요
# 964                        각비의
# 965                        크기를
# 966                       구하세요
# 967                     볼까요각비를
# 968                      기준각으로
# 969                        주어져
# 970                       추론하는
# 971                       추리하는
# 972                        구하라
# 973                        하라는
# 974                        얘기지
# 975                     문제에서이건
# 976                         높이
# 977                        그림이
# 978                         알려
# 979                        높이를
# 980                         주고
# 981                         거네
# 982                     대해서빗변과
# 983                      사인이었어
# 984                         맞아
# 985             빗변분의높이였어육분의삼이야
# 986                      육분의삼은
# 987                         뭐지
# 988                         놓고
# 989                         순간
# 990                       번쩍하고
# 991                         스쳐
# 992                       지나가야
# 993                          어
# 994                    이분의일이었지
# 995                         했을
# 996                   떠올라야죠뭡니까
# 997                        사인은
# 998                         도가
# 999                       삼0도가
# 1000                    이분의일이죠
# 1001                        비의
# 1002                      얼마라는
# 1003                         알
# 1004                        있어
# 1005                     삼십도라는
# 1006                    삼번번이렇게
# 1007                        싶은
# 1008                      얘기인지
# 1009                       알겠죠
# 1010                      삼번으로
# 1011                       텐데요
# 1012                        삼번
# 1013                       조금씩
# 1014                        다른
# 1015                      유형들이
# 1016                       나오고
# 1017                      삼각비를
# 1018                      이용하여
# 1019                       있잖아
# 1020                         전
# 1021                      구하라는
# 1022                       거였죠
# 1023                       하나가
# 1024                     유형이에요
# 1025                       어차피
# 1026                       이용할
# 1027                       거야왜
# 1028                      삼각비는
# 1029                       비율을
# 1030                  각씨는삼십도이고
# 1031                 에이씨는육루트이일
# 1032                   그랬어에이비의
# 1033                      구하래요
# 1034                       하고서
# 1035                     쳐다볼까요
# 1036                    기준각이라고
# 1037                      바라보면
# 1038                        우린
# 1039                        알아
# 1040                    맞죠직각에서
# 1041                     빗변이니까
# 1042                      자동으로
# 1043                      밑변이야
# 1044                       얘기네
# 1045                      에이비를
# 1046                       구하란
# 1047                       얘기고
# 1048                      밑변이네
# 1049                      생각하는
# 1050                      밑변하고
# 1051                       뭐였지
# 1052                     삼십도잖아
# 1053                  밑변분의높이였어
# 1054               육루트이분의에이비였어
# 1055                    얘기예요뭐야
# 1056                       에이비
# 1057                      구하라고
# 1058                        했네
# 1059                       숫자네
# 1060                      숫자이면
# 1061                       거잖아
# 1062                     대입하시면
# 1063                      등식에서
# 1064                       양변에
# 1065                     육루트이를
# 1066                        거고
# 1067           루트삼분의일곱하기육루트이니까
# 1068                      계산이죠
# 1069                이제루트삼분의루트삼
# 1070                       곱해서
# 1071                     유리화까지
# 1072                         해
# 1073                   삼분의육이니까
# 1074                     삼분의육은
# 1075                      남으니까
# 1076                   이루트육이렇게
# 1077                      에이비의
# 1078                      구한다는
# 1079                       그것의
# 1080                       의미는
# 1081                      삼십도에
# 1082                       밑변의
# 1083                       밑변과
# 1084                       안다는
# 1085                       얘기가
# 1086                 의미하니까삼각비가
# 1087                       있거나
# 1088                      삼각비가
# 1089                         꼭
# 1090                     아니더라도
# 1091                      탄젠트의
# 1092                   주어지면우리는
# 1093                       통해서
# 1094                       비들을
# 1095                        있단
# 1096                       정확히
# 1097                      얘기하면
# 1098                    그렇죠그래서
# 1099                      문제에서
# 1100                       구해낼
# 1101                        그게
# 1102                     핵심이겠죠
# 1103                       복잡한
# 1104                        풀기
# 1105                       위해서
# 1106                        가장
# 1107                        일이
# 1108                      뭐라고요
# 1109                        유제
# 1110                    보겠습니다첫
# 1111                      대입하면
# 1112                        풀고
# 1113                        단지
# 1114                       분수로
# 1115                       있어서
# 1116                      번거롭죠
# 1117                        이럴
# 1118                        분모
# 1119                        따로
# 1120                        분자
# 1121                        건데
# 1122                     분모분모는
# 1123                       곱하기
# 1124                     얼마입니까
# 1125                      외우셨죠
# 1126                 루트삼분의일이에요
# 1127                       그대로
# 1128                       분모가
# 1129                        좋다
# 1130                       일이면
# 1131                       가능해
# 1132                       생략이
# 1133                     가능하니까
# 1134                     거예요그냥
# 1135                       갑시다
# 1136                      가운데에
# 1137                       암기돼
# 1138                    돼요마이너스
# 1139                    루트삼이었죠
# 1140                   이분의이루트이
# 1141                      분배법칙
# 1142              루트이더하기루트이이니까
# 1143                    이루트이이죠
# 1144                       그리고
# 1145                     빼기루트삼
# 1146                        답인
# 1147                       외워져
# 1148                       있기만
# 1149                       뭔가를
# 1150                      이해하고
# 1151                     논리적으로
# 1152                      생각하고
# 1153                        필요
# 1154                        없이
# 1155                     형태입니다
# 1156                      마무리가
# 1157                     되고요다음
# 1158                      이번으로
# 1159                         나
# 1160                       알맞은
# 1161                     외웠니라고
# 1162                       대놓고
# 1163                        묻는
# 1164                      문제이죠
# 1165                     됩니까사인
# 1166                       나눴고
# 1167                       곱했고
# 1168                     됐나요이거
# 1169                       설명할
# 1170                    암기하셨다면
# 1171                       해결이
# 1172                     가능합니다
# 1173                      나오겠죠
# 1174                       오른쪽
# 1175                       그림과
# 1176                    삼루트육이고
# 1177                       비씨의
# 1178                     삼루트이야
# 1179                        싶죠
# 1180                       막이거
# 1181                   직각삼각형에서
# 1182                       정리가
# 1183                       너무나
# 1184                      익숙하기
# 1185                      각에이의
# 1186                       했는데
# 1187                       필요가
# 1188                        없는
# 1189                      에이씨를
# 1190                      왜냐하면
# 1191                        말도
# 1192                       없어요
# 1193                        변만
# 1194                      입장에서
# 1195                       밑변이
# 1196                   밑변분의높이는
# 1197                     탄젠트였지
# 1198                      도인지는
# 1199                     모르겠지만
# 1200                   밑변분의높이를
# 1201                      의미했어
# 1202                   삼루트이야일단
# 1203                       모양을
# 1204                 루트삼분의일이라는
# 1205                      외웠는데
# 1206                  루트삼분의일이야
# 1207                    삼십도이구나
# 1208                      마지막에
# 1209                       해결할
# 1210                       것이긴
# 1211                     하지만결국
# 1212                      에이라는
# 1213                      주어지면
# 1214                     주어졌는데
# 1215                       변이야
# 1216                      변이라는
# 1217                        말을
# 1218                       있어로
# 1219                       바꾸는
# 1220                       작업을
# 1221                      거예요왜
# 1222                    기준각에서의
# 1223                       대변이
# 1224                     높이이니까
# 1225                       빗변은
# 1226                        아닐
# 1227                       테니까
# 1228                     밑변이겠죠
# 1229                       얘하고
# 1230                        얘가
# 1231                      밑변이고
# 1232                      높이인지
# 1233                      의미하는
# 1234                       그들의
# 1235                      탄젠트로
# 1236                      연결되는
# 1237                       작업들
# 1238                      그다음에
# 1239                       끝나는
# 1240                     아셨죠이제
# 1241                        사번
# 1242                       문제로
# 1243                      들어가야
# 1244                  보겠습니다어려워
# 1245                       보이죠
# 1246                       굉장히
# 1247                      간단해요
# 1248                    단순화시켜서
# 1249                 이분의루트삼인지만
# 1250                      순서대로
# 1251                    루트삼이었어
# 1252                   이분의루트삼은
# 1253                 이분의루트삼이었지
# 1254                    있다면똑같고
# 1255                     똑같으니까
# 1256         삼각엑스더하기십오도는육십도이구나
# 1257                        알면
# 1258                      끝나겠죠
# 1259                        엑스
# 1260                      얘기잖아
# 1261                     그렇죠결국
# 1262                     삼각엑스가
# 1263                       십오도
# 1264                      이항해서
# 1265                   사십오도이니까
# 1266                        양변
# 1267                       삼으로
# 1268                       나누면
# 1269                      각엑스의
# 1270                       크기는
# 1271                        된다
# 1272                      십오도가
# 1273                       사이에
# 1274                       있는지
# 1275                      확인까지
# 1276                     됐죠똑같이
# 1277                       거지만
# 1278                       삼번과
# 1279                       중에서
# 1280                       삼번이
# 1281                       그래도
# 1282                       거리가
# 1283                        좋은
# 1284                      문제예요
# 1285                   복습하시더라도
# 1286                        신경
# 1287                        써서
# 1288                      주셨으면
# 1289                     좋겠습니다
# 1290                       유형에
# 1291                       이개의
# 1292                       유제가
# 1293                        남아
# 1294                      있는데이
# 1295                       유제는
# 1296                     강조하고자
# 1297                        모든
# 1298                        내용
# 1299                        핵심
# 1300                        끝나
# 1301                     생각하시면
# 1302                      돼요유제
# 1303                      오번부터
# 1304                       풀이를
# 1305                       내용이
# 1306                       오번에
# 1307                    각비는육십도
# 1308                      비씨는오
# 1309                       구하래
# 1310                        비씨
# 1311                이해되셨나요삼각비를
# 1312                     높이잖아요
# 1313                      밑변이죠
# 1314                      빗변이죠
# 1315                      생각하란
# 1316                   얘기야에이비를
# 1317                       빗변을
# 1318                         내
# 1319                     머릿속에선
# 1320                       관계가
# 1321                     뭐였는지를
# 1322                      떠올려야
# 1323                      거야뭐죠
# 1324                      코사인이
# 1325                        특히
# 1326                       뭐예요
# 1327                 빗변분의밑변이었어
# 1328                   에이비분의비씨
# 1329                       오예요
# 1330                       되지뭘
# 1331                       걱정해
# 1332                       걱정할
# 1333                        없지
# 1334                      문자예요
# 1335                      숫자잖아
# 1336                   이분의일입니다
# 1337                      끝나죠왜
# 1338                      에이비가
# 1339                       뭐라는
# 1340                  오곱하기이이니까
# 1341                      십입니다
# 1342                       단위가
# 1343                     십센치미터
# 1344                      지금까지
# 1345                       공부한
# 1346                      출제해야
# 1347                        오번
# 1348                        육번
# 1349                      난이도를
# 1350                        올려
# 1351                   하겠습니다먼저
# 1352                      복잡해요
# 1353                       할게요
# 1354                       그림의
# 1355                 삼각형에이비씨에서
# 1356                   에이에이치하고
# 1357                       비씨가
# 1358                        서로
# 1359                     수직이래요
# 1360                     수직여기가
# 1361                      구십도인
# 1362                       몰라요
# 1363                  직각삼각형에서의
# 1364                        닮음
# 1365                     구십도라는
# 1366                         말
# 1367                      없습니다
# 1368                       구십도
# 1369                        아닌
# 1370                     여러분들은
# 1371                       바라볼
# 1372                      바라봐야
# 1373                  삼각형에이비씨가
# 1374                    보입니다라고
# 1375                        도형
# 1376                       푼다는
# 1377                       그림은
# 1378               삼각형에이비에이치하고
# 1379                삼각형에이에이치씨가
# 1380                    에이에이치를
# 1381                      공통으로
# 1382                        붙어
# 1383                     겁니다라고
# 1384                      해석해야
# 1385                      구하고자
# 1386                    씨에이치예요
# 1387                        거지
# 1388                        내가
# 1389                      어디까지
# 1390                       가야지
# 1391                     씨에이치를
# 1392                   있지씨에이치를
# 1393                       싶다는
# 1394                     숙제입니다
# 1395                        잠깐
# 1396                      엑스라고
# 1397                      구하려면
# 1398                       알아야
# 1399                        되지
# 1400                     삼각형에서
# 1401                       변이든
# 1402                       그래야
# 1403                     사십오도를
# 1404                        쓰든
# 1405                      거거든요
# 1406                      변보다는
# 1407                        누가
# 1408                       구해져
# 1409                     구해지죠왜
# ...
# 1403                                             사십오도를0
# 1404                                   쓰1, 든1, 쓰던1, 거든1
# 1405                                               거거든1
# 1406                                        보다는1, 원보다는1
# 1407                                                누가0
# 1408                                          구해1, 구해줘1
# 1409                                              구했죠왜2
# 1410                       구해2, 구해줘2, 구했죠2, 구했죠2, 구해줘이2
# 1411                                                이쪽0
# 1412                                              이용해야0
# 1413                                       이쪽에서0, 이쪽에서0
# 1414                                             올0, 올0
# 1415                                            공통이잖아요1
# 1416                       에이치3, 금에이치3, 지금에이치3, 에이에이치가0
# 1417  그6, 인그6, 그래6, 재인그6, 인그래6, 그래도6, 문재인그6, 재인그래6, ...
# 1418                                               사십오3
# 1419  십3, 구3, 도3, 십3, 백십3, 십구3, 구할3, 래도3, 도좀3, 사십3, ...
# 1420                                          여기1, 여기사1
# 1421                                         삼각형0, 삼각형0
# 1422                                           에이에이치씨는0
# 1423                                            이등변삼각형0
# 1424                                    에이에이치1, 에이에이치씨1
# 1425                                               엑스가0
# 1426                                        네그럼1, 되네그럼1
# 1427  드1, 리1, 고1, 여1, 기1, 구1, 십1, 도1, 맨1, 여1, 기1, 도1...
# 1428  드1, 리1, 고1, 여1, 기1, 구1, 십1, 도1, 맨1, 여1, 기1, 도1...
# 1429                                              왼쪽으로0
# 1430                                               넘어서1
# 1431                               왼쪽1, 쪽에1, 왼쪽으1, 이쪽에1
# 1432       에있는위치에서7, 쪽에있는위치에서7, 이쪽에있는위치에서7, 아이쪽에있는위치에서7
# 1433                                               보니까0
# 1434                 높이2, 높이2, 높이높2, 높이가2, 높이높이2, 높이가져2
# 1435                                          높이1, 높이아1
# 1436  어떻게5, 아어떻게5, 래아어떻게5, 그래아어떻게5, 아그래아어떻게5, 이아그래아어떻게5
# 1437                                              생각하면0
# 1438                                          밑변불에높이는데3
# 1439                   의싸라는4, 레의싸라는4, 브레의싸라는4, 사브레의싸라는4
# 1440                                              이야기죠1
# 1441                                   루트삼이니까0, 루트삼이니까0
# 1442                                            배1, 내배1
# 1443                                        루트삼1, 가루트삼1
# 1444                                           에이에이치인데0
# 1445                                            에이치씨하고0
# 1446                                          겠죠1, 갔겠죠1
# 1447                                       이등변삼각형이없습니다1
# 1448  씨엠이3, 씨엠이렇3, 씨엠이렇게3, 이4, 답이4, 이아4, 나답이4, 답이아4,...
# 1449                                         사루트삼씨엠이렇게4
# 1450                                          교재1, 교재있1
# 1451                                          전체1, 전체문1
# 1452                                             되었습니다0
# 1453  영2, 숙2, 씨2, 이2, 학2, 년2, 때2, 선2, 생2, 님2, 이2, 그2...
# 1454                                               이학년0
# 1455  선생님1, 선생님1, 선생님이1, 선생님수1, 선생님1, 선생님이1, 선생님1, 선...
# 1456                                            런1, 그런1
# 1457                                   들1, 들1, 들을1, 들이1
# 1458                                        친구들1, 친구들을1
# 1459  수1, 수고1, 굉2, 장2, 히2, 여2, 러2, 분2, 들2, 이2, 습2, 관...
# 1460                                   에서2, 국에서2, 한국에서2
# 1461                                              좋아했던0
# 1462  영4, 숙4, 씨4, 이4, 학4, 년4, 때4, 선4, 생4, 님4, 이4, 그4...
# 1463                                               보통은0
# 1464  보2, 통2, 은2, 수2, 업2, 자2, 꾸2, 만2, 이2, 런2, 거2, 좋2...
# 1465                                             좋아하는데0
# 1466                                               제자들0
# 1467                                          훌륭2, 훌륭한2
# 1468                                            천1, 택천1
# 1469  선2, 생2, 님2, 이2, 막2, 그2, 있2, 죠2, 선2, 택2, 천2, 문2...
# 1470                                               어려운0
# 1471                       에2, 위에2, 관위에2, 에2, 풍에2, 소풍에2
# 1472                                                 글0
# 1473                                               주셔서0
# 1474                                               삼학년0
# 1475  에4, 서4, 위에4, 에좋4, 셔서4, 서삼4, 관위에4, 위에좋4, 에좋은4, ...
# 1476                                           준비를했습니다1
# 1477                                             궁금하시죠0
# 1478   보겠습니다3, 보겠습니다자3, 보겠습니다자손3, 보겠습니다자손이3, 보겠습니다자손이때3
# 1479                                             하겠는데요0
# 1480                                               풀었던0
# 1481                                              문제하고0
# 1482                                               유사한0
# 1483                                          형태1, 형태입1
# 1484                                               해결해0
# 1485                          하겠습니다2, 하겠습니다그2, 하겠습니다그림2
# 1486                                                전혀0
# 1487                                               느낌이0
# 1488                                          다르1, 다르지1
# 1489                                               그림만0
# 1490                                              문제라고0
# 1491                                              생각하기0
# 1492                                               쉬어요1
# 1493                               문제1, 문제1, 문제라1, 문제흐1
# 1494                                               흐름이0
# 1495                                                느껴0
# 1496                          봅시다육이3, 봅시다육이고3, 봅시다육이고지3
# 1497                                                보고0
# 1498                                   해야2, 들해야2, 분들해야2
# 1499                                               알겠어0
# 1500                                         삼각형에이비씨하고0
# 1501                                             또0, 또0
# 1502                                               하나의0
# 1503  디씨비가3, 는디씨비가3, 삼각형에이비3, 기는디씨비가3, 삼각형에이비씨3, 여기는...
# 1504                                               누구를0
# 1505                       비씨를0, 비씨를0, 비씨를0, 비씨를0, 비씨를0
# 1506                                               그러니0
# 1507                                              연결하는0
# 1508                               는3, 하는3, 결하는3, 연결하는3
# 1509                                               누구야0
# 1510                                        포인트1, 포인트야1
# 1511                                        야이걸1, 트야이걸1
# 1512                                              생각해야0
# 1513                                                나는0
# 1514   이2, 이2, 리2, 이쪽2, 이렇2, 다리2, 리를2, 이쪽에2, 이렇게2, 다리를2
# 1515                                             넘어가려면0
# 1516                                               다리를0
# 1517                                                건널0
# 1518                                          야지1, 봐야지1
# 1519                                               넘어갈0
# 1520                                             생각하면서0
# 1521                                                읽어0
# 1522                             볼게요비2, 볼게요비밀2, 볼게요비밀이2
# 1523                                        잖아요1, 되잖아요1
# 1524                                              오른쪽에0
# 1525                                                어느0
# 1526                                         이거든0, 이거든0
# 1527                       그래야3, 다그래야3, 된다그래야3, 야된다그래야3
# 1528                      구하겠1, 구하겠어1, 구하2, 구하라2, 구하라아2
# 1529                                          구하1, 구하라1
# 1530                                               아니죠0
# 1531                                하얀색2, 하얀색써2, 하얀색써넘2
# 1532                                              넘어가야1
# 1533                                            되니까그러면0
# 1534                                               높이죠0
# 1535                       하얀색3, 하얀색이3, 하얀색이상3, 하얀색이상그3
# 1536                                 였2, 모였2, 였어2, 모였어2
# 1537                                          탄젠트니다아그럼2
# 1538                                   니까2, 뭡니까2, 의뭡니까2
# 1539                                            육분의비씨다1
# 1540                                   육1, 육대1, 육1, 육코1
# 1541                                               비씨는0
# 1542                             트삼3, 노트삼3, 트삼의3, 노트삼의3
# 1543                                             거야이렇게0
# 1544                                               단계가0
# 1545                                             들어가야죠0
# 1546                                             오른쪽으로0
# 1547                                               넘어올0
# 1548                                               있겠네0
# 1549                                                다리0
# 1550                                                건너0
# 1551  다5, 비5, 다5, 다리5, 사비5, 비리5, 니다5, 다어5, 다리건5, 목사비...
# 1552                                             사십오돼서1
# 1553                               만3, 그만3, 제그만3, 이제그만3
# 1554                                           됐나요아그러면1
# 1555                                               높이는0
# 1556                                    인이었구나1, 싸인이었구나1
# 1557                                   비디2, 비디피2, 비디피높2
# 1558                                              누구예요0
# 1559                          트삼있잖아3, 노트삼있잖아3, 금노트삼있잖아3
# 1560                                      비2, 비닐2, 비닐을2
# 1561                                            거야아그러면1
# 1562                       이분의루트이2, 이분의루트이적2, 이분의루트이적요2
# 1563                    야3, 거야3, 야아3, 는거야3, 거야아3, 는거야아3
# 1564  이5, 는5, 이5, 이5, 이렇5, 치는5, 는이5, 이렇5, 삼이5, 이적5, ...
# 1565  삼이5, 면삼이5, 삼이적5, 하면삼이5, 면삼이적5, 곱하면삼이5, 하면삼이적5,...
# 1566                                              루트이로0
# 1567                                여기서3, 여기서양3, 여기서양변3
# 1568   니까3, 니니까3, 계사아니3, 아니니까3, 계사아니니3, 사아니니까3, 계사아니니까3
# 1569                                                쭉쭉0
# 1570                                                나갈0
# 1571                       는2, 는2, 이는2, 나는2, 이이는2, 끝나는2
# 1572        이1, 이1, 이1, 이1, 이1, 답이1, 이이1, 면이1, 은이1, 은이1
# 1573                                              약품되면1
# 1574  그1, 래1, 서1, 대1, 답1, 이1, 이1, 는1, 결1, 국1, 뭐1, 가1...
# 1575  그4, 래4, 서4, 대4, 답4, 이4, 이4, 는4, 결4, 국4, 뭐4, 가4...
# 1576                                              구하시면0
# 1577                                있겠죠2, 있겠죠네2, 있겠죠네오2
# 1578  이5, 건5, 할5, 수5, 있5, 겠5, 죠5, 네5, 오5, 늘5, 이5, 문5...
# 1579                                             이하잖아요1
# 1580                                      학교0, 학교0, 학교0
# 1581                                           끝난0, 끝난0
# 1582                                              일단학교0
# 1583                 시험2, 에서2, 시험끝2, 교에서2, 시험끝난2, 학교에서2
# 1584                                               파트에0
# 1585                                               하나로0
# 1586                                               끝난다2
# 1587                                    보겠습니다삼각형에이비씨에서0
# 1588                                           에이비가육이고1
# 1589                                    이고구미다5, 육이고구미다5
# 1590                            비에이치가삼십도일4, 다비에이치가삼십도일4
# 1591                                               결론이0
# 1592                                                보자0
# 1593                                          거야1, 기거야1
# 1594                                          스는1, 덱스는1
# 1595                  밑변4, 밑변인4, 밑변인덱4, 밑변인덱스4, 밑변인덱스는4
# 1596                                  에이에이치분1, 에이에이치분에1
# 1597                   씨에이치0, 에이치1, 는에이치1, 씨에이치0, 씨에이치0
# 1598                                   라고1, 야라고1, 거야라고1
# 1599                                               결론을0
# 1600                                                정해0
# 1601  이5, 에5, 님이5, 이삼5, 형에5, 에서5, 생님이5, 님이삼5, 이삼각5, ...
# 1602                                               않네요0
# 1603                                               맞아요0
# 1604                           에요3, 니에요3, 아니에요3, 거아니에요3
# 1605                                          어렵습니다그러면0
# 1606                                               밑변을0
# 1607                             니까결국2, 히니까결국2, 롭히니까결국2
# 1608                                         육분의에이에이치가0
# 1609                                            삼십도입니다0
# 1610                                        에이에이치는육코사인3
# 1611                                              삼루트삼0
# 1612                  나는4, 가나는4, 치가나는4, 이치가나는4, 에이치가나는4
# 1613                                              해결했어0
# 1614                                              목적이야0
# 1615                                               있느냐0
# 1616               치를선생님3, 위치를선생님3, 스위치를선생님3, 냐스위치를선생님3
# 1617                                           정리0, 정리0
# 1618                                            면1, 으면1
# 1619                                              되나요예0
# 1620                                                써도0
# 1621                                               볼까요0
# 1622                                           제곱0, 제곱0
# 1623  구2, 해2, 볼2, 까2, 요2, 어2, 어2, 떻2, 게2, 구2, 할2, 수2...
# 1624                                           제곱구백팔십일5
# 1625                                    삼루트삼의제곱은이십칠이니까1
# 1626                                            루트오십사가0
# 1627                                              오십사는0
# 1628                              곱은이십칠이니까7, 제곱은이십칠이니까7
# 1629                                    루트육가지2, 살루트육가지2
# 1630                                               끝났네0
# 1631                                              삼루트육0
# 1632                                          결과1, 결과를1
# 1633                                            루트이이렇게0
# 1634  고5, 고5, 라고5, 였고5, 더라고5, 거였고5, 없더라고5, 는거였고5, 는없...
# 1635                                              공부했던1
# 1636                                               핵심은0
# 1637                                               거였고0
# 1638                                                유형0
# 1639                                              문제까지0
# 1640                                              확실하게0
# 1641                                끝냈다1, 끝냈다라1, 끝냈다라고1
# 1642                                                자신0
# 1643                                            말씀드립니다0
# 1644                                            공1, 공소1
# 1645                                              정리하고0
# 1646                                            마무리합니다0
# 1647  오3, 늘3, 함3, 께3, 정3, 리3, 할3, 게3, 요3, 싸3, 인3, 삼3...
# 1648                                             정리할게요0
# 1649                                      분2, 분의2, 분의루2
# 1650                           올라3, 올라갔3, 올라갔으3, 올라갔으면3
# 1651  오2, 늘2, 함2, 께2, 정2, 리2, 할2, 게2, 요2, 싸2, 인2, 삼2...
# 1652                                              내려왔죠0
# 1653  이겼습니다8, 로이겼습니다8, 이겼습니다자8, 일로이겼습니다8, 로이겼습니다자8, ...
# 1654                                           삼분의부산에서4
# 1655                                        루트삼1, 루트삼십1
# 1656                                               나간다0
# 1657  위2, 례2, 에2, 서2, 삼2, 분2, 의2, 부2, 산2, 에2, 서2, 루2...
# 1658                                            부탁드릴게요0
# 1659                                                아까0
# 1660                                               숙제로0
# 1661                                드린다1, 드린다라1, 드린다라고1
# 1662                                             말씀드렸던0
# 1663                                            기억하시나요0
# 1664                                              순서까지0
# 1665                                               나답이3
# 1666                                              아니고요0
# 1667                                               흐름을0
# 1668                                                남겨0
# 1669                                      소2, 소풍2, 소풍에2
# 1670                                      이2, 님이2, 생님이2
# 1671                                              되겠네요0
# 1672                                                수고0
# 1673                                              하셨고요0
# 1674                                               열심히0
# 1675                                          준비1, 준비하1
# 1676                                          도록1, 하도록1
# 1677                                               뵐게요0

# %%
3 -> 삼, 세(개)

# %%
삼각비의 -> 삼갑의 안찾고 다른것찾음

# %%
s_1 = '이건 우리가 중학교 이학년 때 배웠죠 그렇죠 각에이가 공통이고 그다음에 둘 다 직각을 갖고 있으니까 에이에이닮음이 될 테고'
s_2 = '이건 우리가 중학교 이해하는 데 배웠죠 가계가 공통 이고 그 다음에 둘 다 즉각 을 갖고 있으니까 에이에이 닮은 있을 테고'

# %%
수학기호여부이면 데이터프레임에 표시해둘것
