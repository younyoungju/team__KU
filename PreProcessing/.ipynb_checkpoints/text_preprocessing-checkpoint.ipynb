# %%
# !pip install python-docx

# %%
import docx

# %%
def getText_azure(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return ''.join(fullText)
#getText_azure("miso_1.docx")

# %%
import re
def getText_smi( File ):
    text = []
    file = open(File, "r" , encoding = "euc_kr")
    wholefile = file.readlines()
    for line in wholefile:
        line = line.strip()
        if re.search(r"#",line) or line.endswith(":>"):
            continue
        elif line.startswith('<') or line.endswith("; }"):
            continue
        elif line.startswith('--') or line.endswith(";"):
            continue
        text.append(line)   #re 쓰는법 알려주세요
    return ''.join(text).split(' 봅시다.(다)를')[0]  #microsoft가 다 안되서 되는데까지 짤랏어요

#getText_smi('subtitle_2.smi')

# %%
# !pip install cdifflib

# %%
from cdifflib import CSequenceMatcher
def comparison(aText,bText):
    return round(CSequenceMatcher(None, aText, bText).ratio(), 4)

aText = getText_azure('miso_2.docx')#.split(" ")
bText = getText_smi('subtitle_2.smi')#.split(" ")
comparison(aText,bText)
# Out:
# 0.4477

# %%
len(aText)
# Out:
# 4060

# %%
len(bText)
# Out:
# 3359

# %%
import re
def getText_smi( File ):
    text = []
    file = open(File, "r" , encoding = "euc_kr")
    wholefile = file.readlines()
    for line in wholefile:
        line = line.strip()
        if re.search(r"#",line) or line.endswith(":>"):
            continue
        elif line.startswith('<') or line.endswith("; }"):
            continue
        elif line.startswith('--') or line.endswith(";"):
            continue
        text.append(line)   #re 쓰는법 알려주세요
    return ''.join(text)#.split(' 분모 미분하면.')[0]  #microsoft가 다 안되서 되는데까지 짤랏어요

#getText_smi('subtitle_1.smi')

# %%
len(getText_azure('miso_1.docx'))
# Out:
# 10719

# %%
len(getText_smi('subtitle_1.smi'))
# Out:
# 18306

# %%
len(getText_smi('subtitle_1.smi'))
# Out:
# 10297

# %%
aText = getText_azure('miso_1.docx')
bText = getText_smi('subtitle_1.smi')
comparison(aText,bText)
# Out:
# 0.5541

# %%
def getText_azure(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return ''.join(fullText)
getText_azure("miso_3.docx")
# Out:
# '그러니까 파이널 실전 모의고사 수학 가형 에 남편입니다. 삼각 입니다. 자 삼 강의는 요? 그게 이십일번 여러분 기다리고 있는 킬러 문제 준비되어 있습니다. 자, 이번 시간도 우리 디테일하게 정말 이 어려운 문제를 과연 어떻게 해결할 수 있을까? 문항 분석 이란 이런 것이다, 이런 생각을 해보면 해보면서 함께 열심히 공부해 보기로 하겠습니다. 이 십 부탁하겠습니다. 이 십 번은 사실은 이문호 에 비해서 상당히 에 어렵지 않은 문제. 있습니다. 예 반전 이죠. 쉬운 문제는 이제. 오히려 다른 게 어렵지? 20분 이 제가 봤을 때는 앞에 있는 뭐 음 십 팔 번 이나 이런걸 받기가 바뀌어야 되지 않았을까? 그런 생각이 들 정도로 어려운 문제가 아닙니다. 정 여기 나와 있구요 예 삼각함수 나와있죠. 연구부터 파일까지 영상 파일 이 만 542 네 그래요. 네 fi 이상 이 팔 만 일 회를 이거를. II게 무슨 말I까 osiris 먼저 우리0가 좀 그래프를 그래서 좀 생각해 봅시다 왜냐면 그래픽II 나V니까 옆에다0가 Y 축의 있구요? X 있습니다. 아 영 이 상 fi 만 일 때는 오 사이즈입니다. 울산의. 요렇게? 이 상 미망 여기가 오 여기가 fi? 근데 문제는 fi 부터 이 파이 갈 때는? 오분의 삼배 하고 x verify 예를 x 축 방향으로 fi 만큼 평에 이동하고. 오해다 오분의 상태라면 세 배가 되겠지만 쌓인 x 최대값이 이러는데 일 다섯 배로 늘려 써 개를 다시 오븐에 삼배 하니까 뭐가 되는 거야? 삼 이 되는 거죠. 어떻게 리파인 빠져 되겠죠. 여기가 뭐가 됩니까? 에 삼 이 된다. 요것만 바로 그릴 수 있으니 문제는 정말 아무것도 아니야. 그리고 그걸 모른다고 해도 하나씩 너무 먼데 하나씩 대입해 봐봐. 여기 fi 등 있잖아요. Fi 집어 넣어 보세요. 파이의 파이 는. F 영예다 5분 의 삼. F 영은 영 이야? 영업외비용 이라고 여기 이렇게 딱 붙어 있을 거라고 취해질 거라고? 자 그 fi 에서 점점 점점 커져 많이 분의 삼 파이 정도 생각해 
# ...

# %%
#3
import re
def getText_smi( File ):
    text = []
    file = open(File, "r" , encoding = "euc_kr")
    wholefile = file.readlines()
    for line in wholefile:
        line = line.strip()
        if re.search(r"#",line) or line.endswith(":>"):
            continue
        elif line.startswith('<') or line.endswith("; }"):
            continue
        elif line.startswith('-') or line.endswith(";"):
            continue
        text.append(line)   #re 쓰는법 알려주세요
    return ''.join(text)#.split(' 왜 그럴까?')[0]  #microsoft가 다 안되서 되는데까지 짤랏어요
getText_smi('subtitle_3.smi')
# Out:
# "여러분 안녕하십니까? FINAL 실전모의고사 수학 가형의 남치열입니다. 3강입니다. 3강은 드디어 21번 여러분이 기다리고 있는 킬러 문제 준비되어 있습니다.이번 시간도 우리 디테일하게 정말 어려운 문제를 과연 어떻게 내가 해결할 수 있을까? 문항 분석이란 이런 것이다. 이런 생각을 해보면서 함께 열심히 공부해보기로 하겠습니다. 20번부터 가겠습니다.20번은 사실 이 문항 번호에 비해서 상당히 어렵지 않은 문제였습니다. 반전이지요? 쉬운 문제예요, 쉬운 문제. 오히려 다른 것이 어려웠지 20번이 제가 봤을 때는 앞에 있는 18번이나 이런 것으로 바뀌어야 하지 않았을까.그런 생각이 들 정도로 어려운 문제는 아닙니다. 정의역이 나와 있고요. 삼각함수 나와 있지요? 0부터 π까지, 0이상 π미만은 5sinx래요. π이상 2π미만일 때 이것을 읽어내야 돼요.이것이 무슨 말일까? 5sinx 먼저 우리가 그래프를 그려서 생각해봅시다. 왜냐하면 그래프 이야기가 나오니까 여기 옆에다가 y축이 있고요. x축이 있습니다.0 이상 π미만일 때는 5sinx입니다, 이렇게. 여기 이상, 미만. 여기가 5, 여기가 π. 그런데 문제는 π부터 2π 갈 때는 5분의 3배하고 (x-π) 이것을 x축 방향으로 π만큼 평행이동하고 5에다가 5분의 3배를 하면 3배가 되겠지?그러니까 sinx의 최댓값이 1이었는데 이것을 5배로 늘렸어. 그것을 다시 5분의 3배 하니까 무엇이 되는 거야? 3이 되는 것이지요, 이렇게. 여기 2π는 빠져야 하겠지요. 여기가 무엇이 됩니까? 3이 된다.이것만 바로 그려낼 수 있으면 이 문제는 정말 아무것도 아니야. 그리고 그것을 모른다고 해도 하나씩 넣어보면 돼. 하나씩 대입해 볼게, 봐봐. 여기 π 등호 있잖아요? π 집어넣어보세요, 여기다 π.f(π)는 f(0)에다 5분의 3. f(0)은 0이야. 0에다 5분의 3 곱했는데 0이라고. 여기 이렇게 딱 붙어있을 것이라고, 칠해질 것이라고. 그리고 π에서 점점 커져. 그러면 한 2분의 3π 정도 생각해볼까? 이 
# ...

# %%
aText = getText_azure('miso_3.docx')
bText = getText_smi('subtitle_3.smi')
comparison(aText,bText)
# Out:
# 0.4382

# %%
len(aText),len(bText)
# Out:
# (10210, 9726)

# %%
from difflib import context_diff
def comparison2(aText,bText):
    return context_diff(aText.split(" "), bText.split(" "))

# %%
aText = getText_azure('miso_3.docx')
bText = getText_smi('subtitle_3.smi')
print(len(list(comparison2(aText,bText)))/len(bText))
# Out:
# 0.5258071149496196

# %%
dir(difflib)
# Out:
# ['Differ',
#  'HtmlDiff',
#  'IS_CHARACTER_JUNK',
#  'IS_LINE_JUNK',
#  'Match',
#  'SequenceMatcher',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_calculate_ratio',
#  '_check_types',
#  '_count_leading',
#  '_file_template',
#  '_format_range_context',
#  '_format_range_unified',
#  '_legend',
#  '_mdiff',
#  '_namedtuple',
#  '_nlargest',
#  '_styles',
#  '_table_template',
#  '_test',
#  'context_diff',
#  'diff_bytes',
#  'get_close_matches',
#  'ndiff',
#  'restore',
#  'unified_diff']

# %%
import difflib

# %% [markdown]
# # 해야될일
# - ebs에서 음성파일만 받아오는 코드
# - 받아온 파일을 지원하는 확장자로 전화 (or 지원하는 확장자로 다운)
# - 전환된 파일을 stt 서비스 돌리기
# - 돌린후 텍스트 받는 코드
# - 자막이랑 받은 텍스트 비교 하는 코드

# %% [markdown]
# # 1.
#     - <div class="mpv-device"><video webkit-playsinline="true" webkitplaysinline="true" playsinline="true" autoplay="true" id="video_e6b4942e147569713490d8b60f2ac3b9" playertype="video" playerclassname="imgtech.media.VideoPlayer" style="width: 100%; height: 100%; margin: 0px; padding: 0px; text-align: center; vertical-align: middle;" src="http://WSTR.ebsi.co.kr/M41M2001/S20200000109/S20200000109_1M4_000000255748.mp4"></video></div>
#     - <img src="http://image.ebsi.co.kr/ebsi/images/reNskin2020/lecture/ico_play.png" title="고화질 영상보기" id="lecturePlay" class="lecturePlay viewHigh" onclick="mylessonViewNew('', 'LS000000255748', 'V1M4', 'silverlight', 'true',true,0,'');return false;" style="">

# %%
import json

# %%
with open('asrOutput.json') as f:
    data = json.load(f)
print(data)
# Out:
# {'jobName': 'ebs', 'accountId': '086427117987', 'results': {'transcripts': [{'transcript': '여러분 안녕하십니까. 파이널 실전 모의고사 수학 가형 에 넘칩니다. 삼각 입니다. 삼. 가계는 이십일 번 여러분 기다리고 있는 킬러 문제의 준비되어 있습니다. 이번 시간도 우리 디테일하게 정말 어려운 문제를 과연 어떻게 내가 해결할 수 있을까 문항 분석 이란 이런 것이다. 이런 생각을 해보면 해보면서 함께 열심히 거부해 보기로 하겠습니다. 이십 번부터 하겠습니다. 이십 번은 사실 이 문항 번호에 비해 상당히 어렵지 않은 문제였습니다. 반전의 쉬운 문제의식, 오히려 다른 결여 지 이십 번의 제가 봤을 때는 앞에 있는 십팔 번이나 바뀌자 밖에 되지 않았을까 그런 생각이 들 정도로 어려운 문제가 아닙니다. 정력이 나와 있고요. 삼각함수 나와 있죠? 역 부터 팔 일까지 영상 파일 미만은 오 사인 엑스레이 파이 이상 의 팔 일대 요일을 읽어내는 이를 이게 무슨 말일까? 호사 이네스. 먼저 우리가 그래프를 그랬으면 생각해 봅시다. 그래 폐기가 나오니까. 게다가 Y 축 있고요. 백 있습니다. 형 이상 타이 미만일 때는 오 사이 핵심이라고 이상 미만 여기가 오 여기가 파이 네 문제는 팔 일부터 이파리 갈때는 오 분의 삼 배 하고 X 백 의 파이. 이를 X 축 방향으로 파이 만큼 평일 기도하고 오해다. 오 분의 삼 배 라면 세배가 되겠습니까? 사인 X 의 최대 값이 일했는데, 이를 다섯 배로 늘려 있어 개를 다시 오 분에 삼백 하니까 뭐가 되는 거야? 삶의 되는 거죠. 이파리를 빠져 되겠죠. 여기가 뭐가 됩니까? 삶이 됐다. 요금만 바로 그릴 수 있으니 이 문제를 정말 아무것도 아닙니다. 그리고 그걸 모른다고 해도 하나씩 넘었는데 하나씩 대입해 먹기 바바 파리 등 있잖아요. 파인 십오 로봇 IF 파이는 F 형이다. 오 분의 삼 F 형 은 영양 영유아 올해 사고 폐지 용 이라고 묘기를 딱 붙어 있을 거라고 치러질
# ...

# %%
def getText_json(file):
    with open(file) as f:
        data = json.load(f)
    for _ in data['results']['transcripts']:
        return "".join(_['transcript'])

# %%
file = 'asrOutput.json'
with open(file) as f:
    data = json.load(f)
for _ in data['results']['items']:
    print(_)
    #print(_['alternavies']['content'])
#     para =  "".join(_['items'])
# return para
# Out:
# {'start_time': '10.07', 'end_time': '10.31', 'alternatives': [{'confidence': '0.9982', 'content': '여러분'}], 'type': 'pronunciation'}
# {'start_time': '10.31', 'end_time': '10.9', 'alternatives': [{'confidence': '1.0', 'content': '안녕하십니까'}], 'type': 'pronunciation'}
# {'alternatives': [{'confidence': '0.0', 'content': '.'}], 'type': 'punctuation'}
# {'start_time': '10.96', 'end_time': '11.27', 'alternatives': [{'confidence': '0.8808', 'content': '파이널'}], 'type': 'pronunciation'}
# {'start_time': '11.27', 'end_time': '11.56', 'alternatives': [{'confidence': '0.9356', 'content': '실전'}], 'type': 'pronunciation'}
# {'start_time': '11.56', 'end_time': '12.02', 'alternatives': [{'confidence': '1.0', 'content': '모의고사'}], 'type': 'pronunciation'}
# {'start_time': '12.03', 'end_time': '12.3', 'alternatives': [{'confidence': '0.8108', 'content': '수학'}], 'type': 'pronunciation'}
# ...

# %%
getText_json('asrOutput.json')
# Out:
# '여러분 안녕하십니까. 파이널 실전 모의고사 수학 가형 에 넘칩니다. 삼각 입니다. 삼. 가계는 이십일 번 여러분 기다리고 있는 킬러 문제의 준비되어 있습니다. 이번 시간도 우리 디테일하게 정말 어려운 문제를 과연 어떻게 내가 해결할 수 있을까 문항 분석 이란 이런 것이다. 이런 생각을 해보면 해보면서 함께 열심히 거부해 보기로 하겠습니다. 이십 번부터 하겠습니다. 이십 번은 사실 이 문항 번호에 비해 상당히 어렵지 않은 문제였습니다. 반전의 쉬운 문제의식, 오히려 다른 결여 지 이십 번의 제가 봤을 때는 앞에 있는 십팔 번이나 바뀌자 밖에 되지 않았을까 그런 생각이 들 정도로 어려운 문제가 아닙니다. 정력이 나와 있고요. 삼각함수 나와 있죠? 역 부터 팔 일까지 영상 파일 미만은 오 사인 엑스레이 파이 이상 의 팔 일대 요일을 읽어내는 이를 이게 무슨 말일까? 호사 이네스. 먼저 우리가 그래프를 그랬으면 생각해 봅시다. 그래 폐기가 나오니까. 게다가 Y 축 있고요. 백 있습니다. 형 이상 타이 미만일 때는 오 사이 핵심이라고 이상 미만 여기가 오 여기가 파이 네 문제는 팔 일부터 이파리 갈때는 오 분의 삼 배 하고 X 백 의 파이. 이를 X 축 방향으로 파이 만큼 평일 기도하고 오해다. 오 분의 삼 배 라면 세배가 되겠습니까? 사인 X 의 최대 값이 일했는데, 이를 다섯 배로 늘려 있어 개를 다시 오 분에 삼백 하니까 뭐가 되는 거야? 삶의 되는 거죠. 이파리를 빠져 되겠죠. 여기가 뭐가 됩니까? 삶이 됐다. 요금만 바로 그릴 수 있으니 이 문제를 정말 아무것도 아닙니다. 그리고 그걸 모른다고 해도 하나씩 넘었는데 하나씩 대입해 먹기 바바 파리 등 있잖아요. 파인 십오 로봇 IF 파이는 F 형이다. 오 분의 삼 F 형 은 영양 영유아 올해 사고 폐지 용 이라고 묘기를 딱 붙어 있을 거라고 치러질 거라고. 파리에서 점점 커져 동안 이 분의 삼 팔 일 정도 생각해보니까 일자리 이번에 삼 판이 높아. 이번에 삼 판이 너무 새로 이번에 삼 팔 월 팔 일 금 이 
# ...

# %%
bText
# Out:
# "여러분 안녕하십니까? FINAL 실전모의고사 수학 가형의 남치열입니다. 3강입니다. 3강은 드디어 21번 여러분이 기다리고 있는 킬러 문제 준비되어 있습니다.이번 시간도 우리 디테일하게 정말 어려운 문제를 과연 어떻게 내가 해결할 수 있을까? 문항 분석이란 이런 것이다. 이런 생각을 해보면서 함께 열심히 공부해보기로 하겠습니다. 20번부터 가겠습니다.20번은 사실 이 문항 번호에 비해서 상당히 어렵지 않은 문제였습니다. 반전이지요? 쉬운 문제예요, 쉬운 문제. 오히려 다른 것이 어려웠지 20번이 제가 봤을 때는 앞에 있는 18번이나 이런 것으로 바뀌어야 하지 않았을까.그런 생각이 들 정도로 어려운 문제는 아닙니다. 정의역이 나와 있고요. 삼각함수 나와 있지요? 0부터 π까지, 0이상 π미만은 5sinx래요. π이상 2π미만일 때 이것을 읽어내야 돼요.이것이 무슨 말일까? 5sinx 먼저 우리가 그래프를 그려서 생각해봅시다. 왜냐하면 그래프 이야기가 나오니까 여기 옆에다가 y축이 있고요. x축이 있습니다.0 이상 π미만일 때는 5sinx입니다, 이렇게. 여기 이상, 미만. 여기가 5, 여기가 π. 그런데 문제는 π부터 2π 갈 때는 5분의 3배하고 (x-π) 이것을 x축 방향으로 π만큼 평행이동하고 5에다가 5분의 3배를 하면 3배가 되겠지?그러니까 sinx의 최댓값이 1이었는데 이것을 5배로 늘렸어. 그것을 다시 5분의 3배 하니까 무엇이 되는 거야? 3이 되는 것이지요, 이렇게. 여기 2π는 빠져야 하겠지요. 여기가 무엇이 됩니까? 3이 된다.이것만 바로 그려낼 수 있으면 이 문제는 정말 아무것도 아니야. 그리고 그것을 모른다고 해도 하나씩 넣어보면 돼. 하나씩 대입해 볼게, 봐봐. 여기 π 등호 있잖아요? π 집어넣어보세요, 여기다 π.f(π)는 f(0)에다 5분의 3. f(0)은 0이야. 0에다 5분의 3 곱했는데 0이라고. 여기 이렇게 딱 붙어있을 것이라고, 칠해질 것이라고. 그리고 π에서 점점 커져. 그러면 한 2분의 3π 정도 생각해볼까? 이 
# ...

# %%
from cdifflib import CSequenceMatcher
def comparison(aText,bText):
    return round(CSequenceMatcher(None, aText, bText).ratio(), 4)
from difflib import context_diff
def comparison2(aText,bText):
    return context_diff(aText.split(" "), bText.split(" "))

# %%
aText = getText_json('asrOutput.json')
bText = getText_smi('subtitle_3.smi')
comparison(aText,bText)
# Out:
# 0.2857

# %%
print(len(list(comparison2(aText,bText)))/len(bText))
# Out:
# 0.5091258965537349
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-3004b42ae5ce> in <module>
# ----> 1 print(len(list(comparison2(aText,bText)))/len(bText))
#
# TypeError: 'NoneType' object is not iterable

# %%
sentence = (compare,origin)
from sklearn.feature_extraction.text import TfidfVectorizer

# 객체 생성
tfidf_vectorizer = TfidfVectorizer()

# 문장 벡터화 진행
tfidf_matrix = tfidf_vectorizer.fit_transform(sentence)

# 각 단어
text = tfidf_vectorizer.get_feature_names()

# 각 단어의 벡터 값
idf = tfidf_vectorizer.idf_

print(dict(zip(text,idf)))

import numpy as np

def l1_normalize(v):
    norm = np.sum(v)
    return v / norm 
  
# L1 정규화  
tfidf_norm_l1 = l1_normalize(tfidf_matrix)

# 맨하탄 유사도
from sklearn.metrics.pairwise import manhattan_distances

manhattan_distances(tfidf_norm_l1[0:1], tfidf_norm_l1[1:2])

# %% [markdown]
# # 3

# %%
pip install azure-cognitiveservices-speech
# Out:
# ...
#      |████████████████████████████████| 1.9MB 980kB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import azure.cognitiveservices.speech as speechsdk

# %%
# SpeechConfig(subscription: typing.Union[str, NoneType] = None,\n
#              region: typing.Union[str, NoneType] = None, \n 
#              endpoint: typing.Union[str, NoneType] = None, \n 
#              host: typing.Union[str, NoneType] = None, \n
#              auth_token: typing.Union[str, NoneType] = None, \n
#              speech_recognition_language: typing.Union[str, NoneType] = None)
speech_key, service_region = 'Korea Central', "koreacentral"
speech_config = speechsdk.SpeechConfig(subscription=speech_key, region=service_region)

audio_filename = "lec3.wav"
audio_input = speechsdk.AudioConfig(filename=audio_filename)
speech_recognizer = speechsdk.SpeechRecognizer(speech_config=speech_config, audio_config=audio_input)

#single recognition
result = speech_recognizer.recognize_once_async()

if result.reason == speechsdk.ResultReason.RecognizedSpeech:
    print("Recognized: {}".format(result.text))
elif result.reason == speechsdk.ResultReason.NoMatch:
    print("No speech could be recognized: {}".format(result.no_match_details))
elif result.reason == speechsdk.ResultReason.Canceled:
    cancellation_details = result.cancellation_details
    print("Speech Recognition canceled: {}".format(cancellation_details.reason))
    if cancellation_details.reason == speechsdk.CancellationReason.Error:
        print("Error details: {}".format(cancellation_details.error_details))

#continuous recognition
#audio_config = speechsdk.audio.AudioConfig(filename=audio_filename)
#speech_recognizer = speechsdk.SpeechRecognizer(speech_config=speech_config, audio_config=audio_config)
#done = False
#def stop_cb(evt):
#     print('CLOSING on {}'.format(evt))
#     speech_recognizer.stop_continuous_recognition()
#     nonlocal done
#     done = True
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-4a276ae916be> in <module>
#      15 result = speech_recognizer.recognize_once_async()
#      16
# ---> 17 if result.reason == speechsdk.ResultReason.RecognizedSpeech:
#      18     print("Recognized: {}".format(result.text))
#      19 elif result.reason == speechsdk.ResultReason.NoMatch:
#
# AttributeError: 'ResultFuture' object has no attribute 'reason'

# %%
speech_recognizer.recognizing.connect(lambda evt: print('RECOGNIZING: {}'.format(evt)))
speech_recognizer.recognized.connect(lambda evt: print('RECOGNIZED: {}'.format(evt)))
speech_recognizer.session_started.connect(lambda evt: print('SESSION STARTED: {}'.format(evt)))
speech_recognizer.session_stopped.connect(lambda evt: print('SESSION STOPPED {}'.format(evt)))
speech_recognizer.canceled.connect(lambda evt: print('CANCELED {}'.format(evt)))

speech_recognizer.session_stopped.connect(stop_cb)
speech_recognizer.canceled.connect(stop_cb)

speech_recognizer.start_continuous_recognition()
while not done:
    time.sleep(.5)
    
SpeechConfig.enable_dictation

speech_config.speech_recognition_language="ko-KR"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-50ab3d163e15> in <module>
#       5 speech_recognizer.canceled.connect(lambda evt: print('CANCELED {}'.format(evt)))
#       6
# ----> 7 speech_recognizer.session_stopped.connect(stop_cb)
#       8 speech_recognizer.canceled.connect(stop_cb)
#       9
#
# NameError: name 'stop_cb' is not defined

# %%
speech_recognizer.start_continuous_recognition()
while not done:
    time.sleep(.5)
# Out:
# SESSION STARTED: SessionEventArgs(session_id=127ab87d00294116927662eeef2eb121)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-170-4b6390d201bd> in <module>
#       1 speech_recognizer.start_continuous_recognition()
#       2 while not done:
# ----> 3     time.sleep(.5)
#
# NameError: name 'time' is not defined
# CANCELED SpeechRecognitionCanceledEventArgs(session_id=127ab87d00294116927662eeef2eb121, result=SpeechRecognitionResult(result_id=35e34cc61900483ab6b6095f26b36053, text="", reason=ResultReason.Canceled))
