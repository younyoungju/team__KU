# %%
from konlpy.tag import Kkma
import nltk
from nltk.tag import pos_tag
from nltk.corpus import gutenberg
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.tokenize import TweetTokenizer
from nltk.tokenize import regexp_tokenize
from nltk.help import upenn_tagset
from string import punctuation
from nltk import Text
from konlpy.corpus import kolaw, kobill
from konlpy.tag import Kkma, Mecab, Okt, Komoran, Hannanum
import pandas as pd
import re

# %%
similarity_table = pd.DataFrame()

# %%
# symbol dictionary
sd = {'½': '이분의일',
 '□': '사각형',
 '＞': '보다크다',
 '㈏': '나',
 '(': '',
 '×': '곱하기',
 ')': '',
 '①': '일번',
 '+': '더하기',
 '˚': '도',
 '⑤': '오번',
 '⅓': '삼분의일',
 '⅔': '삼분의이',
 '¼': '사분의일',
 '′': '',
 '＜': '보다작다',
 '-': '빼기',
 '!': '',
 '④': '사번',
 'π': '파이',
 '㎞': '킬로미터',
 '=': '는',
 ':': '대',
 '~': '',
 '…': '',
 '△': '삼각형',
 '²': '의제곱',
 '②': '이번',
 '㈎': '가',
 '≤': '보다크거나같다',
 '㎝': '센치미터',
 '|': '절대값',
 '㈐': '다',
 '＝': '는',
 '÷': '나누기',
 '⑵': '이번',
 '㎠': '제곱센치미터',
 '¾': '사분의삼',
 '∠': '각',
 '%': '퍼센트',
 '－': '마이너스',
 "'": '',
 '③': '삼번',
 '＋': '더하기',
 '⑴': '일번',
 '√': '루트',
 'cos': '코사인',
 'sin': '사인',
 'tan': '탄젠트'}
sd
# Out:
# {'½': '이분의일',
#  '□': '사각형',
#  '＞': '보다크다',
#  '㈏': '나',
#  '(': '',
#  '×': '곱하기',
#  ')': '',
#  '①': '일번',
#  '+': '더하기',
#  '˚': '도',
#  '⑤': '오번',
#  '⅓': '삼분의일',
#  '⅔': '삼분의이',
#  '¼': '사분의일',
#  '′': '',
#  '＜': '보다작다',
#  '-': '빼기',
#  '!': '',
#  '④': '사번',
#  'π': '파이',
#  '㎞': '킬로미터',
#  '=': '는',
#  ':': '대',
#  '~': '',
#  '…': '',
#  '△': '삼각형',
#  '²': '의제곱',
#  '②': '이번',
#  '㈎': '가',
#  '≤': '보다크거나같다',
#  '㎝': '센치미터',
#  '|': '절대값',
#  '㈐': '다',
#  '＝': '는',
#  '÷': '나누기',
#  '⑵': '이번',
#  '㎠': '제곱센치미터',
#  '¾': '사분의삼',
#  '∠': '각',
#  '%': '퍼센트',
#  '－': '마이너스',
#  "'": '',
#  '③': '삼번',
#  '＋': '더하기',
#  '⑴': '일번',
#  '√': '루트',
#  'cos': '코사인',
#  'sin': '사인',
#  'tan': '탄젠트'}

# %%
ad = {
    'A':'에이',
    'B':'비',
    'C':'씨',
    'D':'디',
    'E':'이',
    'F':'에프',
    'G':'지',
    'H':'에이치',
    'I':'아이',
    'J':'제이',
    'K':'케이',
    'L':'엘',
    'M':'엠',
    'N':'엔',
    'O':'오',
    'P':'피',
    'Q':'큐',
    'R':'알',
    'S':'에스',
    'T':'티',
    'U':'유',
    'V':'브이',
    'W':'더블유',
    'X':'엑스',
    'Y':'와이',
    'Z':'지'
}

# %%
s = '이건 우리가 중학교 2학년 때 배웠죠, 그렇죠? ∠A가 공통이고, 그다음에 둘 다 직각을 갖고 있으니까 AA닮음이 될 테고.'

# %%
def get_korean_pronunciation_of_number(n):
    nbased = {0 : '', 1 : '일', 2 : '이', 3 : '삼', 4 : '사', 5 : '오', 6 : '육', 7 : '칠', 8 : '팔', 9 : '구' }
    nkopro = {}
    for _ in range(n+1):
        t = _//1000
        h = (_%1000)//100
        d = (_%100)//10
        o = _%10

        if _ == 0:
            nkopro[_] = '영'
        else:
            tt = '' if t == 0 else ('천' if t == 1 else nbased[t] + '천')
            hh = '' if h == 0 else ('백' if h == 1 else nbased[h] + '백')
            dd = '' if d == 0 else ('십' if d == 1 else nbased[d] + '십')
            oo = '' if o == 0 else nbased[o]
            nkopro[_] = tt+hh+dd+oo
            
    return nkopro

# %%
# 초성 리스트. 00 ~ 18
CHOSUNG_LIST = ['ㄱ', 'ㄲ', 'ㄴ', 'ㄷ', 'ㄸ', 'ㄹ', 'ㅁ', 'ㅂ', 'ㅃ', 'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅉ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']
# 중성 리스트. 00 ~ 20
JUNGSUNG_LIST = ['ㅏ', 'ㅐ', 'ㅑ', 'ㅒ', 'ㅓ', 'ㅔ', 'ㅕ', 'ㅖ', 'ㅗ', 'ㅘ', 'ㅙ', 'ㅚ', 'ㅛ', 'ㅜ', 'ㅝ', 'ㅞ', 'ㅟ', 'ㅠ', 'ㅡ', 'ㅢ', 'ㅣ']
# 종성 리스트. 00 ~ 27 + 1(1개 없음)
JONGSUNG_LIST = [' ', 'ㄱ', 'ㄲ', 'ㄳ', 'ㄴ', 'ㄵ', 'ㄶ', 'ㄷ', 'ㄹ', 'ㄺ', 'ㄻ', 'ㄼ', 'ㄽ', 'ㄾ', 'ㄿ', 'ㅀ', 'ㅁ', 'ㅂ', 'ㅄ', 'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']

# %%
def korean_to_be_englished(korean_word):
    r_lst = []
    for w in list(korean_word.strip()):
        if '가'<=w<='힣':
            ch1 = (ord(w) - ord('가'))//588
            ch2 = ((ord(w) - ord('가')) - (588*ch1)) // 28
            ch3 = (ord(w) - ord('가')) - (588*ch1) - 28*ch2
            r_lst.append([CHOSUNG_LIST[ch1], JUNGSUNG_LIST[ch2], JONGSUNG_LIST[ch3]])
        else:
            r_lst.append([w])
    return r_lst

# %%
#similarity
def similarity_prob(s1, s2):
    numerator =  0
    denominator = 3*len(s1)
    for _ in range(len(s1)):
        for c1, c2 in zip(s1[_], s2[_]):
            if c1 == c2:
                numerator += 1

    return numerator / denominator

# %%
with open(r'C:\Users\KYEONGCHAN LEE\(1-1.5) DataCampus\lec00001_EBS_linebyline.txt', 'r', encoding = 'utf-8') as f:
    elbl = f.read() #Ebs Line By Line
    print(elbl)
# Out:
# 반갑습니다, EBS 친구 여러분들. 여러분들과 함께 중학뉴런수학3(하)를 강의하게 된 손석민입니다.
# 2학년 뉴런을 통해서도 만났었는데요.
# 여러분들, 이렇게 다시 만나게 되어서 정말 반갑습니다.
# 앞으로 3(하) 과정 어떻게 진행되는지에 대해서는 여러분들께서 오리엔테이션 강의를 통해서 확인할 수 있을 거고요.
# 오리엔테이션 강의는 반드시 듣고 오셔야 여러분들이 3학년 과정이, (하) 과정이 특히 어떻게 수업되는지 확인할 수 있을 겁니다.
# 일단 3학년 과정 같은 경우에는 크게 3개의 대단원으로 이루어져 있는데요.
# 첫 번째가 삼각비라는 단원이고 두 번째가 원의 성질, 세 번째가 통계. 이렇게 이루어져 있습니다.
# 우리가 1학년(하)도 마찬가지고 2학년(하)도 그래 왔듯, ‘주로 도형에 대한 이야기가 3(하)에서 많이 다루어지는구나.’ 라는 걸 생각하면 될 테고요.
# 오늘은 그 첫 시간이니까 ‘삼각비.’ ‘삼각’ 알아요. ‘비’ 알아요.
# 근데 이제 합쳐져 있는 ‘삼각비’라는 새로운 용어가 나왔죠.
# 그럼 이 개념을 공부하기에 앞서서 당연히 삼각비의 뜻부터 시작하는 것이 첫 시간입니다.
# 오늘 그 첫 시간, 함께 시작해 보도록 할 텐데요. 중학교 3학년 수학! 손샘과 끝냅시다!
# 오늘 공부할 내용, 바로 두 가지 개념인데요. 오늘 두 가지 개념 첫 번째 제목이 굉장히 길어요.
# ‘닮은 직각삼각형에서 대응변의 길이의 비’라는 것이 있습니다.
# 그다음 두 번째 개념이 바로 뭐냐면, ‘삼각비’라는 건데 삼각비의 뜻이겠죠?
# 이 첫 번째 개념은, 앞으로 쭉 공부할 내용이 다 직각삼각형에서 주로 다루어질 텐데직각삼각형에서 갖는 기본적인 성질이 있는데 그 성질을 알고 가자는, ‘삼각비를 공부하기에 앞선 징검다리 내용이다.’ 라고 여러분들이 받아들이시면 됩니다.
# 그렇다면 ‘닮은 직각삼각형에서’라고 했으니까 닮은 직각삼각형을 그려 봐야 되겠죠?
# 닮은 직각삼각형 두 개를 편하게 그릴 수 있는 제일 좋은 방법은 뭘까 생각해 보면우리는 이렇게 그리면 될 거 같아요.
# 이렇게 한번 그려 보겠습니다, 이렇게. 여기에서부터 수선을 이렇게 그어 보겠습니다.
# 일단 바깥쪽에 직각삼각형 하나 보입니다, 그렇죠?
# 또 다른 직각삼각형를 빗변 위 한 점을 잡아서 이렇게 수선을 똑같이 그어 주면 바로 두 직각삼각형 ABC하고, ADE는 서로 어떤 닮음?AA닮음이 된다.
# 이건 우리가 중학교 2학년 때 배웠죠, 그렇죠? ∠A가 공통이고, 그다음에 둘 다 직각을 갖고 있으니까 AA닮음이 될 테고.
# 우리가 중2 때 배웠던 닮음비라는 건 뭐였냐 하면 대응하는 변의 길이의 비였어요, 그렇죠?
# 그래서 만약에 이 길이를 5라고 해 보고, 이 길이를 10이라고 해 보면.두 삼각형의 닮음비는 5:10. 1:2겠죠.
# 그렇다면 우리가 이 길이를 4라고 놔 보면, 이 길이는 얼마가 됩니까, 당연히?
# 그렇죠. 4의 두 배인 8이 돼야 돼.
# 이 길이를 거꾸로 우리가 6이라고 해 보겠습니다.
# 그럼 거꾸로 이 작은 쪽은 얼마가 될까?
# 1:2, 2:1. 얼마? 3이 돼야 된다는 걸 여러분들이 알 수 있죠.
# 그래서 우리는 닮음비라는 건 ‘작은 삼각형과 큰 삼각형의 대응하는 변의 길이의 비’이니까 5:10, 3:6, 4:8. 이것이 모두 다 1:2로 같고 그것을 닮음비라고 한다.
# 이렇게 공부를 했었는데 이것 말고도 이러한 것들도 성립할 거란 얘기예요.
# 예를 들어 작은 삼각형에서 빗변 분의 높이 얼마입니까? 5분의3이죠?
# 큰 삼각형에서 빗변 분의 높이 얼마죠? 10분의6이죠. 이 둘 어때요?
# 5분의3으로 서로 같다는 거 확인할 수 있고.
# 또 마찬가지로 작은 삼각형에서 예를 들어서 빗변 분의 밑변 해 봅시다. 5분의4죠.
#  큰 삼각형에서 빗변 분의 밑변 해 보면 얼마죠?10분의8이죠. 근데 이것도 서로 어때? 같아요.
# 마찬가지로 하나 더 해 볼까요? 작은 삼각형에서 밑변 분의 높이는 4분의3이죠.
# 큰 삼각형에서 밑변 분의 높이는 어때요? 8분의6인데, 이들이 모두 다 어때? 같다는 걸 여러분들이 알 수 있단 얘기예요.

# %%
with open(r'C:\Users\KYEONGCHAN LEE\(1-1.5) DataCampus\lec00001_STT1_Transcribe_linebyline.txt', 'r', encoding = 'utf-8') as f:
    glbl = f.read() #Ebs Line By Line
    print(glbl)
# Out:
# 반갑습니다. WITH 여러분들 여러분들과 함께 중학 유럽 수학 삼 하를 강행하기 된 분석입니다. 사.
# 이 학년 늘어 를 통해서도 만났는데요.
# 여러분들 이렇게 다시 만나게 되어서 정말 반갑습니다.
# 앞으로 삼 하 과정 어떻게 진행되는지 에 대해서는 여러분들께서 오리엔테이션 강의를 통해서 확인할 수 있을 거고요.
#  오리엔테이션 강의는 반드시 듣고 옷 여야 여러분들이 삼 학년 과정의 한 가정의 특히 어떻게 수업 되는지 확인할 수 있을 겁니다.
# 기자 일단 삼 학년 과정 같은 경우에는 크게 세계의 대단원의 으로 이뤄져 있는데요.
#  첫번째가 삼각 이라는 단원고 두 번째가 원에 성질, 세 번째가 통계 이렇게 이뤄져 있습니다.
# 우리가 일 학년 하도 마찬가지고 이 학년 하도 그랬듯 주로 도용에 대한 이야기가 삼 하에서 많이 다뤄지는 구나 라는 걸 생각하면 될 테고요.
#  오늘은 그 첫 시간이 이니까 삼 갑 의 삼각 알아요 이 알아요.
# 합쳐져 있는 삼각 이라는 새로운 용어가 나왔죠.
# 이 개념을 공부하게 앞서 당연히 삼각 비 듯 부터 시작하는 것이 첫 시간입니다.
# 오늘 사 시간 함께 시작해 보도록 할 텐데요. 중학교 삼, 학년 수학 선생과 끝납니다.
# 오늘 공부할 내용, 바로 두 가지 개념 인데요. 아! 오늘 두 가지 기념 첫 번째 제복이 굉장히 길어야
# 닮은 즉각 삼 각 통에서 대응 변의 길이의 이 라는 것이 있습니다.
# 그 다음 두 번째 개념이 바로 뭐냐하면 삼 갑 의 라는 건데 상납 뜻이겠죠
# 의 첫 번째 개념은 두 번째 앞으로 쭉 공부할 내용이 다 즉각 삼각형 에서 주로 다뤄질 텐데 즉각 상황 평에서 갖는 기본적인 성질이 있는데 그 성질을 알고 가자 라는 어떤 삼각 비를 공부하기 앞선 징검다리 내용이라고 여러분들이 받아들이지만 됩니다.
# 그렇다면 닮은 즉각 삼각형 해서 있으니까 닮은 즉각 삼각형을 그려 봐야겠죠.
# 닮은 즉각 삼각형 두 개를 편하게 그릴 수 있는 제일 좋은 방법은 뭘까? 생각해보면 우리는 이렇게 그리면 될 것 같아요.
# 이렇게 만들어보겠습니다 이렇게 이렇게 여기서부터 수선을 이렇게 들어보겠습니다.
#  일단 바깥쪽에 즉각 삼각형 않아 보입니다.
# 또다른 즉각 삼각형 하나를 이 편이 한 점을 잡아서 이렇게 수선을 똑같이 그럴 주면 바로 두 즉각 삼각형 A B 지시하고 AT 서로 어떤 닮은 A 담은 이 된다.
# 이건 우리가 중학교 이해하는 데 배웠죠. 가계가 공통 이고 그 다음에 둘 다 즉각 을 갖고 있으니까 AA 닮은 있을 테고,
#  우리가 중인 팀이었던 닮은 이라는 건 뭐냐면, 대응하는 변의 길이의 이었어요.
# 만약에 이 길이를 오라고 해보고 길이를 십 이라고 안 보면 두 삼각형의 닮은 비는 오 대 십일 대 있겠죠.
# 그렇다면 우리가 이 길이를 살아가다 보면 일이 얼마나 됩니까? 당연히
# 그쳐 사회 두 배인 팔 일 자
#  의 길이를 거꾸로 우리가 육 이라고 해보겠습니다.
# 그럼 거꾸로 이 작은 쪽은 얼마나 될까?
# 일 대 이, 이 대 일 얼마 삶의 돼야 한다는 걸 여러분이 할 수 있죠.
# 그래서 우리는 닮은 이라는 건 작은 상납 형과 큰 삼각형 에 대응하는 별이 길이 보니까 오 대 십, 선대 육, 사 대 팔, 이것이 모두 다 일 대 이 로 갖고 그것을 닮은 이라고 한다.
# 이렇게 공부했는데 이것 말고도 이러한 것들도 성립할 거라는
# 예를 들어 작은 삼각형 에서 이 변 분에 높이 얼마입니까? 오 분의 삼
# 큰 삼각형 에서 이 본부를 높여야 하죠. 십 분 의 유기적 이들 오 대
# 오 분의 삼 으로 서로 같다 라는 것을 알 수 있고
# 또 마찬가지로 작은 삼각형 에서 예를 들어 빚 변 분의 이 편 해봅시다. 오 분의 사적
# 큰 삼각형 에서 이 변 분에 및 편의 봄 얼마전 십 분의 팔 이적 근데 이것도 서로 때 같아요.
# 마찬가지로 하나 더 있을까요? 작은 삼각형 에서 이 편 불이 높이는 사 분의 삼
# 큰 삼각형 에서 및 변 불이 높이는 팔 분의 육 인데 이들이 모두 같다는 걸 여러분들이 할 수 있다는데요.

# %%
pat_math_symbol = re.compile(r'[().,‘’?!]')
pat_number = re.compile(r'\d+')
kopro = get_korean_pronunciation_of_number(9999) #~9999

esl = text1.splitlines() #문장단위로 리스트
gsl = text2.splitlines()

# %%
new_esl = [s.strip() for s in [pat_math_symbol.sub('', _) for _ in esl]]

# %%
for _ in new_gsl:
    fl = re.findall(r'\d+', _)
    for n in fl:
        _ = _.replace(n, kopro[int(n)])
    new_gls2.append(_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-275-e147f1a0c725> in <module>
#       3     for n in fl:
#       4         _ = _.replace(n, kopro[int(n)])
# ----> 5     new_gls2.append(_)
#
# NameError: name 'new_gls2' is not defined

# %%
kopro
# Out:
# {0: '영',
#  1: '일',
#  2: '이',
#  3: '삼',
#  4: '사',
#  5: '오',
#  6: '육',
#  7: '칠',
#  8: '팔',
#  9: '구',
#  10: '십',
#  11: '십일',
#  12: '십이',
#  13: '십삼',
#  14: '십사',
#  15: '십오',
#  16: '십육',
#  17: '십칠',
#  18: '십팔',
#  19: '십구',
#  20: '이십',
#  21: '이십일',
#  22: '이십이',
#  23: '이십삼',
#  24: '이십사',
#  25: '이십오',
#  26: '이십육',
#  27: '이십칠',
#  28: '이십팔',
#  29: '이십구',
#  30: '삼십',
#  31: '삼십일',
#  32: '삼십이',
#  33: '삼십삼',
#  34: '삼십사',
#  35: '삼십오',
#  36: '삼십육',
#  37: '삼십칠',
#  38: '삼십팔',
#  39: '삼십구',
#  40: '사십',
#  41: '사십일',
#  42: '사십이',
#  43: '사십삼',
#  44: '사십사',
#  45: '사십오',
#  46: '사십육',
#  47: '사십칠',
#  48: '사십팔',
#  49: '사십구',
#  50: '오십',
#  51: '오십일',
#  52: '오십이',
#  53: '오십삼',
#  54: '오십사',
#  55: '오십오',
#  56: '오십육',
#  57: '오십칠',
#  58: '오십팔',
#  59: '오십구',
#  60: '육십',
#  61: '육십일',
#  62: '육십이',
#  63: '육십삼',
#  64: '육십사',
#  65: '육십오',
#  66: '육십육',
#  67: '육십칠',
#  68: '육십팔',
#  69: '육십구',
#  70: '칠십',
#  71: '칠십일',
#  72: '칠십이',
#  73: '칠십삼',
#  74: '칠십사',
#  75: '칠십오',
#  76: '칠십육',
#  77: '칠십칠',
#  78: '칠십팔',
#  79: '칠십구',
#  80: '팔십',
#  81: '팔십일',
#  82: '팔십이',
#  83: '팔십삼',
#  84: '팔십사',
#  85: '팔십오',
#  86: '팔십육',
#  87: '팔십칠',
#  88: '팔십팔',
#  89: '팔십구',
#  90: '구십',
#  91: '구십일',
#  92: '구십이',
#  93: '구십삼',
#  94: '구십사',
#  95: '구십오',
#  96: '구십육',
#  97: '구십칠',
#  98: '구십팔',
#  99: '구십구',
#  100: '백',
#  101: '백일',
#  102: '백이',
#  103: '백삼',
#  104: '백사',
#  105: '백오',
#  106: '백육',
#  107: '백칠',
#  108: '백팔',
#  109: '백구',
#  110: '백십',
#  111: '백십일',
#  112: '백십이',
#  113: '백십삼',
#  114: '백십사',
#  115: '백십오',
#  116: '백십육',
#  117: '백십칠',
#  118: '백십팔',
#  119: '백십구',
#  120: '백이십',
#  121: '백이십일',
#  122: '백이십이',
#  123: '백이십삼',
#  124: '백이십사',
#  125: '백이십오',
#  126: '백이십육',
#  127: '백이십칠',
#  128: '백이십팔',
#  129: '백이십구',
#  130: '백삼십',
#  131: '백삼십일',
#  132: '백삼십이',
#  133: '백삼십삼',
#  134: '백삼십사',
#  135: '백삼십오',
#  136: '백삼십육',
#  137: '백삼십칠',
#  138: '백삼십팔',
#  139: '백삼십구',
#  140: '백사십',
#  141: '백사십일',
#  142: '백사십이',
#  143: '백사십삼',
#  144: '백사십사',
#  145: '백사십오',
#  146: '백사십육',
#  147: '백사십칠',
#  148: '백사십팔',
#  149: '백사십구',
#  150: '백오십',
#  151: '백오십일',
#  152: '백오십이',
#  153: '백오십삼',
#  154: '백오십사',
#  155: '백오십오',
#  156: '백오십육',
#  157: '백오십칠',
#  158: '백오십팔',
#  159: '백오십구',
#  160: '백육십',
#  161: '백육십일',
#  162: '백육십이',
#  163: '백육십삼',
#  164: '백육십사',
#  165: '백육십오',
#  166: '백육십육',
#  167: '백육십칠',
#  168: '백육십팔',
#  169: '백육십구',
#  170: '백칠십',
#  171: '백칠십일',
#  172: '백칠십이',
#  173: '백칠십삼',
#  174: '백칠십사',
#  175: '백칠십오',
#  176: '백칠십육',
#  177: '백칠십칠',
#  178: '백칠십팔',
#  179: '백칠십구',
#  180: '백팔십',
#  181: '백팔십일',
#  182: '백팔십이',
#  183: '백팔십삼',
#  184: '백팔십사',
#  185: '백팔십오',
#  186: '백팔십육',
#  187: '백팔십칠',
#  188: '백팔십팔',
#  189: '백팔십구',
#  190: '백구십',
#  191: '백구십일',
#  192: '백구십이',
#  193: '백구십삼',
#  194: '백구십사',
#  195: '백구십오',
#  196: '백구십육',
#  197: '백구십칠',
#  198: '백구십팔',
#  199: '백구십구',
#  200: '이백',
#  201: '이백일',
#  202: '이백이',
#  203: '이백삼',
#  204: '이백사',
#  205: '이백오',
#  206: '이백육',
#  207: '이백칠',
#  208: '이백팔',
#  209: '이백구',
#  210: '이백십',
#  211: '이백십일',
#  212: '이백십이',
#  213: '이백십삼',
#  214: '이백십사',
#  215: '이백십오',
#  216: '이백십육',
#  217: '이백십칠',
#  218: '이백십팔',
#  219: '이백십구',
#  220: '이백이십',
#  221: '이백이십일',
#  222: '이백이십이',
#  223: '이백이십삼',
#  224: '이백이십사',
#  225: '이백이십오',
#  226: '이백이십육',
#  227: '이백이십칠',
#  228: '이백이십팔',
#  229: '이백이십구',
#  230: '이백삼십',
#  231: '이백삼십일',
#  232: '이백삼십이',
#  233: '이백삼십삼',
#  234: '이백삼십사',
#  235: '이백삼십오',
#  236: '이백삼십육',
#  237: '이백삼십칠',
#  238: '이백삼십팔',
#  239: '이백삼십구',
#  240: '이백사십',
#  241: '이백사십일',
#  242: '이백사십이',
#  243: '이백사십삼',
#  244: '이백사십사',
#  245: '이백사십오',
#  246: '이백사십육',
#  247: '이백사십칠',
#  248: '이백사십팔',
#  249: '이백사십구',
#  250: '이백오십',
#  251: '이백오십일',
#  252: '이백오십이',
#  253: '이백오십삼',
#  254: '이백오십사',
#  255: '이백오십오',
#  256: '이백오십육',
#  257: '이백오십칠',
#  258: '이백오십팔',
#  259: '이백오십구',
#  260: '이백육십',
#  261: '이백육십일',
#  262: '이백육십이',
#  263: '이백육십삼',
#  264: '이백육십사',
#  265: '이백육십오',
#  266: '이백육십육',
#  267: '이백육십칠',
#  268: '이백육십팔',
#  269: '이백육십구',
#  270: '이백칠십',
#  271: '이백칠십일',
#  272: '이백칠십이',
#  273: '이백칠십삼',
#  274: '이백칠십사',
#  275: '이백칠십오',
#  276: '이백칠십육',
#  277: '이백칠십칠',
#  278: '이백칠십팔',
#  279: '이백칠십구',
#  280: '이백팔십',
#  281: '이백팔십일',
#  282: '이백팔십이',
#  283: '이백팔십삼',
#  284: '이백팔십사',
#  285: '이백팔십오',
#  286: '이백팔십육',
#  287: '이백팔십칠',
#  288: '이백팔십팔',
#  289: '이백팔십구',
#  290: '이백구십',
#  291: '이백구십일',
#  292: '이백구십이',
#  293: '이백구십삼',
#  294: '이백구십사',
#  295: '이백구십오',
#  296: '이백구십육',
#  297: '이백구십칠',
#  298: '이백구십팔',
#  299: '이백구십구',
#  300: '삼백',
#  301: '삼백일',
#  302: '삼백이',
#  303: '삼백삼',
#  304: '삼백사',
#  305: '삼백오',
#  306: '삼백육',
#  307: '삼백칠',
#  308: '삼백팔',
#  309: '삼백구',
#  310: '삼백십',
#  311: '삼백십일',
#  312: '삼백십이',
#  313: '삼백십삼',
#  314: '삼백십사',
#  315: '삼백십오',
#  316: '삼백십육',
#  317: '삼백십칠',
#  318: '삼백십팔',
#  319: '삼백십구',
#  320: '삼백이십',
#  321: '삼백이십일',
#  322: '삼백이십이',
#  323: '삼백이십삼',
#  324: '삼백이십사',
#  325: '삼백이십오',
#  326: '삼백이십육',
#  327: '삼백이십칠',
#  328: '삼백이십팔',
#  329: '삼백이십구',
#  330: '삼백삼십',
#  331: '삼백삼십일',
#  332: '삼백삼십이',
#  333: '삼백삼십삼',
#  334: '삼백삼십사',
#  335: '삼백삼십오',
#  336: '삼백삼십육',
#  337: '삼백삼십칠',
#  338: '삼백삼십팔',
#  339: '삼백삼십구',
#  340: '삼백사십',
#  341: '삼백사십일',
#  342: '삼백사십이',
#  343: '삼백사십삼',
#  344: '삼백사십사',
#  345: '삼백사십오',
#  346: '삼백사십육',
#  347: '삼백사십칠',
#  348: '삼백사십팔',
#  349: '삼백사십구',
#  350: '삼백오십',
#  351: '삼백오십일',
#  352: '삼백오십이',
#  353: '삼백오십삼',
#  354: '삼백오십사',
#  355: '삼백오십오',
#  356: '삼백오십육',
#  357: '삼백오십칠',
#  358: '삼백오십팔',
#  359: '삼백오십구',
#  360: '삼백육십',
#  361: '삼백육십일',
#  362: '삼백육십이',
#  363: '삼백육십삼',
#  364: '삼백육십사',
#  365: '삼백육십오',
#  366: '삼백육십육',
#  367: '삼백육십칠',
#  368: '삼백육십팔',
#  369: '삼백육십구',
#  370: '삼백칠십',
#  371: '삼백칠십일',
#  372: '삼백칠십이',
#  373: '삼백칠십삼',
#  374: '삼백칠십사',
#  375: '삼백칠십오',
#  376: '삼백칠십육',
#  377: '삼백칠십칠',
#  378: '삼백칠십팔',
#  379: '삼백칠십구',
#  380: '삼백팔십',
#  381: '삼백팔십일',
#  382: '삼백팔십이',
#  383: '삼백팔십삼',
#  384: '삼백팔십사',
#  385: '삼백팔십오',
#  386: '삼백팔십육',
#  387: '삼백팔십칠',
#  388: '삼백팔십팔',
#  389: '삼백팔십구',
#  390: '삼백구십',
#  391: '삼백구십일',
#  392: '삼백구십이',
#  393: '삼백구십삼',
#  394: '삼백구십사',
#  395: '삼백구십오',
#  396: '삼백구십육',
#  397: '삼백구십칠',
#  398: '삼백구십팔',
#  399: '삼백구십구',
#  400: '사백',
#  401: '사백일',
#  402: '사백이',
#  403: '사백삼',
#  404: '사백사',
#  405: '사백오',
#  406: '사백육',
#  407: '사백칠',
#  408: '사백팔',
#  409: '사백구',
#  410: '사백십',
#  411: '사백십일',
#  412: '사백십이',
#  413: '사백십삼',
#  414: '사백십사',
#  415: '사백십오',
#  416: '사백십육',
#  417: '사백십칠',
#  418: '사백십팔',
#  419: '사백십구',
#  420: '사백이십',
#  421: '사백이십일',
#  422: '사백이십이',
#  423: '사백이십삼',
#  424: '사백이십사',
#  425: '사백이십오',
#  426: '사백이십육',
#  427: '사백이십칠',
#  428: '사백이십팔',
#  429: '사백이십구',
#  430: '사백삼십',
#  431: '사백삼십일',
#  432: '사백삼십이',
#  433: '사백삼십삼',
#  434: '사백삼십사',
#  435: '사백삼십오',
#  436: '사백삼십육',
#  437: '사백삼십칠',
#  438: '사백삼십팔',
#  439: '사백삼십구',
#  440: '사백사십',
#  441: '사백사십일',
#  442: '사백사십이',
#  443: '사백사십삼',
#  444: '사백사십사',
#  445: '사백사십오',
#  446: '사백사십육',
#  447: '사백사십칠',
#  448: '사백사십팔',
#  449: '사백사십구',
#  450: '사백오십',
#  451: '사백오십일',
#  452: '사백오십이',
#  453: '사백오십삼',
#  454: '사백오십사',
#  455: '사백오십오',
#  456: '사백오십육',
#  457: '사백오십칠',
#  458: '사백오십팔',
#  459: '사백오십구',
#  460: '사백육십',
#  461: '사백육십일',
#  462: '사백육십이',
#  463: '사백육십삼',
#  464: '사백육십사',
#  465: '사백육십오',
#  466: '사백육십육',
#  467: '사백육십칠',
#  468: '사백육십팔',
#  469: '사백육십구',
#  470: '사백칠십',
#  471: '사백칠십일',
#  472: '사백칠십이',
#  473: '사백칠십삼',
#  474: '사백칠십사',
#  475: '사백칠십오',
#  476: '사백칠십육',
#  477: '사백칠십칠',
#  478: '사백칠십팔',
#  479: '사백칠십구',
#  480: '사백팔십',
#  481: '사백팔십일',
#  482: '사백팔십이',
#  483: '사백팔십삼',
#  484: '사백팔십사',
#  485: '사백팔십오',
#  486: '사백팔십육',
#  487: '사백팔십칠',
#  488: '사백팔십팔',
#  489: '사백팔십구',
#  490: '사백구십',
#  491: '사백구십일',
#  492: '사백구십이',
#  493: '사백구십삼',
#  494: '사백구십사',
#  495: '사백구십오',
#  496: '사백구십육',
#  497: '사백구십칠',
#  498: '사백구십팔',
#  499: '사백구십구',
#  500: '오백',
#  501: '오백일',
#  502: '오백이',
#  503: '오백삼',
#  504: '오백사',
#  505: '오백오',
#  506: '오백육',
#  507: '오백칠',
#  508: '오백팔',
#  509: '오백구',
#  510: '오백십',
#  511: '오백십일',
#  512: '오백십이',
#  513: '오백십삼',
#  514: '오백십사',
#  515: '오백십오',
#  516: '오백십육',
#  517: '오백십칠',
#  518: '오백십팔',
#  519: '오백십구',
#  520: '오백이십',
#  521: '오백이십일',
#  522: '오백이십이',
#  523: '오백이십삼',
#  524: '오백이십사',
#  525: '오백이십오',
#  526: '오백이십육',
#  527: '오백이십칠',
#  528: '오백이십팔',
#  529: '오백이십구',
#  530: '오백삼십',
#  531: '오백삼십일',
#  532: '오백삼십이',
#  533: '오백삼십삼',
#  534: '오백삼십사',
#  535: '오백삼십오',
#  536: '오백삼십육',
#  537: '오백삼십칠',
#  538: '오백삼십팔',
#  539: '오백삼십구',
#  540: '오백사십',
#  541: '오백사십일',
#  542: '오백사십이',
#  543: '오백사십삼',
#  544: '오백사십사',
#  545: '오백사십오',
#  546: '오백사십육',
#  547: '오백사십칠',
#  548: '오백사십팔',
#  549: '오백사십구',
#  550: '오백오십',
#  551: '오백오십일',
#  552: '오백오십이',
#  553: '오백오십삼',
#  554: '오백오십사',
#  555: '오백오십오',
#  556: '오백오십육',
#  557: '오백오십칠',
#  558: '오백오십팔',
#  559: '오백오십구',
#  560: '오백육십',
#  561: '오백육십일',
#  562: '오백육십이',
#  563: '오백육십삼',
#  564: '오백육십사',
#  565: '오백육십오',
#  566: '오백육십육',
#  567: '오백육십칠',
#  568: '오백육십팔',
#  569: '오백육십구',
#  570: '오백칠십',
#  571: '오백칠십일',
#  572: '오백칠십이',
#  573: '오백칠십삼',
#  574: '오백칠십사',
#  575: '오백칠십오',
#  576: '오백칠십육',
#  577: '오백칠십칠',
#  578: '오백칠십팔',
#  579: '오백칠십구',
#  580: '오백팔십',
#  581: '오백팔십일',
#  582: '오백팔십이',
#  583: '오백팔십삼',
#  584: '오백팔십사',
#  585: '오백팔십오',
#  586: '오백팔십육',
#  587: '오백팔십칠',
#  588: '오백팔십팔',
#  589: '오백팔십구',
#  590: '오백구십',
#  591: '오백구십일',
#  592: '오백구십이',
#  593: '오백구십삼',
#  594: '오백구십사',
#  595: '오백구십오',
#  596: '오백구십육',
#  597: '오백구십칠',
#  598: '오백구십팔',
#  599: '오백구십구',
#  600: '육백',
#  601: '육백일',
#  602: '육백이',
#  603: '육백삼',
#  604: '육백사',
#  605: '육백오',
#  606: '육백육',
#  607: '육백칠',
#  608: '육백팔',
#  609: '육백구',
#  610: '육백십',
#  611: '육백십일',
#  612: '육백십이',
#  613: '육백십삼',
#  614: '육백십사',
#  615: '육백십오',
#  616: '육백십육',
#  617: '육백십칠',
#  618: '육백십팔',
#  619: '육백십구',
#  620: '육백이십',
#  621: '육백이십일',
#  622: '육백이십이',
#  623: '육백이십삼',
#  624: '육백이십사',
#  625: '육백이십오',
#  626: '육백이십육',
#  627: '육백이십칠',
#  628: '육백이십팔',
#  629: '육백이십구',
#  630: '육백삼십',
#  631: '육백삼십일',
#  632: '육백삼십이',
#  633: '육백삼십삼',
#  634: '육백삼십사',
#  635: '육백삼십오',
#  636: '육백삼십육',
#  637: '육백삼십칠',
#  638: '육백삼십팔',
#  639: '육백삼십구',
#  640: '육백사십',
#  641: '육백사십일',
#  642: '육백사십이',
#  643: '육백사십삼',
#  644: '육백사십사',
#  645: '육백사십오',
#  646: '육백사십육',
#  647: '육백사십칠',
#  648: '육백사십팔',
#  649: '육백사십구',
#  650: '육백오십',
#  651: '육백오십일',
#  652: '육백오십이',
#  653: '육백오십삼',
#  654: '육백오십사',
#  655: '육백오십오',
#  656: '육백오십육',
#  657: '육백오십칠',
#  658: '육백오십팔',
#  659: '육백오십구',
#  660: '육백육십',
#  661: '육백육십일',
#  662: '육백육십이',
#  663: '육백육십삼',
#  664: '육백육십사',
#  665: '육백육십오',
#  666: '육백육십육',
#  667: '육백육십칠',
#  668: '육백육십팔',
#  669: '육백육십구',
#  670: '육백칠십',
#  671: '육백칠십일',
#  672: '육백칠십이',
#  673: '육백칠십삼',
#  674: '육백칠십사',
#  675: '육백칠십오',
#  676: '육백칠십육',
#  677: '육백칠십칠',
#  678: '육백칠십팔',
#  679: '육백칠십구',
#  680: '육백팔십',
#  681: '육백팔십일',
#  682: '육백팔십이',
#  683: '육백팔십삼',
#  684: '육백팔십사',
#  685: '육백팔십오',
#  686: '육백팔십육',
#  687: '육백팔십칠',
#  688: '육백팔십팔',
#  689: '육백팔십구',
#  690: '육백구십',
#  691: '육백구십일',
#  692: '육백구십이',
#  693: '육백구십삼',
#  694: '육백구십사',
#  695: '육백구십오',
#  696: '육백구십육',
#  697: '육백구십칠',
#  698: '육백구십팔',
#  699: '육백구십구',
#  700: '칠백',
#  701: '칠백일',
#  702: '칠백이',
#  703: '칠백삼',
#  704: '칠백사',
#  705: '칠백오',
#  706: '칠백육',
#  707: '칠백칠',
#  708: '칠백팔',
#  709: '칠백구',
#  710: '칠백십',
#  711: '칠백십일',
#  712: '칠백십이',
#  713: '칠백십삼',
#  714: '칠백십사',
#  715: '칠백십오',
#  716: '칠백십육',
#  717: '칠백십칠',
#  718: '칠백십팔',
#  719: '칠백십구',
#  720: '칠백이십',
#  721: '칠백이십일',
#  722: '칠백이십이',
#  723: '칠백이십삼',
#  724: '칠백이십사',
#  725: '칠백이십오',
#  726: '칠백이십육',
#  727: '칠백이십칠',
#  728: '칠백이십팔',
#  729: '칠백이십구',
#  730: '칠백삼십',
#  731: '칠백삼십일',
#  732: '칠백삼십이',
#  733: '칠백삼십삼',
#  734: '칠백삼십사',
#  735: '칠백삼십오',
#  736: '칠백삼십육',
#  737: '칠백삼십칠',
#  738: '칠백삼십팔',
#  739: '칠백삼십구',
#  740: '칠백사십',
#  741: '칠백사십일',
#  742: '칠백사십이',
#  743: '칠백사십삼',
#  744: '칠백사십사',
#  745: '칠백사십오',
#  746: '칠백사십육',
#  747: '칠백사십칠',
#  748: '칠백사십팔',
#  749: '칠백사십구',
#  750: '칠백오십',
#  751: '칠백오십일',
#  752: '칠백오십이',
#  753: '칠백오십삼',
#  754: '칠백오십사',
#  755: '칠백오십오',
#  756: '칠백오십육',
#  757: '칠백오십칠',
#  758: '칠백오십팔',
#  759: '칠백오십구',
#  760: '칠백육십',
#  761: '칠백육십일',
#  762: '칠백육십이',
#  763: '칠백육십삼',
#  764: '칠백육십사',
#  765: '칠백육십오',
#  766: '칠백육십육',
#  767: '칠백육십칠',
#  768: '칠백육십팔',
#  769: '칠백육십구',
#  770: '칠백칠십',
#  771: '칠백칠십일',
#  772: '칠백칠십이',
#  773: '칠백칠십삼',
#  774: '칠백칠십사',
#  775: '칠백칠십오',
#  776: '칠백칠십육',
#  777: '칠백칠십칠',
#  778: '칠백칠십팔',
#  779: '칠백칠십구',
#  780: '칠백팔십',
#  781: '칠백팔십일',
#  782: '칠백팔십이',
#  783: '칠백팔십삼',
#  784: '칠백팔십사',
#  785: '칠백팔십오',
#  786: '칠백팔십육',
#  787: '칠백팔십칠',
#  788: '칠백팔십팔',
#  789: '칠백팔십구',
#  790: '칠백구십',
#  791: '칠백구십일',
#  792: '칠백구십이',
#  793: '칠백구십삼',
#  794: '칠백구십사',
#  795: '칠백구십오',
#  796: '칠백구십육',
#  797: '칠백구십칠',
#  798: '칠백구십팔',
#  799: '칠백구십구',
#  800: '팔백',
#  801: '팔백일',
#  802: '팔백이',
#  803: '팔백삼',
#  804: '팔백사',
#  805: '팔백오',
#  806: '팔백육',
#  807: '팔백칠',
#  808: '팔백팔',
#  809: '팔백구',
#  810: '팔백십',
#  811: '팔백십일',
#  812: '팔백십이',
#  813: '팔백십삼',
#  814: '팔백십사',
#  815: '팔백십오',
#  816: '팔백십육',
#  817: '팔백십칠',
#  818: '팔백십팔',
#  819: '팔백십구',
#  820: '팔백이십',
#  821: '팔백이십일',
#  822: '팔백이십이',
#  823: '팔백이십삼',
#  824: '팔백이십사',
#  825: '팔백이십오',
#  826: '팔백이십육',
#  827: '팔백이십칠',
#  828: '팔백이십팔',
#  829: '팔백이십구',
#  830: '팔백삼십',
#  831: '팔백삼십일',
#  832: '팔백삼십이',
#  833: '팔백삼십삼',
#  834: '팔백삼십사',
#  835: '팔백삼십오',
#  836: '팔백삼십육',
#  837: '팔백삼십칠',
#  838: '팔백삼십팔',
#  839: '팔백삼십구',
#  840: '팔백사십',
#  841: '팔백사십일',
#  842: '팔백사십이',
#  843: '팔백사십삼',
#  844: '팔백사십사',
#  845: '팔백사십오',
#  846: '팔백사십육',
#  847: '팔백사십칠',
#  848: '팔백사십팔',
#  849: '팔백사십구',
#  850: '팔백오십',
#  851: '팔백오십일',
#  852: '팔백오십이',
#  853: '팔백오십삼',
#  854: '팔백오십사',
#  855: '팔백오십오',
#  856: '팔백오십육',
#  857: '팔백오십칠',
#  858: '팔백오십팔',
#  859: '팔백오십구',
#  860: '팔백육십',
#  861: '팔백육십일',
#  862: '팔백육십이',
#  863: '팔백육십삼',
#  864: '팔백육십사',
#  865: '팔백육십오',
#  866: '팔백육십육',
#  867: '팔백육십칠',
#  868: '팔백육십팔',
#  869: '팔백육십구',
#  870: '팔백칠십',
#  871: '팔백칠십일',
#  872: '팔백칠십이',
#  873: '팔백칠십삼',
#  874: '팔백칠십사',
#  875: '팔백칠십오',
#  876: '팔백칠십육',
#  877: '팔백칠십칠',
#  878: '팔백칠십팔',
#  879: '팔백칠십구',
#  880: '팔백팔십',
#  881: '팔백팔십일',
#  882: '팔백팔십이',
#  883: '팔백팔십삼',
#  884: '팔백팔십사',
#  885: '팔백팔십오',
#  886: '팔백팔십육',
#  887: '팔백팔십칠',
#  888: '팔백팔십팔',
#  889: '팔백팔십구',
#  890: '팔백구십',
#  891: '팔백구십일',
#  892: '팔백구십이',
#  893: '팔백구십삼',
#  894: '팔백구십사',
#  895: '팔백구십오',
#  896: '팔백구십육',
#  897: '팔백구십칠',
#  898: '팔백구십팔',
#  899: '팔백구십구',
#  900: '구백',
#  901: '구백일',
#  902: '구백이',
#  903: '구백삼',
#  904: '구백사',
#  905: '구백오',
#  906: '구백육',
#  907: '구백칠',
#  908: '구백팔',
#  909: '구백구',
#  910: '구백십',
#  911: '구백십일',
#  912: '구백십이',
#  913: '구백십삼',
#  914: '구백십사',
#  915: '구백십오',
#  916: '구백십육',
#  917: '구백십칠',
#  918: '구백십팔',
#  919: '구백십구',
#  920: '구백이십',
#  921: '구백이십일',
#  922: '구백이십이',
#  923: '구백이십삼',
#  924: '구백이십사',
#  925: '구백이십오',
#  926: '구백이십육',
#  927: '구백이십칠',
#  928: '구백이십팔',
#  929: '구백이십구',
#  930: '구백삼십',
#  931: '구백삼십일',
#  932: '구백삼십이',
#  933: '구백삼십삼',
#  934: '구백삼십사',
#  935: '구백삼십오',
#  936: '구백삼십육',
#  937: '구백삼십칠',
#  938: '구백삼십팔',
#  939: '구백삼십구',
#  940: '구백사십',
#  941: '구백사십일',
#  942: '구백사십이',
#  943: '구백사십삼',
#  944: '구백사십사',
#  945: '구백사십오',
#  946: '구백사십육',
#  947: '구백사십칠',
#  948: '구백사십팔',
#  949: '구백사십구',
#  950: '구백오십',
#  951: '구백오십일',
#  952: '구백오십이',
#  953: '구백오십삼',
#  954: '구백오십사',
#  955: '구백오십오',
#  956: '구백오십육',
#  957: '구백오십칠',
#  958: '구백오십팔',
#  959: '구백오십구',
#  960: '구백육십',
#  961: '구백육십일',
#  962: '구백육십이',
#  963: '구백육십삼',
#  964: '구백육십사',
#  965: '구백육십오',
#  966: '구백육십육',
#  967: '구백육십칠',
#  968: '구백육십팔',
#  969: '구백육십구',
#  970: '구백칠십',
#  971: '구백칠십일',
#  972: '구백칠십이',
#  973: '구백칠십삼',
#  974: '구백칠십사',
#  975: '구백칠십오',
#  976: '구백칠십육',
#  977: '구백칠십칠',
#  978: '구백칠십팔',
#  979: '구백칠십구',
#  980: '구백팔십',
#  981: '구백팔십일',
#  982: '구백팔십이',
#  983: '구백팔십삼',
#  984: '구백팔십사',
#  985: '구백팔십오',
#  986: '구백팔십육',
#  987: '구백팔십칠',
#  988: '구백팔십팔',
#  989: '구백팔십구',
#  990: '구백구십',
#  991: '구백구십일',
#  992: '구백구십이',
#  993: '구백구십삼',
#  994: '구백구십사',
#  995: '구백구십오',
#  996: '구백구십육',
#  997: '구백구십칠',
#  998: '구백구십팔',
#  999: '구백구십구',
#  ...}

# %%
def get_similarity_table(text1, text2):
    pat_math_symbol = re.compile(r'[().,‘’?!]')
    pat_number = re.compile(r'\d+')
    kopro = get_korean_pronunciation_of_number(9999) #~9999
    
    esl = text1.splitlines() #문장단위로 리스트
    gsl = text2.splitlines()
    
    # punctuation 제거, 앞뒤 공백 제거
    new_esl = [s.strip() for s in [pat_math_symbol.sub('', _) for _ in esl]]
    new_gsl = [s.strip() for s in [pat_math_symbol.sub('', _) for _ in gsl]]
    
    #수학기호 한국어로 변환(EBS)
    for i in range(len(new_esl)):
        for j in range(len(new_esl[i])):
            s = new_esl[i][j]
            if s in sd:
                new_esl[i] = new_esl[i].replace(s, sd[s])
    
    #숫자 한국어로 변환(EBS)
    new_esl2 = []
    for _ in new_esl:
        fl = re.findall(r'\d+', _)
        for n in fl:
            _ = _.replace(n, kopro[int(n)])
        new_esl2.append(_)
        
    #숫자 한국어로 변환(STT)
    new_gsl2 = []
    for _ in new_gsl:
        fl = re.findall(r'\d+', _)
        for n in fl:
            _ = _.replace(n, kopro[int(n)])
        new_gsl2.append(_)
    
    #알파벳 한국어로 변환(EBS)
    for i in range(len(new_esl2)):
        for j in range(len(new_esl2[i])):
            s = new_esl2[i][j]
            if s in ad:
                new_esl2[i] = new_esl2[i].replace(s, ad[s])
                
    #알파벳 한국어로 변환(STT)
    for i in range(len(new_gsl2)):
        for j in range(len(new_gsl2[i])):
            s = new_gsl2[i][j]
            if s in ad:
                new_gsl2[i] = new_gsl2[i].replace(s, ad[s])
    
    if len(new_esl2) != len(new_gsl2):
        return print('error : not matched line number')
    
    
    maxprb_list_for_plot = []
    for _ in range(len(esl)):
        tokenized_ebs_sentence_list = TweetTokenizer().tokenize(new_esl2[_])
        serial_gsl_string = ''.join(TweetTokenizer().tokenize(new_gsl2[_]))
        print(new_esl2[_])
        print(new_gsl2[_])
        print()
        
        for word_index in range(len(tokenized_ebs_sentence_list)):
            word = tokenized_ebs_sentence_list[word_index]
            max_sim_prob = 0
            for compare_index in range(len(serial_gsl_string)-len(word)+1):
                s1 = korean_to_be_englished(word)
                compared_word = serial_gsl_string[compare_index:compare_index+len(word)]
                s2 = korean_to_be_englished(compared_word)
                prob = similarity_prob(s1, s2)
                if prob > max_sim_prob:
                    max_sim_prob = prob
                    max_sim_word = compared_word
            print('EBS 단어  :', word)
            print('GoogleSTT :', max_sim_word, max_sim_prob)
            print()
            maxprb_list_for_plot.append(max_sim_prob)
            similarity_table.append({word:max_sim_word}, ignore_index=True)
        print('----------------------------------')
    
    return similarity_table, maxprb_list_for_plot

# %%
table, maxprob_list = get_similarity_table(elbl, glbl)
# Out:
# 반갑습니다 이비에스 친구 여러분들 여러분들과 함께 중학뉴런수학삼하를 강의하게 된 손석민입니다
# 반갑습니다 더블유아이티에이치 여러분들 여러분들과 함께 중학 유럽 수학 삼 하를 강행하기 된 분석입니다 사
#
# EBS 단어  : 반갑습니다
# GoogleSTT : 반갑습니다 1.0
#
# EBS 단어  : 이비에스
# GoogleSTT : 이티에이 0.75
#
# EBS 단어  : 친구
# GoogleSTT : 치여 0.5
#
# EBS 단어  : 여러분들
# GoogleSTT : 여러분들 1.0
#
# EBS 단어  : 여러분들과
# GoogleSTT : 여러분들과 1.0
#
# EBS 단어  : 함께
# GoogleSTT : 함께 1.0
#
# EBS 단어  : 중학뉴런수학삼하를
# GoogleSTT : 중학유럽수학삼하를 0.9259259259259259
#
# EBS 단어  : 강의하게
# GoogleSTT : 강행하기 0.6666666666666666
#
# EBS 단어  : 된
# GoogleSTT : 된 1.0
#
# EBS 단어  : 손석민입니다
# GoogleSTT : 된분석입니다 0.5555555555555556
#
# ----------------------------------
# 이학년 뉴런을 통해서도 만났었는데요
# 이 학년 늘어 를 통해서도 만났는데요
#
# EBS 단어  : 이학년
# GoogleSTT : 이학년 1.0
#
# EBS 단어  : 뉴런을
# GoogleSTT : 늘어를 0.4444444444444444
#
# EBS 단어  : 통해서도
# GoogleSTT : 통해서도 1.0
#
# EBS 단어  : 만났었는데요
# GoogleSTT : 도만났는데요 0.6111111111111112
#
# ----------------------------------
# 여러분들 이렇게 다시 만나게 되어서 정말 반갑습니다
# 여러분들 이렇게 다시 만나게 되어서 정말 반갑습니다
#
# EBS 단어  : 여러분들
# GoogleSTT : 여러분들 1.0
#
# EBS 단어  : 이렇게
# GoogleSTT : 이렇게 1.0
#
# EBS 단어  : 다시
# GoogleSTT : 다시 1.0
#
# EBS 단어  : 만나게
# GoogleSTT : 만나게 1.0
#
# EBS 단어  : 되어서
# GoogleSTT : 되어서 1.0
#
# EBS 단어  : 정말
# GoogleSTT : 정말 1.0
#
# EBS 단어  : 반갑습니다
# GoogleSTT : 반갑습니다 1.0
#
# ----------------------------------
# 앞으로 삼하 과정 어떻게 진행되는지에 대해서는 여러분들께서 오리엔테이션 강의를 통해서 확인할 수 있을 거고요
# 앞으로 삼 하 과정 어떻게 진행되는지 에 대해서는 여러분들께서 오리엔테이션 강의를 통해서 확인할 수 있을 거고요
#
# EBS 단어  : 앞으로
# GoogleSTT : 앞으로 1.0
#
# EBS 단어  : 삼하
# GoogleSTT : 삼하 1.0
#
# EBS 단어  : 과정
# GoogleSTT : 과정 1.0
#
# EBS 단어  : 어떻게
# GoogleSTT : 어떻게 1.0
#
# EBS 단어  : 진행되는지에
# GoogleSTT : 진행되는지에 1.0
#
# EBS 단어  : 대해서는
# GoogleSTT : 대해서는 1.0
#
# EBS 단어  : 여러분들께서
# GoogleSTT : 여러분들께서 1.0
#
# EBS 단어  : 오리엔테이션
# GoogleSTT : 오리엔테이션 1.0
#
# EBS 단어  : 강의를
# GoogleSTT : 강의를 1.0
#
# EBS 단어  : 통해서
# GoogleSTT : 통해서 1.0
#
# EBS 단어  : 확인할
# GoogleSTT : 확인할 1.0
#
# EBS 단어  : 수
# GoogleSTT : 수 1.0
#
# EBS 단어  : 있을
# GoogleSTT : 있을 1.0
#
# EBS 단어  : 거고요
# GoogleSTT : 거고요 1.0
#
# ----------------------------------
# 오리엔테이션 강의는 반드시 듣고 오셔야 여러분들이 삼학년 과정이 하 과정이 특히 어떻게 수업되는지 확인할 수 있을 겁니다
# 오리엔테이션 강의는 반드시 듣고 옷 여야 여러분들이 삼 학년 과정의 한 가정의 특히 어떻게 수업 되는지 확인할 수 있을 겁니다
#
# EBS 단어  : 오리엔테이션
# GoogleSTT : 오리엔테이션 1.0
#
# EBS 단어  : 강의는
# GoogleSTT : 강의는 1.0
#
# EBS 단어  : 반드시
# GoogleSTT : 반드시 1.0
#
# EBS 단어  : 듣고
# GoogleSTT : 듣고 1.0
#
# EBS 단어  : 오셔야
# GoogleSTT : 옷여야 0.7777777777777778
#
# EBS 단어  : 여러분들이
# GoogleSTT : 여러분들이 1.0
#
# EBS 단어  : 삼학년
# GoogleSTT : 삼학년 1.0
#
# EBS 단어  : 과정이
# GoogleSTT : 과정의 0.8888888888888888
#
# EBS 단어  : 하
# GoogleSTT : 학 0.6666666666666666
#
# EBS 단어  : 과정이
# GoogleSTT : 과정의 0.8888888888888888
#
# EBS 단어  : 특히
# GoogleSTT : 특히 1.0
#
# EBS 단어  : 어떻게
# GoogleSTT : 어떻게 1.0
#
# EBS 단어  : 수업되는지
# GoogleSTT : 수업되는지 1.0
#
# EBS 단어  : 확인할
# GoogleSTT : 확인할 1.0
#
# EBS 단어  : 수
# GoogleSTT : 수 1.0
#
# EBS 단어  : 있을
# GoogleSTT : 있을 1.0
#
# EBS 단어  : 겁니다
# GoogleSTT : 겁니다 1.0
#
# ----------------------------------
# 일단 삼학년 과정 같은 경우에는 크게 삼개의 대단원으로 이루어져 있는데요
# 기자 일단 삼 학년 과정 같은 경우에는 크게 세계의 대단원의 으로 이뤄져 있는데요
#
# EBS 단어  : 일단
# GoogleSTT : 일단 1.0
#
# EBS 단어  : 삼학년
# GoogleSTT : 삼학년 1.0
#
# EBS 단어  : 과정
# GoogleSTT : 과정 1.0
#
# EBS 단어  : 같은
# GoogleSTT : 같은 1.0
#
# EBS 단어  : 경우에는
# GoogleSTT : 경우에는 1.0
#
# EBS 단어  : 크게
# GoogleSTT : 크게 1.0
#
# EBS 단어  : 삼개의
# GoogleSTT : 세계의 0.6666666666666666
#
# EBS 단어  : 대단원으로
# GoogleSTT : 대단원의으 0.8
#
# EBS 단어  : 이루어져
# GoogleSTT : 으로이뤄 0.5833333333333334
#
# EBS 단어  : 있는데요
# GoogleSTT : 있는데요 1.0
#
# ----------------------------------
# 첫 번째가 삼각비라는 단원이고 두 번째가 원의 성질 세 번째가 통계 이렇게 이루어져 있습니다
# 첫번째가 삼각 이라는 단원고 두 번째가 원에 성질 세 번째가 통계 이렇게 이뤄져 있습니다
#
# EBS 단어  : 첫
# GoogleSTT : 첫 1.0
#
# EBS 단어  : 번째가
# GoogleSTT : 번째가 1.0
#
# EBS 단어  : 삼각비라는
# GoogleSTT : 삼각이라는 0.9333333333333333
#
# EBS 단어  : 단원이고
# GoogleSTT : 단원고두 0.6666666666666666
#
# EBS 단어  : 두
# GoogleSTT : 두 1.0
#
# EBS 단어  : 번째가
# GoogleSTT : 번째가 1.0
#
# EBS 단어  : 원의
# GoogleSTT : 원에 0.8333333333333334
#
# EBS 단어  : 성질
# GoogleSTT : 성질 1.0
#
# EBS 단어  : 세
# GoogleSTT : 세 1.0
#
# EBS 단어  : 번째가
# GoogleSTT : 번째가 1.0
#
# EBS 단어  : 통계
# GoogleSTT : 통계 1.0
#
# EBS 단어  : 이렇게
# GoogleSTT : 이렇게 1.0
#
# EBS 단어  : 이루어져
# GoogleSTT : 이렇게이 0.5
#
# EBS 단어  : 있습니다
# GoogleSTT : 있습니다 1.0
#
# ----------------------------------
# 우리가 일학년하도 마찬가지고 이학년하도 그래 왔듯 주로 도형에 대한 이야기가 삼하에서 많이 다루어지는구나 라는 걸 생각하면 될 테고요
# 우리가 일 학년 하도 마찬가지고 이 학년 하도 그랬듯 주로 도용에 대한 이야기가 삼 하에서 많이 다뤄지는 구나 라는 걸 생각하면 될 테고요
#
# EBS 단어  : 우리가
# GoogleSTT : 우리가 1.0
#
# EBS 단어  : 일학년하도
# GoogleSTT : 일학년하도 1.0
#
# EBS 단어  : 마찬가지고
# GoogleSTT : 마찬가지고 1.0
#
# EBS 단어  : 이학년하도
# GoogleSTT : 이학년하도 1.0
#
# EBS 단어  : 그래
# GoogleSTT : 그랬 0.8333333333333334
#
# EBS 단어  : 왔듯
# GoogleSTT : 랬듯 0.6666666666666666
#
# EBS 단어  : 주로
# GoogleSTT : 주로 1.0
#
# EBS 단어  : 도형에
# GoogleSTT : 도용에 0.7777777777777778
#
# EBS 단어  : 대한
# GoogleSTT : 대한 1.0
#
# EBS 단어  : 이야기가
# GoogleSTT : 이야기가 1.0
#
# EBS 단어  : 삼하에서
# GoogleSTT : 삼하에서 1.0
#
# EBS 단어  : 많이
# GoogleSTT : 많이 1.0
#
# EBS 단어  : 다루어지는구나
# GoogleSTT : 이다뤄지는구나 0.7142857142857143
#
# EBS 단어  : 라는
# GoogleSTT : 라는 1.0
#
# EBS 단어  : 걸
# GoogleSTT : 걸 1.0
#
# EBS 단어  : 생각하면
# GoogleSTT : 생각하면 1.0
#
# EBS 단어  : 될
# GoogleSTT : 될 1.0
#
# EBS 단어  : 테고요
# GoogleSTT : 테고요 1.0
#
# ----------------------------------
# 오늘은 그 첫 시간이니까 삼각비 삼각 알아요 비 알아요
# 오늘은 그 첫 시간이 이니까 삼 갑 의 삼각 알아요 이 알아요
#
# EBS 단어  : 오늘은
# GoogleSTT : 오늘은 1.0
#
# EBS 단어  : 그
# GoogleSTT : 그 1.0
#
# EBS 단어  : 첫
# GoogleSTT : 첫 1.0
#
# EBS 단어  : 시간이니까
# GoogleSTT : 시간이이니 0.8
#
# EBS 단어  : 삼각비
# GoogleSTT : 삼갑의 0.6666666666666666
#
# EBS 단어  : 삼각
# GoogleSTT : 삼각 1.0
#
# EBS 단어  : 알아요
# GoogleSTT : 알아요 1.0
#
# EBS 단어  : 비
# GoogleSTT : 시 0.6666666666666666
#
# EBS 단어  : 알아요
# GoogleSTT : 알아요 1.0
#
# ----------------------------------
# 근데 이제 합쳐져 있는 삼각비라는 새로운 용어가 나왔죠
# 합쳐져 있는 삼각 이라는 새로운 용어가 나왔죠
#
# EBS 단어  : 근데
# GoogleSTT : 는새 0.5
#
# EBS 단어  : 이제
# GoogleSTT : 이라 0.6666666666666666
#
# EBS 단어  : 합쳐져
# GoogleSTT : 합쳐져 1.0
#
# EBS 단어  : 있는
# GoogleSTT : 있는 1.0
#
# EBS 단어  : 삼각비라는
# GoogleSTT : 삼각이라는 0.9333333333333333
#
# EBS 단어  : 새로운
# GoogleSTT : 새로운 1.0
#
# EBS 단어  : 용어가
# GoogleSTT : 용어가 1.0
#
# EBS 단어  : 나왔죠
# GoogleSTT : 나왔죠 1.0
#
# ----------------------------------
# 그럼 이 개념을 공부하기에 앞서서 당연히 삼각비의 뜻부터 시작하는 것이 첫 시간입니다
# 이 개념을 공부하게 앞서 당연히 삼각 비 듯 부터 시작하는 것이 첫 시간입니다
#
# EBS 단어  : 그럼
# GoogleSTT : 개념 0.5
#
# EBS 단어  : 이
# GoogleSTT : 이 1.0
#
# EBS 단어  : 개념을
# GoogleSTT : 개념을 1.0
#
# EBS 단어  : 공부하기에
# GoogleSTT : 공부하게앞 0.8
#
# EBS 단어  : 앞서서
# GoogleSTT : 앞서당 0.6666666666666666
#
# EBS 단어  : 당연히
# GoogleSTT : 당연히 1.0
#
# EBS 단어  : 삼각비의
# GoogleSTT : 삼각비듯 0.75
#
# EBS 단어  : 뜻부터
# GoogleSTT : 듯부터 0.8888888888888888
#
# EBS 단어  : 시작하는
# GoogleSTT : 시작하는 1.0
#
# EBS 단어  : 것이
# GoogleSTT : 것이 1.0
#
# EBS 단어  : 첫
# GoogleSTT : 첫 1.0
#
# EBS 단어  : 시간입니다
# GoogleSTT : 시간입니다 1.0
#
# ----------------------------------
# 오늘 그 첫 시간 함께 시작해 보도록 할 텐데요 중학교 삼학년 수학 손샘과 끝냅시다
# 오늘 사 시간 함께 시작해 보도록 할 텐데요 중학교 삼 학년 수학 선생과 끝납니다
#
# EBS 단어  : 오늘
# GoogleSTT : 오늘 1.0
#
# EBS 단어  : 그
# GoogleSTT : 교 0.6666666666666666
#
# EBS 단어  : 첫
# GoogleSTT : 선 0.3333333333333333
#
# EBS 단어  : 시간
# GoogleSTT : 시간 1.0
#
# EBS 단어  : 함께
# GoogleSTT : 함께 1.0
#
# EBS 단어  : 시작해
# GoogleSTT : 시작해 1.0
#
# EBS 단어  : 보도록
# GoogleSTT : 보도록 1.0
#
# EBS 단어  : 할
# GoogleSTT : 할 1.0
#
# EBS 단어  : 텐데요
# GoogleSTT : 텐데요 1.0
#
# EBS 단어  : 중학교
# GoogleSTT : 중학교 1.0
#
# EBS 단어  : 삼학년
# GoogleSTT : 삼학년 1.0
#
# EBS 단어  : 수학
# GoogleSTT : 수학 1.0
#
# EBS 단어  : 손샘과
# GoogleSTT : 선생과 0.7777777777777778
#
# EBS 단어  : 끝냅시다
# GoogleSTT : 끝납니다 0.8333333333333334
#
# ----------------------------------
# 오늘 공부할 내용 바로 두 가지 개념인데요 오늘 두 가지 개념 첫 번째 제목이 굉장히 길어요
# 오늘 공부할 내용 바로 두 가지 개념 인데요 아 오늘 두 가지 기념 첫 번째 제복이 굉장히 길어야
#
# EBS 단어  : 오늘
# GoogleSTT : 오늘 1.0
#
# EBS 단어  : 공부할
# GoogleSTT : 공부할 1.0
#
# EBS 단어  : 내용
# GoogleSTT : 내용 1.0
#
# EBS 단어  : 바로
# GoogleSTT : 바로 1.0
#
# EBS 단어  : 두
# GoogleSTT : 두 1.0
#
# EBS 단어  : 가지
# GoogleSTT : 가지 1.0
#
# EBS 단어  : 개념인데요
# GoogleSTT : 개념인데요 1.0
#
# EBS 단어  : 오늘
# GoogleSTT : 오늘 1.0
#
# EBS 단어  : 두
# GoogleSTT : 두 1.0
#
# EBS 단어  : 가지
# GoogleSTT : 가지 1.0
#
# EBS 단어  : 개념
# GoogleSTT : 개념 1.0
#
# EBS 단어  : 첫
# GoogleSTT : 첫 1.0
#
# EBS 단어  : 번째
# GoogleSTT : 번째 1.0
#
# EBS 단어  : 제목이
# GoogleSTT : 제복이 0.8888888888888888
#
# EBS 단어  : 굉장히
# GoogleSTT : 굉장히 1.0
#
# EBS 단어  : 길어요
# GoogleSTT : 길어야 0.8888888888888888
#
# ----------------------------------
# 닮은 직각삼각형에서 대응변의 길이의 비라는 것이 있습니다
# 닮은 즉각 삼 각 통에서 대응 변의 길이의 이 라는 것이 있습니다
#
# EBS 단어  : 닮은
# GoogleSTT : 닮은 1.0
#
# EBS 단어  : 직각삼각형에서
# GoogleSTT : 즉각삼각통에서 0.8571428571428571
#
# EBS 단어  : 대응변의
# GoogleSTT : 대응변의 1.0
#
# EBS 단어  : 길이의
# GoogleSTT : 길이의 1.0
#
# EBS 단어  : 비라는
# GoogleSTT : 이라는 0.8888888888888888
#
# EBS 단어  : 것이
# GoogleSTT : 것이 1.0
#
# EBS 단어  : 있습니다
# GoogleSTT : 있습니다 1.0
#
# ----------------------------------
# 그다음 두 번째 개념이 바로 뭐냐면 삼각비라는 건데 삼각비의 뜻이겠죠
# 그 다음 두 번째 개념이 바로 뭐냐하면 삼 갑 의 라는 건데 상납 뜻이겠죠
#
# EBS 단어  : 그다음
# GoogleSTT : 그다음 1.0
#
# EBS 단어  : 두
# GoogleSTT : 두 1.0
#
# EBS 단어  : 번째
# GoogleSTT : 번째 1.0
#
# EBS 단어  : 개념이
# GoogleSTT : 개념이 1.0
#
# EBS 단어  : 바로
# GoogleSTT : 바로 1.0
#
# EBS 단어  : 뭐냐면
# GoogleSTT : 뭐냐하 0.6666666666666666
#
# EBS 단어  : 삼각비라는
# GoogleSTT : 삼갑의라는 0.8
# EBS 단어  : 건데
# GoogleSTT : 건데 1.0
#
# EBS 단어  : 삼각비의
# GoogleSTT : 삼갑의라 0.5833333333333334
#
# EBS 단어  : 뜻이겠죠
# GoogleSTT : 뜻이겠죠 1.0
#
# ----------------------------------
# 이 첫 번째 개념은 앞으로 쭉 공부할 내용이 다 직각삼각형에서 주로 다루어질 텐데직각삼각형에서 갖는 기본적인 성질이 있는데 그 성질을 알고 가자는 삼각비를 공부하기에 앞선 징검다리 내용이다 라고 여러분들이 받아들이시면 됩니다
# 의 첫 번째 개념은 두 번째 앞으로 쭉 공부할 내용이 다 즉각 삼각형 에서 주로 다뤄질 텐데 즉각 상황 평에서 갖는 기본적인 성질이 있는데 그 성질을 알고 가자 라는 어떤 삼각 비를 공부하기 앞선 징검다리 내용이라고 여러분들이 받아들이지만 됩니다
#
# EBS 단어  : 이
# GoogleSTT : 이 1.0
#
# EBS 단어  : 첫
# GoogleSTT : 첫 1.0
#
# EBS 단어  : 번째
# GoogleSTT : 번째 1.0
#
# EBS 단어  : 개념은
# GoogleSTT : 개념은 1.0
#
# EBS 단어  : 앞으로
# GoogleSTT : 앞으로 1.0
#
# EBS 단어  : 쭉
# GoogleSTT : 쭉 1.0
#
# EBS 단어  : 공부할
# GoogleSTT : 공부할 1.0
#
# EBS 단어  : 내용이
# GoogleSTT : 내용이 1.0
#
# EBS 단어  : 다
# GoogleSTT : 다 1.0
#
# EBS 단어  : 직각삼각형에서
# GoogleSTT : 즉각삼각형에서 0.9523809523809523
#
# EBS 단어  : 주로
# GoogleSTT : 주로 1.0
#
# EBS 단어  : 다루어질
# GoogleSTT : 데그성질 0.5833333333333334
#
# EBS 단어  : 텐데직각삼각형에서
# GoogleSTT : 이다즉각삼각형에서 0.8148148148148148
#
# EBS 단어  : 갖는
# GoogleSTT : 갖는 1.0
#
# EBS 단어  : 기본적인
# GoogleSTT : 기본적인 1.0
#
# EBS 단어  : 성질이
# GoogleSTT : 성질이 1.0
#
# EBS 단어  : 있는데
# GoogleSTT : 있는데 1.0
#
# EBS 단어  : 그
# GoogleSTT : 그 1.0
#
# EBS 단어  : 성질을
# GoogleSTT : 성질을 1.0
#
# EBS 단어  : 알고
# GoogleSTT : 알고 1.0
#
# EBS 단어  : 가자는
# GoogleSTT : 자라는 0.7777777777777778
#
# EBS 단어  : 삼각비를
# GoogleSTT : 삼각비를 1.0
#
# EBS 단어  : 공부하기에
# GoogleSTT : 공부하기앞 0.8666666666666667
#
# EBS 단어  : 앞선
# GoogleSTT : 앞선 1.0
#
# EBS 단어  : 징검다리
# GoogleSTT : 징검다리 1.0
#
# EBS 단어  : 내용이다
# GoogleSTT : 내용이다 1.0
#
# EBS 단어  : 라고
# GoogleSTT : 라고 1.0
#
# EBS 단어  : 여러분들이
# GoogleSTT : 여러분들이 1.0
#
# EBS 단어  : 받아들이시면
# GoogleSTT : 받아들이지만 0.8888888888888888
#
# EBS 단어  : 됩니다
# GoogleSTT : 됩니다 1.0
#
# ----------------------------------
# 그렇다면 닮은 직각삼각형에서라고 했으니까 닮은 직각삼각형을 그려 봐야 되겠죠
# 그렇다면 닮은 즉각 삼각형 해서 있으니까 닮은 즉각 삼각형을 그려 봐야겠죠
#
# EBS 단어  : 그렇다면
# GoogleSTT : 그렇다면 1.0
#
# EBS 단어  : 닮은
# GoogleSTT : 닮은 1.0
#
# EBS 단어  : 직각삼각형에서라고
# GoogleSTT : 즉각삼각형해서있으 0.7037037037037037
#
# EBS 단어  : 했으니까
# GoogleSTT : 있으니까 0.8333333333333334
#
# EBS 단어  : 닮은
# GoogleSTT : 닮은 1.0
#
# EBS 단어  : 직각삼각형을
# GoogleSTT : 즉각삼각형을 0.9444444444444444
#
# EBS 단어  : 그려
# GoogleSTT : 그려 1.0
#
# EBS 단어  : 봐야
# GoogleSTT : 봐야 1.0
#
# EBS 단어  : 되겠죠
# GoogleSTT : 야겠죠 0.7777777777777778
#
# ----------------------------------
# 닮은 직각삼각형 두 개를 편하게 그릴 수 있는 제일 좋은 방법은 뭘까 생각해 보면우리는 이렇게 그리면 될 거 같아요
# 닮은 즉각 삼각형 두 개를 편하게 그릴 수 있는 제일 좋은 방법은 뭘까 생각해보면 우리는 이렇게 그리면 될 것 같아요
#
# EBS 단어  : 닮은
# GoogleSTT : 닮은 1.0
#
# EBS 단어  : 직각삼각형
# GoogleSTT : 즉각삼각형 0.9333333333333333
#
# EBS 단어  : 두
# GoogleSTT : 두 1.0
#
# EBS 단어  : 개를
# GoogleSTT : 개를 1.0
#
# EBS 단어  : 편하게
# GoogleSTT : 편하게 1.0
#
# EBS 단어  : 그릴
# GoogleSTT : 그릴 1.0
#
# EBS 단어  : 수
# GoogleSTT : 수 1.0
#
# EBS 단어  : 있는
# GoogleSTT : 있는 1.0
#
# EBS 단어  : 제일
# GoogleSTT : 제일 1.0
#
# EBS 단어  : 좋은
# GoogleSTT : 좋은 1.0
#
# EBS 단어  : 방법은
# GoogleSTT : 방법은 1.0
#
# EBS 단어  : 뭘까
# GoogleSTT : 뭘까 1.0
#
# EBS 단어  : 생각해
# GoogleSTT : 생각해 1.0
#
# EBS 단어  : 보면우리는
# GoogleSTT : 보면우리는 1.0
#
# EBS 단어  : 이렇게
# GoogleSTT : 이렇게 1.0
#
# EBS 단어  : 그리면
# GoogleSTT : 그리면 1.0
#
# EBS 단어  : 될
# GoogleSTT : 될 1.0
#
# EBS 단어  : 거
# GoogleSTT : 개 0.6666666666666666
#
# EBS 단어  : 같아요
# GoogleSTT : 같아요 1.0
#
# ----------------------------------
# 이렇게 한번 그려 보겠습니다 이렇게 여기에서부터 수선을 이렇게 그어 보겠습니다
# 이렇게 만들어보겠습니다 이렇게 이렇게 여기서부터 수선을 이렇게 들어보겠습니다
#
# EBS 단어  : 이렇게
# GoogleSTT : 이렇게 1.0
#
# EBS 단어  : 한번
# GoogleSTT : 만들 0.3333333333333333
#
# EBS 단어  : 그려
# GoogleSTT : 게여 0.6666666666666666
#
# EBS 단어  : 보겠습니다
# GoogleSTT : 보겠습니다 1.0
#
# EBS 단어  : 이렇게
# GoogleSTT : 이렇게 1.0
#
# EBS 단어  : 여기에서부터
# GoogleSTT : 게여기서부터 0.6666666666666666
#
# EBS 단어  : 수선을
# GoogleSTT : 수선을 1.0
#
# EBS 단어  : 이렇게
# GoogleSTT : 이렇게 1.0
#
# EBS 단어  : 그어
# GoogleSTT : 들어 0.6666666666666666
#
# EBS 단어  : 보겠습니다
# GoogleSTT : 보겠습니다 1.0
#
# ----------------------------------
# 일단 바깥쪽에 직각삼각형 하나 보입니다 그렇죠
# 일단 바깥쪽에 즉각 삼각형 않아 보입니다
#
# EBS 단어  : 일단
# GoogleSTT : 일단 1.0
#
# EBS 단어  : 바깥쪽에
# GoogleSTT : 바깥쪽에 1.0
#
# EBS 단어  : 직각삼각형
# GoogleSTT : 즉각삼각형 0.9333333333333333
#
# EBS 단어  : 하나
# GoogleSTT : 단바 0.5
#
# EBS 단어  : 보입니다
# GoogleSTT : 보입니다 1.0
#
# EBS 단어  : 그렇죠
# GoogleSTT : 보입니 0.2222222222222222
#
# ----------------------------------
# 또 다른 직각삼각형를 빗변 위 한 점을 잡아서 이렇게 수선을 똑같이 그어 주면 바로 두 직각삼각형 에이비씨하고 에이디이는 서로 어떤 닮음에이에이닮음이 된다
# 또다른 즉각 삼각형 하나를 이 편이 한 점을 잡아서 이렇게 수선을 똑같이 그럴 주면 바로 두 즉각 삼각형 에이 비 지시하고 에이티 서로 어떤 닮은 에이 담은 이 된다
#
# EBS 단어  : 또
# GoogleSTT : 또 1.0
#
# EBS 단어  : 다른
# GoogleSTT : 다른 1.0
#
# EBS 단어  : 직각삼각형를
# GoogleSTT : 즉각삼각형하 0.7777777777777778
#
# EBS 단어  : 빗변
# GoogleSTT : 이편 0.5
#
# EBS 단어  : 위
# GoogleSTT : 이 0.6666666666666666
#
# EBS 단어  : 한
# GoogleSTT : 한 1.0
#
# EBS 단어  : 점을
# GoogleSTT : 점을 1.0
#
# EBS 단어  : 잡아서
# GoogleSTT : 잡아서 1.0
#
# EBS 단어  : 이렇게
# GoogleSTT : 이렇게 1.0
#
# EBS 단어  : 수선을
# GoogleSTT : 수선을 1.0
#
# EBS 단어  : 똑같이
# GoogleSTT : 똑같이 1.0
#
# EBS 단어  : 그어
# GoogleSTT : 그럴 0.6666666666666666
#
# EBS 단어  : 주면
# GoogleSTT : 주면 1.0
#
# EBS 단어  : 바로
# GoogleSTT : 바로 1.0
#
# EBS 단어  : 두
# GoogleSTT : 두 1.0
#
# EBS 단어  : 직각삼각형
# GoogleSTT : 즉각삼각형 0.9333333333333333
#
# EBS 단어  : 에이비씨하고
# GoogleSTT : 이비지시하고 0.7777777777777778
#
# EBS 단어  : 에이디이는
# GoogleSTT : 에이비지시 0.6666666666666666
#
# EBS 단어  : 서로
# GoogleSTT : 서로 1.0
#
# EBS 단어  : 어떤
# GoogleSTT : 어떤 1.0
#
# EBS 단어  : 닮음에이에이닮음이
# GoogleSTT : 어떤닮은에이담은이 0.5185185185185185
#
# EBS 단어  : 된다
# GoogleSTT : 된다 1.0
#
# ----------------------------------
# 이건 우리가 중학교 이학년 때 배웠죠 그렇죠 각에이가 공통이고 그다음에 둘 다 직각을 갖고 있으니까 에이에이닮음이 될 테고
# 이건 우리가 중학교 이해하는 데 배웠죠 가계가 공통 이고 그 다음에 둘 다 즉각 을 갖고 있으니까 에이에이 닮은 있을 테고
#
# EBS 단어  : 이건
# GoogleSTT : 이건 1.0
#
# EBS 단어  : 우리가
# GoogleSTT : 우리가 1.0
#
# EBS 단어  : 중학교
# GoogleSTT : 중학교 1.0
#
# EBS 단어  : 이학년
# GoogleSTT : 해하는 0.5555555555555556
#
# EBS 단어  : 때
# GoogleSTT : 해 0.6666666666666666
#
# EBS 단어  : 배웠죠
# GoogleSTT : 배웠죠 1.0
#
# EBS 단어  : 그렇죠
# GoogleSTT : 배웠죠 0.4444444444444444
#
# EBS 단어  : 각에이가
# GoogleSTT : 건우리가 0.6666666666666666
#
# EBS 단어  : 공통이고
# GoogleSTT : 공통이고 1.0
#
# EBS 단어  : 그다음에
# GoogleSTT : 그다음에 1.0
#
# EBS 단어  : 둘
# GoogleSTT : 둘 1.0
#
# EBS 단어  : 다
# GoogleSTT : 다 1.0
#
# EBS 단어  : 직각을
# GoogleSTT : 즉각을 0.8888888888888888
#
# EBS 단어  : 갖고
# GoogleSTT : 갖고 1.0
#
# EBS 단어  : 있으니까
# GoogleSTT : 있으니까 1.0
#
# EBS 단어  : 에이에이닮음이
# GoogleSTT : 에이에이닮은있 0.9047619047619048
#
# EBS 단어  : 될
# GoogleSTT : 둘 0.6666666666666666
#
# EBS 단어  : 테고
# GoogleSTT : 테고 1.0
#
# ----------------------------------
# 우리가 중이 때 배웠던 닮음비라는 건 뭐였냐 하면 대응하는 변의 길이의 비였어요 그렇죠
# 우리가 중인 팀이었던 닮은 이라는 건 뭐냐면 대응하는 변의 길이의 이었어요
#
# EBS 단어  : 우리가
# GoogleSTT : 우리가 1.0
#
# EBS 단어  : 중이
# GoogleSTT : 중인 0.8333333333333334
#
# EBS 단어  : 때
# GoogleSTT : 대 0.6666666666666666
#
# EBS 단어  : 배웠던
# GoogleSTT : 이었던 0.6666666666666666
#
# EBS 단어  : 닮음비라는
# GoogleSTT : 닮은이라는 0.8666666666666667
#
# EBS 단어  : 건
# GoogleSTT : 건 1.0
#
# EBS 단어  : 뭐였냐
# GoogleSTT : 이었어 0.4444444444444444
#
# EBS 단어  : 하면
# GoogleSTT : 냐면 0.6666666666666666
#
# EBS 단어  : 대응하는
# GoogleSTT : 대응하는 1.0
#
# EBS 단어  : 변의
# GoogleSTT : 변의 1.0
#
# EBS 단어  : 길이의
# GoogleSTT : 길이의 1.0
#
# EBS 단어  : 비였어요
# GoogleSTT : 이었어요 0.8333333333333334
#
# EBS 단어  : 그렇죠
# GoogleSTT : 우리가 0.3333333333333333
#
# ----------------------------------
# 그래서 만약에 이 길이를 오라고 해 보고 이 길이를 십이라고 해 보면두 삼각형의 닮음비는 오대십 일대이겠죠
# 만약에 이 길이를 오라고 해보고 길이를 십 이라고 안 보면 두 삼각형의 닮은 비는 오 대 십일 대 있겠죠
#
# EBS 단어  : 그래서
# GoogleSTT : 고해보 0.5555555555555556
#
# EBS 단어  : 만약에
# GoogleSTT : 만약에 1.0
#
# EBS 단어  : 이
# GoogleSTT : 이 1.0
#
# EBS 단어  : 길이를
# GoogleSTT : 길이를 1.0
#
# EBS 단어  : 오라고
# GoogleSTT : 오라고 1.0
#
# EBS 단어  : 해
# GoogleSTT : 해 1.0
#
# EBS 단어  : 보고
# GoogleSTT : 보고 1.0
#
# EBS 단어  : 이
# GoogleSTT : 이 1.0
#
# EBS 단어  : 길이를
# GoogleSTT : 길이를 1.0
#
# EBS 단어  : 십이라고
# GoogleSTT : 십이라고 1.0
#
# EBS 단어  : 해
# GoogleSTT : 해 1.0
#
# EBS 단어  : 보면두
# GoogleSTT : 보면두 1.0
#
# EBS 단어  : 삼각형의
# GoogleSTT : 삼각형의 1.0
#
# EBS 단어  : 닮음비는
# GoogleSTT : 닮은비는 0.9166666666666666
#
# EBS 단어  : 오대십
# GoogleSTT : 오대십 1.0
#
# EBS 단어  : 일대이겠죠
# GoogleSTT : 일대있겠죠 0.9333333333333333
#
# ----------------------------------
# 그렇다면 우리가 이 길이를 사라고 놔 보면 이 길이는 얼마가 됩니까 당연히
# 그렇다면 우리가 이 길이를 살아가다 보면 일이 얼마나 됩니까 당연히
#
# EBS 단어  : 그렇다면
# GoogleSTT : 그렇다면 1.0
#
# EBS 단어  : 우리가
# GoogleSTT : 우리가 1.0
#
# EBS 단어  : 이
# GoogleSTT : 이 1.0
#
# EBS 단어  : 길이를
# GoogleSTT : 길이를 1.0
#
# EBS 단어  : 사라고
# GoogleSTT : 살아가 0.6666666666666666
#
# EBS 단어  : 놔
# GoogleSTT : 나 0.6666666666666666
#
# EBS 단어  : 보면
# GoogleSTT : 보면 1.0
#
# EBS 단어  : 이
# GoogleSTT : 이 1.0
#
# EBS 단어  : 길이는
# GoogleSTT : 길이를 0.7777777777777778
#
# EBS 단어  : 얼마가
# GoogleSTT : 얼마나 0.8888888888888888
#
# EBS 단어  : 됩니까
# GoogleSTT : 됩니까 1.0
#
# EBS 단어  : 당연히
# GoogleSTT : 당연히 1.0
#
# ----------------------------------
# 그렇죠 사의 두 배인 팔이 돼야 돼
# 그쳐 사회 두 배인 팔 일 자
#
# EBS 단어  : 그렇죠
# GoogleSTT : 그쳐사 0.4444444444444444
#
# EBS 단어  : 사의
# GoogleSTT : 사회 0.6666666666666666
#
# EBS 단어  : 두
# GoogleSTT : 두 1.0
#
# EBS 단어  : 배인
# GoogleSTT : 배인 1.0
#
# EBS 단어  : 팔이
# GoogleSTT : 팔일 0.8333333333333334
#
# EBS 단어  : 돼야
# GoogleSTT : 두배 0.5
#
# EBS 단어  : 돼
# GoogleSTT : 두 0.6666666666666666
#
# ----------------------------------
# 이 길이를 거꾸로 우리가 육이라고 해 보겠습니다
# 의 길이를 거꾸로 우리가 육 이라고 해보겠습니다
#
# EBS 단어  : 이
# GoogleSTT : 이 1.0
#
# EBS 단어  : 길이를
# GoogleSTT : 길이를 1.0
#
# EBS 단어  : 거꾸로
# GoogleSTT : 거꾸로 1.0
#
# EBS 단어  : 우리가
# GoogleSTT : 우리가 1.0
#
# EBS 단어  : 육이라고
# GoogleSTT : 육이라고 1.0
#
# EBS 단어  : 해
# GoogleSTT : 해 1.0
#
# EBS 단어  : 보겠습니다
# GoogleSTT : 보겠습니다 1.0
#
# ----------------------------------
# 그럼 거꾸로 이 작은 쪽은 얼마가 될까
# 그럼 거꾸로 이 작은 쪽은 얼마나 될까
#
# EBS 단어  : 그럼
# GoogleSTT : 그럼 1.0
#
# EBS 단어  : 거꾸로
# GoogleSTT : 거꾸로 1.0
#
# EBS 단어  : 이
# GoogleSTT : 이 1.0
#
# EBS 단어  : 작은
# GoogleSTT : 작은 1.0
#
# EBS 단어  : 쪽은
# GoogleSTT : 쪽은 1.0
#
# EBS 단어  : 얼마가
# GoogleSTT : 얼마나 0.8888888888888888
#
# EBS 단어  : 될까
# GoogleSTT : 될까 1.0
#
# ----------------------------------
# 일대이 이대일 얼마 삼이 돼야 된다는 걸 여러분들이 알 수 있죠
# 일 대 이 이 대 일 얼마 삶의 돼야 한다는 걸 여러분이 할 수 있죠
#
# EBS 단어  : 일대이
# GoogleSTT : 일대이 1.0
# EBS 단어  : 이대일
# GoogleSTT : 이대일 1.0
#
# EBS 단어  : 얼마
# GoogleSTT : 얼마 1.0
#
# EBS 단어  : 삼이
# GoogleSTT : 삶의 0.6666666666666666
#
# EBS 단어  : 돼야
# GoogleSTT : 돼야 1.0
#
# EBS 단어  : 된다는
# GoogleSTT : 한다는 0.7777777777777778
#
# EBS 단어  : 걸
# GoogleSTT : 걸 1.0
#
# EBS 단어  : 여러분들이
# GoogleSTT : 여러분이할 0.6
#
# EBS 단어  : 알
# GoogleSTT : 일 0.6666666666666666
#
# EBS 단어  : 수
# GoogleSTT : 수 1.0
#
# EBS 단어  : 있죠
# GoogleSTT : 있죠 1.0
#
# ----------------------------------
# 그래서 우리는 닮음비라는 건 작은 삼각형과 큰 삼각형의 대응하는 변의 길이의 비이니까 오대십 삼대육 사대팔 이것이 모두 다 일대이로 같고 그것을 닮음비라고 한다
# 그래서 우리는 닮은 이라는 건 작은 상납 형과 큰 삼각형 에 대응하는 별이 길이 보니까 오 대 십 선대 육 사 대 팔 이것이 모두 다 일 대 이 로 갖고 그것을 닮은 이라고 한다
#
# EBS 단어  : 그래서
# GoogleSTT : 그래서 1.0
#
# EBS 단어  : 우리는
# GoogleSTT : 우리는 1.0
#
# EBS 단어  : 닮음비라는
# GoogleSTT : 닮은이라는 0.8666666666666667
#
# EBS 단어  : 건
# GoogleSTT : 건 1.0
#
# EBS 단어  : 작은
# GoogleSTT : 작은 1.0
#
# EBS 단어  : 삼각형과
# GoogleSTT : 삼각형에 0.8333333333333334
#
# EBS 단어  : 큰
# GoogleSTT : 큰 1.0
#
# EBS 단어  : 삼각형의
# GoogleSTT : 삼각형에 0.9166666666666666
#
# EBS 단어  : 대응하는
# GoogleSTT : 대응하는 1.0
#
# EBS 단어  : 변의
# GoogleSTT : 별이 0.6666666666666666
#
# EBS 단어  : 길이의
# GoogleSTT : 길이보 0.7777777777777778
#
# EBS 단어  : 비이니까
# GoogleSTT : 이보니까 0.75
#
# EBS 단어  : 오대십
# GoogleSTT : 오대십 1.0
#
# EBS 단어  : 삼대육
# GoogleSTT : 선대육 0.7777777777777778
#
# EBS 단어  : 사대팔
# GoogleSTT : 사대팔 1.0
#
# EBS 단어  : 이것이
# GoogleSTT : 이것이 1.0
#
# EBS 단어  : 모두
# GoogleSTT : 모두 1.0
#
# EBS 단어  : 다
# GoogleSTT : 다 1.0
#
# EBS 단어  : 일대이로
# GoogleSTT : 일대이로 1.0
#
# EBS 단어  : 같고
# GoogleSTT : 갖고 0.8333333333333334
#
# EBS 단어  : 그것을
# GoogleSTT : 그것을 1.0
#
# EBS 단어  : 닮음비라고
# GoogleSTT : 닮은이라고 0.8666666666666667
#
# EBS 단어  : 한다
# GoogleSTT : 한다 1.0
#
# ----------------------------------
# 이렇게 공부를 했었는데 이것 말고도 이러한 것들도 성립할 거란 얘기예요
# 이렇게 공부했는데 이것 말고도 이러한 것들도 성립할 거라는
#
# EBS 단어  : 이렇게
# GoogleSTT : 이렇게 1.0
#
# EBS 단어  : 공부를
# GoogleSTT : 공부했 0.6666666666666666
#
# EBS 단어  : 했었는데
# GoogleSTT : 부했는데 0.5833333333333334
#
# EBS 단어  : 이것
# GoogleSTT : 이것 1.0
#
# EBS 단어  : 말고도
# GoogleSTT : 말고도 1.0
#
# EBS 단어  : 이러한
# GoogleSTT : 이러한 1.0
#
# EBS 단어  : 것들도
# GoogleSTT : 것들도 1.0
#
# EBS 단어  : 성립할
# GoogleSTT : 성립할 1.0
#
# EBS 단어  : 거란
# GoogleSTT : 거라 0.8333333333333334
#
# EBS 단어  : 얘기예요
# GoogleSTT : 말고도이 0.4166666666666667
#
# ----------------------------------
# 예를 들어 작은 삼각형에서 빗변 분의 높이 얼마입니까 오분의삼이죠
# 예를 들어 작은 삼각형 에서 이 변 분에 높이 얼마입니까 오 분의 삼
#
# EBS 단어  : 예를
# GoogleSTT : 예를 1.0
#
# EBS 단어  : 들어
# GoogleSTT : 들어 1.0
#
# EBS 단어  : 작은
# GoogleSTT : 작은 1.0
#
# EBS 단어  : 삼각형에서
# GoogleSTT : 삼각형에서 1.0
#
# EBS 단어  : 빗변
# GoogleSTT : 이변 0.6666666666666666
#
# EBS 단어  : 분의
# GoogleSTT : 분의 1.0
#
# EBS 단어  : 높이
# GoogleSTT : 높이 1.0
#
# EBS 단어  : 얼마입니까
# GoogleSTT : 얼마입니까 1.0
#
# EBS 단어  : 오분의삼이죠
# GoogleSTT : 변분에높이얼 0.4444444444444444
#
# ----------------------------------
# 큰 삼각형에서 빗변 분의 높이 얼마죠 십분의육이죠 이 둘 어때요
# 큰 삼각형 에서 이 본부를 높여야 하죠 십 분 의 유기적 이들 오 대
#
# EBS 단어  : 큰
# GoogleSTT : 큰 1.0
#
# EBS 단어  : 삼각형에서
# GoogleSTT : 삼각형에서 1.0
#
# EBS 단어  : 빗변
# GoogleSTT : 이본 0.5
#
# EBS 단어  : 분의
# GoogleSTT : 분의 1.0
#
# EBS 단어  : 높이
# GoogleSTT : 높여 0.8333333333333334
#
# EBS 단어  : 얼마죠
# GoogleSTT : 야하죠 0.6666666666666666
#
# EBS 단어  : 십분의육이죠
# GoogleSTT : 십분의유기적 0.7777777777777778
#
# EBS 단어  : 이
# GoogleSTT : 이 1.0
#
# EBS 단어  : 둘
# GoogleSTT : 들 0.6666666666666666
#
# EBS 단어  : 어때요
# GoogleSTT : 에서이 0.5555555555555556
#
# ----------------------------------
# 오분의삼으로 서로 같다는 거 확인할 수 있고
# 오 분의 삼 으로 서로 같다 라는 것을 알 수 있고
#
# EBS 단어  : 오분의삼으로
# GoogleSTT : 오분의삼으로 1.0
#
# EBS 단어  : 서로
# GoogleSTT : 서로 1.0
#
# EBS 단어  : 같다는
# GoogleSTT : 같다라 0.6666666666666666
#
# EBS 단어  : 거
# GoogleSTT : 서 0.6666666666666666
#
# EBS 단어  : 확인할
# GoogleSTT : 것을알 0.3333333333333333
#
# EBS 단어  : 수
# GoogleSTT : 수 1.0
#
# EBS 단어  : 있고
# GoogleSTT : 있고 1.0
#
# ----------------------------------
# 또 마찬가지로 작은 삼각형에서 예를 들어서 빗변 분의 밑변 해 봅시다 오분의사죠
# 또 마찬가지로 작은 삼각형 에서 예를 들어 빚 변 분의 이 편 해봅시다 오 분의 사적
#
# EBS 단어  : 또
# GoogleSTT : 또 1.0
#
# EBS 단어  : 마찬가지로
# GoogleSTT : 마찬가지로 1.0
#
# EBS 단어  : 작은
# GoogleSTT : 작은 1.0
#
# EBS 단어  : 삼각형에서
# GoogleSTT : 삼각형에서 1.0
#
# EBS 단어  : 예를
# GoogleSTT : 예를 1.0
#
# EBS 단어  : 들어서
# GoogleSTT : 들어빚 0.6666666666666666
#
# EBS 단어  : 빗변
# GoogleSTT : 빚변 0.8333333333333334
#
# EBS 단어  : 분의
# GoogleSTT : 분의 1.0
#
# EBS 단어  : 밑변
# GoogleSTT : 빚변 0.6666666666666666
#
# EBS 단어  : 해
# GoogleSTT : 해 1.0
#
# EBS 단어  : 봅시다
# GoogleSTT : 봅시다 1.0
#
# EBS 단어  : 오분의사죠
# GoogleSTT : 오분의사적 0.8666666666666667
#
# ----------------------------------
# 큰 삼각형에서 빗변 분의 밑변 해 보면 얼마죠십분의팔이죠 근데 이것도 서로 어때 같아요
# 큰 삼각형 에서 이 변 분에 및 편의 봄 얼마전 십 분의 팔 이적 근데 이것도 서로 때 같아요
#
# EBS 단어  : 큰
# GoogleSTT : 큰 1.0
#
# EBS 단어  : 삼각형에서
# GoogleSTT : 삼각형에서 1.0
#
# EBS 단어  : 빗변
# GoogleSTT : 이변 0.6666666666666666
#
# EBS 단어  : 분의
# GoogleSTT : 분의 1.0
#
# EBS 단어  : 밑변
# GoogleSTT : 이변 0.6666666666666666
#
# EBS 단어  : 해
# GoogleSTT : 때 0.6666666666666666
#
# EBS 단어  : 보면
# GoogleSTT : 이변 0.5
#
# EBS 단어  : 얼마죠십분의팔이죠
# GoogleSTT : 얼마전십분의팔이적 0.8518518518518519
#
# EBS 단어  : 근데
# GoogleSTT : 근데 1.0
#
# EBS 단어  : 이것도
# GoogleSTT : 이것도 1.0
#
# EBS 단어  : 서로
# GoogleSTT : 서로 1.0
#
# EBS 단어  : 어때
# GoogleSTT : 로때 0.6666666666666666
#
# EBS 단어  : 같아요
# GoogleSTT : 같아요 1.0
#
# ----------------------------------
# 마찬가지로 하나 더 해 볼까요 작은 삼각형에서 밑변 분의 높이는 사분의삼이죠
# 마찬가지로 하나 더 있을까요 작은 삼각형 에서 이 편 불이 높이는 사 분의 삼
#
# EBS 단어  : 마찬가지로
# GoogleSTT : 마찬가지로 1.0
#
# EBS 단어  : 하나
# GoogleSTT : 하나 1.0
#
# EBS 단어  : 더
# GoogleSTT : 더 1.0
#
# EBS 단어  : 해
# GoogleSTT : 하 0.6666666666666666
#
# EBS 단어  : 볼까요
# GoogleSTT : 을까요 0.7777777777777778
#
# EBS 단어  : 작은
# GoogleSTT : 작은 1.0
#
# EBS 단어  : 삼각형에서
# GoogleSTT : 삼각형에서 1.0
#
# EBS 단어  : 밑변
# GoogleSTT : 이편 0.5
#
# EBS 단어  : 분의
# GoogleSTT : 분의 1.0
#
# EBS 단어  : 높이는
# GoogleSTT : 높이는 1.0
#
# EBS 단어  : 사분의삼이죠
# GoogleSTT : 각형에서이편 0.3888888888888889
#
# ----------------------------------
# 큰 삼각형에서 밑변 분의 높이는 어때요 팔분의육인데 이들이 모두 다 어때 같다는 걸 여러분들이 알 수 있단 얘기예요
# 큰 삼각형 에서 및 변 불이 높이는 팔 분의 육 인데 이들이 모두 같다는 걸 여러분들이 할 수 있다는데요
#
# EBS 단어  : 큰
# GoogleSTT : 큰 1.0
#
# EBS 단어  : 삼각형에서
# GoogleSTT : 삼각형에서 1.0
#
# EBS 단어  : 밑변
# GoogleSTT : 및변 0.8333333333333334
#
# EBS 단어  : 분의
# GoogleSTT : 분의 1.0
#
# EBS 단어  : 높이는
# GoogleSTT : 높이는 1.0
#
# EBS 단어  : 어때요
# GoogleSTT : 이높이 0.4444444444444444
#
# EBS 단어  : 팔분의육인데
# GoogleSTT : 팔분의육인데 1.0
#
# EBS 단어  : 이들이
# GoogleSTT : 이들이 1.0
#
# EBS 단어  : 모두
# GoogleSTT : 모두 1.0
#
# EBS 단어  : 다
# GoogleSTT : 다 1.0
#
# EBS 단어  : 어때
# GoogleSTT : 에서 0.5
#
# EBS 단어  : 같다는
# GoogleSTT : 같다는 1.0
#
# EBS 단어  : 걸
# GoogleSTT : 걸 1.0
#
# EBS 단어  : 여러분들이
# GoogleSTT : 여러분들이 1.0
#
# EBS 단어  : 알
# GoogleSTT : 팔 0.6666666666666666
#
# EBS 단어  : 수
# GoogleSTT : 수 1.0
#
# EBS 단어  : 있단
# GoogleSTT : 있다 0.8333333333333334
#
# EBS 단어  : 얘기예요
# GoogleSTT : 육인데이 0.4166666666666667
#
# ----------------------------------

# %%
import numpy as np

# %%
m = np.array(maxprob_list)

# %%
m = pd.Series(m)
m
# Out:
# 0      1.000000
# 1      0.750000
# 2      0.500000
# 3      1.000000
# 4      1.000000
#          ...
# 465    1.000000
# 466    0.666667
# 467    1.000000
# 468    0.833333
# 469    0.416667
# Length: 470, dtype: float64

# %%
data = pd.DataFrame(m.value_counts())

# %%
data.reset_index(level=0, inplace=True)

# %%
data
# Out:
#        index    0
# 0   1.000000  323
# 1   0.666667   45
# 2   0.833333   14
# 3   0.777778   13
# 4   0.500000   11
# 5   0.888889   10
# 6   0.444444    6
# 7   0.933333    6
# 8   0.866667    5
# 9   0.583333    4
# 10  0.333333    4
# 11  0.800000    4
# 12  0.555556    4
# 13  0.750000    3
# 14  0.416667    2
# 15  0.916667    2
# 16  0.388889    1
# 17  0.703704    1
# 18  0.944444    1
# 19  0.222222    1
# 20  0.518519    1
# 21  0.814815    1
# 22  0.925926    1
# 23  0.611111    1
# 24  0.904762    1
# 25  0.857143    1
# 26  0.851852    1
# 27  0.714286    1
# 28  0.952381    1
# 29  0.600000    1

# %%
data.sort_values(by='index')
# Out:
#        index    0
# 19  0.222222    1
# 10  0.333333    4
# 16  0.388889    1
# 14  0.416667    2
# 6   0.444444    6
# 4   0.500000   11
# 20  0.518519    1
# 12  0.555556    4
# 9   0.583333    4
# 29  0.600000    1
# 23  0.611111    1
# 1   0.666667   45
# 17  0.703704    1
# 27  0.714286    1
# 13  0.750000    3
# 3   0.777778   13
# 11  0.800000    4
# 21  0.814815    1
# 2   0.833333   14
# 26  0.851852    1
# 25  0.857143    1
# 8   0.866667    5
# 5   0.888889   10
# 24  0.904762    1
# 15  0.916667    2
# 22  0.925926    1
# 7   0.933333    6
# 18  0.944444    1
# 28  0.952381    1
# 0   1.000000  323

# %%
s1 = '오분의삼이죠'
s2 = '오분의삼'

# %%
s1 = '공부를 했었는데'
s2 = '공부했는데'
