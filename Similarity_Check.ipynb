# %%
import json

# %%
def getText_json(file):
    with open(file, encoding='UTF-8-sig') as f:
        data = json.load(f)
    for _ in data['results']['transcripts']:
         para = "".join(_['transcript'])
    return para

# %%
compare = getText_json('asrOutput(1).json')
compare
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-9b694e1c7acf> in <module>
# ----> 1 compare = getText_json('asrOutput(1).json')
#       2 compare
#
# <ipython-input-2-c27b84e4fea7> in getText_json(file)
#       1 def getText_json(file):
# ----> 2     with open(file, encoding='UTF-8-sig') as f:
#       3         data = json.load(f)
#       4     for _ in data['results']['transcripts']:
#       5          para = "".join(_['transcript'])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'asrOutput(1).json'

# %%
import re

# %%
def getText_smi( File ):
    text = []
    file = open(File, "r" , encoding = "euc_kr")
    wholefile = file.readlines()
    for line in wholefile:
        line = line.strip()
        if re.search(r"#",line) or line.endswith(":>"):
            continue
        elif line.startswith('<') or line.endswith("; }"):
            continue
        elif line.startswith('—') or line.endswith(";"):
            continue
        text.append(line)   #re 쓰는법 알려주세요
    return ''.join(text)

# %%
origin=getText_smi('mo2_3.smi')
origin
# Out:
# "-->여러분 안녕하십니까? FINAL 실전모의고사 수학 가형의 남치열입니다. 3강입니다. 3강은 드디어 21번 여러분이 기다리고 있는 킬러 문제 준비되어 있습니다.이번 시간도 우리 디테일하게 정말 어려운 문제를 과연 어떻게 내가 해결할 수 있을까? 문항 분석이란 이런 것이다. 이런 생각을 해보면서 함께 열심히 공부해보기로 하겠습니다. 20번부터 가겠습니다.20번은 사실 이 문항 번호에 비해서 상당히 어렵지 않은 문제였습니다. 반전이지요? 쉬운 문제예요, 쉬운 문제. 오히려 다른 것이 어려웠지 20번이 제가 봤을 때는 앞에 있는 18번이나 이런 것으로 바뀌어야 하지 않았을까.그런 생각이 들 정도로 어려운 문제는 아닙니다. 정의역이 나와 있고요. 삼각함수 나와 있지요? 0부터 π까지, 0이상 π미만은 5sinx래요. π이상 2π미만일 때 이것을 읽어내야 돼요.이것이 무슨 말일까? 5sinx 먼저 우리가 그래프를 그려서 생각해봅시다. 왜냐하면 그래프 이야기가 나오니까 여기 옆에다가 y축이 있고요. x축이 있습니다.0 이상 π미만일 때는 5sinx입니다, 이렇게. 여기 이상, 미만. 여기가 5, 여기가 π. 그런데 문제는 π부터 2π 갈 때는 5분의 3배하고 (x-π) 이것을 x축 방향으로 π만큼 평행이동하고 5에다가 5분의 3배를 하면 3배가 되겠지?그러니까 sinx의 최댓값이 1이었는데 이것을 5배로 늘렸어. 그것을 다시 5분의 3배 하니까 무엇이 되는 거야? 3이 되는 것이지요, 이렇게. 여기 2π는 빠져야 하겠지요. 여기가 무엇이 됩니까? 3이 된다.이것만 바로 그려낼 수 있으면 이 문제는 정말 아무것도 아니야. 그리고 그것을 모른다고 해도 하나씩 넣어보면 돼. 하나씩 대입해 볼게, 봐봐. 여기 π 등호 있잖아요? π 집어넣어보세요, 여기다 π.f(π)는 f(0)에다 5분의 3. f(0)은 0이야. 0에다 5분의 3 곱했는데 0이라고. 여기 이렇게 딱 붙어있을 것이라고, 칠해질 것이라고. 그리고 π에서 점점 커져. 그러면 한 2분의 3π 정도 생각해볼까? 이 자리에 2분의 3π 넣어봐.2분의 3π 넣어보세요, 여러분. 2분의 3π에서 π을 빼면 2분의 π야. 5sin 2분의 π에다가 5분의 3을 곱하라는 거예요. 5에다가 5분의 3을 곱하면 3이 나오지, 여기가 2분의 3π라는 이야기야.그런 식으로 여러분 쭉 해보면 이것이 이렇게 그려질 수밖에 없겠구나. 이것을 그리는 순간 99%를 푼 것이라고. 이것하고 y=k가 서로 다른 세 점 P, Q, R에서 만난다. 여기는 뚫려 있고 칠해져 있고 칠해져 있어.y=k가 이렇게 생겼어. 교점이 세 개가 되려면, 이렇게 그려지면 하나, 둘, 셋, 네 개. 이때는 두 개, 세 개가 되는 순간은 이것밖에 안 되는구나. 여기 하나, 여기 하나, 여기 하나. 여기가 α라고 그랬고요.크기 순서대로 여기가 β라고 했고 여기가 구했지요, 이미? 2분의 3π는 γ가 된다. 그리고 y=k라고 했으니까 k는 무엇이 됩니까? 3이 된다. 끝났습니다. 그러면 sinα+γ를 구하래요.sinα+2분의 3π를 구하라는 이야기고 각변환, 얼싸안코 무엇이 됩니까? -cosα가 돼요, 이것은. sinα가.5sinα가 조심해야 하겠네, 여러분. 5sinα가 3이었어요. sina가 5분의 3입니다. 물론 sin, cos 관계식으로 구할 수 있지만 α는 어차피 무엇이에요? 예각입니다, 이 상황에서는.그러면 우리 그려놓고 중학교 때 했던 것 5, 3 하면 여기가 3이지요? 여기가 4네요. cos는 5분의 4가 되는데 앞에 마이너스 있네? 관계식 이용하지 않고 이렇게 빠르게 구해도 되고요. 그다음 이야기 이제 cos(β+γ)입니다.(β+2분의 3π)입니다. 각변환, 이것은 sinβ가 되겠지요. 5sinβ가 3이니까 sinβ는 역시 5분의 3이 된다더라. 따라서 k+-5분의 4가 되겠지요? 주어진 식에 대입해보면.+5분의 3이 돼서 5분의 15에서 5분의 1을 뺀 정답은 5분의 14가 된다는 것을 알 수 있습니다. 20번 치고 상당히 간결하지요? 계산이 상당히 쉬워요. 우리가 알아야 하는 개념은 삼각함수 각변환 할 수 있겠니?이런 것은 사실 기본 계산 과정인 것이고 (가)와 (나)라는 조건을 이용해서 그렇게 그래프를 그려낼 수 있겠니?가 가장 중요한 포인트였습니다. (나)와 같이 나왔을 때 함수 평행이동 가지고.저런 조건을 주고 그래프를 그리는 문제는 기존에 있던 기출문제에 상당히 많아요. 혹시라도 이 문제를 보고 그래프가 바로 안 나왔다고 하는 친구들은 기출문제를 조금 더 분석해야 할 것이다. 좋습니다.이제 객관식 마지막 문제, 최고 난이도 21번 문제가 나왔습니다. 21번 문제에서 우리가 얻을 수 있는 교훈들은 상당히 많고요. 생각보다 할만 합니다. 여러 가지 개념이 담겨져 있어요.미분가능성 이야기 나와 있고 접선의 방정식 이야기 나와 있지요? 원래 제가 앞에 1강에서 문항 출제 분석 이런 것 해줬잖아? 21번을 제가 미분법 단원에다가 넣었잖아요? 미적분의 미분법.그런데 원래 이것은 적분법이지요, 어떻게 보면? 왜냐하면 여기 적분 나왔으니까. 미분법 하고 도함수의 활용이랑 적분법 같이 나온 것인데 사실 미분에 대한 아이디어가.도함수의 활용의 아이디어가 너무 중요하기 때문에 거기다가 분배를 해놨다. 참고하시고요. 문제 풀이 바로 가겠습니다. 상수 a, b에 대하여 함수가 구간에 의해 나누어져 있어요.실수 전체 집합에서 미분 가능하다까지만 끊어 읽겠습니다. 뒤엣것 조금 이따 읽을게요. 그러면 일단 미분 가능하다고 했으니까 실수 전체 집합에서 연속이 돼야 하고.x=0에서 범위가 나누어져 있는데 이것도 연속, 이것도 연속이야. 즉 이것은 x=0에서 연속이어야 합니다. 다시 이야기해서 우극한과 좌극한 그리고 함숫값이 같아야 합니다. 실제로 이렇게 쓰지는 않을 거예요. 왜?이것이 눈에 보이거든. 여기다 0 대입해, b가 되지요? 좌극한은 b가 되고요. 함숫값도 b가 될 것이고 우극한 여기도 0, 극한이니까 어떻게 돼? x가 0을 향해 가면 0이고 그렇지요?1이니까 함수의 극한에 대한 성질 0이 되겠지요. b는 무엇이 된다? 0이 된다. b가 0이 됐어요, 이렇게 0. 끝났어. 이제 a를 구해야 하는데 미분가능하다고 하면 이것은 x=0을 기준으로 나누어져있기 때문에.이것도 미분가능한 함수, 이것도 미분가능한 함수야. 그러면 원래는 x=0에서의 미분계수가 존재한다. 미분계수의 정의대로 극한으로 푸는 것이 정석적인 방법이지만 실제로 해서 그렇게 푸는 사람이 과연 있을까 싶습니다.실제로 그렇게 아무도 안 풀지. 이렇게 풀어야 해? 이 자체가 2차 함수입니다. 미분 가능하고 미분한 함수 또한 1차함수잖아요? 미분 함수 또한 연속인 함수입니다. 그래서 도함수의 극한으로 계산하는 거예요, 그냥.실전에서는 도함수가 연속이기 때문에 즉 무슨 말이냐면 이 친구를 이 구간에 나누어서 각각 미분을 해봐. 이것 미분하면 2x+a고요. 이 친구 미분하면 앞엣것 미분, 뒤엣것 그대로 +앞엣것 그대로 뒤엣것 미분.여기 마이너스가 되지요? 2로 묶어내면 (1-x)의 무리의 e의 -x제곱이야. 1차함수? 1차함수하고 지수함수의 곱으로 나타낸 함수. 각각이 연속이야. 무슨 말이지?각각 이 범위에서 미분이 가능하지만 x=0에서도 미분이 가능하게 만들려면 도함수의 극한으로 그냥 계산하자는 것이지. 여기다 0 집어넣고 여기다 0, x 자리에 0 집어넣어도 성립해. 한 번에 계산이 된다.수능에 나온 함수는 대부분 이런 함수들이니까 좋아요. 등호가 여기 들어가든 여기 들어가든 사실 문제가 되진 않는 거예요, 이것은 미분 가능하게 만들었으니까. a가 2입니다, a가 2까지는 다 구했어요. 무슨 말이야?f 다 구했어. f 끝났어, 이제. 여기까지 했어요? 점 P와 곡선 y=f(x) 위의 점 (t, f(t)) t는 -2 이상이다. PQ의 기울기를 g(t)라 하자. 옳은 것은 찾아라. ㄱ. a 구했고 b 구했어. f(-a)는 즉 f(-2)는 -2 어디?음수니까 마이너스, 4-2×2=4, 0. 0 b 맞는데? 따라서 ㄱ은 참 가볍게 해결되고요. ㄴ. g(t)를 -2부터 정적분하게 되면 계산 결과가 이래. 물론 실전에서 저는 이것을 그려놓고 시작할 수 있겠지만.그것은 이제 ㄷ에서 필요하 ...

# %%
sentence = (compare,origin)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# 객체 생성
tfidf_vectorizer = TfidfVectorizer()

# 문장 벡터화 진행
tfidf_matrix = tfidf_vectorizer.fit_transform(sentence)

# 각 단어
text = tfidf_vectorizer.get_feature_names()

# 각 단어의 벡터 값
idf = tfidf_vectorizer.idf_

# %%
print(dict(zip(text,idf)))
# Out:
# {'0까지': 1.4054651081081644, '0까지입니다': 1.4054651081081644, '0까지지요': 1.4054651081081644, '0보다': 1.4054651081081644, '0부터': 1.4054651081081644, '0에다': 1.4054651081081644, '0에서': 1.4054651081081644, '0에서도': 1.4054651081081644, '0에서의': 1.4054651081081644, '0으로': 1.4054651081081644, '0을': 1.4054651081081644, '0이': 1.4054651081081644, '0이고': 1.4054651081081644, '0이고요': 1.4054651081081644, '0이니까': 1.4054651081081644, '0이라고': 1.4054651081081644, '0이상': 1.4054651081081644, '0이상으로': 1.4054651081081644, '0이야': 1.4054651081081644, '0이하일': 1.4054651081081644, '0입니다': 1.4054651081081644, '10': 1.4054651081081644, '100': 1.4054651081081644, '1000': 1.4054651081081644, '10t에': 1.4054651081081644, '12개를': 1.4054651081081644, '12보다': 1.4054651081081644, '13': 1.4054651081081644, '14': 1.4054651081081644, '149라는': 1.4054651081081644, '14가': 1.4054651081081644, '15': 1.4054651081081644, '15에서': 1.4054651081081644, '16': 1.4054651081081644, '161': 1.4054651081081644, '161개에서': 1.4054651081081644, '162보다': 1.4054651081081644, '16ln2가': 1.4054651081081644, '16이야': 1.4054651081081644, '16이에요': 1.4054651081081644, '16입니다': 1.4054651081081644, '18번이나': 1.4054651081081644, '1t²': 1.4054651081081644, '1강에서': 1.4054651081081644, '1만': 1.4054651081081644, '1번': 1.4054651081081644, '1보다': 1.4054651081081644, '1분의': 1.4054651081081644, '1사분면': 1.4054651081081644, '1사분면에서': 1.4054651081081644, '1사분면이': 1.4054651081081644, '1사분면하다가': 1.4054651081081644, '1에서': 1.4054651081081644, '1을': 1.4054651081081644, '1의': 1.4054651081081644, '1이': 1.4054651081081644, '1이니까': 1.4054651081081644, '1이다': 1.4054651081081644, '1이라고요': 1.4054651081081644, '1이야': 1.4054651081081644, '1이었는데': 1.4054651081081644